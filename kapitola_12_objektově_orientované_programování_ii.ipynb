# %% [markdown]
# # 📚 Kapitola 12: Objektově orientované programování II
#
# <div style="background: linear-gradient(90deg, #667eea 0%, #764ba2 100%); padding: 20px; border-radius: 10px; margin: 20px 0;">
#     <h2 style="color: white; margin: 0;">Blok 2 | INTERMEDIATE</h2>
#     <p style="color: white; margin: 10px 0;">📖 Výuková kapitola</p>
# </div>
#
# ## 🎯 Co se naučíte
#
# V této kapitole se zaměříme na následující témata:
#
# - **Dědičnost (inheritance)**
# - **Method overriding**
# - **Super() function**
# - **Multiple inheritance a MRO**
# - **Abstract base classes (ABC)**
# - **Composition vs. inheritance**
# - **SOLID principy v Pythonu**
#
# ## ⚠️ Předpoklady
# Tato kapitola navazuje na kapitoly: 11
#
# ---

# %%
# ⚙️ Inicializace prostředí
# Tento kód nastavuje prostředí pro kapitolu 12

import sys
import os
from datetime import datetime

# Informace o prostředí
print("=" * 60)
print(f"📚 KAPITOLA 12: Objektově orientované programování II")
print("=" * 60)
print(f"🐍 Python verze: {sys.version}")
print(f"📅 Datum spuštění: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
print(f"💻 OS: {os.name}")
print(f"📁 Pracovní adresář: {os.getcwd()}")
print("=" * 60)

# Instalace potřebných knihoven (odkomentujte podle potřeby)
# !pip install requests pandas numpy matplotlib
# !pip install beautifulsoup4 sqlalchemy fastapi

# Import základních knihoven
import json
import csv
import time
import random
from pathlib import Path
from typing import List, Dict, Optional, Any

print("✅ Prostředí připraveno!")

# %% [markdown]
# ## 📖 Teoretická část
#
# <div style="background: #f0f4ff; padding: 20px; border-left: 5px solid #4a69bd; margin: 20px 0; border-radius: 5px;">
#     <h3 style="color: #2c3e50; margin-top: 0;">🎓 Základní teorie a koncepty</h3>
# </div>
#
# # Objektově orientované programování II
#
# ## 1. Úvod a motivace
#
# V tomto kurzu se podrobněji zaměříme na pokročilé koncepty objektově orientovaného programování (OOP), které jsou klíčem k psaní čistého, rozšiřitelného a udržitelného kódu. V praxi se OOP používá v mnoha oblastech – od vývoje webových aplikací až po softwarové nástroje pro velká data, robotiku i herní engine. Při práci s Pythonem je OOP nezbytný pro tvorbu modulárních programů, které je možné snadno rozšiřovat a udržovat.
#
# Student se naučí vytvářet složitější hierarchie tříd, přepisovat metody, používat abstraktní třídy a aplikovat SOLID principy. Tyto znalosti jsou klíčem k profesionálnímu vývoji softwaru a umožní vám psát kód, který je nejen funkční, ale i čitelný a přehledný.
#
# ---
#
# ## 2. Hlavní koncepty
#
# ### Dědičnost (Inheritance)
#
# Dědičnost je základní koncept OOP, který umožňuje vytvářet nové třídy na základě již existujících. Třída, která dědí (dceřiná třída), získává všechny atributy a metody rodičovské třídy. V Pythonu se dědičnost implementuje jednoduše:
#
# ```python
# class Rodic:
#     def __init__(self, jmeno):
#         self.jmeno = jmeno
#
#     def pozdrav(self):
#         return f"Ahoj, já jsem {self.jmeno}"
#
# class Potomek(Rodic):
#     def __init__(self, jmeno, vek):
#         super().__init__(jmeno)
#         self.vek = vek
#
#     def pozdrav(self):
#         return f"Čau, já jsem {self.jmeno}, mám {self.vek} let"
# ```
#
# V tomto případě třída `Potomek` dědí od `Rodic`, a může přidávat nové vlastnosti nebo přepisovat metody.
#
# ---
#
# ### Method overriding
#
# Přepisování metod (method overriding) je proces, kdy potomkovská třída poskytuje vlastní implementaci metody, která byla definovaná v rodičovské třídě. Výše uvedený příklad ukazuje, jak `potomek.pozdrav()` přepisuje `rodic.pozdrav()`. Tato funkce je zásadní pro flexibilitu a rozšiřitelnost kódu.
#
# ---
#
# ### Super() function
#
# Funkce `super()` umožňuje přístup k metodám rodičovské třídy. Je nezbytná, pokud chceme rozšířit chování rodičovské metody bez jejího úplného přepsání.
#
# ```python
# class Rodic:
#     def __init__(self, jmeno):
#         self.jmeno = jmeno
#
#     def pozdrav(self):
#         return f"Ahoj, já jsem {self.jmeno}"
#
# class Potomek(Rodic):
#     def __init__(self, jmeno, vek):
#         super().__init__(jmeno)  # Volá rodičovský __init__
#         self.vek = vek
#
#     def pozdrav(self):
#         return f"{super().pozdrav()} a mám {self.vek} let"
# ```
#
# ---
#
# ### Multiple inheritance a MRO
#
# Python podporuje více dědičnost (multiple inheritance), tedy třída může dědit z více rodičovských tříd.
#
# ```python
# class A:
#     def metoda(self):
#         print("Metoda z A")
#
# class B:
#     def metoda(self):
#         print("Metoda z B")
#
# class C(A, B):
#     pass
#
# c = C()
# c.metoda()  # Vytiskne "Metoda z A", protože se používá MRO (Method Resolution Order)
# ```
#
# MRO určuje pořadí, ve kterém jsou metody hledány. Python používá algoritmus C3 linearizace.
#
# ---
#
# ### Abstract base classes (ABC)
#
# Abstraktní třídy umožňují definovat rozhraní pro třídy, které musí být implementovány. Použití `abc.ABC` a `@abstractmethod` zaručuje, že potomkovská třída musí implementovat určité metody.
#
# ```python
# from abc import ABC, abstractmethod
#
# class Zvire(ABC):
#     @abstractmethod
#     def zvuk(self):
#         pass
#
# class Pes(Zvire):
#     def zvuk(self):
#         return "Haf!"
#
# class Kocka(Zvire):
#     def zvuk(self):
#         return "Mňau!"
# ```
#
# Tento přístup zajistí, že třídy `Pes` a `Kocka` budou mít implementovanou metodu `zvuk()`.
#
# ---
#
# ### Composition vs. inheritance
#
# Dědičnost je vhodná, když je „je“ vztah mezi třídami (např. Pes je Zvíře). Kompozice se používá, pokud je „má“ vztah (např. Auto má Motor).
#
# ```python
# class Motor:
#     def start(self):
#         return "Motor spuštěn"
#
# class Auto:
#     def __init__(self):
#         self.motor = Motor()  # Kompozice
#
#     def zapni(self):
#         return self.motor.start()
# ```
#
# Dědičnost může vést k komplikovaným hierarchiím, zatímco kompozice je flexibilnější a snadněji testovatelná.
#
# ---
#
# ### SOLID principy v Pythonu
#
# SOLID jsou pět základních pravidel pro objektově orientovaný návrh:
#
# 1. **Single Responsibility Principle (SRP)** – Každá třída by měla mít jen jednu odpovědnost.
# 2. **Open/Closed Principle (OCP)** – Třídy by měly být otevřené pro rozšíření a uzavřené pro modifikaci.
# 3. **Liskov Substitution Principle (LSP)** – Potomkovské třídy by měly být nahraditelné rodičovskými třídami.
# 4. **Interface Segregation Principle (ISP)** – Mnoho specifických rozhraní je lepší než jedno obecné.
# 5. **Dependency Inversion Principle (DIP)** – Závislosti by měly být na abstrakcích, nikoli konkrétních implementacích.
#
# Použití těchto principů v Pythonu zlepšuje kvalitu a čistotu kódu. Například vytváření rozhraní pomocí `ABC` podporuje ISP a DIP.
#
# ---
#
# ## 3. Důležité detaily
#
# ### Časté chyby a jak se jim vyhnout
#
# - **Zapomínání použít `super()` při dědičnosti** – může vést k nedefinovaným chybám.
# - **Přílišná dědičnost** – způsobuje komplexní a těžko udržovatelný kód.
# - **Nesprávné použití abstraktních tříd** – mohou vést k nedostatečnému testování.
#
# ### Best practices
#
# - Používejte kompozici před dědičností, pokud je to možné.
# - Dědičnost by měla být používána jen v případě logického „je“ vztahu.
# - Využívejte `abc` pro definici rozhraní a zajištění konzistence.
#
# ### Performance tipy
#
# - Při kompozici se vyhýbejte přílišnému množství objektů, které vytváříte.
# - Používejte `__slots__` pro třídy s pevným počtem atributů – zvyšuje výkon a snižuje spotřebu paměti.
#
# ---
#
# ## 4. Propojení s předchozími kapitolami
#
# Tato kapitola navazuje na základní koncepty OOP, jako jsou třídy, objekty, metody a atributy. V tomto kurzu budeme pokračovat ve vývoji těchto znalostí a ukážeme si, jak tyto základy využít pro tvorbu složitějších a efektivnějších systémů. Rozšíření o dědičnost, abstrakci a SOLID principy je klíčové pro práci s většími a profesionálnějšími aplikacemi.
#
# ---
#
# Tímto způsobem jsme vytvořili detailní výklad o pokročilých konceptech OOP, který může být použit jako výukový materiál pro studenty na střední nebo vysoké škole.

# %% [markdown]
# ## 💻 Praktické příklady
#
# <div style="background: #e8f5e9; padding: 20px; border-left: 5px solid #4caf50; margin: 20px 0; border-radius: 5px;">
#     <h3 style="color: #2c3e50; margin-top: 0;">👨‍💻 Hands-on příklady ke spuštění</h3>
#     <p>Následující příklady si můžete hned vyzkoušet. Každý příklad je samostatně spustitelný.</p>
# </div>

# %% [markdown]
# ### Příklad 1
#
# ### Co příklad demonstruje:
# Tento příklad ukazuje základní koncept dědičnosti, kdy třída `Potomek` zdědí vlastnosti a metody třídy `Rodic`.

# %%
# Název: Jednoduchá dědičnost
# Co příklad demonstruje: Základní dědičnost mezi třídami

class Rodic:
    def __init__(self, jmeno):
        self.jmeno = jmeno
    
    def pozdrav(self):
        return f"Ahoj, já jsem {self.jmeno}"

class Potomek(Rodic):  # Potomek dědí od Rodice
    def __init__(self, jmeno, vek):
        super().__init__(jmeno)  # Volání konstruktoru rodiče
        self.vek = vek
    
    def pozdrav(self):  # Přepisování metody (method overriding)
        return f"Čau, já jsem {self.jmeno}, mám {self.vek} let"

# Vytvoření objektů
otec = Rodic("Petr")
dcera = Potomek("Marie", 10)

print(otec.pozdrav())
print(dcera.pozdrav())

# %% [markdown]
# ### Příklad 2
#
# ### Očekávaný výstup:
# ```
# Ahoj, já jsem Petr
# Čau, já jsem Marie, mám 10 let
# ```

# %% [markdown]
# ### Příklad 3
#
# ### Vysvětlení:
# - `Potomek` dědí od `Rodic`, takže získává atribut `jmeno` a metodu `pozdrav`
# - Použití `super().__init__()` zajišťuje správné inicializování rodičovské třídy
# - Metoda `pozdrav` v `Potomek` přepisuje metodu z rodiče (method overriding)
#
# ---
#
# ## 2. Method Overriding a Super() function

# %% [markdown]
# ### Příklad 4
#
# ### Co příklad demonstruje:
# Tento příklad ukazuje, jak přepsat metody a použít super() pro přístup k rodičovským metodám.

# %%
# Název: Přepisování metod a použití super()
# Co příklad demonstruje: Method overriding a volání super()

class Zvire:
    def __init__(self, jmeno):
        self.jmeno = jmeno
    
    def zvuk(self):
        return f"{self.jmeno} dělá nějaký zvuk"
    
    def pohyb(self):
        return f"{self.jmeno} se pohybuje"

class Pes(Zvire):
    def __init__(self, jmeno, rasa):
        super().__init__(jmeno)  # Volání rodičovského konstruktoru
        self.rasa = rasa
    
    def zvuk(self):  # Přepisuje metodu z rodiče
        return f"{self.jmeno} mňau!"
    
    def pohyb(self):  # Přepisuje metodu a volá rodičovskou verzi
        rodicova_metoda = super().pohyb()  # Získání rodičovského výsledku
        return f"{rodicova_metoda} a štěká"

# Vytvoření objektů
pes = Pes("Fíka", "labrador")
kočka = Zvire("Mourek")

print(pes.zvuk())
print(pes.pohyb())
print(kočka.zvuk())

# %% [markdown]
# ### Příklad 5
#
# ### Očekávaný výstup:
# ```
# Fíka mňau!
# Fíka se pohybuje a štěká
# Mourek dělá nějaký zvuk
# ```

# %% [markdown]
# ### Příklad 6
#
# ### Vysvětlení:
# - `Pes` přepisuje metody `zvuk()` a `pohyb()`
# - Ve `výběru pohyb()` se používá `super().pohyb()` k získání rodičovského chování
# - Díky tomu můžeme rozšířit chování bez ztráty původní funkcionality
#
# ---
#
# ## 3. Multiple inheritance a MRO (Method Resolution Order)

# %% [markdown]
# ### Příklad 7
#
# ### Co příklad demonstruje:
# Tento příklad ukazuje, jak funguje dědičnost s více rodiči a jak Python řeší pořadí metod.

# %%
# Název: Více následníků (Multiple inheritance)
# Co příklad demonstruje: Více následníků a MRO (Method Resolution Order)

class Zviratko:
    def __init__(self, jmeno):
        self.jmeno = jmeno
    
    def pohyb(self):
        return f"{self.jmeno} se pohybuje"
    
    def zvuk(self):
        return f"{self.jmeno} dělá nějaký zvuk"

class Lety:
    def __init__(self, jmeno):
        self.jmeno = jmeno
    
    def pohyb(self):  # Přepisuje metodu
        return f"{self.jmeno} létá"
    
    def zvuk(self):
        return f"{self.jmeno} píská"

class Vlk(Zviratko, Lety):
    def __init__(self, jmeno):
        super().__init__(jmeno)
    
    def zvuk(self):  # Přepisuje metodu
        return f"{self.jmeno} řvalí"

# Zobrazí pořadí metod (MRO)
print("MRO pro Vlk:")
for cls in Vlk.__mro__:
    print(f"  {cls}")

vlk = Vlk("Štěpán")
print(vlk.pohyb())  # Která metoda se zavolá?
print(vlk.zvuk())

# %% [markdown]
# ### Příklad 8
#
# ### Očekávaný výstup:
# ```
# MRO pro Vlk:
#   <class '__main__.Vlk'>
#   <class '__main__.Zviratko'>
#   <class '__main__.Lety'>
#   <class 'object'>
#
# Štěpán se pohybuje
# Štěpán řvalí
# ```

# %% [markdown]
# ### Příklad 9
#
# ### Vysvětlení:
# - `Vlk` dědí od obou tříd: `Zviratko` a `Lety`
# - MRO určuje pořadí, ve kterém se metody hledají (levý první)
# - Proto `pohyb()` z `Zviratko` a `zvuk()` z `Vlk` (přepsaná)
#
# ---
#
# ## 4. Abstract Base Classes (ABC) - Abstraktní třídy

# %% [markdown]
# ### Příklad 10
#
# ### Co příklad demonstruje:
# Tento příklad ukazuje, jak vytvářet abstraktní třídy a metody pomocí `abc` modulu.

# %%
# Název: Abstraktní třídy (ABC)
# Co příklad demonstruje: Použití ABC pro definování rozhraní

from abc import ABC, abstractmethod

class Tvar(ABC):  # Abstraktní třída
    @abstractmethod
    def obsah(self):
        pass
    
    @abstractmethod
    def obvod(self):
        pass

class Ctverec(Tvar):
    def __init__(self, strana):
        self.strana = strana
    
    def obsah(self):
        return self.strana ** 2
    
    def obvod(self):
        return 4 * self.strana

class Kruh(Tvar):
    def __init__(self, polomer):
        self.polomer = polomer
    
    def obsah(self):
        return 3.14 * self.polomer ** 2
    
    def obvod(self):
        return 2 * 3.14 * self.polomer

# Vytvoření objektů
ctverec = Ctverec(5)
kruh = Kruh(3)

print(f"Obsah čtverce: {ctverec.obsah()}")
print(f"Obvod čtverce: {ctverec.obvod()}")
print(f"Obsah kruhu: {kruh.obsah()}")
print(f"Obvod kruhu: {kruh.obvod()}")

# Toto způsobí chybu, protože nelze vytvořit instanci abstraktní třídy:
# tvar = Tvar()

# %% [markdown]
# ### Příklad 11
#
# ### Očekávaný výstup:
# ```
# Obsah čtverce: 25
# Obvod čtverce: 20
# Obsah kruhu: 28.26
# Obvod kruhu: 18.84
# ```

# %% [markdown]
# ### Příklad 12
#
# ### Vysvětlení:
# - `Tvar` je abstraktní třída s abstraktními metodami `obsah()` a `obvod()`
# - Třídy `Ctverec` a `Kruh` musí implementovat tyto metody
# - Nelze vytvořit instanci abstraktní třídy – to zajišťuje, že rozhraní je dodržené
#
# ---
#
# ## 5. Composition vs. Inheritance + SOLID principy

# %% [markdown]
# ### Příklad 13
#
# ### Co příklad demonstruje:
# Tento příklad ukazuje rozdíl mezi dědičností a kompozicí a aplikuje SOLID principy.
#
# ```python
# # Název: SOLID principy a kompozice vs. dědičnost
# # Co příklad demonstruje: SOLID principy + využití kompozice
#
# from abc import ABC, abstractmethod
#
# # SOLID - Single Responsibility Principle (SRP)
# class Motor(ABC):
#     @abstractmethod
#     def start(self):
#         pass
#
# class BenzinovýMotor(Motor):
#     def start(self):
#         return "Benzinový motor spuštěn"
#
# class ElektrickýMotor(Motor):
#     def start(self):
#         return "Elektrický motor spuštěn"
#
# # SOLID - Open/Closed Principle (OCP)
# class Vozidlo:
#     def __init__(self, motor: Motor):  # Kompozice místo dědičnosti
#         self.motor = motor
#
#     def zapni(self):
#         return self.motor.start()
#
# # SOLID - Liskov Substitution Principle (LSP)
# class Autobus(Vozidlo):
#     def __init

# %% [markdown]
# ## 🎯 Cvičení a úkoly
#
# <div style="background: #fff3e0; padding: 20px; border-left: 5px solid #ff9800; margin: 20px 0; border-radius: 5px;">
#     <h3 style="color: #2c3e50; margin-top: 0;">✍️ Praktická cvičení k procvičení</h3>
#     <p>Vyřešte následující úkoly. Začněte od jednoduššších a postupujte k složitějším.</p>
# </div>
#
# # Praktická cvičení: Objektově orientované programování II
#
# ---
#
# ## Cvičení 1: Vytvoření vlastního iterátoru pro kolekci
#
# ### **Název úkolu**
# Vlastní iterátor pro seznam zvířat
#
# ### **Detailní zadání**
# Vytvořte třídu `AnimalCollection`, která bude obsahovat seznam zvířat (např. `Cat`, `Dog`). Tato třída musí být iterovatelná, tj. musí podporovat příkaz `for` v Pythonu. Implementujte vlastní iterátor pro tuto třídu.
#
# ### **Vstupní data/požadavky**
# - Třídy `Cat` a `Dog` s atributy `name` a `sound`
# - Metoda `add_animal(animal)` pro přidání zvířete do kolekce
# - Při iteraci se má vypisovat jméno a zvuk zvířete
#
# ### **Očekávaný výstup**
# ```python
# collection = AnimalCollection()
# collection.add_animal(Cat("Mourek"))
# collection.add_animal(Dog("Fíka"))
#
# for animal in collection:
#     print(animal)
# # Výstup:
# # Mourek mňau
# # Fíka haf
# ```
#
# ### **Hints/Nápověda**
# 1. Použijte metody `__iter__()` a `__next__()` pro implementaci iterátoru.
# 2. Vytvořte samostatnou třídu `AnimalIterator`, která bude obsahovat logiku iterace.
# 3. Ujistěte se, že iterátor vyhazuje `StopIteration` po dosažení konce seznamu.
# 4. Přidejte základní kontrolu na prázdný seznam.
#
# ### **Kostra řešení**
# ```python
# class Cat:
#     def __init__(self, name):
#         self.name = name
#         self.sound = "mňau"
#
# class Dog:
#     def __init__(self, name):
#         self.name = name
#         self.sound = "haf"
#
# class AnimalCollection:
#     def __init__(self):
#         self.animals = []
#
#     def add_animal(self, animal):
#         self.animals.append(animal)
#
#     def __iter__(self):
#         # TODO: implementuj iterátor
#         pass
#
# class AnimalIterator:
#     def __init__(self, animals):
#         self.animals = animals
#         self.index = 0
#
#     def __iter__(self):
#         return self
#
#     def __next__(self):
#         # TODO: implementuj logiku next
#         pass
# ```
#
# ### **Bonusové rozšíření**
# Přidejte možnost iterace pouze konkrétních typů zvířat (např. jen kočky) pomocí filtru.
#
# ---
#
# ## Cvičení 2: Implementace polymorfismu a abstraktní třídy
#
# ### **Název úkolu**
# Rozhraní pro různé typy geometrických tvarů
#
# ### **Detailní zadání**
# Vytvořte abstraktní třídu `Shape` s metodami `area()` a `perimeter()`. Potom vytvořte konkrétní třídy: `Circle`, `Rectangle`, `Triangle`. Implementujte pro každou z tříd odpovídající metody pro výpočet obsahu a obvodu.
#
# ### **Vstupní data/požadavky**
# - Všechny třídy musí být odvozené od `Shape`
# - Metoda `area()` vrací číslo
# - Metoda `perimeter()` vrací číslo
# - Použijte `@abstractmethod` pro abstraktní metody
#
# ### **Očekávaný výstup**
# ```python
# shapes = [Circle(5), Rectangle(4, 6), Triangle(3, 4, 5)]
# for shape in shapes:
#     print(f"{shape.__class__.__name__}: area={shape.area():.2f}, perimeter={shape.perimeter():.2f}")
# ```
#
# ### **Hints/Nápověda**
# 1. Použijte `abc.ABC` a `@abstractmethod`.
# 2. Pro kruh použijte vzorec: `π * r²` pro obsah, `2 * π * r` pro obvod.
# 3. Pro trojúhelník použijte Heronovu větu nebo přímo délky stran.
# 4. Ujistěte se, že každá třída implementuje obě metody.
#
# ### **Kostra řešení**
# ```python
# from abc import ABC, abstractmethod
#
# class Shape(ABC):
#     @abstractmethod
#     def area(self):
#         pass
#
#     @abstractmethod
#     def perimeter(self):
#         pass
#
# class Circle(Shape):
#     def __init__(self, radius):
#         self.radius = radius
#
#     def area(self):
#         # TODO
#         pass
#
#     def perimeter(self):
#         # TODO
#         pass
#
# class Rectangle(Shape):
#     def __init__(self, width, height):
#         self.width = width
#         self.height = height
#
#     def area(self):
#         # TODO
#         pass
#
#     def perimeter(self):
#         # TODO
#         pass
#
# class Triangle(Shape):
#     def __init__(self, a, b, c):
#         self.a = a
#         self.b = b
#         self.c = c
#
#     def area(self):
#         # TODO (použij Heronovu větu)
#         pass
#
#     def perimeter(self):
#         # TODO
#         pass
# ```
#
# ### **Bonusové rozšíření**
# Vytvořte třídu `ShapeFactory`, která bude vytvářet tvary podle zadaných parametrů (např. typ tvaru, rozměry).
#
# ---
#
# ## Cvičení 3: Dědičnost s překrýváním metod a super()
#
# ### **Název úkolu**
# Vytvoření pracovního systému pro různé typy zaměstnanců
#
# ### **Detailní zadání**
# Vytvořte základní třídu `Employee`, která bude obsahovat atributy `name` a `salary`. Dále vytvořte třídy `Manager` a `Developer`, které dědí od `Employee`. Každá podtřída má vlastní metodu `calculate_bonus()` s různým způsobem výpočtu.
#
# ### **Vstupní data/požadavky**
# - `Employee`: `name`, `salary`
# - `Manager`: bonus je 10 % z platu
# - `Developer`: bonus je 5 % z platu + 200 za každou metodou (`methods`)
# - Přidejte metodu `get_info()` pro tisk informací o zaměstnanci
#
# ### **Očekávaný výstup**
# ```python
# emp = Employee("Petr", 30000)
# mgr = Manager("Jana", 50000)
# dev = Developer("Martin", 40000, 10)
#
# for emp in [emp, mgr, dev]:
#     print(emp.get_info())
# ```
#
# ### **Hints/Nápověda**
# 1. Použijte `super()` pro přístup k metodám rodičovské třídy.
# 2. V každé podtřídě přepište metodu `calculate_bonus()`.
# 3. Implementujte `get_info()` jako obecnou metodu, která se může lišit podle typu zaměstnance.
# 4. Ujistěte se, že všechny třídy mají správný konstruktor.
#
# ### **Kostra řešení**
# ```python
# class Employee:
#     def __init__(self, name, salary):
#         self.name = name
#         self.salary = salary
#
#     def calculate_bonus(self):
#         return 0
#
#     def get_info(self):
#         return f"{self.name}: {self.salary} + bonus: {self.calculate_bonus()}"
#
# class Manager(Employee):
#     def calculate_bonus(self):
#         # TODO
#         pass
#
# class Developer(Employee):
#     def __init__(self, name, salary, methods):
#         super().__init__(name, salary)
#         self.methods = methods
#
#     def calculate_bonus(self):
#         # TODO
#         pass
# ```
#
# ### **Bonusové rozšíření**
# Vytvořte třídu `Team`, která bude

# %% [markdown]
# ## 📚 Další zdroje a materiály
#
# <div style="background: #e3f2fd; padding: 20px; border-left: 5px solid #2196f3; margin: 20px 0; border-radius: 5px;">
#     <h3 style="color: #2c3e50; margin-top: 0;">🔗 Doporučené materiály k dalšímu studiu</h3>
# </div>
#
# # Doporučené zdroje pro kapitolu: **Objektově orientované programování II**
#
# ---
#
# ## 📘 5 doporučených článků / tutoriálů
#
# 1. **[Design Patterns in Python](https://refactoring.guru/design-patterns/python)**
#    *Popis:* Komplexní přehled návrhových vzorů (design patterns) v jazyce Python, vhodné pro pokročilé použití OOP. Vysvětluje, jak efektivně používat singletony, factory metody, observer a další vzory.
#
# 2. **[Advanced OOP Concepts in Java](https://www.baeldung.com/java-oop-concepts)**
#    *Popis:* Podrobný článek o pokročilých konceptech v Javě, jako jsou vnitřní třídy (inner classes), anonymní třídy, abstraktní třídy, interface a jejich kombinace.
#
# 3. **[Inheritance and Polymorphism in C++](https://www.geeksforgeeks.org/inheritance-in-c/)**
#    *Popis:* Výklad dědičnosti a polymorfismu v jazyce C++ s příklady, které ukazují rozdíly mezi jednoduchou a virtuální dědičností.
#
# 4. **[Advanced Python OOP – Decorators and Metaclasses](https://docs.python.org/3/reference/datamodel.html)**
#    *Popis:* Oficiální dokumentace Pythonu o metaklasách a dekorátorech, které jsou klíčové pro pokročilé využití OOP v Pythonu.
#
# 5. **[Object-Oriented Programming in JavaScript: Inheritance and Prototypes](https://developer.mozilla.org/en-US/docs/Web/JavaScript/Inheritance_and_the_prototype_chain)**
#    *Popis:* Vysvětlení konceptů dědičnosti a prototypového modelu v JavaScriptu. Užitečné pro pochopení rozdílů mezi klasickým OOP a prototypovým přístupem.
#
# ---
#
# ## 🎥 3 YouTube videa
#
# 1. **[Design Patterns in Python - Full Course](https://www.youtube.com/watch?v=Et9O2JzgQZ4)**
#    *Délka:* 1 hodina 25 minut
#    *Popis:* Komplexní kurz o návrhových vzorech (design patterns) v Pythonu. Výklad jednotlivých vzorů s praktickými příklady.
#
# 2. **[OOP in Java - Inheritance and Polymorphism Explained](https://www.youtube.com/watch?v=5DdZt3b9w6A)**
#    *Délka:* 48 minut
#    *Popis:* Přehled dědičnosti a polymorfismu v Javě. Výklad základních i pokročilých konceptů s praktickými kódovými příklady.
#
# 3. **[Advanced JavaScript OOP - Classes, Inheritance & Prototypes](https://www.youtube.com/watch?v=5MgBikgcWnY)**
#    *Délka:* 32 minuty
#    *Popis:* Rozšířený výklad objektového přístupu v JavaScriptu – od ES6 tříd až po prototypy. Vhodné pro pokročilé uživatele.
#
# ---
#
# ## 📚 3 knihy / oficiální dokumentace
#
# 1. **"Effective Java" – Joshua Bloch**
#    *Popis:* Nejvýznamnější kniha o lepším používání jazyka Java, včetně pokročilých OOP konceptů, návrhových vzorů a osvědčených postupů.
#
# 2. **[Python Official Documentation – Object-Oriented Programming](https://docs.python.org/3/tutorial/classes.html)**
#    *Popis:* Oficiální dokumentace Pythonu o třídách, dědičnosti, vlastnostech a dalších OOP konceptech.
#
# 3. **"Head First

# %% [markdown]
# ## 📝 Shrnutí kapitoly
#
# <div style="background: linear-gradient(135deg, #667eea 0%, #764ba2 100%); padding: 30px; border-radius: 10px; color: white; margin: 30px 0;">
#     <h3 style="color: white; margin-top: 0;">✅ Co jste se naučili</h3>
#     <ul style="list-style: none; padding-left: 0;">
#         <li>✓ Dědičnost (inheritance)</li>
# <li>✓ Method overriding</li>
# <li>✓ Super() function</li>
# <li>✓ Multiple inheritance a MRO</li>
# <li>✓ Abstract base classes (ABC)</li>
#     </ul>
#
#     <h3 style="color: white;">🎯 Klíčové dovednosti</h3>
#     <p>Po dokončení této kapitoly byste měli být schopni prakticky použít všechny probrané koncepty.</p>
#
#     <h3 style='color: white;'>➡️ Další kapitola</h3><p>Kapitola 13 - pokračujte ve studiu!</p>
# </div>
#
# ---
#
# *📅 Notebook vygenerován: 2025-09-29 12:12:57*
# *🤖 Generátor: Comprehensive Colab Generator v2.0*
# *📚 Učebnice programování - Od základů k AI*

# %% [markdown]
# ## 🧪 Sandbox - Prostor pro experimenty
#
# Použijte následující buňky pro vlastní experimenty a testování:

# %%
# 🧪 Zde můžete experimentovat s kódem z kapitoly
# Napište svůj kód zde:
