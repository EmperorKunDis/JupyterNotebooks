# %% [markdown]
# # 📚 Kapitola 38: LLM aplikace - produkční nasazení
#
# <div style="background: linear-gradient(90deg, #667eea 0%, #764ba2 100%); padding: 20px; border-radius: 10px; margin: 20px 0;">
#     <h2 style="color: white; margin: 0;">Blok 4 | EXPERT</h2>
#     <p style="color: white; margin: 10px 0;">📖 Výuková kapitola</p>
# </div>
#
# ## 🎯 Co se naučíte
#
# V této kapitole se zaměříme na následující témata:
#
# - **Streaming API endpoints**
# - **WebSocket integration**
# - **Queue management for LLM**
# - **Cost optimization strategies**
# - **Rate limiting implementation**
# - **Monitoring LLM metrics**
# - **Fallback strategies**
#
# ## ⚠️ Předpoklady
# Tato kapitola navazuje na kapitoly: 32, 18, 24
#
# ---

# %%
# ⚙️ Inicializace prostředí
# Tento kód nastavuje prostředí pro kapitolu 38

import sys
import os
from datetime import datetime

# Informace o prostředí
print("=" * 60)
print(f"📚 KAPITOLA 38: LLM aplikace - produkční nasazení")
print("=" * 60)
print(f"🐍 Python verze: {sys.version}")
print(f"📅 Datum spuštění: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
print(f"💻 OS: {os.name}")
print(f"📁 Pracovní adresář: {os.getcwd()}")
print("=" * 60)

# Instalace potřebných knihoven (odkomentujte podle potřeby)
# !pip install requests pandas numpy matplotlib
# !pip install beautifulsoup4 sqlalchemy fastapi

# Import základních knihoven
import json
import csv
import time
import random
from pathlib import Path
from typing import List, Dict, Optional, Any

print("✅ Prostředí připraveno!")

# %% [markdown]
# ## 📖 Teoretická část
#
# <div style="background: #f0f4ff; padding: 20px; border-left: 5px solid #4a69bd; margin: 20px 0; border-radius: 5px;">
#     <h3 style="color: #2c3e50; margin-top: 0;">🎓 Základní teorie a koncepty</h3>
# </div>
#
# # LLM aplikace – produkční nasazení
#
# ## 1. Úvod a motivace
#
# V dnešním světě, kde umělá inteligence stále více proniká do běžného života, je klíčové porozumět, jak efektivně nasazovat a spravovat LLM (Large Language Models) v produkčních prostředích. Tato kapitola se zaměřuje na konkrétní technologické aspekty a praktické implementace, které jsou nezbytné pro spolehlivé a eficientní běh LLM aplikací v reálném prostředí.
#
# Zapojení LLM do produkčních systémů se objevuje například u chatbotů, automatizovaných zpracování textu, generování obsahu, kognitivních asistentů, a všech dalších aplikacích, které vyžadují reálnou odpověď na dotazy nebo předpovědi. V praxi se často setkáváme s problémy jako je zpomalení systému, nesprávná správa požadavků, zvýšené náklady a absence monitoringu – všechno to může přinést nejen technické, ale i obchodní problémy.
#
# Po této kapitole bude student schopen navrhnout a implementovat produkční nasazení LLM aplikací, které jsou spolehlivé, škálovatelné a efektivní z hlediska nákladů i výkonu.
#
# ---
#
# ## 2. Hlavní koncepty
#
# ### Streaming API endpoints
#
# **Streaming API endpoints** umožňují posílat odpovědi od LLM aplikace postupně, místo toho, aby celá odpověď byla připravena a odeslána najednou. V praxi se tato metoda používá v reálném čase, například při generování textu, kde uživatel vidí výstup postupně.
#
# - **Příklad:** Chatbot, který vrací odpověď postupně – tedy každé slovo nebo věta se posílá až po jejím vygenerování.
# - **Výhody:**
#   - Lepší uživatelské zkušenosti (člověk ví, že odpověď je generována)
#   - Snížení času doby první odpovědi
#   - Efektivní využití paměti a zdrojů
#
# ### WebSocket integration
#
# **WebSocket integrace** umožňuje komunikaci v reálném čase mezi klientem a serverem, což je velmi užitečné při interaktivních aplikacích jako jsou chaty nebo real-time AI asistenci.
#
# - **Příklad:** Uživatel zadá dotaz a asistent odpovídá v reálném čase, přičemž se odpověď posílá po jednotlivých částech.
# - **Výhody:**
#   - Nezbytné pro real-time zpracování
#   - Umožňuje vícekomunikačních kanálů
#   - Snížení latence
#
# ### Queue management for LLM
#
# **Řízení fronty (queue management)** je klíčové pro správné rozložení požadavků na LLM modely. V produkčním prostředí může být návštěvnost velmi nestabilní, a proto je nutné efektivně řídit požadavky.
#
# - **Příklad:** Použití systému jako je Celery nebo RabbitMQ pro zpracování požadavků v dávkách.
# - **Výhody:**
#   - Zabrání přetížení modelu
#   - Umožňuje řízení priority požadavků
#   - Zajišťuje spolehlivost zpracování
#
# ### Cost optimization strategies
#
# **Strategie optimalizace nákladů** jsou důležité, protože LLM modely mohou být velmi náročné na výpočetní prostředky.
#
# - **Příklady:**
#   - Použití modelů s nižším rozlišením pro jednodušší úkoly
#   - Implementace cacheování častých dotazů
#   - Využití batch processingu
# - **Výhody:**
#   - Snížení nákladů na výpočetní prostředky
#   - Zlepšení efektivity systému
#
# ### Rate limiting implementation
#
# **Implementace rate limitingu (omezení počtu požadavků)** je klíčová pro ochranu systému před overloadem a zaručuje rovnoměrné využití zdrojů.
#
# - **Příklad:** Omezení počtu dotazů na uživatele na 100 za den.
# - **Výhody:**
#   - Zamezuje přetížení systému
#   - Umožňuje správné rozdělení zdrojů mezi uživatele
#
# ### Monitoring LLM metrics
#
# **Monitorování metriky (LLM metrics)** umožňuje sledovat výkonnost modelu, zpomalení, chyby a další kritické indikátory.
#
# - **Příklad:** Sledování latence odpovědi, počtu chyb, času potřebného na vygenerování odpovědi.
# - **Nástroje:** Prometheus, Grafana, LangSmith
# - **Výhody:**
#   - Rychlé zjištění problémů
#   - Umožňuje optimalizaci výkonu
#
# ### Fallback strategies
#
# **Záložní strategie (fallback strategies)** jsou implementovány pro případ, kdy hlavní model selže. Tato strategie zajistí, že aplikace bude nadále fungovat.
#
# - **Příklad:** Pokud LLM selže, systém použije jiný model nebo přepne na statickou odpověď.
# - **Výhody:**
#   - Zvyšuje spolehlivost systému
#   - Umožňuje přechod na záložní řešení
#
# ---
#
# ## 3. Důležité detaily
#
# ### Časté chyby a jak se jim vyhnout
#
# - **Nepřiměřené použití modelu:** Někdy se používají největší modely i pro jednoduché úkoly – to zvyšuje náklady bez zisku.
# - **Neefektivní fronty:** Fronta je přetížená a požadavky se nezpracovávají včas.
# - **Chybějící monitorování:** Bez monitoringu není možné rychle detekovat problémy.
#
# ### Best practices
#
# - **Zabezpečení před overloadem** pomocí limitování počtu požadavků a použití front.
# - **Implementace cacheování** pro časté dotazy.
# - **Pravidelná optimalizace modelu a monitorování výkonu.**
#
# ### Performance tipy
#
# - Využití batch processingu při zpracování většího počtu dotazů.
# - Zvážení použití edge computingu pro snížení latence.
# - Vhodné zvolení modelu podle potřeby – ne všechno musí být "nejlepší" model.
#
# ---
#
# ## 4. Propojení s předchozími kapitolami
#
# Tato kapitola navazuje na předchozí znalosti týkající se základního využívání LLM modelů, jejich trénování, a implementace v prostředí Pythonu. Zde se zaměřujeme na **produkční aspekty**, které jsou klíčové pro reálné nasazení systémů.
#
# Důležité je si uvědomit, že model je jenom základ – v produkci musí být správně integrován s komunikačními protokoly, řízením front a monitorováním. Tato kapitola tedy rozšiřuje již naučené koncepty a ukazuje, jak je aplikovat v praxi.
#
# ---
#
# **Shrnutí:** Produkční nasazení LLM aplikací vyžaduje zvládnutí řady technických detailů – od optimalizace výkonu po monitorování systému. Tato kapitola poskytuje nezbytné nástroje a strategie pro bezpečné a efektivní provoz LLM v reálném prostředí.

# %% [markdown]
# ## 💻 Praktické příklady
#
# <div style="background: #e8f5e9; padding: 20px; border-left: 5px solid #4caf50; margin: 20px 0; border-radius: 5px;">
#     <h3 style="color: #2c3e50; margin-top: 0;">👨‍💻 Hands-on příklady ke spuštění</h3>
#     <p>Následující příklady si můžete hned vyzkoušet. Každý příklad je samostatně spustitelný.</p>
# </div>

# %% [markdown]
# ### Příklad 1
#
# Příklad použití:
# # add_to_queue("Jaký je nejlepší způsob výuky AI?")
# ```
#
# ## Očekávaný výstup:
# ```
# Přidán požadavek do fronty s ID: task_1715683421
# Zpracovávám požadavek: Jaký je nejlepší způsob výuky AI?
# Požadavek zpracován.
# ```
#
# ## Vysvětlení:
# Tento příklad ukazuje, jak může být fronta požadavků na LLM spravována pomocí Redis. Požadavky se ukládají do seznamu `llm_queue`, a oddělený proces je zpracovává postupně, což umožňuje řízení zatížení a efektivní využití prostředků.
#
# ---
#
# # 4. Cost optimization strategies
#
# ## Název příkladu:
# **Cenová optimalizace LLM volání s cache a deduplikací**
#
# ## Co demonstruje:
# Optimalizace nákladů tím, že se výstupy LLM ukládají do mezipaměti a duplicitní požadavky jsou vynechány.
#
# ## Kompletní kód:
#
# ```python
# import hashlib
# import time
# from typing import Optional
#
# # Jednoduchá cache s časovým limitem (např. 30 minut)
# cache = {}
# CACHE_TIMEOUT = 1800  # sekundy
#
# def get_cache_key(prompt: str) -> str:
#     """
#     Vytvoří hash pro prompt, který slouží jako klíč do cache.
#     """
#     return hashlib.md5(prompt.encode()).hexdigest()
#
# def llm_call(prompt: str) -> str:
#     """
#     Simulace volání LLM. V reálném případě bude to API volání.
#     """
#     # Simulace zpracování
#     time.sleep(0.1)
#     return f"Výsledek pro '{prompt}'"
#
# def optimized_llm_call(prompt: str) -> str:
#     """
#     Volání LLM s cache a deduplikací.
#     """
#     cache_key = get_cache_key(prompt)
#
#     # Kontrola cache
#     if cache_key in cache:
#         result, timestamp = cache[cache_key]
#         if time.time() - timestamp < CACHE_TIMEOUT:
#             print("Používám cache")
#             return result
#
#     # Volání LLM a ukládání do cache
#     result = llm_call(prompt)
#     cache[cache_key] = (result, time.time())
#
#     print("Volání LLM provedeno a výsledek uložen do cache")
#     return result
#
# #

# %% [markdown]
# ### Příklad 2
#
# Příklad použití:
# print(optimized_llm_call("Jak se dělá cache?"))
# print(optimized_llm_call("Jak se dělá cache?"))  # Použije cache
# ```
#
# ## Očekávaný výstup:
# ```
# Volání LLM provedeno a výsledek uložen do cache
# Vý

# %% [markdown]
# ## 🎯 Cvičení a úkoly
#
# <div style="background: #fff3e0; padding: 20px; border-left: 5px solid #ff9800; margin: 20px 0; border-radius: 5px;">
#     <h3 style="color: #2c3e50; margin-top: 0;">✍️ Praktická cvičení k procvičení</h3>
#     <p>Vyřešte následující úkoly. Začněte od jednoduššších a postupujte k složitějším.</p>
# </div>
#
# # Cvičení pro kapitolu: LLM aplikace - produkční nasazení
#
# ---
#
# ## **Cvičení 1: Migrace LLM modelu do produkčního prostředí s využitím Dockeru**
#
# ### 1. **Název úkolu**
# Nasazení LLM modelu pomocí Dockeru v produkčním prostředí
#
# ### 2. **Detailní zadání**
# Vytvořte Docker image pro nasazení LLM modelu (např. `llama3` nebo `mistral`) s podporou API endpointu pro inferenci, který bude kompatibilní s produkčním prostředím. V rámci toho implementujte základní ochranné mechanismy proti přetížení a logování.
#
# ### 3. **Vstupní data/požadavky**
# - LLM model (např. `meta-llama/Meta-Llama-3-8B-Instruct`)
# - Python knihovna `transformers` a `torch`
# - API framework: FastAPI nebo Flask
# - Vhodný prostředí pro Docker
#
# ### 4. **Očekávaný výstup**
# - Docker image s nasazeným LLM modelem
# - API endpoint `/predict`, který přijímá JSON ve formátu `{"prompt": "text"}` a vrací generovaný text
# - Základní ochrana proti zahlcení (např. limit počtu požadavků za sekundu)
# - Logování požadavků do souboru nebo konzole
#
# ### 5. **Hints/Nápověda**
# 1. Využijte `transformers` pro načtení modelu a tokenizeru.
# 2. Implementujte `FastAPI` endpoint `/predict`.
# 3. Použijte `asyncio` pro asynchronní zpracování požadavků.
# 4. Přidejte middleware pro limit počtu požadavků (např. `fastapi-limiter`).
#
# ### 6. **Kostra řešení**
# ```python
# from fastapi import FastAPI, HTTPException
# from pydantic import BaseModel
# from transformers import AutoModelForCausalLM, AutoTokenizer
# import torch
#
# app = FastAPI()
#
# class PromptRequest(BaseModel):
#     prompt: str
#
# # Načtení modelu a tokenizeru
# model_name = "meta-llama/Meta-Llama-3-8B-Instruct"
# tokenizer = AutoTokenizer.from_pretrained(model_name)
# model = AutoModelForCausalLM.from_pretrained(model_name)
#
# @app.post("/predict")
# async def predict(request: PromptRequest):
#     inputs = tokenizer(request.prompt, return_tensors="pt")
#     outputs = model.generate(**inputs, max_new_tokens=100)
#     response = tokenizer.decode(outputs[0], skip_special_tokens=True)
#     return {"response": response}
# ```
#
# ### 7. **Bonusové rozšíření**
# - Přidejte podporu pro batch inferenci (více promptů najednou).
# - Implementujte model caching a load balancing mezi více GPU.
#
# ---
#
# ## **Cvičení 2: Implementace LLM API proxy s využitím Redis cache a limitováním požadavků**
#
# ### 1. **Název úkolu**
# Vytvoření API proxy pro LLM model s cache a rate-limitingem
#
# ### 2. **Detailní zadání**
# Naprogramujte API proxy, která přijímá požadavky na inferenci, ukládá výsledky do Redis cache, omezuje počet požadavků a zajišťuje škálovatelnost. Zajistěte logování a monitorování.
#
# ### 3. **Vstupní data/požadavky**
# - LLM model (např. `mistralai/Mistral-7B-v0.1`)
# - Redis instance
# - FastAPI nebo Flask
# - Middleware pro rate-limiting
#
# ### 4. **Očekávaný výstup**
# - API endpoint `/api/inference`, který zpracovává požadavky a ukládá odpovědi do Redis
# - Omezení počtu požadavků (např. 10 za sekundu)
# - Logy odeslaných požadavků a odpovědí
# - Možnost restartu bez ztráty cache
#
# ### 5. **Hints/Nápověda**
# 1. Použijte Redis jako key-value úložiště pro výsledky inferencí.
# 2. Implementujte `RateLimiter` middleware (např. pomocí `fastapi-limiter`).
# 3. Ujistěte se, že požadavky jsou kryptograficky hashované před uložením do Redis.
# 4. Přidejte logování pomocí `logging` modulu.
#
# ### 6. **Kostra řešení**
# ```python
# from fastapi import FastAPI, HTTPException
# import redis
# import hashlib
# import json
#
# app = FastAPI()
# redis_client = redis.StrictRedis(host='localhost', port=6379, db=0)
#
# @app.post("/api/inference")
# async def inference(prompt: str):
#     key = hashlib.md5(prompt.encode()).hexdigest()
#     cached = redis_client.get(key)
#
#     if cached:
#         return {"cached": True, "response": json.loads(cached)}
#
#     # Zde implementujte inferenci modelu
#     response = model_inference(prompt)
#     redis_client.setex(key, 3600, json.dumps(response))
#     return {"cached": False, "response": response}
# ```
#
# ### 7. **Bonusové rozšíření**
# - Implementujte dynamické škálování pomocí Kubernetes a HPA.
# - Přidejte monitoring (např. Prometheus + Grafana).
#
# ---
#
# ## **Cvičení 3: Škálovatelné LLM inference API s využitím Kubernetes a GPU autoscalingu**
#
# ### 1. **Název úkolu**
# Nasazení LLM modelu ve škálovatelném prostředí pomocí Kubernetes
#
# ### 2. **Detailní zadání**
# Vytvořte Kubernetes deployment pro nasazení LLM modelu na GPU, který bude automaticky škálovat podle požadavků. Implementujte přístup k modelu přes API a zabezpečení s využitím Istio nebo Traefik.
#
# ### 3. **Vstupní data/požadavky**
# - Kubernetes cluster (minikube, EKS, GKE)
# - Docker image s LLM modelem
# - GPU podporu (např. nvidia/gpu-device-plugin)
# - Helm chart nebo YAML konfigurace
#
# ### 4. **Očekávaný výstup**
# - Kubernetes deployment s LLM modelem na GPU
# - HPA (Horizontal Pod Autoscaler) pro automatické škálování
# - Ingress controller pro přístup k API
# - Zabezpečení pomocí TLS a autentizace
#
# ### 5. **Hints/Nápověda**
# 1. Použijte `nvidia/k8s-device-plugin` pro podporu GPU.
# 2. Nastavte HPA s metrikou CPU nebo počtem požadavků.
# 3. Implementujte Ingress controller (Traefik, NGINX).
# 4. Zajistěte zabezpečení pomocí cert-manager a Istio.
#
# ### 6. **Kostra řešení**
# ```yaml
# apiVersion: apps/v1
# kind: Deployment
# metadata:
#   name: llm-deployment
# spec:
#   replicas: 1
#   selector:
#     matchLabels:
#       app: llm-app
#   template:
#     metadata:
#       labels:
#         app: llm-app
#     spec:
#       containers:
#       - name: llm-container
#         image: your-llm-image
#         ports:
#         - containerPort: 8000
#         resources:
#           limits:
#             nvidia.com/gpu: 1
# ```
#
# ### 7. **Bonusové rozšíření**
# - Přidejte podporu pro model serving (např. `vLLM`, `Triton Inference Server`).
# - Nastavte CI/CD pipeline s GitHub Actions a ArgoCD.
#
# ---
#
# ## **Cvičení 4: LLM inference monitoring a logování v produkčním prostředí**
#
# ###

# %% [markdown]
# ## 📚 Další zdroje a materiály
#
# <div style="background: #e3f2fd; padding: 20px; border-left: 5px solid #2196f3; margin: 20px 0; border-radius: 5px;">
#     <h3 style="color: #2c3e50; margin-top: 0;">🔗 Doporučené materiály k dalšímu studiu</h3>
# </div>
#
# # Seznam zdrojů pro kapitolu: **LLM aplikace – produkční nasazení**
#
# ---
#
# ## 📚 5 doporučených článků/tutoriálů
#
# 1. **[Deploying Large Language Models in Production – A Complete Guide](https://www.anyscale.com/blog/deploying-llms-in-production)**
#    *Popis:* Komplexní průvodce produkčním nasazením LLM modelů, zahrnuje výběr platformy, optimalizaci a správu infrastruktury.
#
# 2. **[Building and Deploying LLM Applications with Hugging Face and FastAPI](https://huggingface.co/blog/deploy-llm-apps)**
#    *Popis:* Praktický návod na vytvoření API pro LLM aplikace pomocí Hugging Face a FastAPI, včetně základního deploymentu.
#
# 3. **[LLM Deployment Best Practices](https://www.pinecone.io/learn/llm-deployment-best-practices/)**
#    *Popis:* Nejlepší postupy pro deployment LLM modelů v produkčním prostředí, zahrnuje návody na škálování, caching a monitorování.
#
# 4. **[How to Deploy LLMs in Production: From Concept to Reality](https://towardsdatascience.com/how-to-deploy-llms-in-production-1d27e0a31187)**
#    *Popis:* Krok za krokem průvodce implementací LLM aplikací, včetně problémů s výkonem a zabezpečením.
#
# 5. **[Production-Ready LLM Applications with LangChain and Docker](https://blog.langchain.dev/llm-production-deployment/)**
#    *Popis:* Průvodce vytvořením produkčních aplikací pomocí LangChain a Docker, zaměřený na škálovatelnost a udržitelnost.
#
# ---
#
# ## 🎥 3 YouTube videa
#
# 1. **[Deploying LLMs in Production with FastAPI and Hugging Face](https://www.youtube.com/watch?v=2X5gJFv6lWw)**
#    *Délka:* 28 min
#    *Popis:* Demonstrace, jak vytvořit a nasadit LLM aplikaci pomocí FastAPI a Hugging Face v produkčním prostředí.
#
# 2. **[LLM Deployment: From Local to Cloud (with AWS & Kubernetes)](https://www.youtube.com/watch?v=K0Qh7z4Vd5U)**
#    *Délka:* 35 min
#    *Popis:* Průvodce deployem LLM modelů na cloudu, včetně práce s AWS a Kubernetes.
#
# 3. **[Building Scalable LLM Applications with LangChain and Streamlit](https://www.youtube.com/watch?v=7j0Y8v2mPZM)**
#    *Délka:* 40 min
#    *Popis:* Jak vytvářet skalovatelné LLM aplikace pomocí LangChain a Streamlit, zároveň ukázka praktického nasazení.
#
# ---
#
# ## 📘 3 knihy nebo oficiální dokumentace
#
# 1. **[Hugging Face Documentation – Model Deployment Guide](https://huggingface.co/docs/hub/en/model-deployment)**
#    *Popis:* Oficiální průvodce deploymentem modelů na Hugging Face Hub, včetně nástrojů pro produkční nasazení.
#
# 2. **[LangChain Documentation – Deployment and Production](https://docs.langchain.com/docs/deployment/)**
#    *Popis:* Oficiální dokumentace pro nasazování aplikací s LangChain, zahrnuje konfiguraci a integraci do produkčních systémů.
#
# 3. **[The AI Engineer’s Guide to LLMs – Chapter on Production Deployment](https://www.oreilly.com/library/view/the-ai-engineers-guide/9781098126354/ch06.html)**
#    *Popis:* Kapitola o produkčním nasazení LLM modelů ve větší knize zaměřené na inženýrství AI.
#
# ---
#
# ## 💻 2 prakt

# %% [markdown]
# ## 📝 Shrnutí kapitoly
#
# <div style="background: linear-gradient(135deg, #667eea 0%, #764ba2 100%); padding: 30px; border-radius: 10px; color: white; margin: 30px 0;">
#     <h3 style="color: white; margin-top: 0;">✅ Co jste se naučili</h3>
#     <ul style="list-style: none; padding-left: 0;">
#         <li>✓ Streaming API endpoints</li>
# <li>✓ WebSocket integration</li>
# <li>✓ Queue management for LLM</li>
# <li>✓ Cost optimization strategies</li>
# <li>✓ Rate limiting implementation</li>
#     </ul>
#
#     <h3 style="color: white;">🎯 Klíčové dovednosti</h3>
#     <p>Po dokončení této kapitoly byste měli být schopni prakticky použít všechny probrané koncepty.</p>
#
#     <h3 style='color: white;'>➡️ Další kapitola</h3><p>Kapitola 39 - pokračujte ve studiu!</p>
# </div>
#
# ---
#
# *📅 Notebook vygenerován: 2025-09-29 13:36:54*
# *🤖 Generátor: Comprehensive Colab Generator v2.0*
# *📚 Učebnice programování - Od základů k AI*

# %% [markdown]
# ## 🧪 Sandbox - Prostor pro experimenty
#
# Použijte následující buňky pro vlastní experimenty a testování:

# %%
# 🧪 Zde můžete experimentovat s kódem z kapitoly
# Napište svůj kód zde:
