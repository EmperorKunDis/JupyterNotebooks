# %% [markdown]
# # 📚 Kapitola 11: Objektově orientované programování I
#
# <div style="background: linear-gradient(90deg, #667eea 0%, #764ba2 100%); padding: 20px; border-radius: 10px; margin: 20px 0;">
#     <h2 style="color: white; margin: 0;">Blok 2 | INTERMEDIATE</h2>
#     <p style="color: white; margin: 10px 0;">📖 Výuková kapitola</p>
# </div>
#
# ## 🎯 Co se naučíte
#
# V této kapitole se zaměříme na následující témata:
#
# - **Třídy a objekty**
# - **Konstruktor __init__ a destruktor __del__**
# - **Instance vs. class attributes**
# - **Methods: instance, class, static**
# - **Properties a property decorator**
# - **Magic methods: __str__, __repr__, __eq__**
# - **Encapsulation a private attributes**
#
# ## ⚠️ Předpoklady
# Tato kapitola navazuje na kapitoly: 7
#
# ---

# %%
# ⚙️ Inicializace prostředí
# Tento kód nastavuje prostředí pro kapitolu 11

import sys
import os
from datetime import datetime

# Informace o prostředí
print("=" * 60)
print(f"📚 KAPITOLA 11: Objektově orientované programování I")
print("=" * 60)
print(f"🐍 Python verze: {sys.version}")
print(f"📅 Datum spuštění: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
print(f"💻 OS: {os.name}")
print(f"📁 Pracovní adresář: {os.getcwd()}")
print("=" * 60)

# Instalace potřebných knihoven (odkomentujte podle potřeby)
# !pip install requests pandas numpy matplotlib
# !pip install beautifulsoup4 sqlalchemy fastapi

# Import základních knihoven
import json
import csv
import time
import random
from pathlib import Path
from typing import List, Dict, Optional, Any

print("✅ Prostředí připraveno!")

# %% [markdown]
# ## 📖 Teoretická část
#
# <div style="background: #f0f4ff; padding: 20px; border-left: 5px solid #4a69bd; margin: 20px 0; border-radius: 5px;">
#     <h3 style="color: #2c3e50; margin-top: 0;">🎓 Základní teorie a koncepty</h3>
# </div>
#
# # Objektově orientované programování I
#
# ## 1. Úvod a motivace
#
# Objektově orientované programování (OOP) je jedna z nejrozšířenějších paradigmat v moderním programování. Je to přístup, který se zaměřuje na modelování reálných problémů pomocí objektů – tedy prvků, které mají své vlastnosti (atributy) a chování (metody). V Pythonu je OOP základním nástrojem pro psaní čistého, rozšiřitelného a udržitelného kódu.
#
# V praxi se OOP používá v téměř každé moderní aplikaci – od webových systémů přes mobilní aplikace až po velké enterprise řešení. Například frameworky jako Django nebo Flask, které jsou založené na Pythonu, využívají OOP k organizaci kódu a tvoření modulárních systémů.
#
# Studium OOP ti umožní přemýšlet o problémech jako o součástech reálného světa, což zjednodušuje návrh a implementaci programů. Naučíš se tvořit modulární kód, který je snadno rozšiřitelný a opětovně použitelný – důležité dovednosti pro každého profesionálního programátora.
#
# ---
#
# ## 2. Hlavní koncepty
#
# ### Třídy a objekty
#
# Třída je šablona nebo „plánek“, podle kterého se vytvářejí objekty. Objekt (nebo instancie) je konkrétní výskyt třídy. Například:
#
# ```python
# class Osoba:
#     def __init__(self, jmeno, vek):
#         self.jmeno = jmeno
#         self.vek = vek
#
# osoba1 = Osoba("Petr", 25)
# osoba2 = Osoba("Jana", 30)
# ```
#
# Zde `Osoba` je třída, zatímco `osoba1` a `osoba2` jsou objekty (instance) této třídy. Každý objekt má své vlastní hodnoty atributů.
#
# ---
#
# ### Konstruktor `__init__` a destruktor `__del__`
#
# Konstruktor `__init__` je speciální metoda, která se automaticky spustí při vytváření instance třídy. Používá se k inicializaci atributů objektu.
#
# ```python
# class Auto:
#     def __init__(self, znacka):
#         self.znacka = znacka
#         print(f"Vytvořeno auto značky {znacka}")
# ```
#
# Destruktor `__del__` se spustí při odstranění objektu (např. při ukončení programu nebo ručním smazání reference). Používá se zřídka, protože v Pythonu se garbage collector postará o uvolnění paměti automaticky.
#
# ```python
# class Auto:
#     def __del__(self):
#         print("Auto bylo odstraněno")
# ```
#
# ---
#
# ### Instance vs. class attributes
#
# Atributy třídy jsou sdílené mezi všemi instancemi:
#
# ```python
# class Student:
#     skola = "Gymnázium"  # class attribute
#
#     def __init__(self, jmeno):
#         self.jmeno = jmeno   # instance attribute
# ```
#
# Takže všechny studenti mají stejnou školu, ale každý má jiné jméno.
#
# ---
#
# ### Methods: instance, class, static
#
# **Instance metody** pracují s instancí objektu a vždy mají `self` jako první parametr:
#
# ```python
# class Osoba:
#     def __init__(self, jmeno):
#         self.jmeno = jmeno
#
#     def pozdrav(self):  # instance metoda
#         return f"Ahoj, já jsem {self.jmeno}"
# ```
#
# **Class metody** používají `@classmethod` a mají jako první parametr `cls` (třídu):
#
# ```python
# class Osoba:
#     @classmethod
#     def vytvor_z_veku(cls, vek):
#         return cls(f"Osoba s věkem {vek}")
# ```
#
# **Statické metody** nevyžadují ani `self`, ani `cls` a jsou používány pro funkce související s třídou, ale nezávislé na instanci:
#
# ```python
# class Matematika:
#     @staticmethod
#     def secti(a, b):
#         return a + b
# ```
#
# ---
#
# ### Properties a property decorator
#
# V Pythonu se používá `@property` pro vytváření getterů a setterů. To umožňuje kontrolovat přístup k atributům:
#
# ```python
# class Osoba:
#     def __init__(self, jmeno):
#         self._jmeno = jmeno
#
#     @property
#     def jmeno(self):
#         return self._jmeno
#
#     @jmeno.setter
#     def jmeno(self, hodnota):
#         if isinstance(hodnota, str) and len(hodnota) > 0:
#             self._jmeno = hodnota
#         else:
#             raise ValueError("Jméno musí být neprázdný řetězec")
# ```
#
# ---
#
# ### Magic methods: `__str__`, `__repr__`, `__eq__`
#
# Magic metody (neboli dunder metody) jsou speciální metody, které se automaticky volají při určitých operacích.
#
# ```python
# class Osoba:
#     def __init__(self, jmeno):
#         self.jmeno = jmeno
#
#     def __str__(self):  # používá se pro print()
#         return f"Osoba: {self.jmeno}"
#
#     def __repr__(self):  # používá se v debugování
#         return f"Osoba({self.jmeno!r})"
#
#     def __eq__(self, other):
#         if isinstance(other, Osoba):
#             return self.jmeno == other.jmeno
#         return False
# ```
#
# ---
#
# ### Encapsulation a private attributes
#
# Encapsulation je princip skrývání interního stavu objektu před přímým přístupem. V Pythonu se používají „private“ atributy (s jedním nebo dvěma podtržítky), které se interně přejmenují:
#
# ```python
# class BankovniUcet:
#     def __init__(self, castka):
#         self._castka = castka  # privátní atribut
#
#     def vloz(self, suma):
#         self._castka += suma
#
#     @property
#     def castka(self):
#         return self._castka
# ```
#
# Atributy začínající jedním podtržítkem jsou „protected“ (pouze konvence), dvojité podtržítko (`__`) způsobí name mangling – tedy přejmenování atributu.
#
# ---
#
# ## 3. Důležité detaily
#
# ### Časté chyby a jak se jim vyhnout
#
# - **Nepoužívání `self`** v metodách: Vždy je nutné mít `self` jako první parametr instance metod.
# - **Přístup k privátním atributům**: Někdy se pokoušíme přímo měnit `_atribut`, ale lepší je použít property.
# - **Zapomínání na konstruktor**: Pokud třída potřebuje inicializovat nějaké hodnoty, nemusíš nutně psát `__init__` – ale často to způsobí problémy.
#
# ### Best practices
#
# - Vždy používej `@property` pro přístup k proměnným, které mohou být ovlivněny.
# - Používej konvence názvů – např. `_private` pro interní atributy.
# - Rozděl třídy podle svého účelu (single responsibility principle).
#
# ### Performance tipy
#
# - Používej `__slots__`, pokud víš, že třída bude mít pevný počet atributů – zmenší to paměťovou náročnost.
# - Vyhně se přebytečnému vytváření objektů v cyklech.
#
# ---
#
# ## 4. Propojení s předchozími kapitolami
#
# Tato kapitola je přímým rozšířením znalostí z kapitoly o funkcích a proměnných. Víš, jak pracovat s proměnnými a funkcemi – teď se naučíš, jak je vytvářet jako součásti objektů. Tato praxe dává smysl ve spojení s cykly, podmínkami a datovými strukturami – protože objekty mohou být ukládány do seznamů nebo slovníků a využívány v různých kontextech.
#
# Tímto způsobem se tvoje programovací dovednosti postupně rozšiřují – od jednoduchých funkcí k komplexním systémům, které jsou založeny na objektech a jejich interakcích.

# %% [markdown]
# ## 💻 Praktické příklady
#
# <div style="background: #e8f5e9; padding: 20px; border-left: 5px solid #4caf50; margin: 20px 0; border-radius: 5px;">
#     <h3 style="color: #2c3e50; margin-top: 0;">👨‍💻 Hands-on příklady ke spuštění</h3>
#     <p>Následující příklady si můžete hned vyzkoušet. Každý příklad je samostatně spustitelný.</p>
# </div>

# %% [markdown]
# # 1. Název příkladu: Základní třída a objekt
# ## Co demonstruje:
# Základní koncepty OOP – definice třídy, vytvoření instance a práce s atributy
#
# ## Kompletní kód:
# ```python
# # Definujeme jednoduchou třídu Student
# class Student:
#     # Toto je konstruktor (__init__)
#     def __init__(self, jmeno, vek):
#         self.jmeno = jmeno  # instance atribut
#         self.vek = vek      # instance atribut
#
#     # Metoda pro zobrazení informací o studentovi
#     def info(self):
#         return f"Jméno: {self.jmeno}, Věk: {self.vek}"
#
# # Vytvoření instance třídy Student
# student1 = Student("Petr", 20)
#
# # Zobrazení informací o studentovi
# print(student1.info())
# ```
#
# ## Očekávaný výstup:
# ```
# Jméno: Petr, Věk: 20
# ```
#
# ## Vysvětlení:
# Tento příklad ukazuje základní koncept třídy a objektu. Třída `Student` definuje strukturu pro studenta. Konstruktor `__init__` se automaticky spustí při vytvoření instance (`student1 = Student("Petr", 20)`). Atributy `jmeno` a `vek` jsou instance atributy, tedy jednotlivé hodnoty pro každou instanci.
#
# ---
#
# # 2. Název příkladu: Konstruktor a destruktor
# ## Co demonstruje:
# Použití konstruktoru `__init__` a destruktoru `__del__`, který se spustí při odstranění objektu
#
# ## Kompletní kód:
# ```python
# class Kniha:
#     def __init__(self, nazev, autor):
#         self.nazev = nazev
#         self.autor = autor
#         print(f"Knihy '{self.nazev}' byla vytvořena.")
#
#     def __del__(self):
#         print(f"Knihy '{self.nazev}' byla smazána.")
#
# # Vytvoření objektu
# kniha1 = Kniha("1984", "George Orwell")
# print("Knihu jsme vytvořili.")
# # Smazání objektu (volání __del__)
# del kniha1
# ```
#
# ## Očekávaný výstup:
# ```
# Knihy '1984' byla vytvořena.
# Knihu jsme vytvořili.
# Knihy '1984' byla smazána.
# ```
#
# ## Vysvětlení:
# V tomto příkladu je použit konstruktor `__init__`, který se spustí při vytvoření instance. Destruktor `__del__` se spustí při odstranění objektu (např. příkazem `del kniha1`). Tento příklad ukazuje, jak se mohou objekty správně vytvářet a uvolňovat.
#
# ---
#
# # 3. Název příkladu: Instance vs. class atributy
# ## Co demonstruje:
# Rozdíl mezi instance a třídními atributy
#
# ## Kompletní kód:
# ```python
# class Zamestnanec:
#     # Třídní atribut - sdílený pro všechny instance
#     firma = "ABC Solutions"
#
#     def __init__(self, jmeno, pozice):
#         self.jmeno = jmeno     # Instance atribut
#         self.pozice = pozice   # Instance atribut
#
# # Vytvoření dvou zaměstnanců
# zam1 = Zamestnanec("Jan", "Programátor")
# zam2 = Zamestnanec("Marie", "Designer")
#
# # Zobrazení informací o zaměstnancích
# print(f"{zam1.jmeno} pracuje jako {zam1.pozice} ve firmě {zam1.firma}")
# print(f"{zam2.jmeno} pracuje jako {zam2.pozice} ve firmě {zam2.firma}")
#
# # Změna třídního atributu (ovlivní všechny instance)
# Zamestnanec.firma = "XYZ Company"
# print(f"Nyní pracují ve firmě {zam1.firma}")
# ```
#
# ## Očekávaný výstup:
# ```
# Jan pracuje jako Programátor ve firmě ABC Solutions
# Marie pracuje jako Designer ve firmě ABC Solutions
# Nyní pracují ve firmě XYZ Company
# ```
#
# ## Vysvětlení:
# Třídní atribut `firma` je sdílený mezi všemi instancemi třídy. Instance atributy (`jmeno`, `pozice`) jsou jednotlivé pro každou instanci. Změna třídního atributu ovlivní všechny instance.
#
# ---
#
# # 4. Název příkladu: Typy metod a property
# ## Co demonstruje:
# Instance, class a static metody, použití `@property`
#
# ## Kompletní kód:
# ```python
# class Teplota:
#     def __init__(self, celsius):
#         self._celsius = celsius  # Soukromý atribut
#
#     @property
#     def celsius(self):
#         return self._celsius
#
#     @celsius.setter
#     def celsius(self, hodnota):
#         if hodnota < -273.15:
#             raise ValueError("Teplota nemůže být nižší než -273.15 °C")
#         self._celsius = hodnota
#
#     @classmethod
#     def z_fahrenheit(cls, fahrenheit):
#         return cls((fahrenheit - 32) * 5/9)
#
#     @staticmethod
#     def popis():
#         return "Třída pro práci s teplotou"
#
# # Vytvoření instance
# t1 = Teplota(25)
# print(f"Teplota: {t1.celsius} °C")
#
# # Přístup přes property (setter)
# t1.celsius = 30
# print(f"Nastavená teplota: {t1.celsius} °C")
#
# # Použití class metody
# t2 = Teplota.z_fahrenheit(86)
# print(f"Teplota z Fahrenheitů: {t2.celsius:.1f} °C")
#
# # Statická metoda
# print(Teplota.popis())
# ```
#
# ## Očekávaný výstup:
# ```
# Teplota: 25 °C
# Nastavená teplota: 30 °C
# Teplota z Fahrenheitů: 30.0 °C
# Třída pro práci s teplotou
# ```
#
# ## Vysvětlení:
# - `@property` umožňuje přístup k atributu jako k metodě, ale bez závorek.
# - `@celsius.setter` umožňuje kontrolovat hodnoty nastavované do atributu.
# - `@classmethod` je metoda, která pracuje s třídou, nikoli s instancí.
# - `@staticmethod` je běžná funkce, která patří ke třídě, ale nemá přístup k instanci ani třídě.
#
# ---
#
# # 5. Název příkladu: Magic methods a encapsulation
# ## Co demonstruje:
# Použití magic methods (`__str__`, `__repr__`, `__eq__`), soukromé atributy a encapsulation
#
# ## Kompletní kód:
# ```python
# class Osoba:
#     def __init__(self, jmeno, vek):
#         self._jmeno = jmeno  # Soukromý atribut (konvence)
#         self._vek = vek      # Soukromý atribut
#
#     @property
#     def jmeno(self):
#         return self._jmeno
#
#     @jmeno.setter
#     def jmeno(self, hodnota):
#         if not isinstance(hodnota, str):
#             raise ValueError("Jméno musí být řetězec")
#         self._jmeno = hodnota
#
#     # Magic method pro čitelný výpis objektu
#     def __str__(self):
#         return f"Osoba: {self._jmeno}, Věk: {self._vek}"
#
#     # Magic method pro interní reprezentaci
#     def __repr__(self):
#         return f"Osoba('{self._jmeno}', {self._vek})"
#
#     # Porovnání dvou objektů
#     def __eq__(self, jina_osoba):
#         if isinstance(jina_osoba, Osoba):
#             return self._jmeno == jina_osoba._jmeno and self._vek == jina_osoba._vek
#         return False
#
# # Vytvoření instancí
# os1 = Osoba("Petr", 30)
# os2 = Osoba("Petr", 30)
# os3 = Osoba("Jana", 25)
#
# print(os1)          # Použije __str__
# print(repr(os1))    # Použije __repr__
# print(os1 == os2)   # Použije __eq__
# print(os1 == os3)
# ```
#
# ## Očekávaný výstup:
# ```
# Osoba: Petr, Věk: 30
# Osoba('Petr', 30)
# True
# False
# ```
#
# ## Vysvětlení:
# - `__str__` je použit pro čitelný výpis objektu (např. při `print(os1)`).
# - `__repr__` je použit pro interní reprezentaci objektu, často použitá v ladicích nástrojích.
# - `__eq__` umožňuje porovnávat objekty podle určitých kritérií (v tomto případě jméno a věk).
# - Soukromé atributy (`_jmeno`, `_vek`) jsou označeny podtržítkem, což je konvence pro "soukromé" atributy v Pythonu.

# %% [markdown]
# ## 🎯 Cvičení a úkoly
#
# <div style="background: #fff3e0; padding: 20px; border-left: 5px solid #ff9800; margin: 20px 0; border-radius: 5px;">
#     <h3 style="color: #2c3e50; margin-top: 0;">✍️ Praktická cvičení k procvičení</h3>
#     <p>Vyřešte následující úkoly. Začněte od jednoduššších a postupujte k složitějším.</p>
# </div>
#
# # Cvičení pro kapitolu: Objektově orientované programování I
#
# ---
#
# ## 1. **Název úkolu**: Vytvoření třídy Student a jejich správa v seznamu
#
# ### **Detailní zadání**
# Vytvořte třídu `Student` s atributy: jméno, příjmení, věk a průměrné známky. Implementujte metody pro:
# - nastavení a získání hodnot atributů,
# - výpočet průměru známek,
# - porovnání studentů podle průměru (metoda `compareTo`).
#
# Pak vytvořte třídu `StudentManager`, která bude spravovat seznam studentů a umožní jejich řazení podle průměru.
#
# ### **Vstupní data/požadavky**
# - Student má jméno (String), příjmení (String), věk (int) a pole známek (double[]).
# - Metoda `getAverage()` počítá průměr známek.
# - Třída `StudentManager` musí mít metodu `sortByAverage()`.
#
# ### **Očekávaný výstup**
# Výpis studentů seřazených podle průměru (od nejlepšího k nejhoršímu) a výpočet průměrů pro každého studenta.
#
# ### **Hints/Nápověda**
# 1. Použijte konstruktor pro inicializaci atributů třídy `Student`.
# 2. Implementujte metodu `compareTo()` podle průměru známek.
# 3. Použijte `Arrays.sort()` nebo `Collections.sort()` k řazení seznamu studentů.
# 4. V `StudentManager` vytvořte metodu, která přidá studenta do seznamu.
#
# ### **Kostra řešení**
# ```java
# class Student {
#     private String firstName;
#     private String lastName;
#     private int age;
#     private double[] grades;
#
#     // konstruktor, gettery, settery, getAverage()
# }
#
# class StudentManager {
#     private List<Student> students;
#
#     public void addStudent(Student student) { ... }
#     public void sortByAverage() { ... }
# }
# ```
#
# ### **Bonusové rozšíření**
# Přidejte metodu `getTopStudents(int n)` pro získání prvních N studentů podle průměru.
#
# ---
#
# ## 2. **Název úkolu**: Implementace jednoduchého bankovního systému
#
# ### **Detailní zadání**
# Vytvořte třídu `BankAccount` s atributy: číslo účtu, vlastník (String), stav konta (double). Přidejte metody:
# - `deposit(double amount)` – přidávání peněz,
# - `withdraw(double amount)` – odebírání peněz,
# - `getBalance()` – získání stavu konta.
#
# Použijte encapsulation, aby bylo možné nastavit jen platné hodnoty (např. negativní výběr nebo převod).
#
# ### **Vstupní data/požadavky**
# - Třída má číslo účtu jako String.
# - Metody `deposit` a `withdraw` kontrolují platnost operací.
#
# ### **Očekávaný výstup**
# Konzolový výpis po operacích (např. "Vklad 500 Kč, nový stav: 1500 Kč").
#
# ### **Hints/Nápověda**
# 1. Vložte kontrolu, že částka není záporná.
# 2. Implementujte metodu `withdraw`, která kontroluje, jestli je na účtu dostatek peněz.
# 3. Použijte `private` pro všechny atributy a poskytujte veřejné metody pro přístup.
# 4. Umožněte výpis stavu účtu po každé operaci.
#
# ### **Kostra řešení**
# ```java
# class BankAccount {
#     private String accountNumber;
#     private String owner;
#     private double balance;
#
#     public void deposit(double amount) { ... }
#     public boolean withdraw(double amount) { ... }
#     public double getBalance() { ... }
# }
# ```
#
# ### **Bonusové rozšíření**
# Přidejte třídu `Transaction` a logování transakcí do souboru.
#
# ---
#
# ## 3. **Název úkolu**: Vytvoření třídy Auto s vlastnostmi a chováním
#
# ### **Detailní zadání**
# Vytvořte třídu `Car` s atributy: značka, model, rok, barva, spotřeba (litry na 100 km) a aktuální palivo v litrech. Implementujte metody:
# - `drive(double distance)` – simulace jízdy,
# - `refuel(double liters)` – doplnění paliva,
# - `getRange()` – kolik kilometrů může auto ujet při aktuálním palivu.
#
# Použijte konstruktory a overloading.
#
# ### **Vstupní data/požadavky**
# - Třída má více konstruktorů (bezparametrický, s několika parametry).
# - Metoda `drive()` ovlivňuje palivo podle spotřeby.
# - `getRange()` vrací počet kilometrů, které auto může ujet.
#
# ### **Očekávaný výstup**
# Výpis aktuálního stavu auta a možnosti jízdy (např. "Auto má 30L paliva, může jet 450 km").
#
# ### **Hints/Nápověda**
# 1. V konstruktoru nastavte počáteční hodnoty.
# 2. Metoda `drive()` musí ovlivnit stav paliva podle ujeté vzdálenosti a spotřeby.
# 3. Kontrolujte, že počet kilometrů není záporný nebo překračuje dostupnou vzdálenost.
# 4. Vytvořte konstruktor bez parametrů a další s několika parametry.
#
# ### **Kostra řešení**
# ```java
# class Car {
#     private String brand;
#     private String model;
#     private int year;
#     private String color;
#     private double fuelConsumption;
#     private double currentFuel;
#
#     public Car() { ... }
#     public Car(String brand, String model) { ... }
#     public void drive(double distance) { ... }
#     public void refuel(double liters) { ... }
#     public double getRange() { ... }
# }
# ```
#
# ### **Bonusové rozšíření**
# Přidejte metodu `getFuelConsumptionPerKm()` a logování jízdy do souboru.
#
# ---
#
# ## 4. **Název úkolu**: Vytvoření třídy Person a jejich vztahy (dědičnost)
#
# ### **Detailní zadání**
# Vytvořte základní třídu `Person` s atributy: jméno, příjmení, věk. Dále vytvořte dvě odvozené třídy:
# - `Student` (má průměr známek),
# - `Teacher` (má předmět a počet hodin).
#
# Implementujte metodu `getInfo()` v každé třídě, která vrací detailní informace.
#
# ### **Vstupní data/požadavky**
# - Třída `Person` je abstraktní nebo má výchozí implementaci.
# - Dědičnost: `Student extends Person`, `Teacher extends Person`.
#
# ### **Očekávaný výstup**
# Výpis informací o lidích z různých tříd (např. "Student Jan Novák, průměr 2.5").
#
# ### **Hints/Nápověda**
# 1. Vytvořte konstruktor v rodičovské třídě a předávejte parametry dítěti.
# 2. Přepište metodu `getInfo()` pro každou odvozenou třídu.
# 3. Použijte `super()` pro volání konstruktoru

# %% [markdown]
# ## 📚 Další zdroje a materiály
#
# <div style="background: #e3f2fd; padding: 20px; border-left: 5px solid #2196f3; margin: 20px 0; border-radius: 5px;">
#     <h3 style="color: #2c3e50; margin-top: 0;">🔗 Doporučené materiály k dalšímu studiu</h3>
# </div>
#
# # Doporučené zdroje pro kapitolu: **Objektově orientované programování I**
#
# ---
#
# ## 📝 5 doporučených článků / tutoriálů
#
# 1. **[What is Object-Oriented Programming? (W3Schools)](https://www.w3schools.com/java/java_oop.asp)**
#    - **Popis:** Jednoduchý a přehledný úvod do OOP konceptů v jazyce Java. Vysvětluje základní pojmy jako třídy, objekty, dědičnost a zapouzdření.
#
# 2. **[Introduction to Object-Oriented Programming (GeeksforGeeks)](https://www.geeksforgeeks.org/object-oriented-programming-oop-in-java/)**
#    - **Popis:** Tento článek shrnuje základy OOP v jazyce Java, včetně konstruktorů, metod, polí a principů OOP. Velmi vhodné pro začátečníky.
#
# 3. **[Object-Oriented Programming in Python (Real Python)](https://realpython.com/python3-object-oriented-programming/)**
#    - **Popis:** Detailní průvodce OOP v Pythonu. Vysvětluje třídy, objekty, dědičnost, polymorfismus a abstrakci.
#
# 4. **[OOP Concepts Explained (Programiz)](https://www.programiz.com/java-programming/oops)**
#    - **Popis:** Tento tutoriál vysvětluje hlavní koncepty OOP včetně kapslování, dědičnosti, abstrakce a polymorfismu s příklady.
#
# 5. **[Understanding Object-Oriented Programming (Tutorialspoint)](https://www.tutorialspoint.com/java/java_oops_concepts.htm)**
#    - **Popis:** Přehledný tutoriál zaměřený na základní koncepty OOP v jazyce Java, ideální pro začátečníky.
#
# ---
#
# ## 🎥 3 doporučená YouTube videa
#
# 1. **[Object-Oriented Programming in Java - Full Course (CodeWithHarry)](https://www.youtube.com/watch?v=829ZD3wVd0Y)**
#    - **Délka:** 2 hodiny
#    - **Popis:** Komplexní kurz základů OOP v jazyce Java, včetně tříd, objektů, dědičnosti a polymorfismu.
#
# 2. **[Object-Oriented Programming in Python (Programming with Mosh)](https://www.youtube.com/watch?v=ZDa-Z5JzLYM)**
#    - **Délka:** 1 hodina
#    - **Popis:** Úvod do OOP v Pythonu, vysvětlení konceptů tříd a objektů, zapouzdření a dědičnosti.
#
# 3. **[OOP in C++ - Full Tutorial for Beginners (freeCodeCamp)](https://www.youtube.com/watch?v=vLnPwxZdW4Y)**
#    - **Délka:** 1 hodina
#    - **Popis:** Přehledný úvod do OOP v jazyce C++, včetně tříd, konstruktorů a destruktorů.
#
# ---
#
# ## 📚 3 knihy / oficiální dokumentace
#
# 1. **[Java™ Platform, Standard Edition 8 Documentation - Oracle](https://docs.oracle.com/javase/8/docs/)**
#    - **Popis:** Oficiální dokumentace pro Javu 8 s detailním vysvětlením konceptů OOP jako jsou třídy, objekty a dědičnost.
#
# 2. **[Python Documentation - Object-Oriented Programming](https://docs.python.org/3/tutorial/classes.html)**
#    - **Popis:** Oficiální výuková část dokumentace k Pythonu zaměřená na třídy, objekty a OOP koncepty.
#
# 3. **[Head First Java – Kathy Sierra & Bert Bates](https://www.oreilly.com/library/view/head-first-java/0596009279/)**
#    -

# %% [markdown]
# ## 📝 Shrnutí kapitoly
#
# <div style="background: linear-gradient(135deg, #667eea 0%, #764ba2 100%); padding: 30px; border-radius: 10px; color: white; margin: 30px 0;">
#     <h3 style="color: white; margin-top: 0;">✅ Co jste se naučili</h3>
#     <ul style="list-style: none; padding-left: 0;">
#         <li>✓ Třídy a objekty</li>
# <li>✓ Konstruktor __init__ a destruktor __del__</li>
# <li>✓ Instance vs. class attributes</li>
# <li>✓ Methods: instance, class, static</li>
# <li>✓ Properties a property decorator</li>
#     </ul>
#
#     <h3 style="color: white;">🎯 Klíčové dovednosti</h3>
#     <p>Po dokončení této kapitoly byste měli být schopni prakticky použít všechny probrané koncepty.</p>
#
#     <h3 style='color: white;'>➡️ Další kapitola</h3><p>Kapitola 12 - pokračujte ve studiu!</p>
# </div>
#
# ---
#
# *📅 Notebook vygenerován: 2025-09-29 12:09:53*
# *🤖 Generátor: Comprehensive Colab Generator v2.0*
# *📚 Učebnice programování - Od základů k AI*

# %% [markdown]
# ## 🧪 Sandbox - Prostor pro experimenty
#
# Použijte následující buňky pro vlastní experimenty a testování:

# %%
# 🧪 Zde můžete experimentovat s kódem z kapitoly
# Napište svůj kód zde:
