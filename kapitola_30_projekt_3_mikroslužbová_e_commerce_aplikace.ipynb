# %% [markdown]
# # 📚 Kapitola 30: Projekt 3 - Mikroslužbová e-commerce aplikace
#
# <div style="background: linear-gradient(90deg, #667eea 0%, #764ba2 100%); padding: 20px; border-radius: 10px; margin: 20px 0;">
#     <h2 style="color: white; margin: 0;">Blok 3 | ADVANCED</h2>
#     <p style="color: white; margin: 10px 0;">🎯 PROJEKT</p>
# </div>
#
# ## 🎯 Co se naučíte
#
# V této kapitole se zaměříme na následující témata:
#
# - **Microservices design**
# - **User service implementation**
# - **Product catalog service**
# - **Order management service**
# - **Payment integration**
# - **API Gateway setup**
# - **Docker Compose orchestration**
#
# ## ⚠️ Předpoklady
# Tato kapitola navazuje na kapitoly: 21, 22, 23, 24, 25, 26, 27, 28, 29
#
# ---

# %%
# ⚙️ Inicializace prostředí
# Tento kód nastavuje prostředí pro kapitolu 30

import sys
import os
from datetime import datetime

# Informace o prostředí
print("=" * 60)
print(f"📚 KAPITOLA 30: Projekt 3 - Mikroslužbová e-commerce aplikace")
print("=" * 60)
print(f"🐍 Python verze: {sys.version}")
print(f"📅 Datum spuštění: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
print(f"💻 OS: {os.name}")
print(f"📁 Pracovní adresář: {os.getcwd()}")
print("=" * 60)

# Instalace potřebných knihoven (odkomentujte podle potřeby)
# !pip install requests pandas numpy matplotlib
# !pip install beautifulsoup4 sqlalchemy fastapi

# Import základních knihoven
import json
import csv
import time
import random
from pathlib import Path
from typing import List, Dict, Optional, Any

print("✅ Prostředí připraveno!")

# %% [markdown]
# ## 📖 Teoretická část
#
# <div style="background: #f0f4ff; padding: 20px; border-left: 5px solid #4a69bd; margin: 20px 0; border-radius: 5px;">
#     <h3 style="color: #2c3e50; margin-top: 0;">🎓 Základní teorie a koncepty</h3>
# </div>
#
# # Projekt 3 - Mikroslužbová e-commerce aplikace
#
# ## 1. Úvod a motivace
#
# Mikroslužby (microservices) představují moderní přístup k vývoji softwarových aplikací, který se stává nejrozšířenějším řešením pro velké a komplexní systémy. V praxi se mikroslužby používají například u společností jako jsou Amazon, Netflix nebo Uber, kde je potřeba zvládat obrovské množství požadavků a zároveň umožnit rychlý vývoj a údržbu systému.
#
# V tomto projektu se zaměříme na vytvoření e-commerce aplikace postavené na mikroslužbách, což je skvělý příklad toho, jak funguje reálná architektura v praxi. Student se naučí základy návrhu mikroslužeb, komunikaci mezi službami, orchestraci kontejnerů a řešení typických problémů při tvorbě rozšiřitelného systému.
#
# Tento projekt je nezbytný pro každého, kdo se chce naučit vytvářet škálovatelné a udržovatelné aplikace, které jsou schopné růst spolu s obchodním potřebami.
#
# ---
#
# ## 2. Hlavní koncepty
#
# ### Microservices design
#
# Mikroslužby jsou architektonický styl, kdy se složitá aplikace rozdělí na menší, samostatné služby, které komunikují mezi sebou přes API. Každá služba má svůj vlastní datový model a je zodpovědná za jednu konkrétní funkcionalitu.
#
# Výhody mikroslužeb:
# - **Skalovatelnost** – každou službu lze škálovat nezávisle
# - **Technologická nezávislost** – každá služba může být napsaná v jiném jazyce
# - **Jednodušší údržba** – menší kusy kódu jsou snazší na ladění a úpravy
#
# Nevýhody:
# - **Komplexita distribuce** – potřeba spravovat komunikaci mezi službami
# - **Zvýšené nároky na infrastrukturu**
#
# ### User service implementation
#
# Uživatelská služba je zodpovědná za správu uživatelských účtů. Zahrnuje:
# - Registraci a přihlašování
# - Správu profilu
# - Ověřování identity (např. pomocí JWT tokenů)
#
# Příklad jednoduchého endpointu:
#
# ```http
# POST /api/users/register
# {
#   "username": "janNovak",
#   "email": "jan.novak@example.com",
#   "password": "heslo123"
# }
# ```
#
# ### Product catalog service
#
# Tato služba spravuje katalog produktů, včetně informací o jejich popisu, cenách a dostupnosti.
#
# Typické endpointy:
# - `GET /api/products` – získání seznamu produktů
# - `POST /api/products` – přidání nového produktu
#
# Příklad datové struktury:
#
# ```json
# {
#   "id": 1,
#   "name": "Smartfon XYZ",
#   "description": "Moderní smartphone s vysokou kvalitou obrazu",
#   "price": 2999.99,
#   "stock": 50
# }
# ```
#
# ### Order management service
#
# Tato služba zajišťuje správu objednávek – od vytvoření až po dokončení.
#
# Příklad struktury objednávky:
#
# ```json
# {
#   "orderId": "ORD001",
#   "userId": 1,
#   "items": [
#     {
#       "productId": 1,
#       "quantity": 2,
#       "price": 2999.99
#     }
#   ],
#   "totalAmount": 5999.98,
#   "status": "created"
# }
# ```
#
# ### Payment integration
#
# Platební služba zajišťuje bezpečné zpracování plateb. Může být napojena na externí poskytovatele (např. Stripe, PayPal) nebo implementována interně.
#
# Příklad API pro platbu:
#
# ```http
# POST /api/payment/process
# {
#   "orderId": "ORD001",
#   "paymentMethod": "credit_card",
#   "cardNumber": "4242424242424242",
#   "cvv": "123"
# }
# ```
#
# ### API Gateway setup
#
# API gateway je centrální bod, skrze který všechny požadavky přicházejí do systému. Slouží jako brána mezi klienty a mikroslužbami.
#
# Funkce:
# - Autentizace
# - Routování požadavků
# - Load balancing
# - Monitorování
#
# Příklad nastavení v Nginx:
#
# ```nginx
# location /api/ {
#     proxy_pass http://user-service:8080/;
# }
# ```
#
# ### Docker Compose orchestration
#
# Docker Compose umožňuje snadné nasazování více kontejnerů společně. Vytváříme `docker-compose.yml` s definicí každé služby a jejich interakce.
#
# Příklad základního `docker-compose.yml`:
#
# ```yaml
# version: '3'
# services:
#   user-service:
#     image: user-service:latest
#     ports:
#       - "8081:8080"
#   product-service:
#     image: product-service:latest
#     ports:
#       - "8082:8080"
# ```
#
# ---
#
# ## 3. Důležité detaily
#
# ### Časté chyby a jak se jim vyhnout
#
# - **Nedostatečná komunikace mezi službami** – používejte jasné API specifikace (např. OpenAPI)
# - **Ztráta dat při selhání služby** – implementujte robustní mechanismy pro zálohování a logování
# - **Nesprávné škálování** – každá služba by měla být navržena tak, aby se dala snadno škálovat
#
# ### Best practices
#
# - Používejte kontejnery pro izolaci služeb
# - Implementujte monitorování a logování (např. Prometheus + Grafana)
# - Při komunikaci mezi službami používejte asynchronní způsoby (např. message queues)
#
# ### Performance tipy
#
# - Využívejte cacheování (např. Redis) pro častěji čtené data
# - Implementujte limitaci požadavků (rate limiting)
# - Zajišťujte efektivní databázové dotazy a indexování
#
# ---
#
# ## 4. Propojení s předchozími kapitolami
#
# Tento projekt využívá znalosti z předchozích kapitol jako jsou:
# - **Základy Dockeru** – pro nasazení služeb
# - **REST API** – pro komunikaci mezi klientem a serverem
# - **Databáze** – pro ukládání dat v jednotlivých službách
#
# Tento projekt rozšiřuje již naučené dovednosti tím, že převádí teorii o mikroslužbách na praxi a ukazuje, jak se všechny komponenty propojují do jedné celkové aplikace.
#
# ---
#
# Tento projekt je ideální pro studenty, kteří chtějí získat praktické zkušenosti s mikroslužbami a připravit se na komplexní vývojové projekty v reálném prostředí.

# %% [markdown]
# ## 💻 Praktické příklady
#
# <div style="background: #e8f5e9; padding: 20px; border-left: 5px solid #4caf50; margin: 20px 0; border-radius: 5px;">
#     <h3 style="color: #2c3e50; margin-top: 0;">👨‍💻 Hands-on příklady ke spuštění</h3>
#     <p>Následující příklady si můžete hned vyzkoušet. Každý příklad je samostatně spustitelný.</p>
# </div>

# %% [markdown]
# ### Příklad 1
#
# Příklad 1: Základní struktura mikroslužby "User Service"

# %% [markdown]
# ### Příklad 2
#
# ### Co demonstruje:
# Tento příklad ukazuje základní strukturu mikroslužby pro správu uživatelů s jednoduchým REST API.
#
# ```python
# # user_service.py
# """

# %% [markdown]
# ### Příklad 3
#
# Příklad 1: Základní struktura mikroslužby User Service
# Demonstruje základní HTTP endpointy pro práci s uživateli
# """
#
# from flask import Flask, jsonify, request
# import uuid
#
# app = Flask(__name__)
#
# # In-memory databáze uživatelů (v reálné aplikaci by to byla skutečná databáze)
# users_db = {}
#
# @app.route('/users', methods=['POST'])
# def create_user():
#     """Vytvoření nového uživatele"""
#     data = request.get_json()
#
#     # Vytvoříme unikátní ID pro uživatele
#     user_id = str(uuid.uuid4())
#
#     # Uložíme uživatele do databáze
#     users_db[user_id] = {
#         'id': user_id,
#         'name': data.get('name'),
#         'email': data.get('email'),
#         'created_at': '2023-01-01'
#     }
#
#     return jsonify(users_db[user_id]), 201
#
# @app.route('/users/<user_id>', methods=['GET'])
# def get_user(user_id):
#     """Získání informací o uživateli"""
#     user = users_db.get(user_id)
#     if user:
#         return jsonify(user)
#     else:
#         return jsonify({'error': 'Uživatel nenalezen'}), 404
#
# @app.route('/users', methods=['GET'])
# def list_users():
#     """Seznam všech uživatelů"""
#     return jsonify(list(users_db.values()))
#
# # Spuštění serveru
# if __name__ == '__main__':
#     app.run(host='0.0.0.0', port=5001, debug=True)
# ```

# %% [markdown]
# ### Příklad 4
#
# ### Očekávaný výstup:
# - Server běží na portu 5001
# - Přijímá HTTP požadavky na endpointy /users
# - Vrací JSON odpovědi

# %% [markdown]
# ### Příklad 5
#
# ### Vysvětlení:
# Tento kód vytváří jednoduchou mikroslužbu pro správu uživatelů pomocí Flasku. Obsahuje tři hlavní endpointy:
# 1. POST /users - pro vytvoření nového uživatele
# 2. GET /users/<id> - pro získání informací o konkrétním uživateli
# 3. GET /users - pro získání seznamu všech uživatelů
#
# Všechny operace pracují s in-memory databází (simulace databáze).
#
# ---
#
# ##

# %% [markdown]
# ### Příklad 6
#
# Příklad 2: Implementace služby katalogu produktů

# %% [markdown]
# ### Příklad 7
#
# ### Co demonstruje:
# Tento příklad ukazuje implementaci služby pro správu katalogu produktů s funkcemi pro přidání, čtení a vyhledávání produktů.
#
# ```python
# # product_catalog_service.py
# """

# %% [markdown]
# ### Příklad 8
#
# Příklad 2: Implementace služby katalogu produktů
# Demonstruje základní CRUD operace pro produkty
# """
#
# from flask import Flask, jsonify, request
# import uuid
#
# app = Flask(__name__)
#
# # In-memory databáze produktů
# products_db = {}
#
# @app.route('/products', methods=['POST'])
# def create_product():
#     """Vytvoření nového produktu"""
#     data = request.get_json()
#
#     product_id = str(uuid.uuid4())
#
#     products_db[product_id] = {
#         'id': product_id,
#         'name': data.get('name'),
#         'description': data.get('description'),
#         'price': data.get('price'),
#         'category': data.get('category'),
#         'stock': data.get('stock', 0),
#         'created_at': '2023-01-01'
#     }
#
#     return jsonify(products_db[product_id]), 201
#
# @app.route('/products/<product_id>', methods=['GET'])
# def get_product(product_id):
#     """Získání informací o produktu"""
#     product = products_db.get(product_id)
#     if product:
#         return jsonify(product)
#     else:
#         return jsonify({'error': 'Produkt nenalezen'}), 404
#
# @app.route('/products', methods=['GET'])
# def list_products():
#     """Seznam všech produktů"""
#     # Možnost filtrování podle kategorie
#     category = request.args.get('category')
#
#     if category:
#         filtered_products = [p for p in products_db.values() if p['category'] == category]
#         return jsonify(filtered_products)
#
#     return jsonify(list(products_db.values()))
#
# @app.route('/products/search', methods=['GET'])
# def search_products():
#     """Vyhledávání produktů podle jména"""
#     query = request.args.get('q')
#     if not query:
#         return jsonify({'error': 'Nebyl zadán hledaný výraz'}), 400
#
#     results = [p for p in products_db.values()
#                if query.lower() in p['name'].lower()]
#
#     return jsonify(results)
#
# if __name__ == '__main__':
#     # Přidáme nějaké testovací produkty
#     test_products = [
#         {'name': 'Laptop', 'description': 'Přenosný počítač', 'price': 15000, 'category': 'Elektronika', 'stock': 5},
#         {'name': 'Knížka', 'description': 'Učebnice', 'price': 300, 'category': 'Kniha', 'stock': 20}
#     ]
#
#     for product in test_products:
#         data = request.get_json()
#         data = product
#         product_id = str(uuid.uuid4())
#         products_db[product_id] = {
#             'id': product_id,
#             'name': product['name'],
#             'description': product['description'],
#             'price': product['price'],
#             'category': product['category'],
#             'stock': product['stock'],
#             'created_at': '2023-01-01'
#         }
#
#     app.run(host='0.0.0.0', port=5002, debug=True)
# ```

# %% [markdown]
# ### Příklad 9
#
# ### Očekávaný výstup:
# - Server běží na portu 5002
# - Návratové hodnoty ve formátu JSON
# - Podpora filtrů a vyhledávání

# %% [markdown]
# ### Příklad 10
#
# ### Vysvětlení:
# Tento kód implementuje službu katalogu produktů s funkcemi:
# 1. Vytvoření produktu (POST /products)
# 2. Získání konkrétního produktu (GET /products/<id>)
# 3. Seznam produktů (GET /products) - s možností filtrování podle kategorie
# 4. Vyhledávání produktů (GET /products/search)
#
# ---
#
# ##

# %% [markdown]
# ### Příklad 11
#
# Příklad 3: Služba pro správu objednávek

# %% [markdown]
# ### Příklad 12
#
# ### Co demonstruje:
# Tento příklad ukazuje implementaci služby pro správu objednávek s integrací uživatelských a produktových dat.
#
# ```python
# # order_management_service.py
# """

# %% [markdown]
# ### Příklad 13
#
# Příklad 3: Služba pro správu objednávek
# Demonstruje základní funkce pro správu objednávek mezi uživateli a produkty
# """
#
# from flask import Flask, jsonify, request
# import uuid
# from datetime import datetime
#
# app = Flask(__name__)
#
# # Simulace databází
# users_db = {
#     "1": {"id": "1", "name": "Jan Novák", "email": "jan@novak.cz"},
#     "2": {"id": "2", "name": "Petr Svoboda", "email": "petr@svoboda.cz"}
# }
#
# products_db = {
#     "101": {"id": "101", "name": "Laptop", "price": 15000, "stock": 5},
#     "102": {"id": "102", "name": "Knížka", "price": 300, "stock": 20}
# }
#
# orders_db = {}
#
# @app.route('/orders', methods=['POST'])
# def create_order():
#     """Vytvoření nové objednávky"""
#     data = request.get_json()
#
#     # Validace dat
#     if not data.get('user_id') or not data.get('items'):
#         return jsonify({'error': 'Chybějící parametry'}), 400
#
#     # Kontrola existence uživatele
#     user = users_db.get(data['user_id'])
#     if not user:
#         return jsonify({'error': 'Uživatel nenalezen'}), 404
#
#     order_id = str(uuid.uuid4())
#
#     # Výpočet celkové ceny
#     total_price = 0
#     order_items = []
#
#     for item in data['items']:
#         product_id = item['product_id']
#         quantity = item['quantity']
#
#         product = products_db.get(product_id)
#         if not product:
#             return jsonify({'error': f'Produkt {product_id} nenalezen'}), 404
#
#         if product['stock'] < quantity:
#             return jsonify({'error': f'Nedostatek zásob pro produkt {product["name"]}'}), 400
#
#         item_price = product['price'] * quantity
#         total_price += item_price
#
#         order_items.append({
#             'product_id': product_id,
#             'product_name': product['name'],
#             'quantity': quantity,
#             'price': product['price'],
#             'total': item_price
#         })
#
#     # Vytvoření objednávky
#     order = {
#         'id': order_id,
#         'user_id': data['user_id'],
#         'user_name': user['name'],
#         'items': order_items,
#         'total_price': total_price,
#         'status': 'created',
#         'created_at': datetime.now().isoformat()
#     }
#
#     orders_db[order_id] = order
#
#     return jsonify(order), 201
#
# @app.route('/orders/<order_id>', methods=['GET'])
# def get_order(order_id):
#     """Získání informací o objednávce"""
#     order = orders_db.get(order_id)
#     if order:
#         return jsonify(order)
#     else:
#         return jsonify({'error': 'Objednávka nenalezena'}), 404
#
# @app.route('/orders/user/<user_id

# %% [markdown]
# ## 🎯 Cvičení a úkoly
#
# <div style="background: #fff3e0; padding: 20px; border-left: 5px solid #ff9800; margin: 20px 0; border-radius: 5px;">
#     <h3 style="color: #2c3e50; margin-top: 0;">✍️ Praktická cvičení k procvičení</h3>
#     <p>Vyřešte následující úkoly. Začněte od jednoduššších a postupujte k složitějším.</p>
# </div>
#
# # Projekt 3 - Mikroslužbová e-commerce aplikace – 5 praktických cvičení
#
# ---
#
# ## Cvičení 1: **Návrh a implementace API Gateway pro mikroslužby**
#
# ### 1. **Název úkolu**
# Návrh a implementace API Gateway pro mikroslužby e-commerce aplikace
#
# ### 2. **Detailní zadání**
# Student si vytvoří jednoduchou implementaci API Gateway, která bude směrovat požadavky mezi klientem (např. front-end) a mikroslužbami (např. products, users, orders). Cílem je zajistit správné směrování, autentizaci a logování.
#
# ### 3. **Vstupní data/požadavky**
# - Vytvořené mikroslužby: `products`, `users`, `orders`
# - Frontend aplikace (může být simulace pomocí Postman nebo curl)
# - Základní konfigurační soubor pro směrování API
#
# ### 4. **Očekávaný výstup**
# Implementovaná API Gateway, která:
# - Směruje požadavky na správné mikroslužby
# - Loguje příchozí požadavky
# - Zajišťuje základní ochranu proti neoprávněným požadavkům
#
# ### 5. **Hints/Nápověda**
# 1. Použijte nástroj jako Express.js nebo Kong, který podporuje API Gateway.
# 2. Nastavte směrování pro `/api/products`, `/api/users` a `/api/orders`.
# 3. Implementujte logování vstupních požadavků pomocí middleware.
# 4. Přidejte základní kontrolu tokenu (např. Bearer token) před směrováním.
#
# ### 6. **Kostra řešení**
# ```javascript
# // app.js
# const express = require('express');
# const app = express();
#
# app.use(express.json());
#
# // Middleware pro logování
# app.use((req, res, next) => {
#     console.log(`[${new Date().toISOString()}] ${req.method} ${req.url}`);
#     next();
# });
#
# // Směrování podle endpointu
# app.use('/api/products', require('./routes/products'));
# app.use('/api/users', require('./routes/users'));
# app.use('/api/orders', require('./routes/orders'));
#
# app.listen(3000, () => {
#     console.log('API Gateway naslouchá na portu 3000');
# });
# ```
#
# ### 7. **Bonusové rozšíření**
# - Implementujte autentizaci pomocí JWT.
# - Přidejte možnost přidání rate-limitingu (např. pomocí express-rate-limit).
#
# ---
#
# ## Cvičení 2: **Implementace mikroslužby pro správu produktů**
#
# ### 1. **Název úkolu**
# Implementace mikroslužby „products“ s REST API
#
# ### 2. **Detailní zadání**
# Student vytvoří mikroslužbu `products`, která bude obsahovat základní CRUD operace nad produkty. Použijte technologii Node.js + Express a uložení dat do souboru (např. JSON) nebo do databáze (např. MongoDB).
#
# ### 3. **Vstupní data/požadavky**
# - Vstupní požadavky pro GET, POST, PUT, DELETE operace
# - Produkty ve formátu:
#   ```json
#   {
#     "id": "1",
#     "name": "Laptop",
#     "price": 999.99,
#     "category": "Electronics"
#   }
#   ```
#
# ### 4. **Očekávaný výstup**
# - REST API endpointy pro:
#   - `GET /products` – seznam produktů
#   - `GET /products/:id` – detail produktu
#   - `POST /products` – přidání nového produktu
#   - `PUT /products/:id` – aktualizace produktu
#   - `DELETE /products/:id` – smazání produktu
#
# ### 5. **Hints/Nápověda**
# 1. Použijte Express.js a definujte routy pro každou CRUD operaci.
# 2. Implementujte validaci vstupních dat pomocí Joi nebo express-validator.
# 3. Ukládejte data do JSON souboru (můžeš použít `fs` modul).
# 4. Vraťte správné HTTP status kódy (např. 200, 201, 404).
#
# ### 6. **Kostra řešení**
# ```javascript
# const express = require('express');
# const app = express();
# app.use(express.json());
#
# let products = [];
#
# // GET /products
# app.get('/products', (req, res) => {
#     res.json(products);
# });
#
# // POST /products
# app.post('/products', (req, res) => {
#     const product = { id: Date.now().toString(), ...req.body };
#     products.push(product);
#     res.status(201).json(product);
# });
#
# app.listen(3001, () => {
#     console.log('Products microservice naslouchá na portu 3001');
# });
# ```
#
# ### 7. **Bonusové rozšíření**
# - Implementujte databázi (např. MongoDB) místo souborového uložení.
# - Přidejte stránkování a filtrování produktů.
#
# ---
#
# ## Cvičení 3: **Zabezpečení mikroslužeb pomocí JWT**
#
# ### 1. **Název úkolu**
# Implementace autentizace a autorizace pomocí JWT v mikroslužbách
#
# ### 2. **Detailní zadání**
# Student implementuje systém zabezpečení mezi mikroslužbami, který používá JWT tokény pro autentizaci uživatelů. Zajistěte ochranu endpointů v mikroslužbách `users` a `orders`.
#
# ### 3. **Vstupní data/požadavky**
# - Uživatel se přihlásí pomocí endpointu `/login`
# - Po úspěšném přihlášení dostane JWT token
# - Všechny citlivé endpointy musí vyžadovat validní token
#
# ### 4. **Očekávaný výstup**
# - REST API, které:
#   - Vyžaduje JWT token pro přístup k citlivým endpointům
#   - Při neplatném tokenu vrací 401 chybu
#
# ### 5. **Hints/Nápověda**
# 1. Použijte `jsonwebtoken` knihovnu pro generování a ověřování JWT.
# 2. Implementujte middleware, který kontroluje přítomnost a platnost tokenu.
# 3. Vytvořte endpoint `/login`, který ověří uživatele a vrátí token.
# 4. Přidejte ochranu pro všechny citlivé endpointy pomocí middleware.
#
# ### 6. **Kostra řešení**
# ```javascript
# const jwt = require('jsonwebtoken');
#
# // Middleware pro ověření tokenu
# const authenticateToken = (req, res, next) => {
#     const authHeader = req.headers['authorization'];
#     const token = authHeader && authHeader.split(' ')[1];
#
#     if (!token) return res.sendStatus(401);
#
#     jwt.verify(token, 'secret-key', (err, user) => {
#         if (err) return res.sendStatus(403);
#         req.user = user;
#         next();
#     });
# };
#
# // Endpoint /login
# app.post('/login', (req, res) => {
#     const user = { id: 1, username: req.body.username };
#     const token = jwt.sign(user, 'secret-key');
#     res.json({ token });
# });
#
# // Chráněný endpoint
# app.get('/profile', authenticateToken, (req, res) => {
#     res.json(req.user);
# });
# ```
#
# ### 7. **Bonusové rozšíření**
# - Implementujte refresh tokenu.
# - Použijte Redis pro správu živých tokenů.
#
# ---
#
# ## Cvičení 4: **Integrace mikroslužeb pomocí message queue**
#
# ### 1. **Název úkolu**
# Implementace komunikace mezi mikro

# %% [markdown]
# ## 🚀 Kompletní řešení projektu
#
# <div style="background: #f3e5f5; padding: 20px; border-left: 5px solid #9c27b0; margin: 20px 0; border-radius: 5px;">
#     <h3 style="color: #2c3e50; margin-top: 0;">💡 Referenční implementace</h3>
#     <p>Zde je kompletní řešení projektu. Použijte ho jako referenci nebo inspiraci.</p>
# </div>
#
# # Mikroslužbová e-commerce aplikace
#
# ## 1. Kompletní struktura projektu
#
# ```
# ecommerce-microservices/
# ├── src/
# │   ├── main.py
# │   ├── models/
# │   │   ├── __init__.py
# │   │   ├── product.py
# │   │   └── order.py
# │   ├── services/
# │   │   ├── __init__.py
# │   │   ├── product_service.py
# │   │   ├── order_service.py
# │   │   └── payment_service.py
# │   ├── api/
# │   │   ├── __init__.py
# │   │   ├── product_routes.py
# │   │   ├── order_routes.py
# │   │   └── health_check.py
# │   ├── utils/
# │   │   ├── __init__.py
# │   │   ├── database.py
# │   │   └── logger.py
# │   └── config/
# │       ├── __init__.py
# │       └── settings.py
# ├── tests/
# │   ├── test_product_service.py
# │   ├── test_order_service.py
# │   ├── test_payment_service.py
# │   ├── test_product_routes.py
# │   └── test_health_check.py
# ├── requirements.txt
# ├── Dockerfile
# ├── docker-compose.yml
# ├── README.md
# └── .gitignore
# ```
#
# ## 2. Hlavní soubor s kódem (main.py) - 200+ řádků
#
# ```python
# #!/usr/bin/env python3
# """
# Mikroslužbová e-commerce aplikace
# """
#
# import asyncio
# import logging
# from contextlib import asynccontextmanager
# from typing import Dict, Any
# from fastapi import FastAPI, HTTPException, status
# from fastapi.middleware.cors import CORSMiddleware
# from pydantic import BaseModel
# import uvicorn
#
# # Import modulů
# from src.models.product import Product, ProductCreate, ProductUpdate
# from src.models.order import Order, OrderCreate
# from src.services.product_service import ProductService
# from src.services.order_service import OrderService
# from src.services.payment_service import PaymentService
# from src.api.product_routes import router as product_router
# from src.api.order_routes import router as order_router
# from src.api.health_check import router as health_router
# from src.utils.database import get_db_connection, init_db
# from src.utils.logger import setup_logger
#
# # Nastavení logování
# logger = setup_logger(__name__)
#
# # Inicializace FastAPI aplikace
# app = FastAPI(
#     title="E-commerce Mikroslužby",
#     description="Mikroslužbová e-commerce platforma pro správu produktů a objednávek",
#     version="1.0.0"
# )
#
# # Přidání middleware pro CORS
# app.add_middleware(
#     CORSMiddleware,
#     allow_origins=["*"],
#     allow_credentials=True,
#     allow_methods=["*"],
#     allow_headers=["*"],
# )
#
# # Globální instance služeb
# product_service = None
# order_service = None
# payment_service = None
#
# @asynccontextmanager
# async def lifespan(app: FastAPI):
#     """
#     Lifecycle management pro aplikaci
#     """
#     global product_service, order_service, payment_service
#
#     logger.info("Inicializace mikroslužeb...")
#
#     try:
#         # Inicializace databáze
#         await init_db()
#         logger.info("Databáze inicializována")
#
#         # Inicializace služeb
#         product_service = ProductService()
#         order_service = OrderService()
#         payment_service = PaymentService()
#
#         logger.info("Všechny služby inicializovány")
#
#         yield
#
#     except Exception as e:
#         logger.error(f"Chyba při inicializaci: {str(e)}")
#         raise
#     finally:
#         # Uvolnění zdrojů (pokud by bylo potřeba)
#         logger.info("Uvolňování zdrojů...")
#
# # Přidání routerů
# app.include_router(product_router, prefix="/api/products", tags=["Products"])
# app.include_router(order_router, prefix="/api/orders", tags=["Orders"])
# app.include_router(health_router, prefix="/health", tags=["Health"])
#
# @app.get("/", response_model=Dict[str, Any])
# async def root():
#     """
#     Kořenový endpoint aplikace
#     """
#     return {
#         "message": "Vítejte v mikroslužbové e-commerce platformě",
#         "version": "1.0.0",
#         "status": "running"
#     }
#
# @app.get("/health")
# async def health_check():
#     """
#     Health check endpoint
#     """
#     return {
#         "status": "healthy",
#         "services": {
#             "product_service": product_service is not None,
#             "order_service": order_service is not None,
#             "payment_service": payment_service is not None
#         }
#     }
#
# @app.get("/metrics")
# async def metrics():
#     """
#     Metriky aplikace
#     """
#     return {
#         "status": "available",
#         "timestamp": asyncio.get_event_loop().time(),
#         "services_count": 3,
#         "endpoints_count": len(app.routes)
#     }
#
# # Error handling
# @app.exception_handler(Exception)
# async def global_exception_handler(request, exc):
#     """
#     Globální exception handler pro všechny nezachycené chyby
#     """
#     logger.error(f"Neošetřená chyba: {str(exc)}")
#     return JSONResponse(
#         status_code=500,
#         content={"detail": "Interní chyba serveru"}
#     )
#
# # Příklad vlastního error handleru pro HTTPException
# @app.exception_handler(HTTPException)
# async def http_exception_handler(request, exc):
#     """
#     Vlastní handler pro HTTP výjimky
#     """
#     logger.warning(f"HTTP chyba {exc.status_code}: {exc.detail}")
#     return JSONResponse(
#         status_code=exc.status_code,
#         content={"detail": exc.detail}
#     )
#
# # Hlavní spuštění aplikace
# if __name__ == "__main__":
#     # Spuštění serveru
#     logger.info("Spouštím mikroslužbovou aplikaci...")
#
#     try:
#         uvicorn.run(
#             "src.main:app",
#             host="0.0.0.0",
#             port=8000,
#             log_level="info",
#             reload=True
#         )
#         logger.info("Aplikace spuštěna")
#     except Exception as e:
#         logger.error(f"Chyba při spouštění aplikace: {str(e)}")
#         raise
# ```
#
# ## 3. Pomocné moduly
#
# ### models/product.py
# ```python
# from pydantic import BaseModel, Field
# from typing import Optional
# from datetime import datetime
#
# class ProductBase(BaseModel):
#     name: str = Field(..., min_length=1, max_length=255)
#     description: Optional[str] = None
#     price: float = Field(..., gt=0)
#     stock_quantity: int = Field(..., ge=0)
#
# class ProductCreate(ProductBase):
#     category: str = Field(..., min_length=1, max_length=100)
#
# class ProductUpdate(ProductBase):
#     name: Optional[str] = None
#     description: Optional[str] = None
#     price: Optional[float] = None
#     stock_quantity: Optional[int] = None
#     category: Optional[str] = None
#
# class Product(ProductBase):
#     id: int
#     category: str
#     created_at: datetime
#     updated_at: datetime
#
#     class Config:
#         from_attributes = True
# ```
#
# ### models/order.py
# ```python
# from pydantic import BaseModel, Field
# from typing import List, Optional
# from datetime import datetime
#
# class OrderItem(BaseModel):
#     product_id: int
#     quantity: int = Field(..., gt=0)
#     price: float = Field(..., gt=0)
#
# class OrderCreate(BaseModel):
#     customer_name: str = Field(..., min_length=1, max_length=255)
#     customer_email: str = Field(..., pattern=r'^[^@]+@[^@]+\.[^@]+$')
#     items: List[OrderItem] = Field(..., min_items=1)
#     shipping_address: str = Field(..., min_length=1)
#
# class Order(OrderCreate):
#     id: int
#     total_amount: float = Field(..., gt=0)
#     status: str = "pending"
#     created_at: datetime
#     updated_at: datetime
#
#     class Config:
#         from_attributes = True
# ```
#
# ### services/product_service.py
# ```python
# import logging
# from typing import List, Optional
# from sqlalchemy.orm import Session
# from sqlalchemy.exc import SQLAlchemyError
# from src.models.product import Product, ProductCreate, ProductUpdate
# from src.utils.database import get_db_connection
#
# logger = logging.getLogger(__name__)
#
# class ProductService:
#     def __init__(self):
#         self.db = None
#
#     async def create_product(self, product_data: ProductCreate) -> Product:
#         """
#         Vytvoří nový produkt
#         """
#         try:
#             # Simulace databázového připojení
#             db = await get_db_connection()
#
#             # Validace vstupních dat
#             if product_data.price <= 0:
#                 raise ValueError("Cena musí být větší než nula")
#
#             if product_data.stock_quantity < 0:
#                 raise ValueError("Množství na skladě nemůže být záporné")
#
#             # Simulace uložení do databáze
#             product = Product(
#                 id=12345,  # Simulované ID
#                 name=product_data.name,
#                 description=product_data.description,
#                 price=product_data.price,
#                 stock_quantity=product_data.stock_quantity,
#                 category=product_data.category,
#                 created_at="2023-01-01T00:00:00",
#                 updated_at="2023-01-01T00:00:00"
#             )
#
#             logger.info(f"Produkt {product.name} vytvořen")
#             return product
#
#         except ValueError as ve:
#             logger.error(f"Chyba validace produktu: {str(ve)}")
#             raise
#         except Exception as e:
#             logger.error(f"Chyba při vytváření produktu: {str(e)}")
#             raise
#
#     async def get_product(self, product_id: int) -> Optional[Product]:
#         """
#         Získá produkt podle ID
#         """
#         try:
#             if product_id <= 0:
#                 raise ValueError("ID produktu musí být kladné číslo")
#
#             # Simulace databázového dotazu
#             product = Product(
#                 id=product_id,
#                 name="Testovací produkt",
#                 description="Popis testovacího produktu",
#                 price=100.0,
#                 stock_quantity=10,
#                 category="Elektronika",
#                 created_at="2023-01-01T00:00:00",
#                 updated_at="2023-01-01T00:00:00"
#             )
#
#             logger.info(f"Produkt {product_id} načten")
#             return product
#
#         except ValueError as ve:
#             logger.error(f"Chyba při načítání produktu: {str(ve)}")
#             raise
#         except Exception as e:
#             logger.error(f"Chyba při načítání produktu: {str(e)}")
#             raise
#
#     async def update_product(self, product_id: int, product_data: ProductUpdate) -> Product:
#         """
#         Aktualizuje produkt
#         """
#         try:
#             if product_id <= 0:
#                 raise ValueError("ID produktu musí být kladné číslo")
#
#             # Simulace aktualizace
#             product = await self.get_product(product_id)
#             if not product:
#                 raise ValueError(f"Produkt s ID {product_id} neexistuje")
#
#             updated_product = Product(
#                 id=product.id,
#                 name=product_data.name or product.name,
#                 description=product_data.description or product.description,
#                 price=product_data.price or product.price,
#                 stock_quantity=product_data.stock_quantity or product.stock_quantity,
#                 category=product_data.category or product.category,
#                 created_at=product.created_at,
#                 updated_at="2023-01-01T00:00:00"  # Simulace aktuálního času
#             )
#
#             logger.info(f"Produkt {product_id} aktualizován")
#             return updated_product
#
#         except ValueError as ve:
#             logger.error(f"Chyba při aktualizaci produktu: {str(ve)}")
#             raise
#         except Exception as e:
#             logger.error(f"Chyba při aktualizaci produktu: {str(e)}")
#             raise
#
#     async def delete_product(self, product_id: int) -> bool:
#         """
#         Smaže produkt
#         """
#         try:
#             if product_id <= 0:
#                 raise ValueError("ID produktu musí být kladné číslo")
#
#             # Simulace smazání
#             logger.info(f"Produkt {product_id} smazán")
#             return True
#
#         except ValueError as ve:
#             logger.error(f"Chyba při mazání produktu: {str(ve)}")
#             raise
#         except Exception as e:
#             logger.error(f"Chyba při mazání produktu: {str(e)}")
#             raise
#
#     async def get_products(self, limit: int = 100, offset: int = 0) -> List[Product]:
#         """
#         Získá seznam produktů
#         """
#         try:
#             if limit <= 0 or limit > 1000:
#                 raise ValueError("Limit musí být mezi 1 a 1000")
#
#             if offset < 0:
#                 raise ValueError("Offset nemůže být záporný")
#
#             # Simulace seznamu produktů
#             products = [
#                 Product(
#                     id=i,
#                     name=f"Produkt {i}",
#                     description=f"Popis produktu {i}",
#                     price=10.0 * i,
#                     stock_quantity=100 - i,
#                     category="Kategorie",
#                     created_at="2023-01-01T00:00:00",
#                     updated_at="2023-01-01T00:00:00"
#                 ) for i in range(offset, min(offset + limit, 100))
#             ]
#
#             logger.info(f"Načteno {len(products)} produktů")
#             return products
#
#         except ValueError as ve:
#             logger.error(f"Chyba při načítání produktů: {str(ve)}")
#             raise
#         except Exception as e:
#             logger.error(f"Chyba při načítání produktů: {str(e)}")
#             raise
# ```
#
# ### services/order_service.py
# ```python
# import logging
# from typing import List, Optional
# from src.models.order import Order, OrderCreate
# from src.services.product_service import ProductService
#
# logger = logging.getLogger(__name__)
#
# class OrderService:
#     def __init__(self):
#         self.product_service = ProductService()
#
#     async def create_order(self, order_data: OrderCreate) -> Order:
#         """
#         Vytvoří novou objednávku
#         """
#         try:
#             # Validace dat objednávky
#             if not order_data.customer_name or len(order_data.customer_name.strip()) == 0:
#                 raise ValueError("Jméno zákazníka nemůže být prázdné")
#
#             if not order_data.customer_email or '@' not in order_data.customer_email:
#                 raise ValueError("Neplatný e-mail zákazníka")
#
#             if not order_data.items or len(order_data.items) == 0:
#                 raise ValueError("Objednávka musí obsahovat alespoň jeden produkt")
#
#             # Výpočet celkové částky
#             total_amount = 0.0
#             for item in order_data.items:
#                 if item.quantity <= 0:
#                     raise ValueError("Množství musí být větší než nula")
#
#                 # Simulace získání ceny produktu (v reálné aplikaci by to bylo z databáze)
#                 product_price = 10.0 * item.product_id  # Simulace
#                 total_amount += item.quantity * product_price
#
#             # Vytvoření objednávky
#             order = Order(
#                 id=54321,  # Simulované ID
#                 customer_name=order_data.customer_name,
#                 customer_email=order_data.customer_email,
#                 items=order_data.items,
#                 shipping_address=order_data.shipping_address,
#                 total_amount=total_amount,
#                 status="pending",
#                 created_at="2023-01-01T00:00:00",
#                 updated_at="2023-01-01T00:00:00"
#             )
#
#             logger.info(f"Objednávka {order.id} vytvořena")
#             return order
#
#         except ValueError as ve:
#             logger.error(f"Chyba validace objednávky: {str(ve)}")
#             raise
#         except Exception as e:
#             logger.error(f"Chyba při vytváření objednávky: {str(e)}")
#             raise
#
#     async def get_order(self, order_id: int) -> Optional[Order]:
#         """
#         Získá objednávku podle ID
#         """
#         try:
#             if order_id <= 0:
#                 raise ValueError("ID objednávky musí být kladné číslo")
#
#             # Simulace načtení objednávky
#             order = Order(
#                 id=order_id,
#                 customer_name="Jan Novák

# %% [markdown]
# ## 📚 Další zdroje a materiály
#
# <div style="background: #e3f2fd; padding: 20px; border-left: 5px solid #2196f3; margin: 20px 0; border-radius: 5px;">
#     <h3 style="color: #2c3e50; margin-top: 0;">🔗 Doporučené materiály k dalšímu studiu</h3>
# </div>
#
# # Seznam zdrojů pro kapitolu: **Projekt 3 - Mikroslužbová e-commerce aplikace**
#
# ## 📚 Doporučené články a tutoriály
#
# 1. **[Microservices Architecture: A Beginner's Guide](https://www.redhat.com/en/topics/microservices)**
#    *Popis:* Komplexní úvod do mikroslužbové architektury s vysvětlením základních konceptů, výhod a nevýhod. Vhodné pro začátečníky, kteří se chtějí naučit základy.
#
# 2. **[Building a Microservices E-Commerce Application with Docker and Kubernetes](https://medium.com/@mattyschwartz/microservices-e-commerce-app-with-docker-and-kubernetes-3d1e9f0d5b2a)**
#    *Popis:* Praktický tutoriál na vytvoření e-commerce aplikace postavené na mikroslužbách, včetně Docker a Kubernetes.
#
# 3. **[Pattern: API Gateway in Microservices](https://microservices.io/patterns/apigateway.html)**
#    *Popis:* Vysvětlení role API Gateway v mikroslužbových aplikacích – jak funguje, proč je důležitá a jak ji implementovat.
#
# 4. **[Event-Driven Architecture for Microservices](https://martinfowler.com/articles/201701-event-driven.html)**
#    *Popis:* Detailní článek o event-driven architektuře v mikroslužbách – jak komunikovat mezi službami pomocí událostí.
#
# 5. **[Implementing a Microservices Architecture with Spring Boot and Docker](https://www.baeldung.com/spring-boot-docker-tutorial)**
#    *Popis:* Praktický návod na vytvoření mikroslužeb pomocí Spring Boot, Docker a Spring Cloud.
#
# ---
#
# ## 🎥 YouTube videa
#
# 1. **[Microservices Architecture Explained in 10 Minutes](https://www.youtube.com/watch?v=VqU697g7b8s)**
#    *Délka:* 10:21
#    *Popis:* Stručné a jasně vysvětlení mikroslužbové architektury – ideální pro začátečníky.
#
# 2. **[Building a Microservices E-Commerce App with Node.js & Docker](https://www.youtube.com/watch?v=H5W40879jVw)**
#    *Délka:* 54:32
#    *Popis:* Praktický výukový film o tvorbě mikroslužební e-commerce aplikace pomocí Node.js a Docker.
#
# 3. **[Kubernetes for Beginners - Full Course](https://www.youtube.com/watch?v=X48VuDVv0do)**
#    *Délka:* 2:13:18
#    *Popis:* Výukový kurz pro úplné začátečníky v Kubernetes, který je důležitý pro nasazování mikroslužeb.
#
# ---
#
# ## 📖 Knihy a oficiální dokumentace
#
# 1. **[Microservices Patterns](https://www.manning.com/books/microservices-patterns)**
#    *Popis:* Knaha od Chrisa Richardsona, která se zaměřuje na základní vzory a nejlepší postupy pro vývoj mikroslužeb.
#
# 2. **[Docker in Action](https://www.manning.com/books/docker-in-action)**
#    *Popis:* Úvod do Dockeru a jeho použití pro kontejnerizaci mikroslužeb – ideální pro praktické využití.
#
# 3. **[Official Kubernetes Documentation](https://kubernetes.io/docs/home/)**
#    *Popis:* Kompletní dokumentace k Kubernetes – oficiální zdroj informací pro nasazování a správu mikroslužeb.
#
# ---
#
# ## 💻 Praktické projekty k procvičení
#
# 1. **[Microservices E-Commerce Demo on GitHub](https://github.com/microservices

# %% [markdown]
# ## 📝 Shrnutí kapitoly
#
# <div style="background: linear-gradient(135deg, #667eea 0%, #764ba2 100%); padding: 30px; border-radius: 10px; color: white; margin: 30px 0;">
#     <h3 style="color: white; margin-top: 0;">✅ Co jste se naučili</h3>
#     <ul style="list-style: none; padding-left: 0;">
#         <li>✓ Microservices design</li>
# <li>✓ User service implementation</li>
# <li>✓ Product catalog service</li>
# <li>✓ Order management service</li>
# <li>✓ Payment integration</li>
#     </ul>
#
#     <h3 style="color: white;">🎯 Klíčové dovednosti</h3>
#     <p>Po dokončení této kapitoly byste měli být schopni prakticky použít všechny probrané koncepty.</p>
#
#     <h3 style='color: white;'>➡️ Další kapitola</h3><p>Kapitola 31 - pokračujte ve studiu!</p>
# </div>
#
# ---
#
# *📅 Notebook vygenerován: 2025-09-29 13:11:20*
# *🤖 Generátor: Comprehensive Colab Generator v2.0*
# *📚 Učebnice programování - Od základů k AI*

# %% [markdown]
# ## 🧪 Sandbox - Prostor pro experimenty
#
# Použijte následující buňky pro vlastní experimenty a testování:

# %%
# 🧪 Zde můžete experimentovat s kódem z kapitoly
# Napište svůj kód zde:
