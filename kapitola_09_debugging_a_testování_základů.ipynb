# %% [markdown]
# # 📚 Kapitola 9: Debugging a testování základů
#
# <div style="background: linear-gradient(90deg, #667eea 0%, #764ba2 100%); padding: 20px; border-radius: 10px; margin: 20px 0;">
#     <h2 style="color: white; margin: 0;">Blok 1 | BEGINNER</h2>
#     <p style="color: white; margin: 10px 0;">📖 Výuková kapitola</p>
# </div>
#
# ## 🎯 Co se naučíte
#
# V této kapitole se zaměříme na následující témata:
#
# - **Print debugging techniky**
# - **Python debugger (pdb)**
# - **VS Code debugging**
# - **Unittest framework**
# - **Assert statements**
# - **Logging modul - levels a handlers**
# - **Performance profiling základy**
#
# ## ⚠️ Předpoklady
# Tato kapitola navazuje na kapitoly: 7, 8
#
# ---

# %%
# ⚙️ Inicializace prostředí
# Tento kód nastavuje prostředí pro kapitolu 9

import sys
import os
from datetime import datetime

# Informace o prostředí
print("=" * 60)
print(f"📚 KAPITOLA 9: Debugging a testování základů")
print("=" * 60)
print(f"🐍 Python verze: {sys.version}")
print(f"📅 Datum spuštění: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
print(f"💻 OS: {os.name}")
print(f"📁 Pracovní adresář: {os.getcwd()}")
print("=" * 60)

# Instalace potřebných knihoven (odkomentujte podle potřeby)
# !pip install requests pandas numpy matplotlib
# !pip install beautifulsoup4 sqlalchemy fastapi

# Import základních knihoven
import json
import csv
import time
import random
from pathlib import Path
from typing import List, Dict, Optional, Any

print("✅ Prostředí připraveno!")

# %% [markdown]
# ## 📖 Teoretická část
#
# <div style="background: #f0f4ff; padding: 20px; border-left: 5px solid #4a69bd; margin: 20px 0; border-radius: 5px;">
#     <h3 style="color: #2c3e50; margin-top: 0;">🎓 Základní teorie a koncepty</h3>
# </div>
#
# # Debugging a testování základů
#
# ## 1. Úvod a motivace
#
# Debugging (ladění) a testování jsou základní dovednosti každého programátora. V praxi se mnoho času tráví právě na hledání chyb – tzv. "debugging time". V tomto tématu se naučíš, jak efektivně najít a opravit chyby ve svém kódu. Získáš nástroje, které ti pomohou nejen odhalit problémy, ale i zabránit jejich opakovanému vzniku. Naučíš se používat debuggery, testovací frameworky a logovací systémy – všechno to budeš moci využít jak ve školních projektech, tak i v profesionálním vývoji softwaru. Tato kapitola tě připraví na práci s chybami a zároveň ti ukáže, jak se chyby mohou předcházet.
#
# ---
#
# ## 2. Hlavní koncepty
#
# ### Print debugging techniky
#
# Jedna z nejzákladnějších metod ladění je `print()` – tedy výpis hodnot proměnných do konzole. Přestože se zdá jednoduchá, může být velmi efektivní při rychlém ladění. Například:
#
# ```python
# def calculate_average(numbers):
#     total = 0
#     for num in numbers:
#         total += num
#         print(f"Průběžný součet: {total}")  # Zde vypíšeme, co se děje
#     return total / len(numbers)
# ```
#
# Výhodou je jednoduchost, ale zároveň existují i nevýhody – např. můžeš zapomenout odstranit `print()` příkazy a výsledný kód bude nepřehledný.
#
# ---
#
# ### Python debugger (pdb)
#
# Python debugger (`pdb`) je vestavěný nástroj pro ladění programu. Můžeš jej použít přímo v konzoli nebo z integrace do editoru. Například:
#
# ```bash
# python -m pdb script.py
# ```
#
# Nebo můžeš v kódu použít:
#
# ```python
# import pdb
#
# def divide(a, b):
#     pdb.set_trace()  # Zde se program zastaví a otevře debugger
#     return a / b
# ```
#
# V debuggeru můžeš:
# - Zobrazit aktuální řádek (`l`)
# - Vypsat hodnoty proměnných (`p variable`)
# - Pokračovat v provádění (`n`, `s`, `c`)
#
# ---
#
# ### VS Code debugging
#
# VS Code podporuje debuggování přímo v editoru. Stačí kliknout na červenou tečku vedle řádku (breakpoint) a poté spustit ladění pomocí F5. Můžeš si nastavit:
# - Přerušovací body
# - Výstupní okna pro proměnné
# - Nastavení zarážek podle podmínek
#
# To vede k mnohem pohodlnějšímu ladění než pouhé `print()` volání.
#
# ---
#
# ### Unittest framework
#
# `unittest` je vestavěný testovací modul Pythonu. Pomocí něj můžeš psát unit testy – tedy testy, které ověřují jednotlivé funkce. Příklad:
#
# ```python
# import unittest
#
# def add(a, b):
#     return a + b
#
# class TestAdd(unittest.TestCase):
#     def test_add(self):
#         self.assertEqual(add(2, 3), 5)
#
# if __name__ == '__main__':
#     unittest.main()
# ```
#
# Tento přístup zajišťuje, že tvůj kód funguje správně a že se nezhorší, pokud něco změníš.
#
# ---
#
# ### Assert statements
#
# `assert` je klíčové slovo, které používáš pro kontrolu podmínek. Pokud podmínka selže, program skončí s chybou `AssertionError`. Například:
#
# ```python
# def divide(a, b):
#     assert b != 0, "Dělení nulou není povoleno!"
#     return a / b
# ```
#
# Je to rychlý způsob kontroly, ale ne vždy je vhodné používat ho pro ladění – často se používá spíše při testování.
#
# ---
#
# ### Logging modul - levels a handlers
#
# Modul `logging` umožňuje zaznamenávat události ve tvém programu. Má různé úrovně:
#
# - `DEBUG` – detailní informace pro ladění
# - `INFO` – obecné informace o běhu programu
# - `WARNING` – varování
# - `ERROR` – chyba, která způsobila selhání
# - `CRITICAL` – závažná chyba
#
# Příklad:
#
# ```python
# import logging
#
# logging.basicConfig(level=logging.DEBUG)
# logger = logging.getLogger(__name__)
#
# def process_data(data):
#     logger.info("Zpracovávám data...")
#     if not data:
#         logger.warning("Data jsou prázdná!")
# ```
#
# Logy můžeš směrovat do souborů nebo konzole – to se nastavuje pomocí `handlers`.
#
# ---
#
# ### Performance profiling základy
#
# Profiling je technika, která měří, jak dlouho trvá jednotlivé části kódu. Používáš například `cProfile` nebo `timeit`. Například:
#
# ```python
# import cProfile
#
# def slow_function():
#     total = 0
#     for i in range(1000000):
#         total += i
#     return total
#
# cProfile.run('slow_function()')
# ```
#
# Výstup ti ukáže, které funkce trvají nejvíce a kde je možné optimalizovat.
#
# ---
#
# ## 3. Důležité detaily
#
# ### Časté chyby a jak se jim vyhnout
#
# - **Nepoužívání debuggery** – často lidé používají `print()`, ale to není efektivní.
# - **Přehnané používání `assert`** – `assert` by neměl být použit pro validaci uživatelských vstupů.
# - **Nepoužívání logování** – bez logů je těžké zjistit, co se děje při chybách v produkčním prostředí.
#
# ### Best practices
#
# - Vždy používej debuggovací nástroje místo `print()` když jde o složité ladění.
# - Testuj svůj kód pomocí `unittest`.
# - Používej logování pro různé úrovně důležitosti.
# - Nepoužívej `pdb` v produkčním kódu – použij logování.
#
# ### Performance tipy
#
# - Místo `print()` používej `logging` s vhodnými úrovněmi.
# - Používej profiler, když chceš zlepšit výkon.
# - Udržuj čistý a jednoduchý kód – složité funkce jsou těžší na ladění i optimalizaci.
#
# ---
#
# ## 4. Propojení s předchozími kapitolami
#
# Tato kapitola navazuje na základy programování – proměnné, funkce, podmínky, cykly. Naučíš se používat tyto konstrukce v praxi a zároveň se naučíš, jak je efektivně ladit. Předchozí kapitoly mohly pokrývat třídy, knihovny nebo práci s daty – všechno toto se teď dá použít při ladění a testování. Debugging tedy není jen „hledat chyby“, ale je to součást základního programátorského procesu, který zvyšuje kvalitu tvého kódu.
#
# ---
#
# Tato kapitola je důležitá nejen proto, že tě naučí najít chyby – ale i proto, že ti pomůže psát kód, který bude lépe čitelný a snáze odladitelný. Ať už jsi začátečník nebo pokročilý programátor, tato dovednost je klíčová pro úspěšný vývoj softwaru.

# %% [markdown]
# ## 💻 Praktické příklady
#
# <div style="background: #e8f5e9; padding: 20px; border-left: 5px solid #4caf50; margin: 20px 0; border-radius: 5px;">
#     <h3 style="color: #2c3e50; margin-top: 0;">👨‍💻 Hands-on příklady ke spuštění</h3>
#     <p>Následující příklady si můžete hned vyzkoušet. Každý příklad je samostatně spustitelný.</p>
# </div>

# %% [markdown]
# ### Příklad 1
#
# ### Očekávaný výstup:
# ```
# Vstupní data: [10, 20, 30]
# Iterace 0: přidávám 10
# Iterace 1: přidávám 20
# Iterace 2: přidávám 30
# Celkový součet: 60
# Průměr: 20.0
# Výsledek: 20.0
# ```

# %% [markdown]
# ### Příklad 2
#
# ### Vysvětlení:
# Kód demonstruje jednoduché print debugging. Při každé iteraci cyklu a po zpracování dat se vytisknou informace o aktuálním stavu programu. Tato technika je rychlá a jednoduchá pro ladění problémů, ale není vhodná pro složitější aplikace.
#
# ---
#
# # 2. Python debugger (pdb)
#
# ## Co demonstruje:
# Použití vestavěného Python debuggeru pdb pro krok za krokem ladění programu.

# %%
import pdb

def process_data(data_list):
    """
    Zpracování seznamu dat s použitím pdb debuggrování
    """
    pdb.set_trace()  # Nastavení bodu zarážky
    
    result = []
    
    for item in data_list:
        if isinstance(item, (int, float)):
            squared = item ** 2
            result.append(squared)
        else:
            print(f"Nečíselná hodnota: {item}")
    
    return result

# Spuštění funkce
test_data = [1, 2, 'a', 3, 4.5]
processed = process_data(test_data)
print("Výsledek:", processed)

# %% [markdown]
# ### Příklad 3
#
# ### Očekávaný výstup:
# ```
# > /path/to/script.py(7)process_data()
# -> pdb.set_trace()
# (Pdb)
# ```

# %% [markdown]
# ### Příklad 4
#
# ### Vysvětlení:
# Program se zastaví na řádku s `pdb.set_trace()` a čeká na příkazy debuggeru. Uživatel může zadávat příkazy jako `n` (next), `s` (step), `c` (continue), `p variable_name` (výpis proměnné) atd. Tato metoda umožňuje detailní analýzu průběhu programu.
#
# ---
#
# # 3. Unittest framework a Assert statements
#
# ## Co demonstruje:
# Základní použití unittest frameworku s assert příkazy pro testování funkcí.

# %%
import unittest

def add_numbers(a, b):
    """Sčítání dvou čísel"""
    return a + b

def divide_numbers(a, b):
    """Dělení dvou čísel"""
    if b == 0:
        raise ValueError("Dělení nulou není povoleno")
    return a / b

class TestMathFunctions(unittest.TestCase):
    """Testovací třída pro matematické funkce"""
    
    def test_add_numbers(self):
        """Test sčítání čísel"""
        result = add_numbers(3, 5)
        self.assertEqual(result, 8)
        
        result = add_numbers(-1, 1)
        self.assertEqual(result, 0)
        
        result = add_numbers(0, 0)
        self.assertEqual(result, 0)
    
    def test_divide_numbers(self):
        """Test dělení čísel"""
        result = divide_numbers(10, 2)
        self.assertEqual(result, 5.0)
        
        result = divide_numbers(7, 2)
        self.assertAlmostEqual(result, 3.5, places=1)
    
    def test_divide_by_zero(self):
        """Test výjimky při dělení nulou"""
        with self.assertRaises(ValueError):
            divide_numbers(10, 0)

# Spuštění testů
if __name__ == '__main__':
    unittest.main()

# %% [markdown]
# ### Příklad 5
#
# ### Očekávaný výstup:
# ```
# ...
# ----------------------------------------------------------------------
# Ran 3 tests in 0.001s
#
# OK
# ```

# %% [markdown]
# ### Příklad 6
#
# ### Vysvětlení:
# Tento příklad ukazuje základní testování pomocí unittest frameworku. Používají se různé assert metody (`assertEqual`, `assertAlmostEqual`, `assertRaises`) pro ověření správnosti výsledků a chování funkcí. Testy jsou automaticky spouštěny a poskytují jasné informace o průběhu.
#
# ---
#
# # 4. Logging modul - levels a handlers
#
# ## Co demonstruje:
# Použití logging modulu s různými úrovněmi logování a handleri pro záznam událostí.

# %%
import logging

# Konfigurace loggingu
logging.basicConfig(
    level=logging.DEBUG,
    format='%(asctime)s - %(levelname)s - %(message)s',
    handlers=[
        logging.FileHandler('app.log'),  # Zápis do souboru
        logging.StreamHandler()           # Výstup na konzoli
    ]
)

def process_user_data(user_id, data):
    """
    Zpracování uživatelských dat s logováním
    """
    logging.info(f"Začínám zpracovávat data pro uživatele ID: {user_id}")
    
    if not data:
        logging.warning("Předaná data jsou prázdná")
        return None
    
    try:
        # Simulace zpracování dat
        processed_data = [x * 2 for x in data if isinstance(x, (int, float))]
        logging.debug(f"Zpracovaná data: {processed_data}")
        
        if len(processed_data) == 0:
            logging.error("Po zpracování nezbylo žádné platné data")
            return None
            
        logging.info(f"Zpracování pro uživatele {user_id} dokončeno úspěšně")
        return processed_data
        
    except Exception as e:
        logging.error(f"Chyba při zpracování dat: {str(e)}")
        raise

# Testování logování
logging.info("Aplikace spuštěna")

test_user_id = 12345
test_data = [1, 2, 'abc', 3, 4.5]

try:
    result = process_user_data(test_user_id, test_data)
    print(f"Výsledek: {result}")
except Exception as e:
    print(f"Chyba: {e}")

logging.info("Aplikace ukončena")

# %% [markdown]
# ### Příklad 7
#
# ### Očekávaný výstup:
# ```
# 2023-XX-XX XX:XX:XX,XXX - INFO - Aplikace spuštěna
# 2023-XX-XX XX:XX:XX,XXX - INFO - Začínám zpracovávat data pro uživatele ID: 12345
# 2023-XX-XX XX:XX:XX,XXX - WARNING - Předaná data jsou prázdná
# 2023-XX-XX XX:XX:XX,XXX - INFO - Aplikace ukončena
# ```

# %% [markdown]
# ### Příklad 8
#
# ### Vysvětlení:
# Tento příklad demonstruje pokročilejší logování pomocí logging modulu. Používají se různé úrovně (`INFO`, `WARNING`, `ERROR`, `DEBUG`) a dva handleri - jeden zapisuje do souboru, druhý na konzoli. Logování je vhodné pro produkční prostředí, protože poskytuje detailní informace o průběhu aplikace.
#
# ---
#
# # 5. Performance profiling základy
#
# ## Co demonstruje:
# Základní použití profilování výkonu pomocí time module a timeit modulu.
#
# ```python
# import time
# import timeit
# from functools import wraps
#
# def timing_decorator(func):
#     """Dekorátor pro měření času provádění funkce"""
#     @wraps(func)
#     def wrapper(*args, **kwargs):
#         start_time = time.time()
#         result = func(*args, **kwargs)
#         end_time = time.time()
#         print(f"Čas provedení funkce {func.__name__}: {end_time - start_time:.6f} sekund")
#         return result
#     return wrapper
#
# @timing_decorator
# def slow_function():
#     """Pomalá funkce pro demonstraci"""
#     total = 0
#     for i in range(1000000):
#         total += i * i
#     return total
#
# def quick_function():
#     """Rychlá funkce pro porovnání"""
#     return sum(i**2 for i in range(1000000))
#
# # Měření výkonu pomocí timeit
# print("Měření pomocí timeit:")
# time_per_call = timeit.timeit('quick_function()',
#                              setup='from __main__ import quick_function',
#                              number=10)
# print(f"Průměrný čas 10 opakování: {time_per_call/10:.6f} sekund")
#
# # Spuštění pomalé funkce
# print("\nMěření pomalé funkce:")
# result = slow_function()
# print(f"Výsledek: {result}")
#
# # Přímé měření času provádění
# start = time.time()
# for i in range(10):

# %% [markdown]
# ## 🎯 Cvičení a úkoly
#
# <div style="background: #fff3e0; padding: 20px; border-left: 5px solid #ff9800; margin: 20px 0; border-radius: 5px;">
#     <h3 style="color: #2c3e50; margin-top: 0;">✍️ Praktická cvičení k procvičení</h3>
#     <p>Vyřešte následující úkoly. Začněte od jednoduššších a postupujte k složitějším.</p>
# </div>
#
# # 5 Praktických cvičení pro kapitolu: **Debugging a testování základů**
#
# ---
#
# ## Cvičení 1: **Nalezení chyby v jednoduché funkci**
#
# ### 1. **Název úkolu**
# Debugging jednoduché funkce s chybou
#
# ### 2. **Detailní zadání**
# Student dostane kód jednoduché funkce, která má chybu a nevrací správný výsledek. Úkolem je najít chybu a opravit ji.
#
# ### 3. **Vstupní data/požadavky**
# Funkce `calculate_total_price` počítá celkovou cenu produktů s daným počtem kusů a cenou za kus. Funkce má logickou chybu.
#
# ```python
# def calculate_total_price(quantity, price_per_item):
#     total = quantity * price_per_item
#     return total + 10  # Chyba: přidání 10 bez důvodu
# ```
#
# ### 4. **Očekávaný výstup**
# Pro `calculate_total_price(5, 10)` by měl být výsledek `50`.
#
# ### 5. **Hints/Nápověda**
# 1. Zkontroluj, jak se vypočítává celková cena.
# 2. Co se děje s návratovou hodnotou?
# 3. Vyzkoušej funkci s různými parametry a zjisti, kde se chyba objevuje.
# 4. Zkus použít `print()` příkaz pro ladění.
#
# ### 6. **Kostra řešení**
# ```python
# def calculate_total_price(quantity, price_per_item):
#     # TODO: Oprav chybu v této funkci
#     total = quantity * price_per_item
#     return total + 10  # Chyba zde
#
# # Test
# print(calculate_total_price(5, 10))
# ```
#
# ### 7. **Bonusové rozšíření**
# Vytvoř jednoduchý testovací případ pro tuto funkci (např. pomocí `assert`).
#
# ---
#
# ## Cvičení 2: **Základní unit test s chybou**
#
# ### 1. **Název úkolu**
# Přidání a oprava jednoduchého testu
#
# ### 2. **Detailní zadání**
# Student dostane kód funkce, která má chybu, a zároveň testovací případ, který nezachytí chybu. Úkolem je opravit test nebo funkci.
#
# ### 3. **Vstupní data/požadavky**
# Funkce `is_even` má být pravdivá pro sudá čísla a nepravdivá pro lichá.
#
# ```python
# def is_even(number):
#     return number % 2 == 1  # Chyba: má být == 0
# ```
#
# Test:
#
# ```python
# def test_is_even():
#     assert is_even(4) == True
#     assert is_even(5) == False
# ```
#
# ### 4. **Očekávaný výstup**
# Funkce `is_even(4)` by měla vracet `True`, `is_even(5)` by měla vracet `False`.
#
# ### 5. **Hints/Nápověda**
# 1. Jak se určuje, zda je číslo sudé?
# 2. Vyzkoušej si testy s různými čísly.
# 3. Použij `print()` pro zjištění chyby.
# 4. Oprav buď funkci nebo test.
#
# ### 6. **Kostra řešení**
# ```python
# def is_even(number):
#     return number % 2 == 1  # Chyba zde
#
# # Test
# def test_is_even():
#     assert is_even(4) == True
#     assert is_even(5) == False
# ```
#
# ### 7. **Bonusové rozšíření**
# Přidej další testy pro hraniční případy (např. `0`, `1`, `-2`).
#
# ---
#
# ## Cvičení 3: **Debugging pomocí print()**
#
# ### 1. **Název úkolu**
# Ladění chyby pomocí `print`
#
# ### 2. **Detailní zadání**
# Student dostane kód, který má vnitřní logickou chybu. Použitím `print()` příkazu má najít a opravit chybu.
#
# ### 3. **Vstupní data/požadavky**
# Funkce `find_max` hledá maximální hodnotu v seznamu, ale nefunguje správně.
#
# ```python
# def find_max(numbers):
#     max_value = 0
#     for num in numbers:
#         if num > max_value:
#             max_value = num
#     return max_value
# ```
#
# ### 4. **Očekávaný výstup**
# Pro `find_max([-1, -5, 3, 2])` by měla být výsledkem `3`.
#
# ### 5. **Hints/Nápověda**
# 1. Vyzkoušej funkci s různými seznamy.
# 2. Přidej `print()` pro sledování hodnoty `max_value` při průchodu seznamem.
# 3. Co se stane, když bude seznam jen záporných čísel?
# 4. Oprav inicializaci proměnné `max_value`.
#
# ### 6. **Kostra řešení**
# ```python
# def find_max(numbers):
#     max_value = 0  # Chyba: může být i záporné číslo
#     for num in numbers:
#         if num > max_value:
#             max_value = num
#     return max_value
#
# # Test
# print(find_max([-1, -5, 3, 2]))
# ```
#
# ### 7. **Bonusové rozšíření**
# Vytvoř testovací funkci, která ověřuje správnost pro různé případy (např. jen záporná čísla, smíšené, prázdný seznam).
#
# ---
#
# ## Cvičení 4: **Testování funkce s chybou vstupu**
#
# ### 1. **Název úkolu**
# Ověření správnosti funkce s chybným vstupem
#
# ### 2. **Detailní zadání**
# Student dostane funkci, která nemusí být robustní proti špatnému vstupu. Úkolem je opravit chyby a přidat kontrolu vstupu.
#
# ### 3. **Vstupní data/požadavky**
# Funkce `divide` dělí dvě čísla, ale nemá kontrolu vstupů.
#
# ```python
# def divide(a, b):
#     return a / b  # Může vyvolat chybu při b=0
# ```
#
# ### 4. **Očekávaný výstup**
# `divide(10, 2)` má vrátit `5.0`, ale `divide(10, 0)` by měl vrátit zprávu `"Nelze dělit nulou"`.
#
# ### 5. **Hints/Nápověda**
# 1. Co se stane, když dělíš číslem 0?
# 2. Použij `try/except` pro zachycení chyby.
# 3. Můžeš použít podmínku `if b == 0`.
# 4. Přidej ošetření vstupu před dělením.
#
# ### 6. **Kostra řešení**
# ```python
# def divide(a, b):
#     return a / b  # Chyba zde
#
# # Test
# print(divide(10, 2))
# print(divide(10, 0))
# ```
#
# ### 7. **Bonusové rozšíření**
# Přidej testovací případy pro nečíselné hodnoty (`"abc"`, `None`, atd.).
#
# ---
#
# ## Cvičení 5: **Vytvoření jednoduchého testu s assert**
#
# ### 1. **Název úkolu**
# Základní testovací případ pomocí `assert`
#
# ### 2. **Detailní zadání**
# Student dostane

# %% [markdown]
# ## 📚 Další zdroje a materiály
#
# <div style="background: #e3f2fd; padding: 20px; border-left: 5px solid #2196f3; margin: 20px 0; border-radius: 5px;">
#     <h3 style="color: #2c3e50; margin-top: 0;">🔗 Doporučené materiály k dalšímu studiu</h3>
# </div>
#
# # Zdroje pro kapitolu: **Debugging a testování základů**
#
# ---
#
# ## 📘 5 doporučených článků/tutoriálů
#
# 1. **[Debugging in Python with pdb](https://realpython.com/python-debugging-pdb/)**
#    *Popis:* Komplexní průvodce použitím `pdb` (Python Debugger) pro ladění kódu v Pythonu. Vysvětluje základní příkazy, nastavení breakpointů a interaktivní ladění.
#
# 2. **[Unit Testing in Python: The Right Way](https://realpython.com/python-testing/)**
#    *Popis:* Úvod do unit testování v Pythonu s použitím modulu `unittest`. Vysvětluje základní principy, tvorbu testů a jejich spouštění.
#
# 3. **[Effective Debugging: 6 Ways to Find Issues Faster](https://blog.jetbrains.com/pycharm/2020/01/effective-debugging-6-ways-to-find-issues-faster/)**
#    *Popis:* Článek zaměřený na efektivní debugování v Pythonu, zejména v prostředí PyCharm. Nabízí rady pro rychlé zjištění chyb a optimalizaci ladění.
#
# 4. **[How to Write a Test](https://www.guru99.com/python-unit-testing.html)**
#    *Popis:* Praktický průvodce psaním testů v Pythonu. Vysvětluje, jak psát jednoduché a efektivní testy s použitím `pytest`.
#
# 5. **[Debugging Techniques in JavaScript](https://developer.mozilla.org/en-US/docs/Learn/JavaScript/Building_blocks/Debugging)**
#    *Popis:* Pokud se zabýváš i JavaScriptem, tento článek od MDN vysvětluje základní techniky debugování ve webovém prohlížeči a v Node.js.
#
# ---
#
# ## 🎥 3 YouTube videa
#
# 1. **[Python Debugging with pdb | Python Tutorial](https://www.youtube.com/watch?v=K581k04Q29I)** *(Délka: 12 min)*
#    *Popis:* Praktický tutorial o používání `pdb` v Pythonu. Zobrazuje, jak nastavit breakpointy a procházet kód krok za krokem.
#
# 2. **[Learn pytest in 10 Minutes](https://www.youtube.com/watch?v=6t23a8597YU)** *(Délka: 10 min)*
#    *Popis:* Rychlý úvod do testovacího nástroje `pytest`, který je oblíbený v Pythonu. Vysvětluje základní syntaxi a spouštění testů.
#
# 3. **[How to Debug Your Code in VS Code (Python)](https://www.youtube.com/watch?v=b27XgJ1436Y)** *(Délka: 15 min)*
#    *Popis:* Návod, jak debugovat Python kód v prostředí Visual Studio Code. Vysvětluje nastavení debuggeru a použití breakpointů.
#
# ---
#
# ## 📚 3 knihy nebo oficiální dokumentace
#
# 1. **[The Python Standard Library](https://docs.python.org/3/library/index.html)**
#    *Popis:* Oficiální dokumentace k Pythonu, obsahuje sekce o `pdb`, `unittest` a dalších nástrojích pro ladění a testování.
#
# 2. **[Effective Python: 90 Specific Ways to Write Better Python](https://effectivepython.com/)**
#    *Popis:* Knížka od Brettův C. "Effective Python" obsahuje kapitoly o testování a debugování, jak psát čistší a efektivnější kód.
#
# 3. **[Automate the Boring Stuff with Python – Chapter 10 (Debugging)](https://automatetheboringstuff.com/2e/chapter10/)**
#    *Popis:* Tato kapitola se zaměřuje na debugov

# %% [markdown]
# ## 📝 Shrnutí kapitoly
#
# <div style="background: linear-gradient(135deg, #667eea 0%, #764ba2 100%); padding: 30px; border-radius: 10px; color: white; margin: 30px 0;">
#     <h3 style="color: white; margin-top: 0;">✅ Co jste se naučili</h3>
#     <ul style="list-style: none; padding-left: 0;">
#         <li>✓ Print debugging techniky</li>
# <li>✓ Python debugger (pdb)</li>
# <li>✓ VS Code debugging</li>
# <li>✓ Unittest framework</li>
# <li>✓ Assert statements</li>
#     </ul>
#
#     <h3 style="color: white;">🎯 Klíčové dovednosti</h3>
#     <p>Po dokončení této kapitoly byste měli být schopni prakticky použít všechny probrané koncepty.</p>
#
#     <h3 style='color: white;'>➡️ Další kapitola</h3><p>Kapitola 10 - pokračujte ve studiu!</p>
# </div>
#
# ---
#
# *📅 Notebook vygenerován: 2025-09-29 12:01:53*
# *🤖 Generátor: Comprehensive Colab Generator v2.0*
# *📚 Učebnice programování - Od základů k AI*

# %% [markdown]
# ## 🧪 Sandbox - Prostor pro experimenty
#
# Použijte následující buňky pro vlastní experimenty a testování:

# %%
# 🧪 Zde můžete experimentovat s kódem z kapitoly
# Napište svůj kód zde:
