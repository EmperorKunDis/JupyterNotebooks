# %% [markdown]
# # 📚 Kapitola 31: Úvod do LLM a Ollama
#
# <div style="background: linear-gradient(90deg, #667eea 0%, #764ba2 100%); padding: 20px; border-radius: 10px; margin: 20px 0;">
#     <h2 style="color: white; margin: 0;">Blok 4 | EXPERT</h2>
#     <p style="color: white; margin: 10px 0;">📖 Výuková kapitola</p>
# </div>
#
# ## 🎯 Co se naučíte
#
# V této kapitole se zaměříme na následující témata:
#
# - **LLM základní koncepty**
# - **Transformers architecture basics**
# - **Ollama installation všechny OS**
# - **Model management commands**
# - **Ollama models overview**
# - **Hardware requirements**
# - **GPU acceleration setup**
#
# ## ⚠️ Předpoklady
# Tato kapitola navazuje na kapitoly: 4
#
# ---

# %%
# ⚙️ Inicializace prostředí
# Tento kód nastavuje prostředí pro kapitolu 31

import sys
import os
from datetime import datetime

# Informace o prostředí
print("=" * 60)
print(f"📚 KAPITOLA 31: Úvod do LLM a Ollama")
print("=" * 60)
print(f"🐍 Python verze: {sys.version}")
print(f"📅 Datum spuštění: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
print(f"💻 OS: {os.name}")
print(f"📁 Pracovní adresář: {os.getcwd()}")
print("=" * 60)

# Instalace potřebných knihoven (odkomentujte podle potřeby)
# !pip install requests pandas numpy matplotlib
# !pip install beautifulsoup4 sqlalchemy fastapi

# Import základních knihoven
import json
import csv
import time
import random
from pathlib import Path
from typing import List, Dict, Optional, Any

print("✅ Prostředí připraveno!")

# %% [markdown]
# ## 📖 Teoretická část
#
# <div style="background: #f0f4ff; padding: 20px; border-left: 5px solid #4a69bd; margin: 20px 0; border-radius: 5px;">
#     <h3 style="color: #2c3e50; margin-top: 0;">🎓 Základní teorie a koncepty</h3>
# </div>
#
# # Úvod do LLM a Ollama
#
# ## 1. Úvod a motivace
#
# V období, kdy umělá inteligence (AI) stále více proniká do každodenního života a průmyslových procesů, vývoj velkých jazykových modelů (LLM – *Large Language Models*) představuje klíčový významný krok směrem ke zvýšení automatizace, personalizaci a efektivitě. LLM jsou schopny vykonávat nespočet úkolů – od překladu textu, přes tvorbu obsahu, až po rozumové analýzy – výrazně zlepšují výkonnost v oblastech jako je vzdělávání, lékařství, právo nebo finanční služby.
#
# V praxi se LLM používají například ve vývoji chatbotů, automatizovaných systémech pro zpracování dokumentů, analýze dat, generování kódu nebo podpůrných systémů pro programátory. V tomto kurzu se zaměříme na praktické využití nástrojů jako je **Ollama**, které umožňují běh LLM modelů lokálně – tedy bez potřeby přístupu k cloudu – což zvyšuje soukromí, rychlost a kontrolu nad daty.
#
# Student se naučí, jak instalovat Ollama na různých operačních systémech, spravovat modely, využívat akceleraci GPU a zároveň pochopí hlavní principy fungování LLM modelů a jejich architektury. Tato kapitola je základem pro pokračující studium v oblasti LLM, AI modelování a lokálního nasazení umělé inteligence.
#
# ---
#
# ## 2. Hlavní koncepty
#
# ### **LLM – základní koncepty**
#
# Velké jazykové modely (Large Language Models) jsou neuronové sítě trénované na obrovském množství textu, které se naučily předpovídat další slova v textu. Tyto modely jsou schopné nejen číst a interpretovat jazyk, ale i generovat text, odpovídat na otázky, překládat nebo řešit logické úlohy.
#
# Jedním z nejznámějších příkladů je model **GPT-4**, který byl trénován na tisících miliardách slov. Modely jako GPT, LLaMA, Mistral nebo Phi jsou vytvářeny pomocí zpětného šíření chyb (backpropagation), sítí typu Transformer a obrovských datasetů.
#
# Výhodou LLM je jejich schopnost přizpůsobit se různým úkolům, tedy využít stejný model pro mnoho různých aplikací – např. jako chatbot, kreativní nástroj nebo nástroj pro analýzu dat.
#
# ---
#
# ### **Transformers architecture basics**
#
# Architektura Transformers je základním prvkem moderních LLM modelů. Vytvořená v roce 2017 v článku *“Attention is All You Need”*, se jedná o neuronovou síť, která používá mechanismus **attention**, který umožňuje modelu zaměřit se na různé části vstupního textu při generování odpovědi.
#
# Hlavní komponenty Transformeru:
#
# - **Embedding layer** – převádí slova do číselných reprezentací
# - **Multi-head attention** – umožňuje modelu vidět vztahy mezi různými slovy ve větě
# - **Feed-forward neural network** – zpracovává jednotlivé tokeny po pozornosti
# - **Residual connections a Layer Normalization** – pomáhají stabilizovat trénink
#
# Transformer je schopen zpracovávat vstupní text paralelně (ne postupně jako starší modely), což zvyšuje rychlost tréninku a efektivitu.
#
# ---
#
# ### **Ollama – instalace na všechny OS**
#
# Ollama je jednoduchý nástroj, který umožňuje spouštět LLM modely lokálně. Podporuje všechny hlavní operační systémy.
#
# #### **Windows**
# 1. Stáhněte Ollama z oficiálního webu: [https://ollama.com/download](https://ollama.com/download)
# 2. Spusťte instalační program a následujte pokyny.
# 3. Ověřte instalaci příkazem:
#    ```bash
#    ollama --version
#    ```
#
# #### **macOS**
# Použijte Homebrew:
# ```bash
# brew install ollama
# ```
#
# #### **Linux (Ubuntu/Debian)**
# ```bash
# curl -fsSL https://ollama.com/install.sh | sh
# ```
#
# Po instalaci spusťte:
# ```bash
# ollama serve
# ```
#
# ---
#
# ### **Model management – příkazy**
#
# Ollama umožňuje jednoduchou správu modelů pomocí příkazové řádky:
#
# - **Stažení modelu**:
#   ```bash
#   ollama pull llama3
#   ```
# - **Zobrazení seznamu modelů**:
#   ```bash
#   ollama list
#   ```
# - **Spuštění modelu**:
#   ```bash
#   ollama run llama3
#   ```
#
# Příkazy jako `ollama run`, `ollama ps` (zobrazení běžících modelů) a `ollama rm <model>` (smazání modelu) jsou základním nástrojem pro správu.
#
# ---
#
# ### **Ollama – přehled modelů**
#
# Ollama podporuje mnoho open-source LLM modelů, které mohou běžet lokálně. Mezi nejčastěji používané patří:
#
# - **LLaMA 3** – nový model od Meta
# - **Mistral** – vysoký výkon a efektivita
# - **Phi-3** – malý, rychlý model pro edge zařízení
# - **Gemma** – od Google
#
# Každý model má své specifické vlastnosti: rozsah trénovacích dat, velikost (např. 7B, 13B), způsob optimalizace a výkonnost.
#
# ---
#
# ### **Hardware requirements**
#
# Pro běh LLM modelů lokálně je důležitá dostupná paměť a výpočetní kapacita:
#
# - **RAM**: Minimálně 8 GB, pro větší modely doporučeno 16 GB nebo více
# - **GPU** (pokud používáte GPU): Minimálně 8 GB VRAM, ideálně 12–24 GB pro pokročilé modely
# - **CPU**: Pro menší modely postačí i 6-jádrový procesor
#
# Použití GPU výrazně zrychluje běh modelů (např. LLaMA 3 na GPU běží několikanásobně rychleji než na CPU).
#
# ---
#
# ### **GPU acceleration setup**
#
# Pro správné využití GPU ve Windows, Linuxu a macOS:
#
# #### **Windows**
# - Instalace NVIDIA drivérů (CUDA)
# - Nainstalujte Ollama s podporou CUDA:
#   ```bash
#   ollama run --gpu llama3
#   ```
#
# #### **Linux**
# ```bash
# sudo apt install nvidia-driver-535
# ollama run llama3
# ```
#
# #### **macOS**
# Použijte Metal framework – Ollama automaticky využívá podporu pro Apple Silicon (M1/M2).
#
# ---
#
# ## 3. Důležité detaily
#
# ### **Časté chyby a jak se jim vyhnout**
#
# - **Chybějící GPU podpora**: Při spuštění modelu bez podpory GPU se může příkaz zaseknout nebo běžet extrémně pomalu.
# - **Nedostatek paměti RAM**: Modely vyžadují velké množství paměti – v případě chybějící paměti se aplikace může zhroutit.
# - **Špatné použití příkazů**: Např. spuštění `ollama run` bez stahnutého modelu nebo použití `--gpu` na CPU.
#
# ### **Best practices**
#
# - Vždy zkontrolujte dostupnou paměť a výkon před spuštěním modelu.
# - Používejte menší modely (např. Mistral 7B) pro začátek, pak postupně přecházíte na větší.
# - Udržujte modely aktuální pomocí `ollama pull <model>`.
#
# ### **Performance tipy**
#
# - Využijte GPU podporu (`--gpu`)
# - Využijte modely optimalizované pro rychlost (např. Phi, Gemma)
# - Používejte streamování odpovědí (`--stream`) pro lepší zkušenost
#
# ---
#
# ## 4. Propojení s předchozími kapitolami
#
# Tato kapitola navazuje na poznatky z úvodního kurzu do AI a neuronových sítí, kde jsme se naučili základy strojového učení. Nyní se zaměřujeme na konkrétní implementace a praktické nástroje – tedy jak LLM funguje v praxi a jak je možné jej běžet lokálně.
#
# Zároveň rozšiřuje pochopení z předchozích kapitol o modelování, trénink a zpětné šíření chyb – nyní se zaměřujeme na **běh** a **deploy** modelů v reálném prostředí.
#
# ---
#
# Pokud máte zájem o pokračování v tomto kurzu, budete mít připravené základy pro pokročilé práce s prompt engineeringem, fine-tuningem, případně vytváření vlastních LLM modelů.

# %% [markdown]
# ## 💻 Praktické příklady
#
# <div style="background: #e8f5e9; padding: 20px; border-left: 5px solid #4caf50; margin: 20px 0; border-radius: 5px;">
#     <h3 style="color: #2c3e50; margin-top: 0;">👨‍💻 Hands-on příklady ke spuštění</h3>
#     <p>Následující příklady si můžete hned vyzkoušet. Každý příklad je samostatně spustitelný.</p>
# </div>

# %% [markdown]
# ### Příklad 1
#
# ### Co příklad demonstruje:
# Tento příklad ukazuje základní instalaci a spuštění serveru Ollama na různých operačních systémech.

# %% [markdown]
# ### Příklad 2
#
# ### Kompletní kód s českými komentáři:
#
# ```bash
# # Pro Linux (Ubuntu/Debian)
# curl -fsSL https://ollama.com/install.sh | sh
#
# # Pro macOS (použijte Homebrew)
# brew install ollama
#
# # Pro Windows (Použijte PowerShell jako administrátor)
# irm https://ollama.com/install.ps1 | iex
#
# # Spusťte Ollama server (po instalaci)
# ollama serve
# ```

# %% [markdown]
# ### Příklad 3
#
# ### Očekávaný výstup:
# ```
# WARN[0000] failed to get system info: open /etc/os-release: no such file or directory
# Loading model...
# Ollama is running on http://localhost:11434
# ```

# %% [markdown]
# ### Příklad 4
#
# ### Vysvětlení:
# Tento příklad ukazuje různé způsoby instalace Ollama na různých operačních systémech. Po spuštění `ollama serve` se spustí lokální server, který umožňuje komunikaci s LLM modely.
#
# ---
#
# ## 2. **Stažení a spuštění prvního modelu (llama3)**

# %% [markdown]
# ### Příklad 5
#
# ### Co příklad demonstruje:
# Získání a spuštění základního modelu `llama3` pomocí Ollama.

# %% [markdown]
# ### Příklad 6
#
# ### Kompletní kód s českými komentáři:
#
# ```bash
# # Stáhne a spustí model llama3 (výchozí verze)
# ollama run llama3
#
# # Po spuštění můžeš zadávat dotazy:
# # Jak se jmenuješ?
# # Co je umělá inteligence?
#
# #

# %% [markdown]
# ### Příklad 7
#
# Příklad odpovědi:
# # Jsem Llama 3, umělá inteligence vytvořená společností Meta.
# ```

# %% [markdown]
# ### Příklad 8
#
# ### Očekávaný výstup:
# ```
# > Jak se jmenuješ?
# Jsem Llama 3, umělá inteligence vytvořená společností Meta.
# ```

# %% [markdown]
# ### Příklad 9
#
# ### Vysvětlení:
# Příkaz `ollama run llama3` stáhne model (pokud ještě není lokálně) a spustí interaktivní konzoli pro zadávání dotazů. Model se automaticky načte do paměti.
#
# ---
#
# ## 3. **Zobrazení seznamu dostupných modelů**

# %% [markdown]
# ### Příklad 10
#
# ### Co příklad demonstruje:
# Zobrazení všech lokálně nainstalovaných modelů pomocí Ollama.

# %% [markdown]
# ### Příklad 11
#
# ### Kompletní kód s českými komentáři:
#
# ```bash
# # Zobrazí seznam všech modelů nainstalovaných na systému
# ollama list
#
# # Můžeš také použít:
# ollama ls
# ```

# %% [markdown]
# ### Příklad 12
#
# ### Očekávaný výstup:
# ```
# NAME                   ID        SIZE      MODIFIED
# llama3                 7c84a9    4.1 GB    2 hours ago
# mistral                5f3d9a    3.8 GB    1 day ago
# ```

# %% [markdown]
# ### Příklad 13
#
# ### Vysvětlení:
# Příkaz `ollama list` (nebo `ollama ls`) vypíše všechny modely, které jsou momentálně nainstalované v Ollama. Obsahuje informace o ID, velikosti a čase poslední změny.
#
# ---
#
# ## 4. **Nastavení GPU akcelerace (pokud je k dispozici)**

# %% [markdown]
# ### Příklad 14
#
# ### Co příklad demonstruje:
# Použití GPU pro zrychlení provozu modelů v Ollama.

# %% [markdown]
# ### Příklad 15
#
# ### Kompletní kód s českými komentáři:
#
# ```bash
# # Zkontroluj, zda máš podporu GPU (pokud používáš NVIDIA)
# nvidia-smi
#
# # Spusť model s využitím GPU (pokud je dostupné)
# ollama run llama3
#
# # V případě potřeby můžeš explicitně zadat, že chceš použít GPU:
# OLLAMA_NUM_PARALLEL=1 ollama run llama3
# ```

# %% [markdown]
# ### Příklad 16
#
# ### Očekávaný výstup:
# ```
# GPU support detected: CUDA available.
# Model loaded with GPU acceleration.
# ```

# %% [markdown]
# ### Příklad 17
#
# ### Vysvětlení:
# Pokud je k dispozici podpora GPU (např. CUDA), Ollama automaticky použije GPU pro zrychlení operací. Výstup `nvidia-smi` ukazuje, že máme dostupné grafické karty.
#
# ---
#
# ## 5. **Vytvoření vlastního modelu s pomocí Ollama**

# %% [markdown]
# ### Příklad 18
#
# ### Co příklad demonstruje:
# Vytvoření jednoduchého vlastního modelu na základě šablony pomocí `Modelfile`.

# %% [markdown]
# ### Příklad 19
#
# ### Kompletní kód s českými komentáři:
#
# ```bash
# # Vytvoř soubor Modelfile
# cat > my-model-llama3 << EOF
# FROM llama3
# PARAMETER temperature 0.7
# PARAMETER top_p 0.9
# SYSTEM """
# Jsi užitečný asistent, který odpovídá v češtině.
# """
# EOF
#
# # Vytvoř model z Modelfile
# ollama create my-model -f my-model-llama3
#
# # Spusť nově vytvořený model
# ollama run my-model
# ```

# %% [markdown]
# ### Příklad 20
#
# ### Očekávaný výstup:
# ```
# > Jak se máš?
# Jsem dobrý asistent, děkuji za dotaz.
# ```

# %% [markdown]
# ### Příklad 21
#
# ### Vysvětlení:
# `Modelfile` je textový soubor definující model – základní model (např. `llama3`), parametry a systémovou instrukci. Příkaz `ollama create` vytvoří nový model podle této šablony. Poté můžeš použít tento model stejně jako jiné.
#
# ---
#
# ## Shrnutí
#
# Tyto příklady ukazují základní práci s Ollama – od instalace a spuštění modelu, přes správu modelů, až po vytváření vlastních modelů s vlastními nastaveními. Všechny příklady jsou samostatné a lze je spustit na jakémkoli systému podporujícím Ollama.
#
# ---

# %% [markdown]
# ## 🎯 Cvičení a úkoly
#
# <div style="background: #fff3e0; padding: 20px; border-left: 5px solid #ff9800; margin: 20px 0; border-radius: 5px;">
#     <h3 style="color: #2c3e50; margin-top: 0;">✍️ Praktická cvičení k procvičení</h3>
#     <p>Vyřešte následující úkoly. Začněte od jednoduššších a postupujte k složitějším.</p>
# </div>
#
# # Cvičení: Úvod do LLM a Ollama
#
# ---
#
# ## Cvičení 1: Instalace a spuštění prvního modelu pomocí Ollama
#
# ### 1. **Název úkolu**
# Instalace Ollama a spuštění prvního LLM modelu
#
# ### 2. **Detailní zadání**
# Student si nainstaluje Ollama na svůj počítač (podle operačního systému), spustí server, stáhne a spustí základní LLM model (např. `llama3` nebo `mistral`) a provede jednoduchý testovací dotaz pomocí příkazové řádky.
#
# ### 3. **Vstupní data/požadavky**
# - Linux, Windows nebo macOS
# - Přístup k příkazové řádce
# - Internetové připojení (pro stahování modelů)
# - Případně nainstalovaný `curl` nebo `ollama` klient
#
# ### 4. **Očekávaný výstup**
# - Ollama server běží
# - Model je stažen a spuštěn
# - Výstup z modelu na testovací dotaz (např. „Jak se máš?“)
#
# ### 5. **Hints/Nápověda**
# 1. Stáhni Ollama podle svého OS: https://ollama.com/download
# 2. Spusť `ollama run llama3` v terminálu a zadej dotaz.
# 3. Zkontroluj, že je model dostupný přes `ollama list`.
# 4. Můžeš použít `curl` pro testování REST API (`http://localhost:11434`).
#
# ### 6. **Kostra řešení**
# ```bash
# # Instalace Ollama (např. na Linux)
# curl -fsSL https://ollama.com/install.sh | sh
#
# # Spuštění modelu
# ollama run llama3
#
# # Testovací dotaz v interaktivním režimu
# > Jak se máš?
#
# # Výstup by měl být text odpovědi modelu
# ```
#
# ### 7. **Bonusové rozšíření**
# Použij REST API Ollama k odeslání dotazu z Python skriptu:
#
# ```python
# import requests
#
# response = requests.post("http://localhost:11434/api/generate",
#                         json={"model": "llama3", "prompt": "Jak se máš?"})
# print(response.json()['response'])
# ```
#
# ---
#
# ## Cvičení 2: Vytvoření jednoduchého chatbotu přes Ollama REST API
#
# ### 1. **Název úkolu**
# Vytvoření chatovacího robota pomocí Ollama REST API
#
# ### 2. **Detailní zadání**
# Student vytvoří jednoduchý Python skript, který komunikuje s Ollama serverem přes REST API. Skript bude umožňovat zadávat dotazy a získávat odpovědi od modelu (např. `llama3`) v interaktivním režimu.
#
# ### 3. **Vstupní data/požadavky**
# - Spuštěný Ollama server
# - Python 3.x
# - Knihovna `requests`
#
# ### 4. **Očekávaný výstup**
# - Interaktivní chatovací aplikace, která se dotazuje na uživatele a odpovídá z modelu.
# - Průběžné výstupy (při každém dotazu).
#
# ### 5. **Hints/Nápověda**
# 1. Spusť `ollama run llama3` pro zajištění dostupnosti modelu.
# 2. Použij `requests.post()` na endpoint `/api/generate`.
# 3. Vytvoř cyklus, který čte vstup a posílá dotaz.
# 4. Můžeš použít `stream=True` pro reálný výstup.
#
# ### 6. **Kostra řešení**
# ```python
# import requests
#
# def chat_with_model():
#     while True:
#         prompt = input("Ty: ")
#         if prompt.lower() in ["quit", "exit"]:
#             break
#         response = requests.post("http://localhost:11434/api/generate",
#                                 json={"model": "llama3", "prompt": prompt})
#         print("Model:", response.json()['response'])
#
# chat_with_model()
# ```
#
# ### 7. **Bonusové rozšíření**
# Přidej historii konverzace pomocí `messages` v JSONu (pokud podporuje model).
#
# ---
#
# ## Cvičení 3: Vytvoření vlastního promptu pro LLM
#
# ### 1. **Název úkolu**
# Vytvoření efektivního promptu pro konkrétní úkol
#
# ### 2. **Detailní zadání**
# Student navrhne a otestuje prompt, který instruuje model k vykonání specifického úkolu (např. „Přelož následující text do angličtiny“ nebo „Vytvoř stručný shrnutí tohoto článku“). Výsledek porovná s různými verzemi promptu.
#
# ### 3. **Vstupní data/požadavky**
# - Spuštěný model (např. `llama3`)
# - Vstupní text k zpracování
#
# ### 4. **Očekávaný výstup**
# - Vytvořený prompt a jeho testovací výsledek
# - Porovnání efektivity různých promptů (např. s nebo bez instrukcí)
#
# ### 5. **Hints/Nápověda**
# 1. Zkoušej různé formy promptu: „Přelož do angličtiny“, „Přelož do angličtiny a udržuj styl“, „Přelož do angličtiny, vytvoř shrnutí“.
# 2. Vyzkoušej použití „Instruct“ stylu: „Instrukce: překládej následující text.“
# 3. Přidej kontext nebo role modelu (např. „Jsi profesionální překladatel“).
# 4. Můžeš použít `ollama run` s různými prompty a porovnat.
#
# ### 6. **Kostra řešení**
# ```bash
# # Příklad promptu
# ollama run llama3
#
# > Instrukce: Přelož následující text do angličtiny.
# > Vstup: Vítejte v naší aplikaci, která pomáhá uživatelům získat informace rychle a jednoduše.
#
# # Odpověď modelu
# ```
#
# ### 7. **Bonusové rozšíření**
# Vytvoř Python skript, který automaticky testuje několik promptů a porovnává jejich výsledky (např. podle kvality překladu).
#
# ---
#
# ## Cvičení 4: Integrace LLM do vlastního API
#
# ### 1. **Název úkolu**
# Vytvoření jednoduchého REST API pro komunikaci s LLM
#
# ### 2. **Detailní zadání**
# Student vytvoří jednoduché Flask API, které přijímá požadavky na zpracování textu (např. překlad nebo shrnutí) a používá Ollama jako backend.
#
# ### 3. **Vstupní data/požadavky**
# - Nainstalovaný Flask
# - Spuštěný Ollama server
#
# ### 4. **Očekávaný výstup**
# - REST API, které přijímá JSON s textem a vrací odpověď modelu
# - Funkční test přes `curl` nebo Postman
#
# ### 5. **Hints/Nápověda**
# 1. Nainstaluj Flask (`pip install flask`)
# 2. Vytvoř endpoint `/process` pro

# %% [markdown]
# ## 📚 Další zdroje a materiály
#
# <div style="background: #e3f2fd; padding: 20px; border-left: 5px solid #2196f3; margin: 20px 0; border-radius: 5px;">
#     <h3 style="color: #2c3e50; margin-top: 0;">🔗 Doporučené materiály k dalšímu studiu</h3>
# </div>
#
# # Zdroje pro kapitolu: Úvod do LLM a Ollama
#
# ## 1. Doporučené články/tutoriály
#
# 1. **[What are Large Language Models?](https://towardsdatascience.com/what-are-large-language-models-7e8b8a4d3f0c)** – *Towards Data Science*
#    Přehledné a jednoduché vysvětlení, co jsou LLM, jak fungují a jak se liší od tradičních modelů. Skvělé pro začátečníky.
#
# 2. **[Getting Started with Ollama](https://ollama.com/blog/getting-started)** – *Ollama blog*
#    Oficiální průvodce pro instalaci a základní použití Ollama. Obsahuje praktické příklady a vysvětlení konceptu „local AI“.
#
# 3. **[A Visual Guide to LLMs](https://jalammar.github.io/visual-interactive-guide-bert-embeddings/)** – *Jay Alammar*
#    Interaktivní a vizuální přehled architektury LLM, včetně BERT a GPT. Vhodné pro lepší porozumění fungování neuronových sítí.
#
# 4. **[Understanding Transformers](https://www.youtube.com/watch?v=UF8uR6Z6KLw)** – *3Blue1Brown*
#    Animovaný výklad principu Transformer architektury (např. používané v GPT). Vhodné pro hlubší porozumění mechanismu LLM.
#
# 5. **[LLM Use Cases and Applications](https://www.ibm.com/cloud/learn/what-are-large-language-models)** – *IBM Cloud Learn*
#    Přehled reálných použití LLM v průmyslu a technologiích. Velmi vhodné pro představu o praktickém využití modelů.
#
# ---
#
# ## 2. YouTube videa
#
# 1. **[Ollama Explained - Install, Run, and Use Local AI Models](https://www.youtube.com/watch?v=QX3FVl0v6ZU)** – *Derek Banas* (15 min)
#    Jednoduchý a praktický úvod do Ollama, včetně instalace a spuštění modelů lokálně.
#
# 2. **[What are Large Language Models (LLMs)?](https://www.youtube.com/watch?v=9xS505V61d4)** – *Lex Fridman* (23 min)
#    Rozhovor s Lex Fridmanem o LLM, jejich vývoji a budoucnosti. Hlubší pohled na technologii.
#
# 3. **[How to Use Ollama with Python](https://www.youtube.com/watch?v=1V8F7Xx2YzE)** – *AI Coding* (10 min)
#    Výukové video pro začátečníky, jak integrovat Ollama do Python aplikací.
#
# ---
#
# ## 3. Knihy a oficiální dokumentace
#
# 1. **[The Illustrated Guide to Transformers](https://www.amazon.com/Illustrated-Guide-Transformers-Bert-GPT/dp/0578971610)** – *Jay Alammar*
#    Vizuálně přehledná kniha o architektuře Transformer a jejích aplikacích, ideální pro výklad LLM.
#
# 2. **[Official Ollama Documentation](https://ollama.com/docs)**
#    Kompletní průvodce použitím Ollama – instalace, konfigurace, modely a API.
#
# 3. **[Deep Learning with Python by François Chollet](https://www.manning.com/books/deep-learning-with-python)**
#    Hluboký úvod do neuronových sítí včetně kapitoly o transformeru – dobrý základ pro rozumění LLM.
#
# ---
#
# ## 4. Praktické projekty
#
# 1. **Vytvoření jednoduchého chatbotu pomocí Ollama a Pythonu**
#    Implementace jednoduchého

# %% [markdown]
# ## 📝 Shrnutí kapitoly
#
# <div style="background: linear-gradient(135deg, #667eea 0%, #764ba2 100%); padding: 30px; border-radius: 10px; color: white; margin: 30px 0;">
#     <h3 style="color: white; margin-top: 0;">✅ Co jste se naučili</h3>
#     <ul style="list-style: none; padding-left: 0;">
#         <li>✓ LLM základní koncepty</li>
# <li>✓ Transformers architecture basics</li>
# <li>✓ Ollama installation všechny OS</li>
# <li>✓ Model management commands</li>
# <li>✓ Ollama models overview</li>
#     </ul>
#
#     <h3 style="color: white;">🎯 Klíčové dovednosti</h3>
#     <p>Po dokončení této kapitoly byste měli být schopni prakticky použít všechny probrané koncepty.</p>
#
#     <h3 style='color: white;'>➡️ Další kapitola</h3><p>Kapitola 32 - pokračujte ve studiu!</p>
# </div>
#
# ---
#
# *📅 Notebook vygenerován: 2025-09-29 13:14:15*
# *🤖 Generátor: Comprehensive Colab Generator v2.0*
# *📚 Učebnice programování - Od základů k AI*

# %% [markdown]
# ## 🧪 Sandbox - Prostor pro experimenty
#
# Použijte následující buňky pro vlastní experimenty a testování:

# %%
# 🧪 Zde můžete experimentovat s kódem z kapitoly
# Napište svůj kód zde:
