# %% [markdown]
# # 📚 Kapitola 6: Základy Pythonu II - Kolekce dat
#
# <div style="background: linear-gradient(90deg, #667eea 0%, #764ba2 100%); padding: 20px; border-radius: 10px; margin: 20px 0;">
#     <h2 style="color: white; margin: 0;">Blok 1 | BEGINNER</h2>
#     <p style="color: white; margin: 10px 0;">📖 Výuková kapitola</p>
# </div>
#
# ## 🎯 Co se naučíte
#
# V této kapitole se zaměříme na následující témata:
#
# - **Seznamy (lists) - metody a operace**
# - **Tuple - immutable sequences**
# - **Množiny (sets) - unique values**
# - **Slovníky (dictionaries) - key-value pairs**
# - **Cykly: for, while, else clause**
# - **List/dict/set comprehensions**
# - **Generator expressions**
#
# ## ⚠️ Předpoklady
# Tato kapitola navazuje na kapitoly: 5
#
# ---

# %%
# ⚙️ Inicializace prostředí
# Tento kód nastavuje prostředí pro kapitolu 6

import sys
import os
from datetime import datetime

# Informace o prostředí
print("=" * 60)
print(f"📚 KAPITOLA 6: Základy Pythonu II - Kolekce dat")
print("=" * 60)
print(f"🐍 Python verze: {sys.version}")
print(f"📅 Datum spuštění: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
print(f"💻 OS: {os.name}")
print(f"📁 Pracovní adresář: {os.getcwd()}")
print("=" * 60)

# Instalace potřebných knihoven (odkomentujte podle potřeby)
# !pip install requests pandas numpy matplotlib
# !pip install beautifulsoup4 sqlalchemy fastapi

# Import základních knihoven
import json
import csv
import time
import random
from pathlib import Path
from typing import List, Dict, Optional, Any

print("✅ Prostředí připraveno!")

# %% [markdown]
# ## 📖 Teoretická část
#
# <div style="background: #f0f4ff; padding: 20px; border-left: 5px solid #4a69bd; margin: 20px 0; border-radius: 5px;">
#     <h3 style="color: #2c3e50; margin-top: 0;">🎓 Základní teorie a koncepty</h3>
# </div>
#
# # Základy Pythonu II – Kolekce dat
#
# ## 1. Úvod a motivace
#
# V této kapitole se ponoříme do světa **kolekcí dat** v jazyku Python. Kolekce jsou způsoby, jak ukládat a organizovat více hodnot najednou – například seznam čísel, jména nebo slovníková data.
#
# Toto téma je **zásadní pro každého začátečníka**, protože všechny programy, které budeme dělat, budou potřebovat ukládat a pracovat s daty. V praxi se kolekce používají všude – od jednoduchých seznamů úkolů po složité databázové systémy, webové aplikace i analýzy dat.
#
# Zde si vysvětlíme základní druhy kolekcí: **seznamy (lists), n-tice (tuples), množiny (sets) a slovníky (dictionaries)**. Naučíme se, jak s nimi pracovat, jak je vytvářet, upravovat a procházet, a také jak je efektivně používat ve svých programech.
#
# Po této kapitole budeš umět:
# - Vytvářet, měnit a získávat data z různých typů kolekcí
# - Používat cykly k iteraci přes prvky
# - Vytvářet komplexní struktury pomocí list/dict/set comprehensions
# - Získat základní přehled o tvorbě generátorů
#
# ## 2. Hlavní koncepty
#
# ### Seznamy (lists) – metody a operace
#
# **Seznamy** jsou nejčastěji používané kolekce v Pythonu. Jsou **změnitelné** (mutable), tedy můžeš přidávat, odstraňovat a měnit jejich prvky.
#
# #### Vytváření seznamu:
# ```python
# seznam = [1, 2, 3]
# prazdny_seznam = []
# ```
#
# #### Operace s listy:
# ```python
# # Přidání prvku na konec
# seznam.append(4)
# print(seznam)  # [1, 2, 3, 4]
#
# # Přidání prvku na konkrétní pozici
# seznam.insert(1, 'nove')
# print(seznam)  # [1, 'nove', 2, 3, 4]
#
# # Odstranění prvku podle hodnoty
# seznam.remove('nove')
# print(seznam)  # [1, 2, 3, 4]
#
# # Odstranění podle indexu
# del seznam[0]
# print(seznam)  # [2, 3, 4]
#
# # Získání délky seznamu
# print(len(seznam))  # 3
#
# # Seřazení seznamu
# seznam.sort()
# print(seznam)  # [2, 3, 4]
# ```
#
# ### Tuple – neměnné sekvence
#
# **Tuple (n-tice)** je **nezměnitelná** kolekce prvků. Používá se v případech, kdy chceš zajistit, že data nebudou měněna.
#
# #### Vytvoření:
# ```python
# t = (1, 2, 3)
# # nebo
# t = 1, 2, 3  # bez závorek
#
# # Tuples jsou neměnné – toto vyvolá chybu:
# # t[0] = 5  # TypeError: 'tuple' object does not support item assignment
# ```
#
# #### Použití:
# ```python
# # Tuple lze použít jako klíč ve slovníku (protože jsou hashovatelné)
# slovnik = {t: "hodnota"}
# print(slovnik)  # {(1, 2, 3): 'hodnota'}
# ```
#
# ### Množiny (sets) – jedinečné hodnoty
#
# **Množina** je kolekce **bez duplikátů** a **neuspořádaná**, což znamená, že pořadí prvků není důležité.
#
# #### Vytvoření:
# ```python
# mnozina = {1, 2, 3}
# prazdna_mnozina = set()  # NE {}
# ```
#
# #### Operace s množinami:
# ```python
# # Přidání prvku
# mnozina.add(4)
#
# # Odstranění prvku (pokud neexistuje, vyvolá chybu)
# mnozina.remove(1)
#
# # Odstranění prvku bez chyby
# mnozina.discard(5)  # Nevyhodí chybu
#
# # Průnik a sjednocení množin
# set1 = {1, 2, 3}
# set2 = {3, 4, 5}
# print(set1 & set2)  # {3} – průnik
# print(set1 | set2)  # {1, 2, 3, 4, 5} – sjednocení
# ```
#
# ### Slovníky (dictionaries) – klíče a hodnoty
#
# **Slovník** je kolekce dvojic: **klíč → hodnota**, kde každý klíč je jedinečný.
#
# #### Vytvoření:
# ```python
# slovnik = {"jmeno": "Petr", "vek": 25}
# prazdny_slovnik = {}
# ```
#
# #### Operace:
# ```python
# # Přidání nebo změna hodnoty
# slovnik["mesto"] = "Praha"
#
# # Získání hodnoty podle klíče
# print(slovnik["jmeno"])  # Petr
#
# # Smazání dvojice klíč-hodnota
# del slovnik["vek"]
#
# # Iterace přes klíče
# for klic in slovnik:
#     print(klic, slovnik[klic])
#
# # Nebo pomocí .items()
# for klic, hodnota in slovnik.items():
#     print(f"{klic}: {hodnota}")
# ```
#
# ### Cykly: `for`, `while`, a `else` klauzule
#
# **Cyklus `for`** je ideální pro průchod kolekcemi:
#
# ```python
# seznam = [1, 2, 3]
# for prvek in seznam:
#     print(prvek)
# ```
#
# **Cyklus `while`** se používá, když nevíš předem, kolikrát se má cyklus opakovat:
#
# ```python
# i = 0
# while i < 5:
#     print(i)
#     i += 1
# ```
#
# #### Klauzule `else`:
# Klauzule `else` se spustí **pouze tehdy, pokud cyklus skončil normálně**, tedy bez použití `break`.
#
# ```python
# for i in range(3):
#     if i == 2:
#         break
# else:
#     print("Cyklus skončil bez přerušení")
# ```
#
# V tomto případě se `else` **nevytiskne**, protože cyklus byl přerušen.
#
# ### List/dict/set comprehensions
#
# **Comprehension** je způsob, jak vytvářet kolekce jednoduše a čistě.
#
# #### List comprehension:
# ```python
# # Jednoduché použití
# seznam = [x for x in range(5)]
# print(seznam)  # [0, 1, 2, 3, 4]
#
# # S podmínkou
# seznam = [x for x in range(10) if x % 2 == 0]
# print(seznam)  # [0, 2, 4, 6, 8]
# ```
#
# #### Dict comprehension:
# ```python
# slovnik = {x: x**2 for x in range(5)}
# print(slovnik)  # {0: 0, 1: 1, 2: 4, 3: 9, 4: 16}
# ```
#
# #### Set comprehension:
# ```python
# mnozina = {x for x in range(5) if x % 2 == 0}
# print(mnozina)  # {0, 2, 4}
# ```
#
# Comprehensions jsou **rychlejší** a čitelnější než klasické cykly.
#
# ### Generator expressions
#
# **Generator** je speciální typ iterátoru, který vytváří hodnoty „na požadavek“ – tedy při každém volání `next()`.
#
# #### Vytvoření:
# ```python
# # Použijeme závorky místo hranatých nebo složených závorek
# generovac = (x for x in range(5))
#
# print(next(generovac))  # 0
# print(next(generovac))  # 1
# ```
#
# #### Rozdíl mezi seznamem a generátorem:
# ```python
# # Seznam vytvoří všechny hodnoty najednou
# seznam = [x for x in range(1000000)]
#
# # Generator vytvoří hodnoty postupně – úspornější paměťově
# generator = (x for x in range(1000000))
# ```
#
# ## 3. Důležité detaily
#
# ### Časté chyby a jak se jim vyhnout:
# - **Použití `==` místo `is`**: Použij `is` pro porovnání referencí (např. `x is None`)
# - **Změna seznamu během iterace**: Vytvářej kopii nebo používej `for i in reversed(seznam)`
# - **Nepřístup k neexistujícímu klíči ve slovníku**: Použij `.get()` nebo `try/except`
#
# ### Best practices:
# - Využívej **comprehensions** místo klasických cyklů, pokud to jde.
# - Používej **tuple**, pokud data nechceš měnit.
# - Množiny jsou rychlé pro kontrolu přítomnosti prvků.
#
# ### Performance tipy:
# - Používání `set` místo `list` pro kontrolu duplicit
# - Generátory využívej, pokud pracuješ s velkými daty
# - Vyhýbej se opakovanému přidávání do seznamu – použij `extend()` nebo `append()` jen jednou
#
# ## 4. Propojení s předchozími kapitolami
#
# Tato kapitola **pokračuje** v rámci naučených konceptů jako jsou proměnné, podmínky a funkce. Naučili jsme se pracovat s jednotlivými daty, nyní se učíme, jak je seskupovat a řídit.
#
# Základy kolekcí rozšiřují naše schopnosti:
# - Vytvářet složitější programy
# - Uchovávat a zpracovávat data efektivněji
# - Pracovat s větším množstvím informací
#
# Takže pokud jsi už schopen psát jednoduché funkce a používat podmínky, nyní tvoje programy mohou **přecházet od jednoduchých dat k složitým strukturám** – a to je základ všeho, co budeš dál dělat.

# %% [markdown]
# ## 💻 Praktické příklady
#
# <div style="background: #e8f5e9; padding: 20px; border-left: 5px solid #4caf50; margin: 20px 0; border-radius: 5px;">
#     <h3 style="color: #2c3e50; margin-top: 0;">👨‍💻 Hands-on příklady ke spuštění</h3>
#     <p>Následující příklady si můžete hned vyzkoušet. Každý příklad je samostatně spustitelný.</p>
# </div>

# %% [markdown]
# # Příklady základů Pythonu II - Kolekce dat
#
# ## 1. Seznamy (lists) - základní metody a operace
#
# **Co příklad demonstruje:** Základní práce se seznamy, přidávání prvků, mazání a vyhledávání.
#
# ```python
# # Název příkladu: Základní operace se seznamy
#
# # Vytvoření seznamu
# seznam = [1, 2, 3, 4, 5]
# print("Původní seznam:", seznam)
#
# # Přidání prvku na konec
# seznam.append(6)
# print("Po přidání 6:", seznam)
#
# # Přidání prvku na určité místo
# seznam.insert(2, 10)  # Vloží 10 na pozici 2 (třetí prvek)
# print("Po vložení 10 na pozici 2:", seznam)
#
# # Odstranění prvku podle hodnoty
# seznam.remove(3)  # Odstraní první výskyt čísla 3
# print("Po odstranění 3:", seznam)
#
# # Seřazení seznamu
# seznam.sort()
# print("Seřazený seznam:", seznam)
#
# # Výpočet délky seznamu
# delka = len(seznam)
# print("Délka seznamu:", delka)
#
# # Vyhledání prvku
# if 10 in seznam:
#     print("Číslo 10 se nachází v seznamu")
# else:
#     print("Číslo 10 není v seznamu")
#
# # Získání prvního a posledního prvku
# prvni = seznam[0]
# posledni = seznam[-1]
# print("První prvek:", prvni, "Poslední prvek:", posledni)
# ```
#
# **Očekávaný výstup:**
# ```
# Původní seznam: [1, 2, 3, 4, 5]
# Po přidání 6: [1, 2, 3, 4, 5, 6]
# Po vložení 10 na pozici 2: [1, 2, 10, 3, 4, 5, 6]
# Po odstranění 3: [1, 2, 10, 4, 5, 6]
# Seřazený seznam: [1, 2, 4, 5, 6, 10]
# Délka seznamu: 6
# Číslo 10 se nachází v seznamu
# První prvek: 1 Poslední prvek: 10
# ```
#
# **Vysvětlení:** Tento příklad ukazuje základní metody práce se seznamy. Používáme `append()` pro přidání prvku na konec, `insert()` pro vložení na konkrétní pozici, `remove()` pro odstranění podle hodnoty. Metoda `sort()` řadí prvky vzestupně, `len()` zjišťuje délku seznamu a operátor `in` kontroluje přítomnost prvku.
#
# ## 2. N-tice (tuple) - neměnné sekvence
#
# **Co příklad demonstruje:** Vytváření a práce s n-ticemi, které jsou neměnné.
#
# ```python
# # Název příkladu: Práce s nticemi (tuple)
#
# # Vytvoření n-tice
# osoby = ("Petr", "Jana", "Martin", "Eva")
# print("N-tice osob:", osoby)
#
# # Přístup k prvkům podle indexu
# print("První osoba:", osoby[0])
# print("Poslední osoba:", osoby[-1])
#
# # Počet prvků v n-tici
# pocet = len(osoby)
# print("Počet osob:", pocet)
#
# # Vyhledání pozice prvku
# pozice = osoby.index("Jana")
# print("Pozice Jany:", pozice)
#
# # N-tice může obsahovat různé typy dat
# smes = (1, "text", 3.14, True)
# print("Smíšená n-tice:", smes)
#
# # N-tice nelze měnit - pokus o změnu způsobí chybu
# try:
#     osoby[0] = "Karel"  # Toto způsobí chybu TypeError
# except TypeError as e:
#     print("Chyba při pokusu o změnu n-tice:", e)
#
# # N-tice lze spojovat
# nova_osoba = ("Anna",)
# cela_osoba = osoby + nova_osoba
# print("Po přidání Anny:", cela_osoba)
#
# # N-tice mohou být použity jako klíče ve slovníku
# slovnik = {osoby: "Původní seznam"}
# print("Slovník s nticí jako klíčem:", slovnik)
# ```
#
# **Očekávaný výstup:**
# ```
# N-tice osob: ('Petr', 'Jana', 'Martin', 'Eva')
# První osoba: Petr
# Poslední osoba: Eva
# Počet osob: 4
# Pozice Jany: 1
# Smíšená n-tice: (1, 'text', 3.14, True)
# Chyba při pokusu o změnu n-tice: 'tuple' object does not support item assignment
# Po přidání Anny: ('Petr', 'Jana', 'Martin', 'Eva', 'Anna')
# Slovník s nticí jako klíčem: {('Petr', 'Jana', 'Martin', 'Eva'): 'Původní seznam'}
# ```
#
# **Vysvětlení:** N-tice jsou neměnné sekvence, které nelze po vytvoření měnit. Používají se pro data, která by neměla být změněna, například koordináty nebo informace o zákazníkovi. V tomto příkladu ukazujeme, že n-tice podporují indexaci a operace jako `len()`, ale nelze je měnit.
#
# ## 3. Množiny (sets) - jedinečné hodnoty
#
# **Co příklad demonstruje:** Vytváření množin, práce s jedinečnými prvky a množkové operace.
#
# ```python
# # Název příkladu: Práce s množinami
#
# # Vytvoření množiny
# mnozina = {1, 2, 3, 4, 5}
# print("Původní množina:", mnozina)
#
# # Přidání prvku do množiny
# mnozina.add(6)
# print("Po přidání 6:", mnozina)
#
# # Přidání více prvků najednou
# mnozina.update([7, 8, 9])
# print("Po přidání 7,8,9:", mnozina)
#
# # Odstranění prvku
# mnozina.remove(3)  # Vyhodí chybu pokud prvek neexistuje
# print("Po odstranění 3:", mnozina)
#
# # Odstranění prvku bez vyhazování chyby (pokud prvek neexistuje)
# mnozina.discard(10)  # Nevyhodí chybu
# print("Po pokusu o odstranění 10:", mnozina)
#
# # Vytvoření množiny z listu (automaticky odstraní duplikáty)
# seznam = [1, 2, 3, 2, 4, 5, 4, 6]
# unikatni = set(seznam)
# print("Původní seznam:", seznam)
# print("Množina bez duplikátů:", unikatni)
#
# # Množkové operace
# mnozina1 = {1, 2, 3, 4}
# mnozina2 = {3, 4, 5, 6}
#
# # Průnik množin
# prunik = mnozina1 & mnozina2
# print("Průnik:", prunik)
#
# # Sjednocení množin
# sjednoceni = mnozina1 | mnozina2
# print("Sjednocení:", sjednoceni)
#
# # Rozdíl množin
# rozdil = mnozina1 - mnozina2
# print("Rozdíl (mnozina1 - mnozina2):", rozdil)
# ```
#
# **Očekávaný výstup:**
# ```
# Původní množina: {1, 2, 3, 4, 5}
# Po přidání 6: {1, 2, 3, 4, 5, 6}
# Po přidání 7,8,9: {1, 2, 3, 4, 5, 6, 7, 8, 9}
# Po odstranění 3: {1, 2, 4, 5, 6, 7, 8, 9}
# Po pokusu o odstranění 10: {1, 2, 4, 5, 6, 7, 8, 9}
# Původní seznam: [1, 2, 3, 2, 4, 5, 4, 6]
# Množina bez duplikátů: {1, 2, 3, 4, 5, 6}
# Průnik: {3, 4}
# Sjednocení: {1, 2, 3, 4, 5, 6}
# Rozdíl (mnozina1 - mnozina2): {1, 2}
# ```
#
# **Vysvětlení:** Množiny jsou kolekce jedinečných prvků, které se automaticky odstraňují duplikáty. Používají se pro práci s unikátními daty a množkové operace (průnik, sjednocení, rozdíl). V tomto příkladu ukazujeme základ

# %% [markdown]
# ## 🎯 Cvičení a úkoly
#
# <div style="background: #fff3e0; padding: 20px; border-left: 5px solid #ff9800; margin: 20px 0; border-radius: 5px;">
#     <h3 style="color: #2c3e50; margin-top: 0;">✍️ Praktická cvičení k procvičení</h3>
#     <p>Vyřešte následující úkoly. Začněte od jednoduššších a postupujte k složitějším.</p>
# </div>
#
# # Cvičení pro kapitolu: Základy Pythonu II - Kolekce dat
#
# ---
#
# ## Cvičení 1: Práce s listy (seznamy)
#
# ### **Název úkolu**
# Zpracování seznamu známek studenta
#
# ### **Detailní zadání**
# Vytvoř program, který bude přijímat seznam známek studenta a pak vypočítá průměr. Zároveň program zjistí nejlepší a nejhorší známku.
#
# ### **Vstupní data/požadavky**
# - Vstup: Seznam celých čísel (známky)
# - Příklad vstupu: `[1, 2, 3, 4, 5]`
#
# ### **Očekávaný výstup**
# Vytiskni:
# - Průměr známek
# - Nejlepší známku
# - Nejhorší známku
#
# ### **Hints/Nápověda**
# 1. Použij funkce `sum()` a `len()` pro výpočet průměru.
# 2. Použij funkce `max()` a `min()` pro nalezení nejlepší a nejhorší známky.
# 3. Ujisti se, že vstup je platný seznam čísel.
# 4. Formátuj výstup hezky, např. jako řetězec.
#
# ### **Kostra řešení**
# ```python
# známky = [1, 2, 3, 4, 5]
#
# # Výpočty
#
# print(f"Průměr: {průměr}")
# print(f"Nejlepší známka: {nejlepší}")
# print(f"Nejhorší známka: {nejhorší}")
# ```
#
# ### **Bonusové rozšíření**
# Přidej možnost zadání známek přes uživatelský vstup a ošetři případné chyby (např. nečíselný vstup).
#
# ---
#
# ## Cvičení 2: Práce s slovníky
#
# ### **Název úkolu**
# Vytvoř jednoduchý slovník pro evidenci knih
#
# ### **Detailní zadání**
# Vytvoř program, který umožní ukládat informace o knihách do slovníku (název, autor, rok vydání). Přidej možnost přidat novou knihu a vyhledat knihu podle autora.
#
# ### **Vstupní data/požadavky**
# - Slovník obsahuje položky jako `{"název": "Kniha", "autor": "Autor", "rok": 2020}`
# - Možnost přidat více knih
#
# ### **Očekávaný výstup**
# - Výpis všech knih
# - Vyhledání knih podle autora (výpis všech knih od daného autora)
#
# ### **Hints/Nápověda**
# 1. Použij slovník k ukládání informací o knize.
# 2. Vytvoř funkci pro přidání nové knihy.
# 3. Iteruj přes seznam slovníků (knih).
# 4. Použij klíče ve slovníku k vyhledání knih podle autora.
#
# ### **Kostra řešení**
# ```python
# knihy = []
#
# def pridej_knihu(název, autor, rok):
#     # Přidání knihy do seznamu
#
# def vyhledej_podle_autora(autor):
#     # Vyhledání knih podle autora
#
# # Příklad použití
# ```
#
# ### **Bonusové rozšíření**
# Přidej možnost smazat knihu podle názvu a vytisknout seznam všech autorů.
#
# ---
#
# ## Cvičení 3: Práce s množinami
#
# ### **Název úkolu**
# Analýza jedinečných hodnot ve třídě
#
# ### **Detailní zadání**
# Máš seznam jmen studentů, kteří se zúčastnili různých aktivit. Vytvoř program, který najde:
# - Seznam všech jedinečných jmen (bez opakování)
# - Počet studentů, kteří se zúčastnili více aktivit
#
# ### **Vstupní data/požadavky**
# - Seznam jmen jako řetězce
# - Příklad: `["Petr", "Jana", "Petr", "Martin", "Jana"]`
#
# ### **Očekávaný výstup**
# - Seznam jedinečných jmen
# - Počet studentů, kteří se zúčastnili více aktivit
#
# ### **Hints/Nápověda**
# 1. Použij `set()` pro odstranění duplicit.
# 2. Počítej výskyt každého jména ve vstupu.
# 3. Porovnej délku původního seznamu a množiny.
# 4. Vypiš jedinečná jména a počet opakujících se.
#
# ### **Kostra řešení**
# ```python
# seznam_studentu = ["Petr", "Jana", "Petr", "Martin", "Jana"]
#
# # Výpočty
#
# print(f"Jedineční studenti: {jedinecni}")
# print(f"Studenti, kteří se zúčastnili více aktivit: {pocet_opakovani}")
# ```
#
# ### **Bonusové rozšíření**
# Přidej funkci pro výpis počtu aktivit u každého studenta.
#
# ---
#
# ## Cvičení 4: Práce s n-ticemi
#
# ### **Název úkolu**
# Zpracování souřadnic bodů
#
# ### **Detailní zadání**
# Vytvoř program, který přijme seznam souřadnic (x, y) jako n-tice a spočítá vzdálenost mezi prvním a posledním bodem.
#
# ### **Vstupní data/požadavky**
# - Seznam n-tic ve tvaru `[(x1, y1), (x2, y2), ...]`
# - Příklad: `[(0, 0), (3, 4), (6, 8)]`
#
# ### **Očekávaný výstup**
# Výpočet vzdálenosti mezi prvním a posledním bodem pomocí Pythagorovy věty
#
# ### **Hints/Nápověda**
# 1. Využij `math.sqrt()` a `math.pow()` pro výpočet vzdálenosti.
# 2. První bod je první n-tice, poslední je poslední n-tice.
# 3. Použij základní Pythagorovu větu: `c = √((x₂ - x₁)² + (y₂ - y₁)²)`
# 4. Výpočet vzdálenosti mezi dvěma body
#
# ### **Kostra řešení**
# ```python
# import math
#
# souřadnice = [(0, 0), (3, 4), (6, 8)]
#
# # Výpočet vzdálenosti
#
# print(f"Vzdálenost: {vzdalenost}")
# ```
#
# ### **Bonusové rozšíření**
# Přidej funkci pro výpočet vzdálenosti mezi libovolnými dvěma body.
#
# ---
#
# ## Cvičení 5: Práce s kombinací kolekcí
#
# ### **Název úkolu**
# Analýza dat o studentech a jejich známkách
#
# ### **Detailní zadání**
# Vytvoř program, který bude obsahovat:
# - Seznam jmen studentů
# - Slovník známek (jméno → seznam známek)
# - Výpočet průměru pro každého studenta
#
# ### **Vstupní data/požadavky**
# - `studenti = ["Petr", "Jana", "Martin"]`
# - `známky = {"P

# %% [markdown]
# ## 📚 Další zdroje a materiály
#
# <div style="background: #e3f2fd; padding: 20px; border-left: 5px solid #2196f3; margin: 20px 0; border-radius: 5px;">
#     <h3 style="color: #2c3e50; margin-top: 0;">🔗 Doporučené materiály k dalšímu studiu</h3>
# </div>
#
# # Základy Pythonu II – Kolekce dat – Seznam zdrojů
#
# ## 1. Články a tutoriály
#
# 1. **[Python Collections Module - Real Python](https://realpython.com/python-collections-module/)**
#    *Popis:* Komplexní průvodce modulům `collections` v Pythonu, které poskytují rozšířené datové struktury jako `deque`, `Counter`, `namedtuple` a další. Vhodné pro začátečníky i pokročilé uživatele.
#
# 2. **[Python Lists, Tuples, Sets, and Dictionaries - W3Schools](https://www.w3schools.com/python/python_datatypes.asp)**
#    *Popis:* Jednoduchý a přehledný výukový materiál o základních kolekcích dat v Pythonu. Vhodný pro rychlé zopakování nebo úvod do tématu.
#
# 3. **[Data Structures in Python - GeeksforGeeks](https://www.geeksforgeeks.org/data-structures-in-python/)**
#    *Popis:* Detailní přehled různých datových struktur v Pythonu, včetně seznamů, slovníků, množin a dalších. Obsahuje i příklady kódu a vysvětlení jejich využití.
#
# 4. **[Python Data Structures - Python.org](https://docs.python.org/3/tutorial/datastructures.html)**
#    *Popis:* Oficiální dokumentace z Pythonu 3 – rozšířený úvod do datových struktur, který je velmi podrobný a vhodný pro uživatele, kteří chtějí porozumět fungování základních kolekcí.
#
# 5. **[Python Collections - Tutorialspoint](https://www.tutorialspoint.com/python/python_collections.htm)**
#    *Popis:* Shrnutí a vysvětlení různých typů kolekcí v Pythonu, včetně praktických příkladů. Vhodné pro uživatele hledající strukturovaný kurz.
#
# ## 2. YouTube videa
#
# 1. **[Python Collections - Programming with Mosh](https://www.youtube.com/watch?v=3Z6k5gF780M)**
#    *Délka:* 14:36
#    *Popis:* Krátké a srozumitelné video o kolekcích v Pythonu – seznamy, n-tice, slovníky a množiny. Vhodné pro začátečníky.
#
# 2. **[Python Collections Module Explained - Corey Schafer](https://www.youtube.com/watch?v=9q2dJ06cY4E)**
#    *Délka:* 18:17
#    *Popis:* Výklad modulu `collections` v Pythonu – vysvětlení `defaultdict`, `Counter`, `namedtuple` a dalších. Velmi užitečné pro pokročilého programátora.
#
# 3. **[Python Data Structures - freeCodeCamp](https://www.youtube.com/watch?v=0V6i781d20g)**
#    *Délka:* 28:43
#    *Popis:* Komplexní video o různých datových strukturách v Pythonu. Obsahuje i praktické příklady a aplikace.
#
# ## 3. Knihy a oficiální dokumentace
#
# 1. **[Automate the Boring Stuff with Python – Al Sweigart](https://automatetheboringstuff.com/)**
#    *Popis:* Skvělá kniha pro začátečníky, která vysvětluje základy Pythonu i pokročilé koncepty jako práce s kolekcemi. Obsahuje praktické projekty.
#
# 2. **[Python Tricks - Dan Bader](https://www.pythontricks.org/book)**
#    *Popis:* Výuková kniha zaměřená na pokročilé techniky v Pythonu, včetně práce s

# %% [markdown]
# ## 📝 Shrnutí kapitoly
#
# <div style="background: linear-gradient(135deg, #667eea 0%, #764ba2 100%); padding: 30px; border-radius: 10px; color: white; margin: 30px 0;">
#     <h3 style="color: white; margin-top: 0;">✅ Co jste se naučili</h3>
#     <ul style="list-style: none; padding-left: 0;">
#         <li>✓ Seznamy (lists) - metody a operace</li>
# <li>✓ Tuple - immutable sequences</li>
# <li>✓ Množiny (sets) - unique values</li>
# <li>✓ Slovníky (dictionaries) - key-value pairs</li>
# <li>✓ Cykly: for, while, else clause</li>
#     </ul>
#
#     <h3 style="color: white;">🎯 Klíčové dovednosti</h3>
#     <p>Po dokončení této kapitoly byste měli být schopni prakticky použít všechny probrané koncepty.</p>
#
#     <h3 style='color: white;'>➡️ Další kapitola</h3><p>Kapitola 7 - pokračujte ve studiu!</p>
# </div>
#
# ---
#
# *📅 Notebook vygenerován: 2025-09-29 11:52:44*
# *🤖 Generátor: Comprehensive Colab Generator v2.0*
# *📚 Učebnice programování - Od základů k AI*

# %% [markdown]
# ## 🧪 Sandbox - Prostor pro experimenty
#
# Použijte následující buňky pro vlastní experimenty a testování:

# %%
# 🧪 Zde můžete experimentovat s kódem z kapitoly
# Napište svůj kód zde:
