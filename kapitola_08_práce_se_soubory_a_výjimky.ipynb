# %% [markdown]
# # 📚 Kapitola 8: Práce se soubory a výjimky
#
# <div style="background: linear-gradient(90deg, #667eea 0%, #764ba2 100%); padding: 20px; border-radius: 10px; margin: 20px 0;">
#     <h2 style="color: white; margin: 0;">Blok 1 | BEGINNER</h2>
#     <p style="color: white; margin: 10px 0;">📖 Výuková kapitola</p>
# </div>
#
# ## 🎯 Co se naučíte
#
# V této kapitole se zaměříme na následující témata:
#
# - **Čtení a zápis textových souborů**
# - **Binary files**
# - **Context managers (with statement)**
# - **CSV - reading and writing**
# - **JSON - parsing and generation**
# - **Try/except/else/finally**
# - **Vlastní výjimky, raise statement**
#
# ## ⚠️ Předpoklady
# Tato kapitola navazuje na kapitoly: 7
#
# ---

# %%
# ⚙️ Inicializace prostředí
# Tento kód nastavuje prostředí pro kapitolu 8

import sys
import os
from datetime import datetime

# Informace o prostředí
print("=" * 60)
print(f"📚 KAPITOLA 8: Práce se soubory a výjimky")
print("=" * 60)
print(f"🐍 Python verze: {sys.version}")
print(f"📅 Datum spuštění: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
print(f"💻 OS: {os.name}")
print(f"📁 Pracovní adresář: {os.getcwd()}")
print("=" * 60)

# Instalace potřebných knihoven (odkomentujte podle potřeby)
# !pip install requests pandas numpy matplotlib
# !pip install beautifulsoup4 sqlalchemy fastapi

# Import základních knihoven
import json
import csv
import time
import random
from pathlib import Path
from typing import List, Dict, Optional, Any

print("✅ Prostředí připraveno!")

# %% [markdown]
# ## 📖 Teoretická část
#
# <div style="background: #f0f4ff; padding: 20px; border-left: 5px solid #4a69bd; margin: 20px 0; border-radius: 5px;">
#     <h3 style="color: #2c3e50; margin-top: 0;">🎓 Základní teorie a koncepty</h3>
# </div>
#
# # Práce se soubory a výjimky
#
# ## 1. Úvod a motivace
#
# Práce se soubory a práce s výjimkami jsou základními dovednostmi každého programátora, které se objevují prakticky ve všech aplikacích – od jednoduchých skriptů po složité systémy. V Pythonu je práce se soubory jednoduchá a přehledná, ale zároveň velmi důležitá, protože umožňuje ukládat a číst data z disku, což je nezbytné pro většinu reálných aplikací. Výjimky (exceptions) jsou mechanismus, který nám pomáhá řešit chyby během provádění programu – bez nich by naše programy často spadly při nečekaném chování.
#
# V praxi se setkáváme s mnoha situacemi, kdy potřebujeme načíst data z externího zdroje (např. konfigurační soubor), uložit výsledky práce programu, nebo načíst CSV tabulku pro zpracování dat. Všechny tyto operace mohou selhat – například soubor nemusí existovat, nemá správné oprávnění, nebo je poškozený. Proto je velmi důležité vést řízení nad těmito chybami pomocí výjimek. Tato kapitola tě naučí, jak efektivně pracovat se soubory a jak se správně vyrovnávat s chybami – což je klíčové pro psaní spolehlivého a robustního kódu.
#
# ## 2. Hlavní koncepty
#
# ### Čtení a zápis textových souborů
#
# Práce se soubory v Pythonu začíná otevřením. Nejjednodušší způsob je použít funkci `open()`. Tato funkce přijímá název souboru a režim, ve kterém ho chceme otevřít – například `'r'` pro čtení, `'w'` pro zápis nebo `'a'` pro přidání obsahu na konec souboru.
#
# ```python
# # Otevření souboru pro čtení
# file = open("data.txt", "r")
# content = file.read()
# print(content)
# file.close()  # Důležité: soubor je nutné uzavřít!
# ```
#
# Používání `close()` je důležité – bez něj může dojít k ztrátě dat nebo problémům se systémem. Abychom se vyhnuli chybám, používáme **context manager** (např. příkaz `with`), který automaticky uzavře soubor.
#
# ```python
# # Použití with – automatické uzavření
# with open("data.txt", "r") as file:
#     content = file.read()
#     print(content)
# # Soubor je automaticky uzavřen po skončení bloku `with`
# ```
#
# Pro zápis do souboru se používá režim `"w"` nebo `"a"`. Režim `"w"` přepíše celý obsah, zatímco `"a"` přidá nový text na konec.
#
# ```python
# # Zápis do souboru
# with open("output.txt", "w") as file:
#     file.write("Hello, world!\n")
# ```
#
# ### Binary files
#
# Kromě textových souborů můžeme pracovat i s binárními soubory – např. obrázky, audio nebo video soubory. Tyto soubory se otevírají stejným způsobem, ale s příznakem `'b'` (binary mode).
#
# ```python
# # Čtení binárního souboru
# with open("image.jpg", "rb") as file:
#     data = file.read()
# ```
#
# Použití binárních režimů je důležité při práci s daty, které nemají textovou podobu. Například obrázky se nevykreslí správně, pokud se budou číst jako text.
#
# ### Context managers (with statement)
#
# V Pythonu je `with` klíčové slovo pro práci s context managerem – tedy objekty, které mají metody `__enter__()` a `__exit__()`. Použití `with` zajistí, že se zdroje (např. soubory) správně uvolní, i kdyby došlo k chybě.
#
# ```python
# # Příklad context manageru – soubor se automaticky uzavře
# with open("file.txt", "r") as f:
#     content = f.read()
#     # Kód zde může vyvolat výjimku, ale soubor se stále uzavře
# ```
#
# Více context managerů:
#
# ```python
# with open("input.txt", "r") as infile, open("output.txt", "w") as outfile:
#     data = infile.read()
#     outfile.write(data.upper())
# ```
#
# ### CSV - čtení a zápis
#
# CSV (Comma-Separated Values) soubory jsou velmi časté pro ukládání tabulkových dat. V Pythonu se pracuje s nimi pomocí modulu `csv`.
#
# ```python
# import csv
#
# # Čtení CSV
# with open("data.csv", "r") as file:
#     reader = csv.reader(file)
#     for row in reader:
#         print(row)
#
# # Zápis CSV
# data = [["Jmeno", "Vek"], ["Petr", 25], ["Anna", 30]]
#
# with open("output.csv", "w", newline="") as file:
#     writer = csv.writer(file)
#     writer.writerows(data)
# ```
#
# ### JSON - parsování a generování
#
# JSON (JavaScript Object Notation) je běžný formát pro přenos dat mezi klientem a serverem. V Pythonu se používá modul `json` pro práci s tímto formátem.
#
# ```python
# import json
#
# # Zápis do JSON
# data = {"jméno": "Petr", "vek": 25}
# with open("data.json", "w") as file:
#     json.dump(data, file)
#
# # Čtení z JSON
# with open("data.json", "r") as file:
#     data = json.load(file)
#     print(data)  # {'jméno': 'Petr', 'vek': 25}
# ```
#
# ### Try/except/else/finally
#
# Chyby se v Pythonu řeší pomocí bloků `try`, `except`, `else` a `finally`. Tento mechanismus nám umožňuje předvídat a řešit chyby bez pádu programu.
#
# ```python
# try:
#     file = open("nonexistent.txt", "r")
#     content = file.read()
# except FileNotFoundError:
#     print("Soubor nebyl nalezen.")
# except PermissionError:
#     print("Nemáte oprávnění k přístupu.")
# else:
#     print("Soubor byl úspěšně přečten.")
# finally:
#     print("Tento blok se vždy spustí.")
# ```
#
# - `try`: obsahuje kód, který může vyvolat výjimku.
# - `except`: zachytí konkrétní typ výjimky.
# - `else`: spustí se, pokud žádná výjimka nevznikne.
# - `finally`: spustí se vždy, bez ohledu na to, zda došlo k chybě.
#
# ### Vlastní výjimky, raise statement
#
# Python umožňuje definovat vlastní typy výjimek. To je užitečné při tvorbě knihoven nebo aplikací s komplexním řízením chyb.
#
# ```python
# class CustomError(Exception):
#     pass
#
# def divide(a, b):
#     if b == 0:
#         raise CustomError("Dělení nulou není povoleno!")
#     return a / b
#
# try:
#     result = divide(10, 0)
# except CustomError as e:
#     print(e)
# ```
#
# Pomocí `raise` můžeme vlastní chyby vyvolat v libovolném místě programu.
#
# ## 3. Důležité detaily
#
# ### Časté chyby a jak se jim vyhnout
#
# - **Nepoužívání `with` při práci se soubory** – to může vést k ztrátě dat nebo problémům s otevřením.
# - **Nezavírání souborů ručně** – pokud někde skončí chyba, soubor se nemusí uzavřít.
# - **Zapomínání na režim při práci se soubory** – např. čtení binárních souborů v textovém režimu.
# - **Nepoužívání `json.load()` a `json.dump()`** – místo toho použití `open()` a `read()` nebo `write()` může způsobit chyby.
#
# ### Best practices
#
# - Vždy používej `with` pro práci se soubory.
# - Používej konkrétní typy výjimek (`FileNotFoundError`, `PermissionError`) místo obecného `except:`.
# - Zabezpečuj správné ošetření chyb při práci s externími daty (např. soubory, API).
# - Při práci s JSON používej `indent` parametr pro čitelnost.
#
# ### Performance tipy
#
# - Pro velké soubory čti po řádcích (např. `for line in file:`) místo `read()` – ušetříš paměť.
# - Využívej bufferování, pokud pracuješ s výkonnostními operacemi.
# - V případě opakované práce se stejnými daty je efektivní jejich uložení do proměnné nebo cache.
#
# ## 4. Propojení s předchozími kapitolami
#
# Tato kapitola se vztahuje k předchozím tématům jako jsou proměnné, cykly a funkce – každá z těchto konceptů je nutná pro správnou práci s daty. Například cykly se používají pro čtení řádků ze souboru nebo pro zpracování seznamu dat. Funkce mohou být využity k čistému a opakovaně použitelnému zpracování souborů. Výjimky rozšiřují znalosti o tom, jak řešit chyby – což je klíčové pro spolehlivost programu.
#
# Práce se soubory a výjimkami tvoří základ pro další pokročilé téma jako například práce s databázemi, REST API nebo logování – všechno to závisí na správném ošetření chyb a ukládání dat.

# %% [markdown]
# ## 💻 Praktické příklady
#
# <div style="background: #e8f5e9; padding: 20px; border-left: 5px solid #4caf50; margin: 20px 0; border-radius: 5px;">
#     <h3 style="color: #2c3e50; margin-top: 0;">👨‍💻 Hands-on příklady ke spuštění</h3>
#     <p>Následující příklady si můžete hned vyzkoušet. Každý příklad je samostatně spustitelný.</p>
# </div>

# %% [markdown]
# ### Příklad 1
#
# Příklad použití try/except/else/finally
# def zpracuj_vek(vez):
#     try:
#         print(f"Zpracovávám věk: {vez}")
#         vysledek = over_vez(vez)
#
#     except NeplatneVek as e:
#         print(f"Chyba: {e}")
#         return None
#
#     else:
#         print("Věk byl úspěšně ověřen")
#         return vysledek
#
#     finally:
#         print("Zpracování věku bylo dokončeno")
#
# # Testování různých případů
# print("Test 1 - platný věk:")
# zpracuj_vek(25)
#
# print("\nTest 2 - záporný věk:")
# zpracuj_vek(-5)
#
# print("\nTest 3 - příliš velký věk:")
# zpracuj_vek(200)
#
# # Zápis do souboru se správnou obsluhou chyb
# def zapis_do_souboru(soubor, data):
#     try:
#         with open(soubor, "w", encoding="utf-8") as f:
#             f.write(data)
#
#     except PermissionError:
#         print("Chyba: Nemám oprávnění zapisovat do souboru")
#
#     except Exception as e:
#         print(f"Nečekaná chyba při zápisu: {e}")
#
#     else:
#         print("Data byla úspěšně zapsána do souboru")
#
#     finally:
#         print("Zápis do souboru dokončen")
#
# print("\nTest 4 - zápis do souboru:")
# zapis_do_souboru("test.txt", "Toto je testovací obsah")
# ```
#
# ## Očekávaný výstup:
# ```
# Test 1 - platný věk:
# Zpracovávám věk: 25
# Věk byl úspěšně ověřen
# Věk

# %% [markdown]
# ## 🎯 Cvičení a úkoly
#
# <div style="background: #fff3e0; padding: 20px; border-left: 5px solid #ff9800; margin: 20px 0; border-radius: 5px;">
#     <h3 style="color: #2c3e50; margin-top: 0;">✍️ Praktická cvičení k procvičení</h3>
#     <p>Vyřešte následující úkoly. Začněte od jednoduššších a postupujte k složitějším.</p>
# </div>
#
# # 5 Praktických cvičení: Práce se soubory a výjimky
#
# ---
#
# ## **Cvičení 1: Čtení dat ze souboru a zpracování chyb**
#
# ### **Název úkolu**
# Čtení souboru s kontrolou výjimek
#
# ### **Detailní zadání**
# Vytvořte program, který načte obsah textového souboru `data.txt` a vytiskne jeho obsah. Pokud soubor neexistuje nebo nemá přístup pro čtení, program vypíše chybovou zprávu a pokračuje bez chyby.
#
# ### **Vstupní data/požadavky**
# - Soubor `data.txt` obsahuje libovolný text (např. „Ahoj světe!“)
# - Pokud soubor neexistuje, program nesmí skončit chybou.
#
# ### **Očekávaný výstup**
# - Pokud soubor existuje: Vytiskne obsah souboru.
# - Pokud soubor neexistuje: Vypíše „Soubor data.txt nebyl nalezen.“
#
# ### **Hints/Nápověda**
# 1. Použijte příkaz `try` a `except` pro zachycení chyb.
# 2. Ověřte existenci souboru pomocí funkce `os.path.exists()` nebo zkuste otevřít soubor.
# 3. Výjimka `FileNotFoundError` se vyvolá při pokusu o otevření neexistujícího souboru.
# 4. Můžete použít `with open(...)` pro bezpečné otevírání souboru.
#
# ### **Kostra řešení**
# ```python
# try:
#     with open("data.txt", "r") as file:
#         content = file.read()
#         print(content)
# except FileNotFoundError:
#     print("Soubor data.txt nebyl nalezen.")
# ```
#
# ### **Bonusové rozšíření**
# Přidejte možnost zadání jména souboru přes uživatelský vstup a zpracujte i jiné chyby (např. práva k čtení).
#
# ---
#
# ## **Cvičení 2: Zápis do souboru s ošetřením výjimek**
#
# ### **Název úkolu**
# Zápis dat do souboru a kontrola chyb
#
# ### **Detailní zadání**
# Vytvořte program, který zapíše uživatelský text do souboru `output.txt`. Pokud se zápis nezdaří (např. kvůli právům), program vypíše chybovou hlášku.
#
# ### **Vstupní data/požadavky**
# - Uživatel zadá text (např. „Tento text by měl být uložen.“)
# - Soubor `output.txt` nemusí existovat, ale pokud ano, může být přepsán.
#
# ### **Očekávaný výstup**
# - Pokud zápis proběhne úspěšně: Vypíše „Text byl úspěšně uložen.“
# - Pokud nastane chyba: Vypíše „Chyba při zápisu do souboru.“
#
# ### **Hints/Nápověda**
# 1. Použijte `open(..., "w")` pro zápis do souboru.
# 2. Ošetřete výjimku `PermissionError` a `IOError`.
# 3. Využijte blok `try-except-finally`, pokud potřebujete něco udělat i po chybě.
# 4. Můžete použít `input()` pro přijetí uživatelského vstupu.
#
# ### **Kostra řešení**
# ```python
# try:
#     with open("output.txt", "w") as file:
#         text = input("Zadejte text: ")
#         file.write(text)
#         print("Text byl úspěšně uložen.")
# except (PermissionError, IOError):
#     print("Chyba při zápisu do souboru.")
# ```
#
# ### **Bonusové rozšíření**
# Zapište text do souboru i v případě chyby – např. do záložního souboru.
#
# ---
#
# ## **Cvičení 3: Výjimky při práci s neexistujícím souborem**
#
# ### **Název úkolu**
# Zpracování chyb při čtení souboru
#
# ### **Detailní zadání**
# Vytvořte program, který pokusí se otevřít soubor `unknown.txt`. Pokud se to nepodaří, vypíše název chyby a zaloguje ji do souboru `error.log`.
#
# ### **Vstupní data/požadavky**
# - Soubor `unknown.txt` neexistuje.
# - Program musí zaznamenat chybu do `error.log`.
#
# ### **Očekávaný výstup**
# - V konzoli: „Chyba při čtení souboru: [název chyby]“
# - Obsah `error.log`: Text s názvem chyby a časem.
#
# ### **Hints/Nápověda**
# 1. Použijte `try-except` k zachycení chyby.
# 2. Použijte modul `datetime` pro zaznamenání času.
# 3. Zapište chybu do log souboru pomocí příkazu `with open(..., "a")`.
# 4. Můžete použít `repr()` k zobrazení názvu chyby.
#
# ### **Kostra řešení**
# ```python
# import datetime
#
# try:
#     with open("unknown.txt", "r") as file:
#         content = file.read()
# except FileNotFoundError as e:
#     error_msg = f"Chyba při čtení souboru: {repr(e)} - {datetime.datetime.now()}\n"
#     print(error_msg.strip())
#     with open("error.log", "a") as log_file:
#         log_file.write(error_msg)
# ```
#
# ### **Bonusové rozšíření**
# Zapište i zásadní informace o chybě (např. typ výjimky, čas, cesta k souboru).
#
# ---
#
# ## **Cvičení 4: Řetězcová konverze a kontrola vstupu**
#
# ### **Název úkolu**
# Zpracování chyb při práci se soubory a číselnými daty
#
# ### **Detailní zadání**
# Vytvořte program, který otevře soubor `numbers.txt`, který obsahuje čísla v řetězcích (např. „10\n20\n30“). Převeďte jejich součet a zapište do nového souboru `sum.txt`. V případě chyby (např. chybná hodnota) vypište chybu.
#
# ### **Vstupní data/požadavky**
# - Soubor `numbers.txt` obsahuje čísla na jednotlivých řádcích.
# - Pokud se jedná o nečíselné hodnoty, program musí zachytit chybu.
#
# ### **Očekávaný výstup**
# - Pokud je vše v pořádku: Zapíše součet do `sum.txt`.
# - Pokud je chyba: Vypíše „Chybný formát čísla ve souboru.“
#
# ### **Hints/Nápověda**
# 1. Čtení souboru: použijte `readlines()` nebo `for line in file`.
# 2. Použijte `int()` nebo `float()` pro převod řetězce na číslo.
# 3. Výjimka `ValueError` se vyvolá, pokud převod selže.
# 4. Můžete použít `continue` v cyklu pro přeskočení chybných hodnot.
#
# ### **Kostra řešení**
# ```python

# %% [markdown]
# ## 📚 Další zdroje a materiály
#
# <div style="background: #e3f2fd; padding: 20px; border-left: 5px solid #2196f3; margin: 20px 0; border-radius: 5px;">
#     <h3 style="color: #2c3e50; margin-top: 0;">🔗 Doporučené materiály k dalšímu studiu</h3>
# </div>
#
# # Zdroje pro kapitolu: Práce se soubory a výjimky
#
# ## Články a tutoriály
#
# 1. **[Python File Handling - Real Python](https://realpython.com/read-write-files-python/)**
#    Komplexní průvodce práci se soubory v Pythonu, včetně čtení, zápisu, správy kurzorů a práce s různými formáty. Vhodné pro začátečníky i pokročilé.
#
# 2. **[Python Exception Handling - GeeksforGeeks](https://www.geeksforgeeks.org/python-exception-handling/)**
#    Podrobný článek o výjimkách v Pythonu, s příklady použití `try`, `except`, `else` a `finally`. Obsahuje i pokyny pro vlastní výjimky.
#
# 3. **[Working with Files in Python - Python.org Official Tutorial](https://docs.python.org/3/tutorial/inputoutput.html#reading-and-writing-files)**
#    Oficiální dokumentace z Pythonu s příklady práce se soubory – jedna z nejdůležitějších částí pro pochopení základní práce se soubory.
#
# 4. **[Python File I/O and Exception Handling - W3Schools](https://www.w3schools.com/python/python_file_handling.asp)**
#    Jednoduchý a přehledný tutoriál zaměřený na základy práce se soubory i zpracování výjimek, vhodný pro rychlé osvojení.
#
# 5. **[Python Exceptions and File Handling - Programiz](https://www.programiz.com/python-programming/exception-handling)**
#    Článek zaměřený na základní pojmy výjimek a jejich správné použití, doplněný praktickými příklady.
#
# ## YouTube videa
#
# 1. **[Python File Handling - Programming with Mosh](https://www.youtube.com/watch?v=7R6358Z29Q0)**
#    Délka: 14 min
#    Videa vysvětluje práci se soubory, jak otevírat, číst a zapisovat do souborů. Jasný výklad pro začátečníky.
#
# 2. **[Python Exception Handling - Corey Schafer](https://www.youtube.com/watch?v=NIWwJIFpYkM)**
#    Délka: 17 min
#    Výukové video o zpracování výjimek, ukázky použití `try/except`, `raise` a jak řešit chyby efektivně.
#
# 3. **[Python File Operations - Telusko](https://www.youtube.com/watch?v=2Fh6D9Vg1Yw)**
#    Délka: 20 min
#    Komplexní přehled práce se soubory včetně zápisu, čtení a správy souborových kurzorů.
#
# ## Knihy a oficiální dokumentace
#
# 1. **[Automate the Boring Stuff with Python](https://automatetheboringstuff.com/)**
#    Skvělá kniha zaměřená na praktické aplikace Pythonu, včetně práce se soubory a zpracování chyb. Vhodné pro začátečníky.
#
# 2. **[Python Official Documentation - Exceptions](https://docs.python.org/3/tutorial/errors.html)**
#    Oficiální stránka o výjimkách v Pythonu – detailní popis všech typů výjimek, jejich použití a zpracování.
#
# 3. **[Effective Python: 90 Specific Ways to Write Better Python](https://effectivepython.com/)**
#    Kniha, která se zaměřuje na pokyny pro psaní efektivního a čistého kódu v Pythonu – obsahuje kapitoly i o správném zacházení s výjimkami a soubory.
#
# ## Praktické projekty
#
# 1

# %% [markdown]
# ## 📝 Shrnutí kapitoly
#
# <div style="background: linear-gradient(135deg, #667eea 0%, #764ba2 100%); padding: 30px; border-radius: 10px; color: white; margin: 30px 0;">
#     <h3 style="color: white; margin-top: 0;">✅ Co jste se naučili</h3>
#     <ul style="list-style: none; padding-left: 0;">
#         <li>✓ Čtení a zápis textových souborů</li>
# <li>✓ Binary files</li>
# <li>✓ Context managers (with statement)</li>
# <li>✓ CSV - reading and writing</li>
# <li>✓ JSON - parsing and generation</li>
#     </ul>
#
#     <h3 style="color: white;">🎯 Klíčové dovednosti</h3>
#     <p>Po dokončení této kapitoly byste měli být schopni prakticky použít všechny probrané koncepty.</p>
#
#     <h3 style='color: white;'>➡️ Další kapitola</h3><p>Kapitola 9 - pokračujte ve studiu!</p>
# </div>
#
# ---
#
# *📅 Notebook vygenerován: 2025-09-29 11:58:55*
# *🤖 Generátor: Comprehensive Colab Generator v2.0*
# *📚 Učebnice programování - Od základů k AI*

# %% [markdown]
# ## 🧪 Sandbox - Prostor pro experimenty
#
# Použijte následující buňky pro vlastní experimenty a testování:

# %%
# 🧪 Zde můžete experimentovat s kódem z kapitoly
# Napište svůj kód zde:
