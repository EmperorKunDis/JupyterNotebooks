# %% [markdown]
# # 📚 Kapitola 21: Docker základy
#
# <div style="background: linear-gradient(90deg, #667eea 0%, #764ba2 100%); padding: 20px; border-radius: 10px; margin: 20px 0;">
#     <h2 style="color: white; margin: 0;">Blok 3 | ADVANCED</h2>
#     <p style="color: white; margin: 10px 0;">📖 Výuková kapitola</p>
# </div>
#
# ## 🎯 Co se naučíte
#
# V této kapitole se zaměříme na následující témata:
#
# - **Docker installation všechny OS**
# - **Docker architecture**
# - **Dockerfile syntax a best practices**
# - **Building images**
# - **Container management**
# - **Volumes a bind mounts**
# - **Networking basics**
#
# ## ⚠️ Předpoklady
# Tato kapitola navazuje na kapitoly: 4
#
# ---

# %%
# ⚙️ Inicializace prostředí
# Tento kód nastavuje prostředí pro kapitolu 21

import sys
import os
from datetime import datetime

# Informace o prostředí
print("=" * 60)
print(f"📚 KAPITOLA 21: Docker základy")
print("=" * 60)
print(f"🐍 Python verze: {sys.version}")
print(f"📅 Datum spuštění: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
print(f"💻 OS: {os.name}")
print(f"📁 Pracovní adresář: {os.getcwd()}")
print("=" * 60)

# Instalace potřebných knihoven (odkomentujte podle potřeby)
# !pip install requests pandas numpy matplotlib
# !pip install beautifulsoup4 sqlalchemy fastapi

# Import základních knihoven
import json
import csv
import time
import random
from pathlib import Path
from typing import List, Dict, Optional, Any

print("✅ Prostředí připraveno!")

# %% [markdown]
# ## 📖 Teoretická část
#
# <div style="background: #f0f4ff; padding: 20px; border-left: 5px solid #4a69bd; margin: 20px 0; border-radius: 5px;">
#     <h3 style="color: #2c3e50; margin-top: 0;">🎓 Základní teorie a koncepty</h3>
# </div>
#
# # Docker základy – Detailní teoretický výklad
#
# ---
#
# ## 1. Úvod a motivace
#
# Docker je jedna z nejvýznamnějších technologií v oblasti kontejnerizace, která umožňuje snadné nasazování, spouštění a správu aplikací ve všech prostředích – od vývojového po produkční. V dnešní době, kdy se zvyšuje důraz na automatizaci, škálovatelnost a kontrolovatelnost aplikací, je Docker nezbytný nástroj pro každého vývojáře nebo DevOps inženýra.
#
# Zajímavé je, že Docker se používá ve velkých společnostech jako jsou Netflix, Spotify, Uber a mnoho jiných – a to jak na interních systémech, tak v cloudu. V praxi se Docker používá zejména pro:
#
# - **Kontrolu závislostí aplikací**,
# - **Zajištění konzistence mezi prostředími (dev, test, prod)**,
# - **Snadnou škálovatelnost mikroslužeb**,
# - **Rychlé nasazování a aktualizace aplikací**.
#
# Student, který se naučí Docker základy, se naučí práci s kontejnery, správu image a vytváření konzistentních nasazení – což je klíčová dovednost pro moderní softwarový vývoj.
#
# ---
#
# ## 2. Hlavní koncepty
#
# ### Docker Installation všechny OS
#
# Docker se dá nainstalovat na různé operační systémy (Linux, macOS, Windows). Pro každý systém je zvláštní instalační postup:
#
# - **Linux**: Instalace probíhá přes balíčkovací systémy jako `apt` nebo `yum`. Např. na Ubuntu:
#   ```bash
#   sudo apt update
#   sudo apt install docker.io
#   ```
#
# - **macOS a Windows**: Zde se používá Docker Desktop, který zajišťuje spuštění Docker engine ve virtuálním prostředí.
#
# Po instalaci je možné ověřit správnost instalace:
# ```bash
# docker --version
# ```
#
# ### Docker Architecture
#
# Docker je postavený na **client-server architektuře**. Základní komponenty jsou:
#
# - **Docker Client**: Klient, který se používá pro komunikaci s Docker daemonem.
# - **Docker Daemon (dockerd)**: Server, který zpracovává příkazy a spravuje image, kontejnery a síťové prostředí.
# - **Docker Images**: Nezměnitelné šablony použité pro vytvoření kontejneru.
# - **Docker Containers**: Spuštěné instance Docker image.
#
# Základní princip: klient (např. příkaz `docker run`) komunikuje s démonem, který pak vytváří nebo spravuje kontejnery.
#
# ### Dockerfile syntax a best practices
#
# Dockerfile je textový soubor, který obsahuje pokyny pro vytvoření image. Zde je základní syntaxe:
#
# ```dockerfile
# FROM ubuntu:20.04
# RUN apt update && apt install -y python3
# COPY . /app
# WORKDIR /app
# CMD ["python3", "app.py"]
# ```
#
# **Nejlepší praktiky**:
# - Používej `ARG` a `ENV` pro nastavení proměnných.
# - Minimalizuj počet vrstev (`RUN`) – použij `&&` a `||`.
# - Nastav `USER` na neprávního uživatele.
# - Používej `.dockerignore`.
#
# ### Building images
#
# Příkaz `docker build` vytvoří image z Dockerfile:
#
# ```bash
# docker build -t my-app .
# ```
#
# Tento příkaz:
# - Projde Dockerfile,
# - Vytvoří vrstvy (layers),
# - Uloží image s názvem `my-app`.
#
# Vrstvy se mezi buildy ukládají do cache – pokud se soubory nezmění, použije se uložená vrstva.
#
# ### Container management
#
# Základní příkazy pro práci s kontejnery:
#
# - `docker run` – spustí kontejner.
# - `docker ps` – zobrazí běžící kontejnery.
# - `docker stop <container_id>` – zastaví kontejner.
# - `docker rm <container_id>` – smaže kontejner.
# - `docker logs <container_id>` – zobrazí logy.
#
# ### Volumes a bind mounts
#
# **Volumes** jsou vytvořeny Dockerem a jsou spravovány systémem. Vhodné pro trvalá data:
#
# ```bash
# docker volume create my-volume
# docker run -v my-volume:/data app
# ```
#
# **Bind mounts** připojují adresář z hostitelského systému do kontejneru:
#
# ```bash
# docker run -v /host/path:/container/path app
# ```
#
# ### Networking basics
#
# Docker vytváří vlastní síťové prostředí pro každý kontejner. Výchozí sítě:
# - `bridge` – výchozí, spojuje kontejnery v rámci jednoho hostitele.
# - `host` – sdílí síť hostitelského systému.
# - `none` – žádná síťová izolace.
#
# Příklad:
# ```bash
# docker run --network bridge my-app
# ```
#
# ---
#
# ## 3. Důležité detaily
#
# ### Časté chyby a jak se jim vyhnout
#
# - **Nepoužívání `.dockerignore`**: Může způsobit velké image, které se dlouho buildují.
# - **Používání `root useru` v kontejneru**: Sníží bezpečnost – použij `USER` příkaz.
# - **Nezachytávání logů**: Při ladění je důležité sledovat logy kontejneru.
#
# ### Best practices
#
# - Využívej multi-stage buildy pro snížení velikosti image.
# - Používej tagy image (např. `latest`, `v1.0`).
# - Vyčisti nepoužité image pomocí `docker system prune`.
# - Nepoužívej `CMD` a `ENTRYPOINT` společně – pokud ano, použij `exec`.
#
# ### Performance tipy
#
# - Využívej Docker build cache.
# - Používej co nejmenší základní image (např. `alpine`).
# - Zkontroluj, jestli kontejner nepoužívá nadbytečné porty nebo zdroje.
#
# ---
#
# ## 4. Propojení s předchozími kapitolami
#
# Tato kapitola je těsně propojená s kapitolami o Linuxu a systémech, protože Docker využívá Linuxové technologie jako namespaces, cgroups a chroot. Znalosti základů Linuxu (např. práce s terminálem, správa souborů, procesy) jsou klíčové pro porozumění tomu, jak Docker funguje pod pokličkou.
#
# Také je to rozšíření kapitoly o virtualizaci – zatímco virtualizace vytváří celé virtuální počítače, Docker používá sdílení jádra a izolaci procesů, což umožňuje rychlejší a efektivnější spouštění aplikací.
#
# ---
#
# Tato kapitola tedy představuje základní výklad Dockeru pro pokročilé úrovně – od instalace přes práci s image a kontejnery až po pokročilé koncepty jako síťování a správa dat. Po jejím studiu bude student schopen plně využívat Docker ve svých projektech a připravený k dalším kapitolám o orchestraci (např. Kubernetes).

# %% [markdown]
# ## 💻 Praktické příklady
#
# <div style="background: #e8f5e9; padding: 20px; border-left: 5px solid #4caf50; margin: 20px 0; border-radius: 5px;">
#     <h3 style="color: #2c3e50; margin-top: 0;">👨‍💻 Hands-on příklady ke spuštění</h3>
#     <p>Následující příklady si můžete hned vyzkoušet. Každý příklad je samostatně spustitelný.</p>
# </div>

# %% [markdown]
# ### Příklad 1
#
# Příklad 1: Instalace Dockeru na různých OS
#
# ```bash
# #!/bin/bash
# # Název: Instalace Dockeru - Linux (Ubuntu/Debian)
# # Co demonstruje: Základní instalace Dockeru na Linux systému
#
# echo "=== Instalace Dockeru na Ubuntu ==="
#
# # Aktualizace balíčků
# sudo apt update
#
# # Nainstalujte potřebné balíčky pro práci s repozitáři přes HTTPS
# sudo apt install -y apt-transport-https ca-certificates curl gnupg lsb-release
#
# # Přidání Dockeru oficiálního GPG klíče
# curl -fsSL https://download.docker.com/linux/ubuntu/gpg | sudo gpg --dearmor -o /usr/share/keyrings/docker-archive-keyring.gpg
#
# # Přidání Docker repozitáře do seznamu zdrojů
# echo "deb [arch=amd64 signed-by=/usr/share/keyrings/docker-archive-keyring.gpg] https://download.docker.com/linux/ubuntu $(lsb_release -cs) stable" | sudo tee /etc/apt/sources.list.d/docker.list > /dev/null
#
# # Aktualizace seznamu balíčků
# sudo apt update
#
# # Instalace Dockeru
# sudo apt install -y docker-ce docker-ce-cli containerd.io
#
# # Spuštění a povolení služby Docker
# sudo systemctl start docker
# sudo systemctl enable docker
#
# echo "Docker byl úspěšně nainstalován a spuštěn!"
# ```
#
# **Očekávaný výstup:**
# ```
# === Instalace Dockeru na Ubuntu ===
# ...
# Docker byl úspěšně nainstalován a spuštěn!
# ```
#
# **Vysvětlení:** Tento skript demonstrovává základní instalaci Dockeru na Ubuntu systému. Obsahuje kroky pro přidání repozitáře, instalaci balíčků a spuštění služby.
#
# ---
#
# ##

# %% [markdown]
# ### Příklad 2
#
# Příklad 2: Základní Docker architecture
#
# ```dockerfile
# # Název: Základní Docker architecture
# # Co demonstruje: Jak fungují Docker komponenty - klient, daemon, image a container
#
# # Vytvoření jednoduchého Dockerfile pro testovací účely
# FROM alpine:latest
#
# # Vytvoření jednoduché aplikace v kontejneru
# RUN echo "Hello from Docker container" > /app/hello.txt
#
# # Výstupní informace o architektuře
# CMD ["cat", "/app/hello.txt"]
# ```
#
# ```bash
# #!/bin/bash
# # Spuštění kontejneru a zobrazení architektury
# echo "=== Docker Architecture Demo ==="
#
# # Vytvoření image z Dockerfile
# docker build -t my-test-image .
#
# # Spuštění kontejneru
# docker run my-test-image
#
# # Zobrazení informací o Docker daemonu
# echo "=== Docker info ==="
# docker info
#
# # Seznam všech spuštěných kontejnerů
# echo "=== Running containers ==="
# docker ps -a
#
# echo "Docker architecture demo dokončen!"
# ```
#
# **Očekávaný výstup:**
# ```
# === Docker Architecture Demo ===
# Hello from Docker container
# === Docker info ===
# ...
# === Running containers ===
# CONTAINER ID   IMAGE             COMMAND       CREATED         STATUS
# <container_id> my-test-image     "cat /app/hel..." 10 seconds ago  Exited (0) 10 seconds ago
#
# Docker architecture demo dokončen!
# ```
#
# **Vysvětlení:** Tento příklad ukazuje základní architekturu Dockeru - klient (CLI), daemon, image a container. Vytvoříme jednoduchý image a spustíme kontejner.
#
# ---
#
# ##

# %% [markdown]
# ### Příklad 3
#
# Příklad 3: Dockerfile syntax a best practices
#
# ```dockerfile
# # Název: Dockerfile syntax a best practices
# # Co demonstruje: Použití nejlepších praktik při psaní Dockerfile
#
# FROM node:18-alpine
#
# # Vytvoření uživatele pro bezpečnost
# RUN addgroup -g 1001 -S nodejs && \
#     adduser -S nextjs -u 1001
#
# # Nastavení práv a přepnutí do uživatele
# USER nextjs
# WORKDIR /home/nextjs
#
# # Kopírování balíčků (před instalací pro lepší cachování)
# COPY --chown=nextjs:nextjs package*.json ./
#
# # Instalace závislostí
# RUN npm ci && npm cache clean --force
#
# # Kopírování zdrojového kódu
# COPY --chown=nextjs:nextjs . .
#
# # Vystavení portu aplikace
# EXPOSE 3000
#
# # Spuštění aplikace
# CMD ["npm", "run", "dev"]
# ```
#
# ```bash
# #!/bin/bash
# # Spuštění vytvořeného image s optimalizací
# echo "=== Best practices Dockerfile demo ==="
#
# # Vytvoření image z Dockerfile (předpokládáme, že Dockerfile je ve složce)
# docker build -t my-node-app .
#
# # Spuštění kontejneru na portu 3000
# docker run -p 3000:3000 my-node-app
#
# echo "Image vytvořen a spuštěn s nejlepšími praktikami!"
# ```
#
# **Očekávaný výstup:**
# ```
# === Best practices Dockerfile demo ===
# ...
# Image vytvořen a spuštěn s nejlepšími praktikami!
# ```
#
# **Vysvětlení:** Tento příklad ukazuje základní best practices pro psaní Dockerfile, jako je použití několika RUN příkazů, správné nastavení uživatele, správné kopírování souborů a optimalizace cache.
#
# ---
#
# ##

# %% [markdown]
# ### Příklad 4
#
# Příklad 4: Vytváření image a správa kontejnerů
#
# ```dockerfile
# # Název: Building images and managing containers
# # Co demonstruje: Vytváření image, spouštění, zastavování, odstraňování kontejnerů
#
# FROM nginx:alpine
#
# # Kopírování vlastního index.html
# COPY index.html /usr/share/nginx/html/
#
# # Exponování portu 80
# EXPOSE 80
#
# # Výchozí příkaz pro spuštění serveru
# CMD ["nginx", "-g", "daemon off;"]
# ```
#
# ```html
# <!-- index.html -->
# <!DOCTYPE html>
# <html>
# <head>
#     <title>Docker Demo</title>
# </head>
# <body>
#     <h1>Vítejte v Docker demo!</h1>
#     <p>Toto je jednoduchá webová stránka spuštěná v kontejneru.</p>
# </body>
# </html>
# ```
#
# ```bash
# #!/bin/bash
# # Správa kontejnerů a image
# echo "=== Building and managing containers ==="
#
# # Vytvoření image z Dockerfile
# docker build -t my-web-app .
#
# # Spuštění kontejneru na portu 8080
# CONTAINER_ID=$(docker run -d -p 8080:80 my-web-app)
#
# echo "Kontejner spuštěn s ID: $CONTAINER_ID"
#
# # Zobrazení běžících kontejnerů
# echo "=== Běžící kontejnery ==="
# docker ps
#
# # Zastavení kontejneru
# docker stop $CONTAINER_ID
#
# echo "Kontejner zastaven"
#
# # Odstranění kontejneru
# docker rm $CONTAINER_ID
#
# echo "Kontejner odstraněn"
# ```
#
# **Očekávaný výstup:**
# ```
# === Building and managing containers ===
# ...
# Kontejner spuštěn s ID: <container_id>
# === Běžící kontejnery ===
# CONTAINER ID   IMAGE           COMMAND                  CREATED         STATUS
# <container_id> my-web-app      "nginx -g 'daemon of..." 10 seconds ago  Up 10 seconds
#
# Kontejner zastaven
# Kontejner odstraněn
# ```
#
# **Vysvětlení:** Tento příklad ukazuje celý proces vytváření image, spouštění kontejneru, jeho správy a odstraňování. Demonstruje základní operace s kontejnery.
#
# ---
#
# ##

# %% [markdown]
# ### Příklad 5
#
# Příklad 5: Volumes a bind mounts
#
# ```dockerfile
# # Název: Working with volumes and bind mounts
# # Co demonstruje: Použití volumes a bind mounts v Dockeru
#
# FROM php:8.1-apache
#
# # Instalace balíčků pro práci s databází
# RUN docker-php-ext-install pdo_mysql mysqli
#
# # Kopírování PHP aplikace
# COPY . /var/www/html/
#
# # Nastavení práv
# RUN chmod -R 755 /var/www/html/
#
# # Vystavení portu
# EXPOSE 80
# ```
#
# ```bash
# #!/bin/bash
# # Demonstrace použití volumes a bind mounts
# echo "=== Working with volumes and bind mounts ==="
#
# # Vytvoření datového volume
# docker volume create my-app-data
#
# # Spuštění kontejneru s bind mountem (připojení lokální složky)
# docker run -d \
#   --name web-app \
#   -p 8080:80 \
#   -v $(pwd)/app:/var/www/html \
#   -v my-app-data:/var/www/html/data \
#   my-php-app
#
# echo "Kontejner spuštěn s bind mountem a volume"
#
# # Zobrazení vytvořených volume
# echo "=== Created volumes ==="
# docker volume ls
#
# # Informace o kontejneru
# echo "=== Container info ==="
# docker inspect web-app
#
# # Vytvoření souboru ve volume
# docker exec web-app mkdir -p /var/www/html/data/logs
# docker exec web-app touch /var/www/html/data/logs/app.log
#
# echo "Soubor vytvořen ve volume"
#
# # Zastavení a odstranění kontejneru
# docker stop web-app
# docker rm web-app
#
# echo "Demo dokončeno!"
# ``

# %% [markdown]
# ## 🎯 Cvičení a úkoly
#
# <div style="background: #fff3e0; padding: 20px; border-left: 5px solid #ff9800; margin: 20px 0; border-radius: 5px;">
#     <h3 style="color: #2c3e50; margin-top: 0;">✍️ Praktická cvičení k procvičení</h3>
#     <p>Vyřešte následující úkoly. Začněte od jednoduššších a postupujte k složitějším.</p>
# </div>
#
# # Cvičení pro kapitolu: Docker základy
#
# ---
#
# ## 1. **Název úkolu**: Vytvoření a spuštění jednoduchého kontejneru
#
# ### 2. **Detailní zadání**:
# Vytvoř jednoduchý Docker kontejner, který běží na základním obrazu `nginx` a naslouchá na portu 80. Kontejner musí mít vlastní název `my-nginx-app`, a musí přesměrovat lokální port 8080 na port 80 kontejneru. Přidej i vlastní konfigurační soubor do kontejneru.
#
# ### 3. **Vstupní data/požadavky**:
# - Základní obraz: `nginx`
# - Název kontejneru: `my-nginx-app`
# - Mapování portu: lokální port 8080 → port 80 v kontejneru
# - Vlastní konfigurace: soubor `nginx.conf` ve složce `config/`
#
# ### 4. **Očekávaný výstup**:
# - Spuštěný kontejner s názvem `my-nginx-app`
# - Kontejner naslouchá na portu 8080 lokálně
# - Vlastní konfigurace je použita
#
# ### 5. **Hints/Nápověda**:
# 1. Použij příkaz `docker run` pro spuštění kontejneru.
# 2. Použij `-p` pro mapování portů a `-v` pro připojení svazku (mount).
# 3. Nastav název kontejneru pomocí `--name`.
# 4. Vytvoř složku `config/` s konfiguračním souborem.
#
# ### 6. **Kostra řešení**:
# ```bash
# mkdir -p config
# echo "server { listen 80; location / { return 200 'Hello from custom nginx'; } }" > config/nginx.conf
# docker run -d --name my-nginx-app -p 8080:80 -v $(pwd)/config/nginx.conf:/etc/nginx/conf.d/default.conf nginx
# ```
#
# ### 7. **Bonusové rozšíření**:
# Přidej proměnné prostředí do kontejneru pomocí `-e` a vytvoř jednoduchý skript, který vypisuje obsah proměnných.
#
# ---
#
# ## 2. **Název úkolu**: Vytvoření Docker obrazu z vlastní aplikace
#
# ### 2. **Detailní zadání**:
# Vytvoř jednoduchou webovou aplikaci ve stylu "Hello World" v Pythonu (`Flask`). Vytvoř k tomu `Dockerfile`, který vytvoří obraz a aplikace běží na portu 5000. Kontejner se spustí pod názvem `my-flask-app`.
#
# ### 3. **Vstupní data/požadavky**:
# - Aplikace: Python + Flask
# - Soubor `app.py` s jednoduchým endpointem `/`
# - `Dockerfile`, který použije oficiální obraz `python:3.10-slim`
# - Spuštění kontejneru na portu 5000
#
# ### 4. **Očekávaný výstup**:
# - Obraz `my-flask-app` vytvořen pomocí Dockerfile
# - Kontejner se spustí a naslouchá na portu 5000
# - Přístup přes `curl localhost:5000`
#
# ### 5. **Hints/Nápověda**:
# 1. Vytvoř soubor `app.py` s jednoduchou Flask aplikací.
# 2. V `Dockerfile` nastav `WORKDIR`, kopíruj aplikaci a nainstaluj závislosti.
# 3. Použij `EXPOSE 5000` a `CMD`.
# 4. Spusť kontejner s mapováním portu `-p 5000:5000`.
#
# ### 6. **Kostra řešení**:
# ```Dockerfile
# FROM python:3.10-slim
# WORKDIR /app
# COPY app.py .
# RUN pip install flask
# EXPOSE 5000
# CMD ["python", "app.py"]
# ```
#
# ```bash
# docker build -t my-flask-app .
# docker run -d --name my-flask-app -p 5000:5000 my-flask-app
# ```
#
# ### 7. **Bonusové rozšíření**:
# Použij multi-stage build a přidej `requirements.txt` pro správu závislostí.
#
# ---
#
# ## 3. **Název úkolu**: Vytvoření Docker Compose s více službami
#
# ### 2. **Detailní zadání**:
# Vytvoř Docker Compose konfiguraci, která spustí:
# - Webovou aplikaci (např. `nginx`)
# - Databázi (`mysql`)
# - Aplikaci (např. Python Flask s připojením k DB)
#
# Kontejnery musí být propojené přes vlastní Docker network.
#
# ### 3. **Vstupní data/požadavky**:
# - `docker-compose.yml` s 3 službami
# - Služby: `web`, `db`, `app`
# - Připojení mezi kontejnery
# - Mapování portů pro web a DB
#
# ### 4. **Očekávaný výstup**:
# - Spuštěné služby přes `docker-compose up`
# - Všechny služby komunikují mezi sebou
# - Web je dostupný na portu 8080
#
# ### 5. **Hints/Nápověda**:
# 1. Definuj vlastní network v `docker-compose.yml`.
# 2. Použij `depends_on` pro správné spouštění služeb.
# 3. Přidej proměnné prostředí do DB kontejneru.
# 4. Nastav mount point pro sdílení dat.
#
# ### 6. **Kostra řešení**:
# ```yaml
# version: '3'
# services:
#   web:
#     image: nginx
#     ports:
#       - "8080:80"
#     depends_on:
#       - app
#   db:
#     image: mysql
#     environment:
#       MYSQL_ROOT_PASSWORD: rootpass
#   app:
#     build: .
#     depends_on:
#       - db
# ```
#
# ### 7. **Bonusové rozšíření**:
# Přidej `volume` pro ukládání dat z DB a nastav připojení aplikace k DB pomocí environment proměnných.
#
# ---
#
# ## 4. **Název úkolu**: Správa Docker obrazů a kontejnerů
#
# ### 2. **Detailní zadání**:
# Vytvoř jednoduchý skript (např. v Bashu), který:
# 1. Seznamuje všechny spuštěné kontejnery.
# 2. Vymaže všechny zastaralé obrazy.
# 3. Zobrazí detailní informace o konkrétním kontejneru (podle názvu).
# 4. Uvolní nepoužívané prostředky (`docker system prune`).
#
# ### 3. **Vstupní data/požadavky**:
# - Nastav základní kontejnery (`nginx`, `mysql`)
# - Skript v Bashu
#
# ### 4. **Očekávaný výstup**:
# - Výpis seznamu běžících kontejnerů
# - Odstraněné obrazy
# - Detaily konkrétního kontejneru
# - Uvolněné prostředky
#
# ### 5. **Hints/Nápověda**:
# 1. Použij `docker ps`, `docker images`, `docker inspect`.
# 2. Použij `docker rmi` a `docker rm`.
# 3. Přidej `docker system prune` pro čištění.
# 4. Vytvoř proměnné pro získání ID nebo názvu.
#
# ### 6. **Kostra řešení**:
# ```bash

# %% [markdown]
# ## 📚 Další zdroje a materiály
#
# <div style="background: #e3f2fd; padding: 20px; border-left: 5px solid #2196f3; margin: 20px 0; border-radius: 5px;">
#     <h3 style="color: #2c3e50; margin-top: 0;">🔗 Doporučené materiály k dalšímu studiu</h3>
# </div>
#
# # Docker základy – Doporučené zdroje
#
# ## 1. Články a tutoriály
#
# 1. **[Docker Official Documentation - Get Started](https://docs.docker.com/get-started/)**
#    Oficiální úvodní průvodce Dockerem od Dockeru. Obsahuje krok za krokem návody na instalaci, vytváření kontejnerů a práci s imagemi.
#
# 2. **[Docker Mastery: with Kubernetes & DevOps](https://www.udemy.com/course/docker-mastery/)**
#    Rozsáhlý online kurz (nejlépe v angličtině) zaměřený na pokročilé Docker koncepty a jeho integraci s Kubernetes a DevOps procesy.
#
# 3. **[Docker for Beginners - Tutorial by Docker](https://github.com/docker/getting-started)**
#    Interaktivní kurz pro začátečníky, který vás provede základními koncepty Dockeru a jejich praktickým použitím.
#
# 4. **[A Complete Guide to Docker for Beginners](https://www.freecodecamp.org/news/a-complete-guide-to-docker-for-beginners/)**
#    Detailní článek pro začátečníky, který vysvětluje Docker včetně kontejnerů, imagí, sítí a svazků.
#
# 5. **[Docker Cheat Sheet (by Docker)](https://www.docker.com/resources/what-container)**
#    Stručný přehled příkazů Dockeru s jednoduchými příklady – ideální pro rychlé opakování a přehled.
#
# ## 2. YouTube videa
#
# 1. **[Docker in 1 Hour - Beginner's Tutorial](https://www.youtube.com/watch?v=17Pl8qWj9xQ)**
#    Délka: 1 hodina
#    Komplexní úvodní video pro začátečníky, které vysvětluje základní koncepty Dockeru a ukazuje praktické příklady.
#
# 2. **[Docker Tutorial for Beginners - Full Course in 3 Hours](https://www.youtube.com/watch?v=19X0g14Qm6o)**
#    Délka: 3 hodiny
#    Detailní tutoriál zahrnující instalaci Dockeru, práci s kontejnery, buildování imagí a spouštění aplikací.
#
# 3. **[Docker for Beginners - Step by Step Guide](https://www.youtube.com/watch?v=9R01d6357g4)**
#    Délka: 25 minut
#    Zábavný a jednoduchý úvod do Dockeru s praktickými příklady a ukázkami.
#
# ## 3. Knihy a oficiální dokumentace
#
# 1. **[Docker in Action, 2nd Edition](https://www.manning.com/books/docker-in-action-second-edition)**
#    Kompletní kniha o Dockeru, která se zaměřuje na praxi a využití Dockeru v reálném prostředí. Vhodná pro začátečníky i pokročilé uživatele.
#
# 2. **[The Docker Book: Containerization is the New Virtualization](https://www.dockerbook.com/)**
#    Kniha, která vysvětluje koncepty kontejnerizace a poskytuje praktické příklady použití Dockeru v různých scénářích.
#
# 3. **[Docker Official Documentation](https://docs.docker.com/)**
#    Oficiální dokumentace – nejlepší zdroj pro detailní informace o příkazech, konfiguraci a architektuře Dockeru.
#
# ## 4. Praktické projekty
#
# 1. **Nastavení vlastního webového serveru s Dockerem**
#    Vytvořte jednoduchý web (např. pomocí Node.js nebo Python Flask) a spusťte ho v kontejneru. Přidejte případně databázi (např. MongoDB) ve svazku.
#
# 2. **Vytvo

# %% [markdown]
# ## 📝 Shrnutí kapitoly
#
# <div style="background: linear-gradient(135deg, #667eea 0%, #764ba2 100%); padding: 30px; border-radius: 10px; color: white; margin: 30px 0;">
#     <h3 style="color: white; margin-top: 0;">✅ Co jste se naučili</h3>
#     <ul style="list-style: none; padding-left: 0;">
#         <li>✓ Docker installation všechny OS</li>
# <li>✓ Docker architecture</li>
# <li>✓ Dockerfile syntax a best practices</li>
# <li>✓ Building images</li>
# <li>✓ Container management</li>
#     </ul>
#
#     <h3 style="color: white;">🎯 Klíčové dovednosti</h3>
#     <p>Po dokončení této kapitoly byste měli být schopni prakticky použít všechny probrané koncepty.</p>
#
#     <h3 style='color: white;'>➡️ Další kapitola</h3><p>Kapitola 22 - pokračujte ve studiu!</p>
# </div>
#
# ---
#
# *📅 Notebook vygenerován: 2025-09-29 12:42:36*
# *🤖 Generátor: Comprehensive Colab Generator v2.0*
# *📚 Učebnice programování - Od základů k AI*

# %% [markdown]
# ## 🧪 Sandbox - Prostor pro experimenty
#
# Použijte následující buňky pro vlastní experimenty a testování:

# %%
# 🧪 Zde můžete experimentovat s kódem z kapitoly
# Napište svůj kód zde:
