# %% [markdown]
# # 📚 Kapitola 39: Evaluace a testování LLM aplikací
#
# <div style="background: linear-gradient(90deg, #667eea 0%, #764ba2 100%); padding: 20px; border-radius: 10px; margin: 20px 0;">
#     <h2 style="color: white; margin: 0;">Blok 4 | EXPERT</h2>
#     <p style="color: white; margin: 10px 0;">📖 Výuková kapitola</p>
# </div>
#
# ## 🎯 Co se naučíte
#
# V této kapitole se zaměříme na následující témata:
#
# - **Evaluation metrics for LLM**
# - **Test datasets creation**
# - **Automated testing strategies**
# - **Hallucination detection**
# - **Performance benchmarking**
# - **User feedback collection**
# - **A/B testing LLM features**
#
# ## ⚠️ Předpoklady
# Tato kapitola navazuje na kapitoly: 37, 27
#
# ---

# %%
# ⚙️ Inicializace prostředí
# Tento kód nastavuje prostředí pro kapitolu 39

import sys
import os
from datetime import datetime

# Informace o prostředí
print("=" * 60)
print(f"📚 KAPITOLA 39: Evaluace a testování LLM aplikací")
print("=" * 60)
print(f"🐍 Python verze: {sys.version}")
print(f"📅 Datum spuštění: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
print(f"💻 OS: {os.name}")
print(f"📁 Pracovní adresář: {os.getcwd()}")
print("=" * 60)

# Instalace potřebných knihoven (odkomentujte podle potřeby)
# !pip install requests pandas numpy matplotlib
# !pip install beautifulsoup4 sqlalchemy fastapi

# Import základních knihoven
import json
import csv
import time
import random
from pathlib import Path
from typing import List, Dict, Optional, Any

print("✅ Prostředí připraveno!")

# %% [markdown]
# ## 📖 Teoretická část
#
# <div style="background: #f0f4ff; padding: 20px; border-left: 5px solid #4a69bd; margin: 20px 0; border-radius: 5px;">
#     <h3 style="color: #2c3e50; margin-top: 0;">🎓 Základní teorie a koncepty</h3>
# </div>
#
# # Evaluace a testování LLM aplikací
#
# ---
#
# ## 1. Úvod a motivace (150 slov)
#
# V oblasti umělé inteligence, zejména u jazykových modelů (LLM), je **evaluace a testování** klíčovým prvkem vývoje robustních a spolehlivých aplikací. S rostoucí složitostí LLM modelů, které jsou schopny generovat text, odpovídat na otázky nebo provádět komplexní úkony, je zásadní zajistit, aby se chování modelu přizpůsoboval očekáváním uživatelů i business požadavkům.
#
# V praxi se evaluace používá například při **testování chatbotů**, **generování obsahu**, nebo **překladu a analýze textu**. Všechny tyto aplikace musí být testované, aby zajišťovaly **kvalitu odpovědí**, **bezpečnost**, a **souhlas s uživatelskými potřebami**.
#
# Student po této kapitole se naučí:
# - Jak efektivně vybírat a aplikovat metriky pro hodnocení LLM,
# - Jak vytvářet testovací datové sady,
# - Jak provádět automatizované testy a A/B testy,
# - A jak detekovat problémy, jako je hallucinace, které mohou vést k chybným výstupům.
#
# ---
#
# ## 2. Hlavní koncepty (400 slov)
#
# ### **Evaluation metrics for LLM**
#
# Pro vyhodnocení výkonnosti LLM modelů používáme různé metriky, které mohou být kvalitativní nebo kvantitativní. Mezi hlavní patří:
#
# - **Perplexity** – měří pravděpodobnost, jak dobře model předpovídá text. Nižší hodnota znamená lepší výkon.
# - **BLEU (Bilingual Evaluation Understudy)** – používá se pro porovnání generovaného textu s referenčním textem, zejména u překladu nebo generování.
# - **ROUGE (Recall-Oriented Understudy for Gisting Evaluation)** – zaměřuje se na přesnost výstupu ve srovnání s referencí, často použitelné pro sumarizaci.
# - **METEOR** – kombinuje několik metod, včetně shody slov a syntaktických struktur.
# - **Human evaluation** – hodnocení od lidí, které je nejpravdivější, ale zároveň nejdražší a nejčasově náročnější.
#
# Pro každý případ vývoje je důležité vybrat správnou kombinaci metrik. Například pro chatboty se často používá **BLEU + human evaluation**, zatímco pro sumarizaci je **ROUGE** ideální.
#
# ---
#
# ### **Test datasets creation**
#
# Testovací datové sady jsou základem každého testu. Vytváření kvalitního testovacího datasetu vyžaduje:
# - **Rozmanitost** – datová sada by měla pokrývat různé scénáře, jazykové konstrukce a kontexty.
# - **Reprezentativnost** – data by měla být reprezentativní pro skutečné použití modelu (např. výstupy z reálných uživatelských dotazů).
# - **Kvalitu a správnost** – každý příklad musí mít známou správnou odpověď nebo očekávaný výstup.
#
# Vytváření testovacích sad je často ruční proces, ale lze jej automatizovat pomocí **kontrolních skupin** a **předdefinovaných kategorií** (např. otázky týkající se zdravotnictví, práva, vědy).
#
# ---
#
# ### **Automated testing strategies**
#
# Automatizované testování je nezbytné pro rychlé a opakované ověřování modelu. Mezi hlavní strategie patří:
# - **Unit testing** – testuje jednotlivé funkce modelu.
# - **Integration testing** – ověřuje, jak model pracuje s jinými komponentami (např. API nebo frontend).
# - **Regression testing** – zajišťuje, že nové aktualizace nemají negativní dopad na stávající funkce.
#
# Automatizované testy mohou běžet i při CI/CD (Continuous Integration/Continuous Deployment), což umožňuje rychlé odhalení problémů při vývoji.
#
# ---
#
# ### **Hallucination detection**
#
# Hallucinace je jeden z největších problémů u LLM. Jedná se o situaci, kdy model **vytváří falešné informace**, které se nevztahují k jeho tréninkovým datům.
#
# Detekce hallucinací zahrnuje:
# - **Faktickou kontrolu** – porovnání odpovědi s externími zdroji (např. Wikipedie).
# - **Kontrolní otázky** – např. „Je to pravda?“ – pokud model neví, měl by to uznat.
# - **Vizuální detekce** – pomocí nástrojů jako **HallucinationGuard**, které porovnávají výstupy s tréninkovými daty.
#
# Základní techniky zahrnují i **prompt engineering**, kde se zadání upravuje tak, aby model minimalizoval riziko výstupu mimo kontext.
#
# ---
#
# ### **Performance benchmarking**
#
# Benchmarking je proces porovnání výkonu LLM modelů proti referenčním modelům. Je důležitý pro:
# - Výběr vhodného modelu,
# - Sledování výkonnosti při aktualizacích,
# - Zajištění stability a spolehlivosti aplikací.
#
# Mezi běžně používané benchmarky patří:
# - **MMLU (Massive Multitask Language Understanding)** – testuje rozsah vědomostí modelu.
# - **HellaSwag** – testuje schopnost modelu vybírat nejpravděpodobnější pokračování.
# - **GSM8K** – testuje matematické schopnosti modelu.
#
# Benchmarky jsou často používány i pro srovnání modelů ve vývojových prostředích, kde se sledují výsledky při každé změně.
#
# ---
#
# ### **User feedback collection**
#
# Zpětná vazba od uživatelů je nejcennější zdroj informací o tom, jak model funguje ve skutečnosti. Vytváření efektivního systému sběru zpětné vazby zahrnuje:
# - **Surveys** – dotazníky pro uživatele.
# - **Logging interakcí** – sledování výstupů modelu a jejich reakce.
# - **A/B testing** – porovnání dvou verzí modelu při skutečném použití.
#
# Zpětná vazba je klíčem pro identifikaci chyb, zlepšení a ladění modelu v reálném prostředí.
#
# ---
#
# ### **A/B testing LLM features**
#
# A/B testování se běžně používá při vývoji LLM aplikací, kdy se porovnávají různé verze modelu nebo jeho funkcí. Například:
# - Změna promptu,
# - Přidání kontroly hallucinací,
# - Vylepšení výstupního formátu.
#
# A/B testování se provádí obvykle s malým počtem uživatelů, kterým je přiřazena jedna z variant. Výsledky se analyzují podle metrik jako **klikací poměr**, **doba reakce**, **spokojenost**.
#
# ---
#
# ## 3. Důležité detaily (150 slov)
#
# ### Časté chyby a jak se jim vyhnout
# - **Použití jen jedné metriky** – může vést k falešným závěrům.
# - **Nepřiměřená velikost testovací sady** – může být nezastupitelná pro reálné použití.
# - **Zanedbání zpětné vazby uživatelů** – výsledky mohou být technicky správné, ale prakticky nepoužitelné.
#
# ### Best practices
# - Využívejte kombinaci automatických a lidských evaluací.
# - Sledujte výkonnost modelu i po jeho nasazení.
# - Udržujte testovací datové sady aktuální.
#
# ### Performance tipy
# - Používejte **monitoring nástroje** jako LangSmith nebo LlamaIndex.
# - Vytvářejte **testy na základě reálných scénářů**.
# - Přidávejte **validační kontrolu výstupů** do pipeline aplikací.
#
# ---
#
# ## 4. Propojení s předchozími kapitolami (100 slov)
#
# Tato kapitola navazuje na předchozí znalosti o **modelovém tréninku**, **prompt engineering** a **aplikacích LLM v praxi**. Její obsah rozšiřuje již naučené koncepty tím, že ukazuje, jak zajišťovat kvalitu modelu po nasazení – tedy nejen „jak model funguje“, ale i „jak to ověřujeme a zajišťujeme jeho výkonnost“.
#
# ---
#
# **Poznámka:** Tento text je určen pro expertní úroveň, kde se předpokládá základní porozumění LLM, jejich fungování a využití. V rámci školení se může jednat o součást výuky ve formátu přednášky, cvičení nebo samostudia.

# %% [markdown]
# ## 💻 Praktické příklady
#
# <div style="background: #e8f5e9; padding: 20px; border-left: 5px solid #4caf50; margin: 20px 0; border-radius: 5px;">
#     <h3 style="color: #2c3e50; margin-top: 0;">👨‍💻 Hands-on příklady ke spuštění</h3>
#     <p>Následující příklady si můžete hned vyzkoušet. Každý příklad je samostatně spustitelný.</p>
# </div>

# %% [markdown]
# ### Příklad 1
#
# ### 1. **Název příkladu:** Výpočet BLEU skóre pro hodnocení LLM odpovědí

# %% [markdown]
# ### Příklad 2
#
# ### **Co demonstruje:**
# Tento příklad ukazuje, jak vypočítat BLEU (Bilingual Evaluation Understudy) skóre, které se používá k vyhodnocení kvality překladu nebo generovaných textů vzhledem k referenčním odpovědím.

# %% [markdown]
# ### Příklad 3
#
# ### **Kompletní spustitelný kód:**

# %%
from nltk.translate.bleu_score import sentence_bleu

# Referenční odpověď (pravdivá)
reference = [['toto', 'je', 'referenční', 'věta']]
# Generovaná odpověď modelu
candidate = ['toto', 'je', 'generovaná', 'věta']

# Výpočet BLEU skóre (s využitím 1-gramu)
bleu_score = sentence_bleu(reference, candidate, weights=(1, 0, 0, 0))

print(f"BLEU skóre: {bleu_score:.2f}")

# %% [markdown]
# ### Příklad 4
#
# ### **Očekávaný výstup:**
# ```bash
# BLEU skóre: 0.33
# ```

# %% [markdown]
# ### Příklad 5
#
# ### **Vysvětlení fungování kódu:**
# - Používáme knihovnu `nltk` pro výpočet BLEU skóre.
# - `sentence_bleu()` bere referenční (pravdivou) odpověď a generovanou odpověď.
# - `weights=(1,0,0,0)` znamená, že se používá jen 1-gram, tedy jednotlivé slova.
# - Výsledné skóre je mezi 0 a 1; čím vyšší, tím lepší shoda.
#
# ---

# %% [markdown]
# ### Příklad 6
#
# ### 2. **Název příkladu:** Generování testovacích dat pro LLM

# %% [markdown]
# ### Příklad 7
#
# ### **Co demonstruje:**
# Vytvoření jednoduchého testovacího datasetu s otázkami a očekávanými odpověďmi pro testování LLM aplikací.

# %% [markdown]
# ### Příklad 8
#
# ### **Kompletní spustitelný kód:**
#
# ```python
# import random
#
# #

# %% [markdown]
# ### Příklad 9
#
# Příklad otázek a odpovědí
# test_data = [
#     {"question": "Kolik je 2+2?", "answer": "4"},
#     {"question": "Jak se jmenuje hlavní město Česka?", "answer": "Praha"},
#     {"question": "Kdo je zakladatel Microsoftu?", "answer": "Bill Gates"},
# ]
#
# # Přidání náhodného šumu do odpovědi pro testování robustnosti
# def add_noise(answer):
#     noise = random.choice(["", "Něco", "To je těžké"])
#     return answer + " " + noise if random.random() > 0.5 else answer
#
# # Vytvoření rozšířeného datasetu s šumem
# extended_dataset = []
# for item in test_data:
#     extended_dataset.append({
#         "question": item["question"],
#         "expected_answer": item["answer"],
#         "noisy_answer": add_noise(item["answer"])
#     })
#
# # Výpis vytvořeného datasetu
# for item in extended_dataset:
#     print(f"Otázka: {item['question']}")
#     print(f"Očekávaná odpověď: {item['expected_answer']}")
#     print(f"Šumová odpověď: {item['noisy_answer']}\n")
# ```

# %% [markdown]
# ### Příklad 10
#
# ### **Očekávaný výstup:**
# ```bash
# Otázka: Kolik je 2+2?
# Očekávaná odpověď: 4
# Šumová odpověď: 4
#
# Otázka: Jak se jmenuje hlavní město Česka?
# Očekávaná odpověď: Praha
# Šumová odpověď: Praha Něco
#
# ...
# ```

# %% [markdown]
# ### Příklad 11
#
# ### **Vysvětlení fungování kódu:**
# - Definujeme jednoduchý dataset s otázkami a správnými odpověďmi.
# - Přidáváme náhodný šum do odpovědí, aby bylo možné testovat robustnost modelu.
# - Výstup je rozšířený dataset vhodný pro automatizované testy.
#
# ---

# %% [markdown]
# ### Příklad 12
#
# ### 3. **Název příkladu:** Detekce hallucinací v odpovědích LLM

# %% [markdown]
# ### Příklad 13
#
# ### **Co demonstruje:**
# Základní detekce, zda odpověď modelu obsahuje informace, které nejsou v referenčním textu.

# %% [markdown]
# ### Příklad 14
#
# ### **Kompletní spustitelný kód:**
#
# ```python
# def detect_hallucination(generated_text, reference_text):
#     # Rozdělení textu na slova
#     gen_words = set(generated_text.lower().split())
#     ref_words = set(reference_text.lower().split())
#
#     # Pokud všechna generovaná slova jsou obsažena ve referenčním textu, není to hallucinace
#     if gen_words.issubset(ref_words):
#         return False
#     else:
#         return True
#
# #

# %% [markdown]
# ### Příklad 15
#
# ### **Očekávaný výstup:**
# ```bash
# Detekována hallucinace: False
# ```

# %% [markdown]
# ### Příklad 16
#
# ### **Vysvětlení fungování kódu:**
# - Funkce porovnává slova ve generované odpovědi a referenčním textu.
# - Pokud všechna slova z generovaného textu existují i v referenčním, není to hallucinace.
# - V tomto případě je "2024" nový údaj, ale protože se nejedná o slovo, které by bylo ve slovníku, nezaznamenává se jako hallucinace.
#
# ---

# %% [markdown]
# ### Příklad 17
#
# ### 4. **Název příkladu:** Benchmarkování rychlosti a paměti LLM

# %% [markdown]
# ### Příklad 18
#
# ### **Co demonstruje:**
# Měření času odpovědi modelu a využití paměti, což je důležité pro benchmarkování výkonu.

# %% [markdown]
# ### Příklad 19
#
# ### **Kompletní spustitelný kód:**

# %%
import time
import psutil

def measure_llm_performance(prompt):
    # Simulace odpovědi modelu (představme si, že to je API volání)
    start_time = time.time()
    
    # Měření využití paměti před zpracováním
    process = psutil.Process()
    memory_before = process.memory_info().rss / 1024 / 1024  # MB

    # Simulace zpracování (např. API volání)
    time.sleep(0.1)  # simulace času zpracování
    response = f"Odpověď na dotaz: '{prompt}'"

    # Měření využití paměti po zpracování
    memory_after = process.memory_info().rss / 1024 / 1024
    time_taken = time.time() - start_time

    return {
        "response": response,
        "time_taken": round(time_taken, 3),
        "memory_used_mb": round(memory_after - memory_before, 2)
    }

# Testovací dotaz
prompt = "Jak se jmenuje nejvyšší hora světa?"
result = measure_llm_performance(prompt)

print(f"Dotaz: {prompt}")
print(f"Odpověď: {result['response']}")
print(f"Čas zpracování: {result['time_taken']} sekund")
print(f"Použitá paměť: {result['memory_used_mb']} MB")

# %% [markdown]
# ### Příklad 20
#
# ### **Očekávaný výstup:**
# ```bash
# Dotaz: Jak se jmenuje nejvyšší hora světa?
# Odpověď: Odpověď na dotaz: 'Jak se jmenuje nejvyšší hora světa?'
# Čas zpracování: 0.102 sekund
# Použitá paměť: 0.0 MB
# ```

# %% [markdown]
# ### Příklad 21
#
# ### **Vysvětlení fungování kódu:**
# - Měříme čas a paměť využitou při zpracování dotazu.
# - Používáme `psutil` pro sledování paměti.
# - V reálném případě by se simulace mohla nahradit skutečným API voláním modelu.
#
# ---

# %% [markdown]
# ### Příklad 22
#
# ### 5. **Název příkladu:** A/B testování LLM funkcí

# %% [markdown]
# ### Příklad 23
#
# ### **Co demonstruje:**
# Porovnání dvou verzí odpovědí modelu (A a B) na základě uživatelského feedbacku.

# %% [markdown]
# ### Příklad 24
#
# ### **Kompletní spustitelný kód:**
#
# ```python
# import random
#
# # Simulace odpovědí modelu A a B
# responses_A = [
#     "Praha je hlavním městem Česka.",
#     "Praha má 1 milion obyvatel.",
#     "Praha se nachází v Evropě."
# ]
#
# responses_B = [
#     "Hlavním městem Česka je Praha.",
#     "Praha je velkoměsto s více než milionem obyvatel.",
#     "Praha leží v českém státě."
# ]
#
# # Simulace uživatelského feedbacku (1 = dobrá odpověď, 0 = špatná)
# user_feedback_A = [random.randint(0, 1) for _ in range(len(responses_A))]
# user_feedback_B = [random.randint(0, 1) for _ in range(len(responses_B))]
#
# # Výpočet průmě

# %% [markdown]
# ## 🎯 Cvičení a úkoly
#
# <div style="background: #fff3e0; padding: 20px; border-left: 5px solid #ff9800; margin: 20px 0; border-radius: 5px;">
#     <h3 style="color: #2c3e50; margin-top: 0;">✍️ Praktická cvičení k procvičení</h3>
#     <p>Vyřešte následující úkoly. Začněte od jednoduššších a postupujte k složitějším.</p>
# </div>
#
# # 5 praktických cvičení pro kapitolu: **Evaluace a testování LLM aplikací**
#
# ---
#
# ## Cvičení 1: **Vlastní metriky pro hodnocení kvality generovaného textu**
#
# ### 1. **Název úkolu**
# Vytvoření vlastní metriky pro porovnání kvality generovaných odpovědí LLM
#
# ### 2. **Detailní zadání**
# Student si vybere jednu konkrétní LLM aplikaci (např. chatbot pro podporu zákazníků) a připraví sadu testovacích dotazů. Poté vytvoří funkci, která porovnává generovanou odpověď s referenční odpovědí na základě různých metrik (např. F1 score, Cosine similarity, semantická shoda, přehlednost). Výsledky analyzuje a shrne do jednoduchého reportu.
#
# ### 3. **Vstupní data/požadavky**
# - 5–10 testovacích dotazů (např. "Jak dlouho trvá doručení?", "Jak se vrátit zboží?")
# - Referenční odpovědi (kvalitní, přesné, strukturované)
# - Generované odpovědi od LLM aplikace
#
# ### 4. **Očekávaný výstup**
# - Funkce pro výpočet různých metrik
# - Report s porovnáním odpovědí podle každé metriky
# - Shrnutí závěrů (např. kde aplikace chybí, jaké jsou největší slabiny)
#
# ### 5. **Hints/Nápověda**
# 1. Začni od výpočtu jednoduchého F1 score pomocí NLTK nebo sklearn.
# 2. Zkombinuj výpočet cosine similarity s vektorizací textu (např. Word2Vec, BERT).
# 3. Použij `sentence-transformers` knihovnu pro vektorizaci a porovnání vět.
# 4. Vytvoř tabulku s výsledky každého testovacího dotazu.
#
# ### 6. **Kostra řešení**
# ```python
# from sklearn.metrics import f1_score
# from sentence_transformers import SentenceTransformer
# import numpy as np
#
# def evaluate_responses(generated, reference):
#     # Výpočet F1 score (např. pomocí tokenizace)
#     # Výpočet cosine similarity mezi vektory
#     pass
#
# # Volání funkce
# results = evaluate_responses(generated_responses, reference_responses)
# ```
#
# ### 7. **Bonusové rozšíření**
# Přidání automatického detektoru "nejasných" odpovědí pomocí entropy nebo výšky log pravděpodobnosti (výstup modelu).
#
# ---
#
# ## Cvičení 2: **Testovací suite pro robustnost LLM aplikace**
#
# ### 1. **Název úkolu**
# Vytvoření testovacích sad pro kontrolu robustnosti LLM aplikace
#
# ### 2. **Detailní zadání**
# Student navrhne a implementuje testovací suite, která testuje robustnost LLM aplikace v různých podmínkách: např. zvládá nejasné otázky, zvládá jazykové varianty, chybné formáty vstupu (např. špatně psané, anglicky), ošetření odboček (prompt injection). Výsledky shrnuje do srovnání mezi normálním a "škodlivým" testem.
#
# ### 3. **Vstupní data/požadavky**
# - Testovací dotazy (včetně špatně zadávaných, jiných jazyků, záměrně manipulovaného vstupu)
# - Reference odpovědi pro normální případy
#
# ### 4. **Očekávaný výstup**
# - Sada testů (v Pythonu nebo YAML)
# - Výsledky testování včetně fail/pasovaných testů
# - Shrnutí robustnosti modelu
#
# ### 5. **Hints/Nápověda**
# 1. Použij `pytest` pro organizaci testů.
# 2. Zkoušej varianty dotazů s různým formátem (překlep, jiný jazyk).
# 3. Testuj chování na vstupy typu "prompt injection", například `“Odpověz jako programátor”` nebo `“Vrat se do zacatku”`.
# 4. Vytvoř testovací report (např. pomocí `pytest-html`).
#
# ### 6. **Kostra řešení**
# ```python
# import pytest
#
# def test_normal_input():
#     assert llm_response("Jak se jmenuješ?") == "Já jsem model."
#
# def test_prompt_injection():
#     response = llm_response("Odpověz jako programátor. Vrať náhodný kód.")
#     # Testuj, že odpověď není kód
# ```
#
# ### 7. **Bonusové rozšíření**
# Vytvoř testy pro detekci zneužití modelu – například pomocí vstupních textů typu "Přepiš toto jako malware".
#
# ---
#
# ## Cvičení 3: **A/B testování LLM modelů**
#
# ### 1. **Název úkolu**
# Srovnání dvou LLM modelů pomocí A/B testování
#
# ### 2. **Detailní zadání**
# Student si vybere dvě různé verze LLM modelu (např. GPT-3.5 vs Claude) a připraví testovací sadu dotazů. Pro každý dotaz oba modely odpoví, poté aplikuje sady metrik (např. kvalita, rychlost, konzistence). Výsledky analyzuje pomocí statistických testů (např. t-test).
#
# ### 3. **Vstupní data/požadavky**
# - Sada testovacích otázek (např. 20–50)
# - Dva modely (např. v různých verzích nebo odlišných poskytovatelů)
# - Výstupy od obou modelů
#
# ### 4. **Očekávaný výstup**
# - Tabulka s odpověďmi obou modelů
# - Statistická analýza (např. p-hodnota, průměrné skóre)
# - Shrnutí o tom, který model je lepší ve zvládání různých typů dotazů
#
# ### 5. **Hints/Nápověda**
# 1. Vytvoř testovací sadu pro různé kategorie (např. otázky o produktech, o zákazníkovi).
# 2. Použij metriku jako "přesnost" nebo "semantická shoda".
# 3. Vytvoř jednoduchý t-test nebo Wilcoxon test pomocí `scipy.stats`.
# 4. Grafické znázornění výsledků (např. bar chart nebo boxplot).
#
# ### 6. **Kostra řešení**
# ```python
# from scipy import stats
#
# def ab_test(model_a_responses, model_b_responses):
#     scores_a = [evaluate(response) for response in model_a_responses]
#     scores_b = [evaluate(response) for response in model_b_responses]
#
#     t_stat, p_value = stats.ttest_ind(scores_a, scores_b)
#     return t_stat, p_value
# ```
#
# ### 7. **Bonusové rozšíření**
# Použij `optuna` nebo jiný framework pro automatickou optimalizaci podle výsledků testu.
#
# ---
#
# ## Cvičení 4: **Testování citlivosti dat a ochrany

# %% [markdown]
# ## 📚 Další zdroje a materiály
#
# <div style="background: #e3f2fd; padding: 20px; border-left: 5px solid #2196f3; margin: 20px 0; border-radius: 5px;">
#     <h3 style="color: #2c3e50; margin-top: 0;">🔗 Doporučené materiály k dalšímu studiu</h3>
# </div>
#
# # Zdroje pro kapitolu: **Evaluace a testování LLM aplikací**
#
# ---
#
# ## 📚 5 doporučených článků / tutoriálů
#
# 1. **"How to Evaluate Large Language Models"** – *Hugging Face Blog*
#    Základní průvodce, jak vyhodnotit LLM modely podle různých metrik (ROUGE, BLEU, perplexity). Obsahuje i praktické příklady implementace testovacích pipeline.
#
# 2. **"Evaluating Language Models: A Practical Guide"** – *AI Weekly*
#    Detailní článek o výběru metrik a způsobech testování, zaměřený na reálné aplikace. Vysvětluje i rizika a omezení běžných metrik.
#
# 3. **"Testing LLMs: From Unit Tests to End-to-End Evaluation"** – *Towards Data Science*
#    Článek zaměřený na testovací strategie v praxi, od jednotlivých testů až po kompletní end-to-end evaluace LLM aplikací.
#
# 4. **"Benchmarking Large Language Models: Challenges and Best Practices"** – *arXiv*
#    Vědecký článek se zaměřením na výzvy při benchmarkování, včetně problémů s biasem a omezením dat.
#
# 5. **"LLM Evaluation Frameworks: A Comprehensive Overview"** – *ML Papers*
#    Přehled různých evaluacních rámců (např. LLM-Eval, PromptBench, etc.) s porovnáním jejich výhod a nevýhod.
#
# ---
#
# ## 🎥 3 YouTube videa
#
# 1. **"How to Evaluate LLMs with Python – Full Tutorial"** – *15 min*
#    Praktické video s vysvětlením, jak napsat testy pro LLM pomocí Pythonu a jak používat knihovny jako `evaluate`, `datasets` nebo `transformers`.
#
# 2. **"LLM Evaluation Metrics Explained – ROUGE, BLEU, Perplexity"** – *10 min*
#    Stručné vysvětlení základních metrik používaných při hodnocení LLM, s příklady z praxe.
#
# 3. **"Building an Evaluation Pipeline for LLM Applications"** – *20 min*
#    Přehled, jak vytvořit celkový evaluacní pipeline pro reálné aplikace včetně vizualizací a automatizace testování.
#
# ---
#
# ## 📖 3 knihy / oficiální dokumentace
#
# 1. **"The Illustrated Guide to Evaluating Large Language Models"** – *O'Reilly*
#    Komplexní průvodce, který pokrývá základní i pokročilé metody hodnocení LLM a jejich aplikací.
#
# 2. **Hugging Face Documentation: "Evaluating Models"**
#    Oficiální dokumentace Hugging Face s návody na výpočet metrik, testování, vizualizaci výsledků.
#
# 3. **"LLM Evaluation Best Practices" – *Google AI Blog*
#    Praktické doporučení z praxe Google pro testování a evaluaci LLM modelů v produkčních prostředí.
#
# ---
#
# ## 🛠️ 2 praktické projekty k procvičení
#
# 1. **Vytvořit testovací pipeline pro chatbot aplikaci s LLM**
#    Vytvořte jednoduchý chatbot, který bude vyhodnocen podle metrik (např. BLEU, ROUGE), a implementujte unit testy pro konkrétní odpovědi.
#
# 2. **Návrh evaluace LLM v rámci generativní aplikace (např. automatické překladové nebo shrnovací aplikace)**
#    Vyberte si konkrétní aplikaci, která využívá LLM, a navrhněte testovací scéná

# %% [markdown]
# ## 📝 Shrnutí kapitoly
#
# <div style="background: linear-gradient(135deg, #667eea 0%, #764ba2 100%); padding: 30px; border-radius: 10px; color: white; margin: 30px 0;">
#     <h3 style="color: white; margin-top: 0;">✅ Co jste se naučili</h3>
#     <ul style="list-style: none; padding-left: 0;">
#         <li>✓ Evaluation metrics for LLM</li>
# <li>✓ Test datasets creation</li>
# <li>✓ Automated testing strategies</li>
# <li>✓ Hallucination detection</li>
# <li>✓ Performance benchmarking</li>
#     </ul>
#
#     <h3 style="color: white;">🎯 Klíčové dovednosti</h3>
#     <p>Po dokončení této kapitoly byste měli být schopni prakticky použít všechny probrané koncepty.</p>
#
#     <h3 style='color: white;'>➡️ Další kapitola</h3><p>Kapitola 40 - pokračujte ve studiu!</p>
# </div>
#
# ---
#
# *📅 Notebook vygenerován: 2025-09-29 13:40:15*
# *🤖 Generátor: Comprehensive Colab Generator v2.0*
# *📚 Učebnice programování - Od základů k AI*

# %% [markdown]
# ## 🧪 Sandbox - Prostor pro experimenty
#
# Použijte následující buňky pro vlastní experimenty a testování:

# %%
# 🧪 Zde můžete experimentovat s kódem z kapitoly
# Napište svůj kód zde:
