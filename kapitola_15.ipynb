# %% [markdown]
# # 📚 Kapitola 15: Databáze - SQL základy
#
# <div style="background: linear-gradient(90deg, #667eea 0%, #764ba2 100%); padding: 20px; border-radius: 10px; margin: 20px 0;">
#     <h2 style="color: white; margin: 0;">Blok 2 | INTERMEDIATE</h2>
#     <p style="color: white; margin: 10px 0;">📖 Výuková kapitola</p>
# </div>
#
# ## 🎯 Co se naučíte
#
# V této kapitole se zaměříme na následující témata:
#
# - **SQLite introduction**
# - **CREATE, ALTER, DROP statements**
# - **INSERT, SELECT, UPDATE, DELETE**
# - **JOINs: INNER, LEFT, RIGHT, FULL**
# - **Indexes a performance**
# - **Python sqlite3 module**
# - **SQL injection prevention**
#
# ## ⚠️ Předpoklady
# Tato kapitola navazuje na kapitoly: 8
#
# ---

# %%
# ⚙️ Inicializace prostředí
# Tento kód nastavuje prostředí pro kapitolu 15

import sys
import os
from datetime import datetime

# Informace o prostředí
print("=" * 60)
print(f"📚 KAPITOLA 15: Databáze - SQL základy")
print("=" * 60)
print(f"🐍 Python verze: {sys.version}")
print(f"📅 Datum spuštění: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
print(f"💻 OS: {os.name}")
print(f"📁 Pracovní adresář: {os.getcwd()}")
print("=" * 60)

# Instalace potřebných knihoven (odkomentujte podle potřeby)
# !pip install requests pandas numpy matplotlib
# !pip install beautifulsoup4 sqlalchemy fastapi

# Import základních knihoven
import json
import csv
import time
import random
from pathlib import Path
from typing import List, Dict, Optional, Any

print("✅ Prostředí připraveno!")

# %% [markdown]
# ## 📖 Teoretická část
#
# <div style="background: #f0f4ff; padding: 20px; border-left: 5px solid #4a69bd; margin: 20px 0; border-radius: 5px;">
#     <h3 style="color: #2c3e50; margin-top: 0;">🎓 Základní teorie a koncepty</h3>
# </div>
#
# # Databáze - SQL základy
#
# ## 1. Úvod a motivace
#
# V oblasti vývoje softwaru a práce s daty je SQL (Structured Query Language) jedním z nejdůležitějších nástrojů, které každý profesionál musí znát. SQL umožňuje efektivně pracovat s relačními databázemi – tedy s daty uspořádanými do tabulek, které si navzájem vzájemně propojují.
#
# Téma databází a SQL základů je důležité proto, že se používá ve většině webových aplikací, systémů pro správu dat i v oblasti analýzy informací. Od jednoduchých aplikací na správu kontaktů až po komplexní e-commerce platformy, kde je zásadní správné zpracování dat, tedy práce s databázemi.
#
# Student se v této kapitole naučí vytvářet, upravovat a dotazovat se na data ve vztahu k relačním databázím. Pochopí, jak fungují základní SQL příkazy, jaký je vliv indexů na výkon a jak se vyhnout nejčastějším chybám. V praxi tato vědomost bude klíčová při tvorbě webových aplikací, automatizaci datových procesů i při práci s většími systémy.
#
# ## 2. Hlavní koncepty
#
# ### SQLite introduction
#
# SQLite je jednoduchý, bezserverový systém pro správu relačních databází, který se používá ve velkém množství aplikací – od mobilních aplikací až po webové stránky. V rozdílu k těžším databázím jako MySQL nebo PostgreSQL je SQLite jednodušší v instalaci a použití, protože nemusí běžet na samostatném serveru. Vše je uloženo v jednom souboru (např. `database.db`), což ho činí ideálním pro testování, prototypování nebo malé projekty.
#
# SQLite podporuje většinu základních SQL příkazů a je kompatibilní s většinou SQL funkcí. Je výborným nástrojem pro začátečníky, protože není potřeba instalovat žádný server, stačí jenom importovat knihovnu nebo modul (např. `sqlite3` v Pythonu).
#
# ### CREATE, ALTER, DROP statements
#
# Příkazy CREATE, ALTER a DROP jsou základními nástroji pro práci s databázovými strukturami.
#
# - **CREATE** slouží k vytvoření nových tabulek, databází nebo indexů.
#
#   Příklad:
#   ```sql
#   CREATE TABLE users (
#       id INTEGER PRIMARY KEY,
#       name TEXT NOT NULL,
#       email TEXT UNIQUE
#   );
#   ```
#
# - **ALTER** umožňuje změnit strukturu existující tabulky – např. přidat sloupec, upravit typ dat nebo smazat sloupec.
#
#   Příklad:
#   ```sql
#   ALTER TABLE users ADD COLUMN age INTEGER;
#   ```
#
# - **DROP** slouží k odstranění tabulek, databází nebo indexů. Při použití je důležité být opatrný, protože data jsou trvale smazána.
#
#   Příklad:
#   ```sql
#   DROP TABLE users;
#   ```
#
# Tyto příkazy jsou klíčové pro správu databází a jejich struktury – bez nich by nešlo vytvářet, rozšiřovat ani měnit databázovou architekturu.
#
# ### INSERT, SELECT, UPDATE, DELETE
#
# Tato čtyři základní příkazy tvoří jádro práce s daty v SQL. Význam:
#
# - **INSERT** – vkládá nové záznamy do tabulky.
#
#   Příklad:
#   ```sql
#   INSERT INTO users (name, email) VALUES ('Jan Novák', 'jan@novak.cz');
#   ```
#
# - **SELECT** – vybírá data z databáze podle daných kritérií.
#
#   Příklad:
#   ```sql
#   SELECT name FROM users WHERE email = 'jan@novak.cz';
#   ```
#
# - **UPDATE** – mění stávající data v tabulce.
#
#   Příklad:
#   ```sql
#   UPDATE users SET age = 30 WHERE name = 'Jan Novák';
#   ```
#
# - **DELETE** – odstraňuje záznamy z tabulky.
#
#   Příklad:
#   ```sql
#   DELETE FROM users WHERE name = 'Jan Novák';
#   ```
#
# Tato čtyři příkazy tvoří základ práce s daty a jsou v každé aplikaci, která pracuje s databází, nezbytné.
#
# ### JOINs: INNER, LEFT, RIGHT, FULL
#
# JOIN příkazy umožňují spojovat data z více tabulek podle určitých podmínek. Jsou klíčové pro komplexní dotazování a vytváření výsledků z více zdrojů.
#
# - **INNER JOIN** – vybere pouze řádky, které mají odpovídající hodnoty ve všech spojených tabulkách.
#
#   Příklad:
#   ```sql
#   SELECT users.name, orders.order_date
#   FROM users
#   INNER JOIN orders ON users.id = orders.user_id;
#   ```
#
# - **LEFT JOIN** – vybere všechny řádky z levé tabulky a odpovídající z pravé. Pokud žádný odpovídající záznam není, hodnota bude NULL.
#
# - **RIGHT JOIN** – podobně jako LEFT, ale naopak – vybere všechny řádky z pravé tabulky.
#
# - **FULL OUTER JOIN** – spojí všechny řádky z obou tabulek, bez ohledu na to, zda existují odpovídající hodnoty.
#
# JOINy jsou důležité pro práci s relačními databázemi, kde data jsou rozdělená do více tabulek.
#
# ### Indexes a performance
#
# Indexy jsou datové struktury, které zrychlují hledání dat v databázi. Při použití indexu se databáze nemusí procházet celou tabulkou, ale může přímo najít požadované záznamy.
#
# Příklad vytvoření indexu:
# ```sql
# CREATE INDEX idx_users_email ON users(email);
# ```
#
# Výhody:
# - Rychlejší dotazy na velkých tabulkách.
# - Uspořádání dat pro efektivní vyhledávání.
#
# Nevýhody:
# - Indexy zabírají místo.
# - Při vkládání, aktualizaci nebo mazání dat se musí indexy také aktualizovat – což může zpomalit operace.
#
# Používání indexů je klíčové pro optimalizaci výkonu databází.
#
# ### Python sqlite3 module
#
# V Pythonu je možné pracovat s SQLite databázemi přímo pomocí modulu `sqlite3`. Tento modul poskytuje jednoduchou komunikaci mezi Pythonem a databází, bez nutnosti externího serveru.
#
# Příklad:
# ```python
# import sqlite3
#
# # Připojení k databázi
# conn = sqlite3.connect('database.db')
# cursor = conn.cursor()
#
# # Vytvoření tabulky
# cursor.execute('''
#     CREATE TABLE IF NOT EXISTS users (
#         id INTEGER PRIMARY KEY,
#         name TEXT NOT NULL,
#         email TEXT UNIQUE
#     )
# ''')
#
# # Vložení dat
# cursor.execute("INSERT INTO users (name, email) VALUES (?, ?)", ("Jan Novák", "jan@novak.cz"))
#
# # Potvrzení změn a uzavření spojení
# conn.commit()
# conn.close()
# ```
#
# Modul `sqlite3` je ideální pro začátek, ale ve složitějších aplikacích se často používají i ORM nástroje jako SQLAlchemy.
#
# ### SQL injection prevention
#
# SQL injection je jedna z nejčastějších bezpečnostních ohrožení v aplikacích, které pracují s databázemi. Jedná se o útok, při kterém hacker vloží škodlivý SQL kód do vstupního pole, aby ovlivnil průběh dotazu.
#
# Příklad škodlivého vstupu:
# ```sql
# ' OR '1'='1
# ```
#
# Pokud se tento vstup přímo vloží do dotazu bez ověření, může být dotaz například:
# ```sql
# SELECT * FROM users WHERE name = '' OR '1'='1';
# ```
# Tím se vybere celá tabulka – což je velké riziko.
#
# **Prevence:**
# - Používejte parametrizované dotazy (např. `cursor.execute("SELECT * FROM users WHERE name = ?", (name,))`).
# - Validujte vstupy a používejte whitelistové seznamy.
# - Nepoužívejte `eval()` nebo `exec()` na uživatelský vstup.
#
# ## 3. Důležité detaily
#
# ### Časté chyby a jak se jim vyhnout
#
# - **Nepoužití parametrizovaných dotazů** – může vést k SQL injection.
# - **Zapomnění `COMMIT` v transakcích** – změny se neuloží.
# - **Chybné použití JOINů** – mohou vést k neočekávaným výsledkům nebo zpomalení.
# - **Nepřidání indexu na často dotazované sloupce** – zpomaluje výkon.
#
# ### Best practices
#
# - Vždy používejte `PRIMARY KEY` a `NOT NULL` pro zajištění integrity dat.
# - Používejte jednoduché názvy tabulek a sloupců – čitelnost je důležitá.
# - Dělte velké dotazy na menší části, pokud to jde.
# - Udržujte databázi v souladu s principy normalizace (např. 3NF).
#
# ### Performance tipy
#
# - Vytvářejte indexy na sloupce, které se často používají ve `WHERE` podmínkách.
# - Vyhněte se použití `SELECT *`, pokud nepotřebujete všechny sloupce.
# - Používejte `LIMIT` při výběru velkého množství dat.
# - Využívejte `EXPLAIN` pro analýzu výkonu dotazů.
#
# ## 4. Propojení s předchozími kapitolami
#
# Tato kapitola navazuje na základní poznatky o databázích, které byly prezentovány v předchozích kapitolách – zejména na koncepty tabulek, sloupců a relací. Práce s SQL je rozšířením těchto znalostí o praktické práci s daty.
#
# Databázové koncepty se v tomto kontextu stávají nástrojem pro reálné aplikace – studenti mohou přejít od teorie k praxi a začít tvorbu vlastních databázových systémů. Tento poznatek ovlivňuje i další kapitoly, které budou zahrnovat pokročilé technik

# %% [markdown]
# ## 💻 Praktické příklady
#
# <div style="background: #e8f5e9; padding: 20px; border-left: 5px solid #4caf50; margin: 20px 0; border-radius: 5px;">
#     <h3 style="color: #2c3e50; margin-top: 0;">👨‍💻 Hands-on příklady ke spuštění</h3>
#     <p>Následující příklady si můžete hned vyzkoušet. Každý příklad je samostatně spustitelný.</p>
# </div>

# %% [markdown]
# ### Příklad 1
#
# Příklad 1: Vytvoření databáze a tabulky

# %% [markdown]
# ### Příklad 2
#
# ### 1. Název příkladu
# Vytvoření tabulky v SQLite databázi

# %% [markdown]
# ### Příklad 3
#
# ### 2. Co demonstruje
# Založení nové SQLite databáze, vytvoření tabulky `students` s jednoduchými sloupci.

# %% [markdown]
# ### Příklad 4
#
# ### 3. Kompletní kód

# %%
import sqlite3

# Připojení k databázi (vytvoří se soubor students.db)
conn = sqlite3.connect('students.db')
cursor = conn.cursor()

# Vytvoření tabulky students
cursor.execute('''
    CREATE TABLE IF NOT EXISTS students (
        id INTEGER PRIMARY KEY AUTOINCREMENT,
        name TEXT NOT NULL,
        age INTEGER,
        grade REAL
    )
''')

# Uložení změn a uzavření spojení
conn.commit()
conn.close()

print("Tabulka 'students' byla úspěšně vytvořena.")

# %% [markdown]
# ### Příklad 5
#
# ### 4. Očekávaný výstup
# ```
# Tabulka 'students' byla úspěšně vytvořena.
# ```

# %% [markdown]
# ### Příklad 6
#
# ### 5. Vysvětlení kódu
# - `sqlite3.connect()` vytvoří nebo otevře databázi `students.db`.
# - `CREATE TABLE IF NOT EXISTS` vytvoří tabulku, pokud ještě neexistuje.
# - Sloupce:
#   - `id`: primární klíč, automaticky se zvyšuje
#   - `name`, `age`, `grade`: datové typy pro jméno, věk a známku
#
# ---
#
# ## 🧪

# %% [markdown]
# ### Příklad 7
#
# Příklad 2: Vložení dat (INSERT) a výběr (SELECT)

# %% [markdown]
# ### Příklad 8
#
# ### 1. Název příkladu
# Vložení dat do tabulky a jejich výpis

# %% [markdown]
# ### Příklad 9
#
# ### 2. Co demonstruje
# Použití `INSERT` pro vložení záznamů a `SELECT` pro jejich načtení.

# %% [markdown]
# ### Příklad 10
#
# ### 3. Kompletní kód

# %%
import sqlite3

# Připojení k databázi
conn = sqlite3.connect('students.db')
cursor = conn.cursor()

# Vložení dat do tabulky students
students_data = [
    ('Jan Novák', 20, 8.5),
    ('Eva Svobodová', 19, 9.2),
    ('Petr Dvořák', 21, 7.8)
]

cursor.executemany('''
    INSERT INTO students (name, age, grade)
    VALUES (?, ?, ?)
''', students_data)

# Výběr všech studentů
cursor.execute('SELECT * FROM students')
rows = cursor.fetchall()

print("Všichni studenti:")
for row in rows:
    print(row)

# Uložení změn a uzavření spojení
conn.commit()
conn.close()

# %% [markdown]
# ### Příklad 11
#
# ### 4. Očekávaný výstup
# ```
# Všichni studenti:
# (1, 'Jan Novák', 20, 8.5)
# (2, 'Eva Svobodová', 19, 9.2)
# (3, 'Petr Dvořák', 21, 7.8)
# ```

# %% [markdown]
# ### Příklad 12
#
# ### 5. Vysvětlení kódu
# - `executemany()` vloží více záznamů najednou.
# - `SELECT * FROM students` vrací všechny řádky.
# - `fetchall()` načte výsledky do proměnné.
#
# ---
#
# ## 🧪

# %% [markdown]
# ### Příklad 13
#
# Příklad 3: Aktualizace a mazání dat (UPDATE, DELETE)

# %% [markdown]
# ### Příklad 14
#
# ### 1. Název příkladu
# Úprava a odstranění dat

# %% [markdown]
# ### Příklad 15
#
# ### 2. Co demonstruje
# Použití `UPDATE` pro změnu dat a `DELETE` pro odstranění záznamu.

# %% [markdown]
# ### Příklad 16
#
# ### 3. Kompletní kód

# %%
import sqlite3

# Připojení k databázi
conn = sqlite3.connect('students.db')
cursor = conn.cursor()

# Aktualizace známky studenta
cursor.execute('''
    UPDATE students
    SET grade = 9.0
    WHERE name = 'Jan Novák'
''')

# Smazání studenta podle jména
cursor.execute('''
    DELETE FROM students
    WHERE name = 'Petr Dvořák'
''')

# Výběr všech studentů po úpravách
cursor.execute('SELECT * FROM students')
rows = cursor.fetchall()

print("Studenti po úpravách:")
for row in rows:
    print(row)

# Uložení změn a uzavření spojení
conn.commit()
conn.close()

# %% [markdown]
# ### Příklad 17
#
# ### 4. Očekávaný výstup
# ```
# Studenti po úpravách:
# (1, 'Jan Novák', 20, 9.0)
# (2, 'Eva Svobodová', 19, 9.2)
# ```

# %% [markdown]
# ### Příklad 18
#
# ### 5. Vysvětlení kódu
# - `UPDATE` mění hodnotu v tabulce podle podmínky.
# - `DELETE` odstraní řádky odpovídající podmínce.
# - `WHERE` určuje, které řádky se mají upravovat nebo mazat.
#
# ---
#
# ## 🧪

# %% [markdown]
# ### Příklad 19
#
# Příklad 4: JOINy (INNER, LEFT, RIGHT)

# %% [markdown]
# ### Příklad 20
#
# ### 1. Název příkladu
# Použití JOINů pro spojení tabulek

# %% [markdown]
# ### Příklad 21
#
# ### 2. Co demonstruje
# Vytvoření dvou tabulek a jejich spojení pomocí `INNER`, `LEFT` a `RIGHT JOIN`.

# %% [markdown]
# ### Příklad 22
#
# ### 3. Kompletní kód

# %%
import sqlite3

# Připojení k databázi
conn = sqlite3.connect('school.db')
cursor = conn.cursor()

# Vytvoření tabulky subjects
cursor.execute('''
    CREATE TABLE IF NOT EXISTS subjects (
        id INTEGER PRIMARY KEY,
        name TEXT
    )
''')

# Vytvoření tabulky enrollments
cursor.execute('''
    CREATE TABLE IF NOT EXISTS enrollments (
        student_id INTEGER,
        subject_id INTEGER,
        grade REAL
    )
''')

# Vložení dat
cursor.execute("INSERT OR REPLACE INTO subjects VALUES (1, 'Matematika')")
cursor.execute("INSERT OR REPLACE INTO subjects VALUES (2, 'Fyzika')")

cursor.execute("INSERT OR REPLACE INTO enrollments VALUES (1, 1, 8.5)")
cursor.execute("INSERT OR REPLACE INTO enrollments VALUES (1, 2, 9.0)")

# INNER JOIN - společné záznamy
print("INNER JOIN:")
cursor.execute('''
    SELECT s.name AS subject, e.grade
    FROM subjects s
    INNER JOIN enrollments e ON s.id = e.subject_id
''')
for row in cursor.fetchall():
    print(row)

# LEFT JOIN - všechny studenty i s nezapsanými předměty
print("\nLEFT JOIN:")
cursor.execute('''
    SELECT s.name AS subject, e.grade
    FROM subjects s
    LEFT JOIN enrollments e ON s.id = e.subject_id
''')
for row in cursor.fetchall():
    print(row)

# Uložení změn a uzavření spojení
conn.commit()
conn.close()

# %% [markdown]
# ### Příklad 23
#
# ### 4. Očekávaný výstup
# ```
# INNER JOIN:
# ('Matematika', 8.5)
# ('Fyzika', 9.0)
#
# LEFT JOIN:
# ('Matematika', 8.5)
# ('Fyzika', 9.0)
# ```

# %% [markdown]
# ### Příklad 24
#
# ### 5. Vysvětlení kódu
# - `INNER JOIN` spojuje tabulky podle shody klíčů.
# - `LEFT JOIN` vrací všechny záznamy z levé tabulky, i když neexistují odpovídající záznamy ve druhé.
# - V tomto případě jsou obě tabulky plně spojené.
#
# ---
#
# ## 🧪

# %% [markdown]
# ### Příklad 25
#
# Příklad 5: SQL injection prevence a použití indexů

# %% [markdown]
# ### Příklad 26
#
# ### 1. Název příkladu
# Bezpečné dotazy, indexování a SQL injection ochrana

# %% [markdown]
# ### Příklad 27
#
# ### 2. Co demonstruje
# Vytvoření indexu, bezpečné použití parametrů (ne SQL injection) a výkon.

# %% [markdown]
# ### Příklad 28
#
# ### 3. Kompletní kód

# %%
import sqlite3

# Připojení k databázi
conn = sqlite3.connect('students.db')
cursor = conn.cursor()

# Vytvoření indexu na sloupci name pro zrychlení vyhledávání
cursor.execute('''
    CREATE INDEX IF NOT EXISTS idx_student_name ON students(name)
''')

# Bezpečné použití parametrů (ne SQL injection)
student_name = "Jan Novák"
cursor.execute('SELECT * FROM students WHERE name = ?', (student_name,))
row = cursor.fetchone()

if row:
    print(f"Nalezen student: {row}")
else:
    print("Student nenalezen.")

# Uložení změn a uzavření spojení
conn.commit()
conn.close()

# %% [markdown]
# ### Příklad 29
#
# ### 4. Očekávaný výstup
# ```
# Nalezen student: (1, 'Jan Novák', 20, 9.0)
# ```

# %% [markdown]
# ### Příklad 30
#
# ### 5. Vysvětlení kódu
# - `CREATE INDEX` zrychluje vyhledávání podle sloupce `name`.
# - Použití `?` jako placeholder zabraňuje SQL injection.
# - `fetchone()` vrací jen první nalezený záznam.
#
# ---
#
# Pokud chceš, mohu ti připravit i další pokročilé příklady (např. transakce, views, agregace, atd.).

# %% [markdown]
# ## 🎯 Cvičení a úkoly
#
# <div style="background: #fff3e0; padding: 20px; border-left: 5px solid #ff9800; margin: 20px 0; border-radius: 5px;">
#     <h3 style="color: #2c3e50; margin-top: 0;">✍️ Praktická cvičení k procvičení</h3>
#     <p>Vyřešte následující úkoly. Začněte od jednoduššších a postupujte k složitějším.</p>
# </div>
#
# # Cvičení 1: Základní SELECT dotaz
#
# ## Název úkolu
# Vytvoření jednoduchého dotazu pro výběr dat z tabulky
#
# ## Detailní zadání
# Vytvořte SQL dotaz, který vybere všechny sloupce z tabulky `zakaznici` a výstup seřaďte podle příjmení.
#
# ## Vstupní data/požadavky
# Tabulka `zakaznici` s následujícími sloupci:
# - id (integer)
# - jmeno (text)
# - prijmeni (text)
# - email (text)
# - datum_narozeni (date)
#
# ## Očekávaný výstup
# Všechny záznamy z tabulky `zakaznici` seřazené podle příjmení.
#
# ## Hints/Nápověda
# 1. Použijte klíčové slovo SELECT pro výběr dat.
# 2. Zadejte jméno tabulky za klíčovým slovem FROM.
# 3. Přidejte ORDER BY příjmení.
# 4. Ujistěte se, že používáte správnou syntaxi pro řazení.
#
# ## Kostra řešení
# ```sql
# SELECT *
# FROM zakaznici
# ORDER BY prijmeni;
# ```
#
# ## Bonusové rozšíření
# Přidejte filtr podle roku narození (např. pouze osoby narozené po roce 1990).
#
# ---
#
# # Cvičení 2: Filtrace dat pomocí WHERE
#
# ## Název úkolu
# Filtrace záznamů podle konkrétního kritéria
#
# ## Detailní zadání
# Vytvořte SQL dotaz, který vybere jméno a email zákazníků, kteří mají e-mail v doméně "@gmail.com".
#
# ## Vstupní data/požadavky
# Tabulka `zakaznici` s poli jmeno, prijmeni, email a datum_narozeni.
#
# ## Očekávaný výstup
# Seznam zákazníků s e-maily z domény "@gmail.com".
#
# ## Hints/Nápověda
# 1. Použijte WHERE pro filtrování dat.
# 2. Pomocí LIKE nebo operátoru = vyberte správné emaily.
# 3. Zadejte příslušné sloupce do SELECT.
# 4. Využijte konkrétní podmínku na emailovou doménu.
#
# ## Kostra řešení
# ```sql
# SELECT jmeno, email
# FROM zakaznici
# WHERE email LIKE '%@gmail.com';
# ```
#
# ## Bonusové rozšíření
# Přidejte filtr podle datu narození (např. pouze osoby mladší 30 let).
#
# ---
#
# # Cvičení 3: Použití agregačních funkcí
#
# ## Název úkolu
# Výpočet průměru a počtu záznamů
#
# ## Detailní zadání
# Vytvořte dotaz, který spočítá průměrný věk zákazníků a celkový počet zákazníků.
#
# ## Vstupní data/požadavky
# Tabulka `zakaznici` s poli jmeno, prijmeni, email a datum_narozeni.
#
# ## Očekávaný výstup
# Jeden řádek s průměrným věkem a celkovým počtem zákazníků.
#
# ## Hints/Nápověda
# 1. Použijte funkci AVG() pro výpočet průměru.
# 2. Použijte COUNT(*) pro spočítání řádků.
# 3. Spočítejte věk z datum_narozeni (např. pomocí DATEDIFF).
# 4. Zadejte všechny funkce do SELECT.
#
# ## Kostra řešení
# ```sql
# SELECT AVG(YEAR(CURRENT_DATE) - YEAR(datum_narozeni)) AS prumerny_vek,
#        COUNT(*) AS pocet_zakazniku
# FROM zakaznici;
# ```
#
# ## Bonusové rozšíření
# Přidejte podmínku, že se počítá jen průměrný věk mužů (pokud je sloupec pohlaví).
#
# ---
#
# # Cvičení 4: Skupinování dat a GROUP BY
#
# ## Název úkolu
# Skupinování zákazníků podle ročníku narození
#
# ## Detailní zadání
# Vytvořte dotaz, který spočítá počet zákazníků podle roku narození a seřadí výsledky sestupně.
#
# ## Vstupní data/požadavky
# Tabulka `zakaznici` s poli jmeno, prijmeni, email a datum_narozeni.
#
# ## Očekávaný výstup
# Seznam roku narození a počtu zákazníků pro každý rok, seřazený podle roku sestupně.
#
# ## Hints/Nápověda
# 1. Použijte GROUP BY na rok narození.
# 2. Použijte funkci YEAR() pro výběr roku z datum_narozeni.
# 3. Přidejte počet zákazníků pomocí COUNT().
# 4. Seřaďte podle roku sestupně.
#
# ## Kostra řešení
# ```sql
# SELECT YEAR(datum_narozeni) AS rok_narozeni,
#        COUNT(*) AS pocet_zakazniku
# FROM zakaznici
# GROUP BY YEAR(datum_narozeni)
# ORDER BY rok_narozeni DESC;
# ```
#
# ## Bonusové rozšíření
# Přidejte podmínku, že se počítají jen zákazníci s e-maily z konkrétní domény.
#
# ---
#
# # Cvičení 5: Připojení (JOIN) dvou tabulek
#
# ## Název úkolu
# Spojení tabulek zakaznici a objednavky
#
# ## Detailní zadání
# Vytvořte dotaz, který spojí tabulku `zakaznici` a `objednavky`, aby zobrazil jméno zákazníka a datum objednávky.
#
# ## Vstupní data/požadavky
# Tabulka `zakaznici`:
# - id (integer)
# - jmeno (text)
# - prijmeni (text)
# - email (text)
#
# Tabulka `objednavky`:
# - id (integer)
# - zakaznik_id (integer, foreign key)
# - datum_objednavky (date)
# - cena (decimal)
#
# ## Očekávaný výstup
# Seznam zákazníků s jejich objednávkami.
#
# ## Hints/Nápověda
# 1. Použijte INNER JOIN pro spojení tabulek.
# 2. Zadejte podmínku spojení podle id a zakaznik_id.
# 3. Vyberte požadované sloupce z obou tabulek.
# 4. Ujistěte se, že je spojení správné (použijte aliasy pokud potřebujete).
#
# ## Kostra řešení
# ```sql
# SELECT z.jmeno, z.prijmeni, o.datum_objednavky
# FROM zakaznici z
# INNER JOIN objednavky o ON z.id = o.zakaznik_id;
# ```
#
# ## Bonusové rozšíření
# Přidejte filtr podle data objednávky (např. jen objednávky po roce 2023) a přidejte celkovou cenu objednávek.

# %% [markdown]
# ## 📚 Další zdroje a materiály
#
# <div style="background: #e3f2fd; padding: 20px; border-left: 5px solid #2196f3; margin: 20px 0; border-radius: 5px;">
#     <h3 style="color: #2c3e50; margin-top: 0;">🔗 Doporučené materiály k dalšímu studiu</h3>
# </div>
#
# # Databáze – SQL základy – Seznam zdrojů
#
# ## 5 doporučených článků/tutoriálů
#
# 1. **[W3Schools SQL Tutorial](https://www.w3schools.com/sql/)**
#    *Popis:* Komplexní a přátelský úvod do SQL, vhodný pro začátečníky. Obsahuje interaktivní příklady, cvičení a jednoduché vysvětlení syntaxe.
#
# 2. **[SQLBolt - Interactive SQL Tutorial](https://sqlbolt.com/)**
#    *Popis:* Interaktivní tutoriál, kde se naučíš SQL krok za krokem. Každá lekce obsahuje krátké vysvětlení a praktické cvičení.
#
# 3. **[The Odin Project - SQL](https://www.theodinproject.com/lessons/databases-and-sql)**
#    *Popis:* Tento tutoriál je součástí širšího kurzu pro vývojáře. Vysvětluje SQL základy včetně relačních databáz a základních příkazů.
#
# 4. **[SQLZoo - Learn SQL with Interactive Exercises](https://sqlzoo.net/)**
#    *Popis:* Interaktivní platforma pro učení SQL, kde si můžeš procvičit příkazy přímo v prohlížeči na reálných datech.
#
# 5. **[Khan Academy - Intro to SQL](https://www.khanacademy.org/computing/computer-programming/sql)**
#    *Popis:* Úvodní kurz od Khan Academy, který využívá vizuální výukové přístupy k vysvětlení SQL konceptů.
#
# ## 3 YouTube videa
#
# 1. **[The Net Ninja - SQL Tutorial for Beginners](https://www.youtube.com/watch?v=HXV3zeQKqGY)**
#    *Délka:* 2 hodiny 15 minut
#    *Popis:* Komplexní úvod do SQL pro začátečníky, vysvětluje základní příkazy jako SELECT, INSERT, UPDATE a DELETE.
#
# 2. **[freeCodeCamp.org - SQL Crash Course](https://www.youtube.com/watch?v=HXV3zeQKqGY)**
#    *Délka:* 1 hodina 45 minut
#    *Popis:* Rychlý crash course pro začátečníky, který pokrývá základní SQL syntaxi, tabulky, vztahy a agregační funkce.
#
# 3. **[Programming with Mosh - SQL Tutorial](https://www.youtube.com/watch?v=0Zg6Dl8Xb0Y)**
#    *Délka:* 1 hodina 20 minut
#    *Popis:* Moderní výukový kurz, který podrobně vysvětluje SQL základy a ukazuje praktické příklady.
#
# ## 3 knihy nebo oficiální dokumentace
#
# 1. **[SQL for Dummies](https://www.amazon.com/SQL-Dummies-Allen-Gilligan/dp/0470161905)**
#    *Popis:* Přátelský úvod do SQL, který je ideální pro začátečníky. Vysvětluje koncepty jasným jazykem a obsahuje praktické příklady.
#
# 2. **[PostgreSQL Documentation - SQL Syntax](https://www.postgresql.org/docs/current/sql.html)**
#    *Popis:* Oficiální dokumentace PostgreSQL pro pokročilé uživatele, která obsahuje detailní informace o SQL syntaxi a funkcích.
#
# 3. **[Microsoft SQL Server Documentation](https://docs.microsoft.com/en-us/sql/sql-server/)**
#    *Popis:* Dokumentace k Microsoft SQL Serveru, která zahrnuje i základní SQL příkazy a jejich implementaci v praxi.
#
# ## 2 praktické projekty k procvičení
#
# 1. **Vytvořit databázi knihovny**

# %% [markdown]
# ## 📝 Shrnutí kapitoly
#
# <div style="background: linear-gradient(135deg, #667eea 0%, #764ba2 100%); padding: 30px; border-radius: 10px; color: white; margin: 30px 0;">
#     <h3 style="color: white; margin-top: 0;">✅ Co jste se naučili</h3>
#     <ul style="list-style: none; padding-left: 0;">
#         <li>✓ SQLite introduction</li>
# <li>✓ CREATE, ALTER, DROP statements</li>
# <li>✓ INSERT, SELECT, UPDATE, DELETE</li>
# <li>✓ JOINs: INNER, LEFT, RIGHT, FULL</li>
# <li>✓ Indexes a performance</li>
#     </ul>
#
#     <h3 style="color: white;">🎯 Klíčové dovednosti</h3>
#     <p>Po dokončení této kapitoly byste měli být schopni prakticky použít všechny probrané koncepty.</p>
#
#     <h3 style='color: white;'>➡️ Další kapitola</h3><p>Kapitola 16 - pokračujte ve studiu!</p>
# </div>
#
# ---
#
# *📅 Notebook vygenerován: 2025-09-29 12:22:30*
# *🤖 Generátor: Comprehensive Colab Generator v2.0*
# *📚 Učebnice programování - Od základů k AI*

# %% [markdown]
# ## 🧪 Sandbox - Prostor pro experimenty
#
# Použijte následující buňky pro vlastní experimenty a testování:

# %%
# 🧪 Zde můžete experimentovat s kódem z kapitoly
# Napište svůj kód zde:
