# %% [markdown]
# # 📚 Kapitola 5: Základy Pythonu I - Datové typy a řízení toku
#
# <div style="background: linear-gradient(90deg, #667eea 0%, #764ba2 100%); padding: 20px; border-radius: 10px; margin: 20px 0;">
#     <h2 style="color: white; margin: 0;">Blok 1 | BEGINNER</h2>
#     <p style="color: white; margin: 10px 0;">📖 Výuková kapitola</p>
# </div>
#
# ## 🎯 Co se naučíte
#
# V této kapitole se zaměříme na následující témata:
#
# - **Datové typy: int, float, string, boolean, None**
# - **Proměnné a konstanty**
# - **Operátory: aritmetické, logické, porovnávací, bitové**
# - **Type hints a typing modul**
# - **Input/Output operace**
# - **Podmínky: if, elif, else**
# - **Ternární operátor**
#
# ## ⚠️ Předpoklady
# Tato kapitola navazuje na kapitoly: 4
#
# ---

# %%
# ⚙️ Inicializace prostředí
# Tento kód nastavuje prostředí pro kapitolu 5

import sys
import os
from datetime import datetime

# Informace o prostředí
print("=" * 60)
print(f"📚 KAPITOLA 5: Základy Pythonu I - Datové typy a řízení toku")
print("=" * 60)
print(f"🐍 Python verze: {sys.version}")
print(f"📅 Datum spuštění: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
print(f"💻 OS: {os.name}")
print(f"📁 Pracovní adresář: {os.getcwd()}")
print("=" * 60)

# Instalace potřebných knihoven (odkomentujte podle potřeby)
# !pip install requests pandas numpy matplotlib
# !pip install beautifulsoup4 sqlalchemy fastapi

# Import základních knihoven
import json
import csv
import time
import random
from pathlib import Path
from typing import List, Dict, Optional, Any

print("✅ Prostředí připraveno!")

# %% [markdown]
# ## 📖 Teoretická část
#
# <div style="background: #f0f4ff; padding: 20px; border-left: 5px solid #4a69bd; margin: 20px 0; border-radius: 5px;">
#     <h3 style="color: #2c3e50; margin-top: 0;">🎓 Základní teorie a koncepty</h3>
# </div>
#
# # Základy Pythonu I – Datové typy a řízení toku
#
# ---
#
# ## 1. Úvod a motivace
#
# Základní pojmy jako datové typy a řízení toku jsou základními stavebními kameny každého programovacího jazyka, a to i Pythonu. Učení se těmto konceptům ti umožní vytvářet logické a funkcionalní programy – od jednoduchých kalkulaček až po složité aplikace.
#
# Tato kapitola je zásadní pro každého začátečníka, protože se s ní setkáš prakticky ve všech projektech. V praxi používáme datové typy, aby jsme mohli ukládat a zpracovávat různé informace – například čísla pro výpočty, texty pro zobrazení, logické hodnoty pro podmínky.
#
# Když se naučíš správně pracovat s proměnnými, operátory a podmínkami, budeš schopen psát programy, které reagují na různé situace. To je klíč k tvorbě inteligentních a interaktivních aplikací – od webových stránek po automatizaci úkolů.
#
# Toto téma tě naučí:
# - Rozpoznat a používat základní datové typy
# - Vytvářet proměnné a správně je používat
# - Řídit tok programu pomocí podmínek
# - Pracovat s vstupem a výstupem
#
# ---
#
# ## 2. Hlavní koncepty
#
# ### Datové typy: `int`, `float`, `string`, `boolean`, `None`
#
# Python má několik základních datových typů, které se používají k ukládání různých informací:
#
# #### `int` – celá čísla
# Celá čísla (např. 1, -5, 42) jsou uložena jako typ `int`. Například:
# ```python
# x = 10
# y = -3
# ```
#
# #### `float` – desetinná čísla
# Desetinná čísla (např. 3.14, -2.5) jsou typu `float`:
# ```python
# pi = 3.14159
# temperature = -5.2
# ```
#
# #### `string` – textové řetězce
# Texty se zadávají do uvozovek (jednoduchých nebo dvojitých):
# ```python
# name = "Petr"
# greeting = 'Ahoj světe!'
# ```
#
# #### `boolean` – logické hodnoty
# Mají dvě možné hodnoty: `True` a `False`. Používají se pro podmínky:
# ```python
# is_active = True
# is_complete = False
# ```
#
# #### `None` – neexistující hodnota
# Typ `None` označuje „nic“:
# ```python
# value = None
# ```
#
# ---
#
# ### Proměnné a konstanty
#
# Proměnná je místo v paměti, kam ukládáme hodnotu. Její hodnota se může během programu změnit:
#
# ```python
# age = 25
# age = 26  # hodnota se změnila
# ```
#
# Konstanta je proměnná, jejíž hodnotu **nechceme měnit**. V Pythonu se konstanty nepřímo deklaruje – používáme konvenci psaní velkými písmeny:
#
# ```python
# PI = 3.14159
# MAX_SIZE = 1000
# ```
#
# ---
#
# ### Operátory
#
# Operátory slouží k provádění operací nad daty.
#
# #### Aritmetické operátory:
# ```python
# a = 10
# b = 3
#
# print(a + b)   # sčítání: 13
# print(a - b)   # odčítání: 7
# print(a * b)   # násobení: 30
# print(a / b)   # dělení: 3.333...
# print(a // b)  # celočíselné dělení: 3
# print(a % b)   # zbytek po dělení: 1
# print(a ** b)  # mocnina: 1000
# ```
#
# #### Porovnávací operátory:
# ```python
# print(5 > 3)   # True
# print(5 == 5)  # True
# print(5 != 3)  # True
# ```
#
# #### Logické operátory:
# ```python
# print(True and False)  # False
# print(True or False)   # True
# print(not True)        # False
# ```
#
# #### Bitové operátory (pokročilé, pro zájemce):
# ```python
# a = 5   # binárně: 101
# b = 3   # binárně: 011
#
# print(a & b)  # AND: 001 → 1
# print(a | b)  # OR: 111 → 7
# print(a ^ b)  # XOR: 110 → 6
# ```
#
# ---
#
# ### Type hints a modul `typing`
#
# Type hints umožňují zadávat typ proměnné – pomáhá při ladění a čitelnosti kódu:
#
# ```python
# def greet(name: str) -> str:
#     return f"Ahoj, {name}!"
#
# age: int = 25
# is_student: bool = True
# ```
#
# Modul `typing` poskytuje další typy jako např. `List`, `Dict`, `Optional`:
#
# ```python
# from typing import List
#
# numbers: List[int] = [1, 2, 3]
# ```
#
# ---
#
# ### Input/Output operace
#
# Získání vstupu od uživatele:
# ```python
# name = input("Jak se jmenuješ? ")
# print(f"Vítej, {name}!")
# ```
#
# Výstup do konzole:
# ```python
# print("Ahoj světe!")
# print(123)
# print("Číslo", 456)  # výstup: "Číslo 456"
# ```
#
# ---
#
# ### Podmínky: `if`, `elif`, `else`
#
# Podmínky umožňují programu reagovat na různé situace:
#
# ```python
# age = int(input("Kolik máš let? "))
#
# if age < 18:
#     print("Nejdeš do kina.")
# elif age == 18:
#     print("Můžeš jít, ale musíš mít průkaz.")
# else:
#     print("Vítej v kině!")
# ```
#
# ---
#
# ### Ternární operátor
#
# Zkrácený zápis podmínky:
#
# ```python
# age = 20
# status = "dospělý" if age >= 18 else "neplnoletý"
# print(status)
# # Výstup: dospělý
# ```
#
# ---
#
# ## 3. Důležité detaily
#
# ### Časté chyby a jak se jim vyhnout
#
# - **Nepřiřazování proměnné před použitím**:
# ```python
# # Špatně:
# print(x)  # NameError: name 'x' is not defined
# x = 5
#
# # Správně:
# x = 5
# print(x)
# ```
#
# - **Zaměňování `==` a `=`**:
# ```python
# if x = 5:  # SyntaxError
#     print("Je to pět")
#
# if x == 5:  # správně
#     print("Je to pět")
# ```
#
# ### Best practices
#
# - Používej popisné názvy proměnných:
# ```python
# # Lépe
# user_age = 25
#
# # Méně vhodné
# a = 25
# ```
#
# - Dodržuj konvence psaní kódu (např. snake_case pro proměnné).
#
# ### Performance tipy
#
# - V Pythonu je lepší používat `join()` místo `+` při spojování stringů:
# ```python
# # Pomalejší
# result = ""
# for item in items:
#     result += item
#
# # Rychlejší
# result = "".join(items)
# ```
#
# ---
#
# ## 4. Propojení s předchozími kapitolami
#
# Toto téma navazuje na základy Pythonu – jako například:
# - První programy a výstup do konzole,
# - Základy práce s proměnnými a daty,
# - Větší porozumění tomu, jak se Python chová při provádění kódu.
#
# Tato kapitola rozšiřuje již naučené znalosti o tom, **jak efektivně ukládat a zpracovávat informace**, a připravuje tě na další kapitoly jako cykly, funkce, kolekce a objektové programování.
#
# ---
#
# **Shrnutí:**
# Tato kapitola je základem pro každého Python programátora. Po jejím prostudování budeš schopen vytvářet jednoduché programy, které reagují na různé podmínky a pracují s různými typy dat. Dále se zde budou dále rozvíjet koncepty jako funkce, cykly a práce se slovníky.
#
# 👉 Pokračuj dál, protože tato kapitola tě připraví na všechno ostatní, co budeš v Pythonu potřebovat!

# %% [markdown]
# ## 💻 Praktické příklady
#
# <div style="background: #e8f5e9; padding: 20px; border-left: 5px solid #4caf50; margin: 20px 0; border-radius: 5px;">
#     <h3 style="color: #2c3e50; margin-top: 0;">👨‍💻 Hands-on příklady ke spuštění</h3>
#     <p>Následující příklady si můžete hned vyzkoušet. Každý příklad je samostatně spustitelný.</p>
# </div>

# %% [markdown]
# ### Příklad 1
#
# ### Očekávaný výstup:
# ```
# Celé číslo: 42 typ: <class 'int'>
# Desetinné číslo: 3.14 typ: <class 'float'>
# Řetězec: Ahoj světe! typ: <class 'str'>
# Boolean: True typ: <class 'bool'>
# None: None typ: <class 'NoneType'>
# ```

# %% [markdown]
# ### Příklad 2
#
# ### Vysvětlení:
# Kód vytváří proměnné různých datových typů a pomocí funkce `type()` kontroluje jejich typ. Každý datový typ má specifické použití – celá čísla pro počítání, desetinná čísla pro přesné výpočty, řetězce pro texty, boolean pro logické hodnoty a None pro chybějící hodnotu.
#
# ---
#
# # 2. Název příkladu: **Operátory a proměnné**
# ## Co demonstruje:
# Aritmetické, porovnávací a logické operátory v Pythonu.

# %%
# Definice proměnných
a = 10
b = 3

# Aritmetické operátory
soucet = a + b
rozdil = a - b
nasobek = a * b
podil = a / b
zbytek = a % b
mocnina = a ** b

print("Aritmetické operátory:")
print(f"{a} + {b} = {soucet}")
print(f"{a} - {b} = {rozdil}")
print(f"{a} * {b} = {nasobek}")
print(f"{a} / {b} = {podil}")
print(f"{a} % {b} = {zbytek}")
print(f"{a} ** {b} = {mocnina}")

# Porovnávací operátory
print("\nPorovnávací operátory:")
print(f"{a} > {b}: {a > b}")
print(f"{a} < {b}: {a < b}")
print(f"{a} == {b}: {a == b}")
print(f"{a} != {b}: {a != b}")

# Logické operátory
x = True
y = False
print("\nLogické operátory:")
print(f"AND: {x} and {y} = {x and y}")
print(f"OR:  {x} or {y} = {x or y}")
print(f"NOT: not {x} = {not x}")

# %% [markdown]
# ### Příklad 3
#
# ### Očekávaný výstup:
# ```
# Aritmetické operátory:
# 10 + 3 = 13
# 10 - 3 = 7
# 10 * 3 = 30
# 10 / 3 = 3.3333333333333335
# 10 % 3 = 1
# 10 ** 3 = 1000
#
# Porovnávací operátory:
# 10 > 3: True
# 10 < 3: False
# 10 == 3: False
# 10 != 3: True
#
# Logické operátory:
# AND: True and False = False
# OR:  True or False = True
# NOT: not True = False
# ```

# %% [markdown]
# ### Příklad 4
#
# ### Vysvětlení:
# Kód ukazuje základní operátory v Pythonu. Aritmetické operátory provádějí základní matematické výpočty. Porovnávací operátory porovnávají hodnoty a vrací boolean. Logické operátory pracují s boolean hodnotami a jsou klíčem pro řízení toku programu.
#
# ---
#
# # 3. Název příkladu: **Type hints a input/output**
# ## Co demonstruje:
# Použití type hintů, vstupu od uživatele a formátovaného výstupu.

# %%
from typing import List

def vypocitej_prumer(cisla: List[float]) -> float:
    """Spočítá průměr seznamu čísel."""
    return sum(cisla) / len(cisla) if cisla else 0

# Načtení dat od uživatele
print("Zadejte tři čísla oddělená mezerou:")
vstup = input()
cisla = [float(x) for x in vstup.split()]

# Výpočet a výstup
prumer = vypocitej_prumer(cisla)
print(f"Zadala jste čísla: {cisla}")
print(f"Průměr je: {prumer:.2f}")

# %% [markdown]
# ### Příklad 5
#
# ### Očekávaný výstup (pokud zadáme 10 20 30):
# ```
# Zadejte tři čísla oddělená mezerou:
# 10 20 30
# Zadala jste čísla: [10.0, 20.0, 30.0]
# Průměr je: 20.00
# ```

# %% [markdown]
# ### Příklad 6
#
# ### Vysvětlení:
# Použití `input()` umožňuje uživateli zadávat data. Type hints (např. `List[float]`) pomáhají dokumentovat očekávané typy a zlepšují čitelnost kódu. Formátovaný výstup (`:.2f`) zajistí, že průměr bude zobrazen s přesně dvěma desetinnými místy.
#
# ---
#
# # 4. Název příkladu: **Podmínky a ternární operátor**
# ## Co demonstruje:
# Použití podmínek `if`, `elif`, `else` a ternárního operátoru.

# %%
# Načtení čísla od uživatele
cislo = int(input("Zadejte celé číslo: "))

# Použití podmínek
if cislo > 0:
    print("Číslo je kladné")
elif cislo < 0:
    print("Číslo je záporné")
else:
    print("Číslo je nula")

# Ternární operátor (alternativa k if-else)
znamenko = "kladné" if cislo > 0 else ("záporné" if cislo < 0 else "nula")
print(f"Číslo je {znamenko}")

# %% [markdown]
# ### Příklad 7
#
# ### Očekávaný výstup (pokud zadáme -5):
# ```
# Zadejte celé číslo: -5
# Číslo je záporné
# Číslo je záporné
# ```

# %% [markdown]
# ### Příklad 8
#
# ### Vysvětlení:
# Podmínky (`if`, `elif`, `else`) umožňují programu reagovat na různé podmínky. Ternární operátor je zkrácený zápis podmínky, který se používá pro jednoduché přiřazení hodnoty – např. `hodnota = x if condition else y`.
#
# ---
#
# # 5. Název příkladu: **Komplexní aplikace datových typů a řízení toku**
# ## Co demonstruje:
# Kombinaci všech tématických okruhů do jedné praktické aplikace.

# %%
from typing import Optional

def zkontroluj_vek(vstup: str) -> Optional[int]:
    """Zkontroluje, jestli je vstup číslo a vrátí ho jako int."""
    try:
        return int(vstup)
    except ValueError:
        return None

# Vstup od uživatele
vek = input("Zadejte svůj věk: ")

# Kontrola vstupu
kontrolni_vek = zkontroluj_vek(vek)

if kontrolni_vek is not None:
    # Podmínky podle věku
    if kontrolni_vek >= 18:
        print("Jste dospělý.")
    elif kontrolni_vek >= 13:
        print("Jste teenager.")
    else:
        print("Jste dítě.")
    
    # Ternární operátor pro zjištění, jestli je číslo sudé
    je_sude = "ano" if kontrolni_vek % 2 == 0 else "ne"
    print(f"Váš věk ({kontrolni_vek}) je {je_sude}.")
else:
    print("Zadali jste neplatný věk.")

# %% [markdown]
# ### Příklad 9
#
# ### Očekávaný výstup (pokud zadáme 16):
# ```
# Zadejte svůj věk: 16
# Jste teenager.
# Váš věk (16) je ano.
# ```

# %% [markdown]
# ### Příklad 10
#
# ### Vysvětlení:
# Tento příklad kombinuje všechny témata. Uživatel zadá věk, který se zkontroluje a převede na číslo. Podmínky určují věkovou skupinu a ternární operátor zjistí, jestli je číslo sudé. Použití `Optional[int]` ve type hintu ukazuje, že funkce může vracet buď cel

# %% [markdown]
# ## 🎯 Cvičení a úkoly
#
# <div style="background: #fff3e0; padding: 20px; border-left: 5px solid #ff9800; margin: 20px 0; border-radius: 5px;">
#     <h3 style="color: #2c3e50; margin-top: 0;">✍️ Praktická cvičení k procvičení</h3>
#     <p>Vyřešte následující úkoly. Začněte od jednoduššších a postupujte k složitějším.</p>
# </div>
#
# # Cvičení: Základy Pythonu I - Datové typy a řízení toku
#
# ---
#
# ## 1. **Název úkolu:**
# **Kalkulačka s podmínkami**
#
# ### **Detailní zadání:**
# Vytvoř jednoduchou kalkulačku, která umí sčítat, odčítat, násobit a dělit. Použij podmínky (`if`, `elif`, `else`) pro výběr operace.
#
# ### **Vstupní data/požadavky:**
# - Uživatel zadá dvě čísla (celá nebo desetinná čísla).
# - Uživatel zadá operaci (`+`, `-`, `*`, `/`).
#
# ### **Očekávaný výstup:**
# Výsledek operace. Pokud uživatel zadá neplatnou operaci, vypiš chybovou zprávu.
#
# ### **Hints/Nápověda:**
# 1. Použij `input()` pro zadání čísel a operace.
# 2. Převeď čísla na typ `float`.
# 3. Použij podmínky (`if`, `elif`, `else`) k provedení správné operace.
# 4. Ošetři dělení nulou.
#
# ### **Kostra řešení:**
# ```python
# cislo1 = float(input("Zadej první číslo: "))
# operace = input("Zadej operaci (+, -, *, /): ")
# cislo2 = float(input("Zadej druhé číslo: "))
#
# # TODO: proved operaci podle zadaného znaku
#
# ```
#
# ### **Bonusové rozšíření:**
# Přidej možnost opakování výpočtu (např. „Chceš pokračovat? (ano/ne)“).
#
# ---
#
# ## 2. **Název úkolu:**
# **Zjištění typu proměnné**
#
# ### **Detailní zadání:**
# Vytvoř program, který vypíše typ proměnné podle její hodnoty. Využij `type()` a podmínky.
#
# ### **Vstupní data/požadavky:**
# - Program přijímá číslo (celé nebo desetinné), text nebo boolean.
#
# ### **Očekávaný výstup:**
# Text, který říká: „Proměnná má typ: <typ>“.
#
# ### **Hints/Nápověda:**
# 1. Použij `input()` pro zadání hodnoty.
# 2. Použij `eval()` nebo převod na konkrétní typ (např. `int`, `float`, `str`).
# 3. Při kontrole použij `if` podmínky (`==`).
# 4. Vypiš odpovídající text podle typu.
#
# ### **Kostra řešení:**
# ```python
# hodnota = input("Zadej hodnotu: ")
#
# # TODO: zjisti typ a vypiš ho
#
# ```
#
# ### **Bonusové rozšíření:**
# Přidej kontrolu, jestli uživatel zadává správný formát (např. číslo jako text).
#
# ---
#
# ## 3. **Název úkolu:**
# **Vítejte v programu**
#
# ### **Detailní zadání:**
# Vytvoř program, který drží uživatele v cyklu `while`, dokud nezadá správné heslo (např. „Python“). Po zadání správného hesla se vypíše „Vítej!“.
#
# ### **Vstupní data/požadavky:**
# - Uživatel zadává heslo pomocí `input()`.
#
# ### **Očekávaný výstup:**
# Po zadání správného hesla: „Vítej!“.
#
# ### **Hints/Nápověda:**
# 1. Použij cyklus `while`.
# 2. Vytvoř podmínku, která kontroluje heslo.
# 3. Použij `break` pro ukončení cyklu.
# 4. Při špatném zadání vypiš „Zkus to znovu.“
#
# ### **Kostra řešení:**
# ```python
# heslo = "Python"
#
# # TODO: zadej heslo a porovnej ho s proměnnou
#
# ```
#
# ### **Bonusové rozšíření:**
# Omez počet pokusů (např. 3 pokusy).
#
# ---
#
# ## 4. **Název úkolu:**
# **Seznam jmen a jejich délky**
#
# ### **Detailní zadání:**
# Vytvoř program, který se zeptá uživatele na několik jmen (pomocí `input`) a uloží je do seznamu. Poté vypiš délku každého jména.
#
# ### **Vstupní data/požadavky:**
# - Uživatel zadá jména postupně.
# - Zadání ukončí pomocí prázdného řádku.
#
# ### **Očekávaný výstup:**
# Seznam jmen a jejich délky (např. „Petr – 4 znaky“).
#
# ### **Hints/Nápověda:**
# 1. Použij `while` smyčku pro zadání jmen.
# 2. Ulož jména do seznamu (`list`).
# 3. Použij `len()` k zjištění délky jména.
# 4. Vypiš výsledky pomocí cyklu `for`.
#
# ### **Kostra řešení:**
# ```python
# jmena = []
#
# # TODO: přidej jména do seznamu a vypiš jejich délku
#
# ```
#
# ### **Bonusové rozšíření:**
# Seřaď jména podle délky.
#
# ---
#
# ## 5. **Název úkolu:**
# **Složitější kalkulačka s cyklem**
#
# ### **Detailní zadání:**
# Vytvoř kalkulačku, která umožňuje více výpočtů bez ukončení programu. Umožni uživateli zvolit operaci a poté zadat dvě čísla. Po každém výpočtu se zeptá, zda chce pokračovat.
#
# ### **Vstupní data/požadavky:**
# - Výběr operace (`+`, `-`, `*`, `/`).
# - Zadání dvou čísel.
# - Volba pokračování.
#
# ### **Očekávaný výstup:**
# Výsledek operace a dotaz na pokračování.
#
# ### **Hints/Nápověda:**
# 1. Použij `while True` smyčku.
# 2. Přidej podmínky pro operace (`if`, `elif`, `else`).
# 3. Umožni uživateli opakovat výpočty.
# 4. Při volbě „ne“ ukonči program pomocí `break`.
#
# ### **Kostra řešení:**
# ```python
# while True:
#     # TODO: vlož operace a výpočet
#
# ```
#
# ### **Bonusové rozšíření:**
# Přidej možnost volby typu čísla (celé, desetinné) a ošetři dělení nulou.
#
# ---

# %% [markdown]
# ## 📚 Další zdroje a materiály
#
# <div style="background: #e3f2fd; padding: 20px; border-left: 5px solid #2196f3; margin: 20px 0; border-radius: 5px;">
#     <h3 style="color: #2c3e50; margin-top: 0;">🔗 Doporučené materiály k dalšímu studiu</h3>
# </div>
#
# # Zdroje pro kapitolu: **Základy Pythonu I – Datové typy a řízení toku**
#
# ---
#
# ## 📚 5 doporučených článků/tutoriálů
#
# 1. **[Python.org - Tutorial: Data Types](https://docs.python.org/3/tutorial/introduction.html#numbers)**
#    Oficiální úvodní kapitola v dokumentaci Pythonu, která se zabývá základními datovými typy, proměnnými a základními operacemi. Vhodné pro začátečníky.
#
# 2. **[Real Python - Python Data Types and Variables](https://realpython.com/python-data-types/)**
#    Detailní článek o datových typech v Pythonu s praktickými příklady. Vysvětluje rozdíly mezi int, float, string, bool a dalšími typy.
#
# 3. **[W3Schools - Python Data Types](https://www.w3schools.com/python/python_datatypes.asp)**
#    Stručný a přehledný tutoriál pro rychlé seznámení s datovými typy v Pythonu, vhodný pro začátečníky.
#
# 4. **[Python.org - Tutorial: Control Flow Tools](https://docs.python.org/3/tutorial/controlflow.html)**
#    Oficiální dokumentace o řízení toku – `if`, `for`, `while`, `break`, `continue`, `else`.
#
# 5. **[Automate the Boring Stuff with Python - Chapter 2: Flow Control](https://automatetheboringstuff.com/2e/chapter2/)**
#    Výukový materiál zaměřený na praktické využití řízení toku v reálných příkladech, ideální pro začátečníky.
#
# ---
#
# ## 🎥 3 YouTube videa
#
# 1. **[Corey Schafer - Python Tutorial for Beginners (Full Course)](https://www.youtube.com/watch?v=YYXdXT2l-Gg)**
#    Délka: 2:08:42
#    Komplexní úvod do Pythonu, včetně práce s datovými typy a základního řízení toku. Vhodné pro začátečníky.
#
# 2. **[Programming with Mosh - Python Tutorial for Beginners](https://www.youtube.com/watch?v=kqtD5dpn9C8)**
#    Délka: 1:34:15
#    Stručný a přehledný výukový video kurz, který pokrývá datové typy, proměnné, podmínky a cykly.
#
# 3. **[freeCodeCamp.org - Python for Beginners - Full Course](https://www.youtube.com/watch?v=rfscVS0vtbw)**
#    Délka: 2:19:47
#    Výukový kurz pro začátečníky, který zahrnuje i řízení toku v Pythonu a základní práci s proměnnými.
#
# ---
#
# ## 📘 3 knihy / oficiální dokumentace
#
# 1. **[Dokumentace Pythonu – Oficiální dokumentace](https://docs.python.org/3/)**
#    Kompletní a spolehlivá referenční dokumentace, která obsahuje všechny informace o datových typech i řízení toku.
#
# 2. **["Python Crash Course" – Eric Matthes](https://www.amazon.com/Python-Crash-Course-2nd-Edition/dp/1593279280)**
#    Praktická učebnice pro začátečníky, která obsahuje kapitoly o proměnných, datech a řízení toku.
#
# 3. **["Automate the Boring Stuff with Python" – Al Sweigart](https://automatetheboringstuff.com/)**
#    Knihu lze číst online nebo v tištěné podobě. Vhodná pro začátečníky, kteří chtějí nau

# %% [markdown]
# ## 📝 Shrnutí kapitoly
#
# <div style="background: linear-gradient(135deg, #667eea 0%, #764ba2 100%); padding: 30px; border-radius: 10px; color: white; margin: 30px 0;">
#     <h3 style="color: white; margin-top: 0;">✅ Co jste se naučili</h3>
#     <ul style="list-style: none; padding-left: 0;">
#         <li>✓ Datové typy: int, float, string, boolean, None</li>
# <li>✓ Proměnné a konstanty</li>
# <li>✓ Operátory: aritmetické, logické, porovnávací, bitové</li>
# <li>✓ Type hints a typing modul</li>
# <li>✓ Input/Output operace</li>
#     </ul>
#
#     <h3 style="color: white;">🎯 Klíčové dovednosti</h3>
#     <p>Po dokončení této kapitoly byste měli být schopni prakticky použít všechny probrané koncepty.</p>
#
#     <h3 style='color: white;'>➡️ Další kapitola</h3><p>Kapitola 6 - pokračujte ve studiu!</p>
# </div>
#
# ---
#
# *📅 Notebook vygenerován: 2025-09-29 11:49:24*
# *🤖 Generátor: Comprehensive Colab Generator v2.0*
# *📚 Učebnice programování - Od základů k AI*

# %% [markdown]
# ## 🧪 Sandbox - Prostor pro experimenty
#
# Použijte následující buňky pro vlastní experimenty a testování:

# %%
# 🧪 Zde můžete experimentovat s kódem z kapitoly
# Napište svůj kód zde:
