# %% [markdown]
# # 📚 Učebnice Programování - Kompletní Obsah
#
# <div style="background: linear-gradient(135deg, #667eea 0%, #764ba2 100%); padding: 40px; border-radius: 15px; text-align: center; color: white; margin: 20px 0;">
#     <h1 style="color: white; font-size: 36px; margin: 0;">Od Terminálu k AI</h1>
#     <p style="font-size: 20px; margin: 20px 0;">Kompletní průvodce moderním programováním</p>
#     <p style="font-size: 16px;">40 kapitol | 4 bloky | 4 projekty</p>
# </div>
#
# ## 📖 O učebnici
#
# Tato interaktivní učebnice vás provede cestou od úplných základů programování až po tvorbu pokročilých AI aplikací.
# Každá kapitola obsahuje:
#
# - 📖 **Teoretický výklad** - Detailní vysvětlení konceptů
# - 💻 **Praktické příklady** - Spustitelný kód k experimentování
# - 🎯 **Cvičení** - Úkoly k procvičení
# - 📚 **Další zdroje** - Odkazy na dodatečné materiály
# - 🚀 **Projekty** - Komplexní aplikace k vytvoření
#
# ## 🗂️ Struktura učebnice

# %% [markdown]
# ## Blok 1: Základy programování
#
# <div style="background: #4caf5020; padding: 20px; border-left: 5px solid #4caf50; margin: 20px 0; border-radius: 5px;">
#
# ### Kapitola 1: Úvod do terminálu a příkazové řádky
# - **Témata**: Windows: Command Prompt, PowerShell, Windows Terminal, MacOS: Terminal.app, iTerm2, zsh/bash shell, Ubuntu: GNOME Terminal, Konsole, Terminator...
# - **Obtížnost**: beginner
#
# ### Kapitola 2: Instalace vývojových nástrojů
# - **Témata**: Windows: Chocolatey, Scoop, winget, MacOS: Homebrew, MacPorts, Ubuntu/Debian: APT, snap packages...
# - **Obtížnost**: beginner
# - **Prerekvizity**: Kapitoly 1
#
# ### Kapitola 3: Git a verzování kódu
# - **Témata**: Git instalace a konfigurace, Základní příkazy: init, add, commit, status, log, Branching: branch, checkout, merge...
# - **Obtížnost**: beginner
# - **Prerekvizity**: Kapitoly 1, 2
#
# ### Kapitola 4: Python - instalace a virtuální prostředí
# - **Témata**: Python 3.11+ instalace, Windows: py launcher, python.exe, MacOS: pyenv, python3...
# - **Obtížnost**: beginner
# - **Prerekvizity**: Kapitoly 1, 2
#
# ### Kapitola 5: Základy Pythonu I - Datové typy a řízení toku
# - **Témata**: Datové typy: int, float, string, boolean, None, Proměnné a konstanty, Operátory: aritmetické, logické, porovnávací, bitové...
# - **Obtížnost**: beginner
# - **Prerekvizity**: Kapitoly 4
#
# ### Kapitola 6: Základy Pythonu II - Kolekce dat
# - **Témata**: Seznamy (lists) - metody a operace, Tuple - immutable sequences, Množiny (sets) - unique values...
# - **Obtížnost**: beginner
# - **Prerekvizity**: Kapitoly 5
#
# ### Kapitola 7: Funkce a moduly
# - **Témata**: Definice funkcí, return statement, Parametry: positional, keyword, default, *args a **kwargs...
# - **Obtížnost**: beginner
# - **Prerekvizity**: Kapitoly 5, 6
#
# ### Kapitola 8: Práce se soubory a výjimky
# - **Témata**: Čtení a zápis textových souborů, Binary files, Context managers (with statement)...
# - **Obtížnost**: beginner
# - **Prerekvizity**: Kapitoly 7
#
# ### Kapitola 9: Debugging a testování základů
# - **Témata**: Print debugging techniky, Python debugger (pdb), VS Code debugging...
# - **Obtížnost**: beginner
# - **Prerekvizity**: Kapitoly 7, 8
#
# ### Kapitola 10: Projekt 1 - CLI Todo aplikace 🎯 **[PROJEKT]**
# - **Témata**: Argument parsing s argparse, JSON persistence layer, CRUD operace implementation...
# - **Obtížnost**: beginner
# - **Prerekvizity**: Kapitoly 1, 2, 3
#
# </div>

# %% [markdown]
# ## Blok 2: Středně pokročilé techniky
#
# <div style="background: #2196f320; padding: 20px; border-left: 5px solid #2196f3; margin: 20px 0; border-radius: 5px;">
#
# ### Kapitola 11: Objektově orientované programování I
# - **Témata**: Třídy a objekty, Konstruktor __init__ a destruktor __del__, Instance vs. class attributes...
# - **Obtížnost**: intermediate
# - **Prerekvizity**: Kapitoly 7
#
# ### Kapitola 12: Objektově orientované programování II
# - **Témata**: Dědičnost (inheritance), Method overriding, Super() function...
# - **Obtížnost**: intermediate
# - **Prerekvizity**: Kapitoly 11
#
# ### Kapitola 13: Práce s API a HTTP requests
# - **Témata**: Requests library - installation, HTTP methods: GET, POST, PUT, DELETE, PATCH, Headers a authentication...
# - **Obtížnost**: intermediate
# - **Prerekvizity**: Kapitoly 8
#
# ### Kapitola 14: Web scraping základy
# - **Témata**: BeautifulSoup4 installation, HTML/XML parsing, CSS selectors a find methods...
# - **Obtížnost**: intermediate
# - **Prerekvizity**: Kapitoly 13
#
# ### Kapitola 15: Databáze - SQL základy
# - **Témata**: SQLite introduction, CREATE, ALTER, DROP statements, INSERT, SELECT, UPDATE, DELETE...
# - **Obtížnost**: intermediate
# - **Prerekvizity**: Kapitoly 8
#
# ### Kapitola 16: ORM - SQLAlchemy
# - **Témata**: SQLAlchemy Core vs. ORM, Declarative mapping, Sessions a Unit of Work...
# - **Obtížnost**: intermediate
# - **Prerekvizity**: Kapitoly 15
#
# ### Kapitola 17: Asynchronní programování
# - **Témata**: Asyncio event loop, Coroutines a async/await, Tasks a futures...
# - **Obtížnost**: intermediate
# - **Prerekvizity**: Kapitoly 13
#
# ### Kapitola 18: REST API vytvoření s FastAPI
# - **Témata**: FastAPI installation a setup, Path a query parameters, Request/Response models (Pydantic)...
# - **Obtížnost**: intermediate
# - **Prerekvizity**: Kapitoly 13, 16
#
# ### Kapitola 19: Autentizace a bezpečnost
# - **Témata**: Password hashing (bcrypt, argon2), JWT tokens generation a validation, OAuth2 implementation...
# - **Obtížnost**: intermediate
# - **Prerekvizity**: Kapitoly 18
#
# ### Kapitola 20: Projekt 2 - REST API pro blog 🎯 **[PROJEKT]**
# - **Témata**: FastAPI application structure, User registration/authentication, Blog posts CRUD...
# - **Obtížnost**: intermediate
# - **Prerekvizity**: Kapitoly 11, 12, 13
#
# </div>

# %% [markdown]
# ## Blok 3: Pokročilé koncepty
#
# <div style="background: #ff980020; padding: 20px; border-left: 5px solid #ff9800; margin: 20px 0; border-radius: 5px;">
#
# ### Kapitola 21: Docker základy
# - **Témata**: Docker installation všechny OS, Docker architecture, Dockerfile syntax a best practices...
# - **Obtížnost**: advanced
# - **Prerekvizity**: Kapitoly 4
#
# ### Kapitola 22: Docker Compose
# - **Témata**: docker-compose.yml structure, Services definition, Multi-container applications...
# - **Obtížnost**: advanced
# - **Prerekvizity**: Kapitoly 21
#
# ### Kapitola 23: CI/CD pipeline
# - **Témata**: GitHub Actions workflows, GitLab CI/CD pipelines, Jenkins basics...
# - **Obtížnost**: advanced
# - **Prerekvizity**: Kapitoly 3, 21
#
# ### Kapitola 24: Cloud deployment základy
# - **Témata**: Cloud providers: AWS, GCP, Azure, Heroku deployment, DigitalOcean droplets...
# - **Obtížnost**: advanced
# - **Prerekvizity**: Kapitoly 21, 22
#
# ### Kapitola 25: Mikroslužby architektura
# - **Témata**: Monolith vs. mikroslužby, Service boundaries, API Gateway pattern...
# - **Obtížnost**: advanced
# - **Prerekvizity**: Kapitoly 18, 22
#
# ### Kapitola 26: Performance optimalizace
# - **Témata**: Python profiling tools, Memory profiling, Caching strategies...
# - **Obtížnost**: advanced
# - **Prerekvizity**: Kapitoly 17
#
# ### Kapitola 27: Pokročilé testování
# - **Témata**: Pytest framework advanced, Fixtures a parametrize, Mocking a monkeypatching...
# - **Obtížnost**: advanced
# - **Prerekvizity**: Kapitoly 9
#
# ### Kapitola 28: Design patterns v Pythonu
# - **Témata**: Creational patterns: Singleton, Factory, Builder, Structural patterns: Adapter, Decorator, Facade, Behavioral patterns: Observer, Strategy, Command...
# - **Obtížnost**: advanced
# - **Prerekvizity**: Kapitoly 12
#
# ### Kapitola 29: GraphQL API
# - **Témata**: GraphQL vs. REST comparison, Schema definition language, Queries, mutations, subscriptions...
# - **Obtížnost**: advanced
# - **Prerekvizity**: Kapitoly 18
#
# ### Kapitola 30: Projekt 3 - Mikroslužbová e-commerce aplikace 🎯 **[PROJEKT]**
# - **Témata**: Microservices design, User service implementation, Product catalog service...
# - **Obtížnost**: advanced
# - **Prerekvizity**: Kapitoly 21, 22, 23
#
# </div>

# %% [markdown]
# ## Blok 4: AI a LLM integrace
#
# <div style="background: #9c27b020; padding: 20px; border-left: 5px solid #9c27b0; margin: 20px 0; border-radius: 5px;">
#
# ### Kapitola 31: Úvod do LLM a Ollama
# - **Témata**: LLM základní koncepty, Transformers architecture basics, Ollama installation všechny OS...
# - **Obtížnost**: expert
# - **Prerekvizity**: Kapitoly 4
#
# ### Kapitola 32: Ollama API integrace
# - **Témata**: Ollama REST API endpoints, Python client implementation, Streaming responses...
# - **Obtížnost**: expert
# - **Prerekvizity**: Kapitoly 31, 13
#
# ### Kapitola 33: LangChain základy
# - **Témata**: LangChain installation, Core concepts: Chains, Prompts, Memory types...
# - **Obtížnost**: expert
# - **Prerekvizity**: Kapitoly 32
#
# ### Kapitola 34: LangGraph úvod
# - **Témata**: Graph-based LLM orchestration, Nodes a edges definition, State management...
# - **Obtížnost**: expert
# - **Prerekvizity**: Kapitoly 33
#
# ### Kapitola 35: RAG (Retrieval Augmented Generation)
# - **Témata**: RAG architecture, Vector databases: ChromaDB, Pinecone, Weaviate, Embeddings models...
# - **Obtížnost**: expert
# - **Prerekvizity**: Kapitoly 33
#
# ### Kapitola 36: Agents a Tools
# - **Témata**: LangChain agents types, Custom tool creation, ReAct pattern implementation...
# - **Obtížnost**: expert
# - **Prerekvizity**: Kapitoly 33, 34
#
# ### Kapitola 37: Prompt Engineering pokročilé
# - **Témata**: System prompts optimization, Few-shot learning techniques, Chain-of-thought prompting...
# - **Obtížnost**: expert
# - **Prerekvizity**: Kapitoly 32
#
# ### Kapitola 38: LLM aplikace - produkční nasazení
# - **Témata**: Streaming API endpoints, WebSocket integration, Queue management for LLM...
# - **Obtížnost**: expert
# - **Prerekvizity**: Kapitoly 32, 18, 24
#
# ### Kapitola 39: Evaluace a testování LLM aplikací
# - **Témata**: Evaluation metrics for LLM, Test datasets creation, Automated testing strategies...
# - **Obtížnost**: expert
# - **Prerekvizity**: Kapitoly 37, 27
#
# ### Kapitola 40: Finální projekt - AI asistent s LangGraph 🎯 **[PROJEKT]**
# - **Témata**: Complete AI assistant architecture, Multi-turn conversation handling, RAG integration...
# - **Obtížnost**: expert
# - **Prerekvizity**: Kapitoly 31, 32, 33
#
# </div>

# %% [markdown]
# ## 📊 Statistiky učebnice
#
# <div style="background: #f5f5f5; padding: 20px; border-radius: 10px; margin: 20px 0;">
#     <h3>Celkový obsah:</h3>
#     <ul>
#         <li>📚 <strong>40 kapitol</strong> pokrývajících vše od základů po AI</li>
#         <li>🎯 <strong>4 komplexní projekty</strong> k implementaci</li>
#         <li>💻 <strong>200+ příkladů kódu</strong> k vyzkoušení</li>
#         <li>✍️ <strong>200+ cvičení</strong> k procvičení</li>
#         <li>⏱️ <strong>120+ hodin</strong> výukového obsahu</li>
#     </ul>
# </div>
#
# ## 🚀 Jak začít
#
# 1. **Prostudujte kapitoly postupně** - každá kapitola staví na předchozích znalostech
# 2. **Spouštějte příklady** - všechen kód je interaktivní
# 3. **Řešte cvičení** - procvičte si naučené
# 4. **Vytvořte projekty** - aplikujte znalosti v praxi
#
# ## 💡 Tipy pro studium
#
# - 📅 Věnujte každé kapitole alespoň 2-3 hodiny
# - 🔄 Vraťte se k předchozím kapitolám při nejasnostech
# - 💬 Experimentujte s kódem a modifikujte příklady
# - 📝 Dělejte si poznámky přímo do notebooků
#
# ---
#
# *Vygenerováno: 2025-09-29 11:34:37*
