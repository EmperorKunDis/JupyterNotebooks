# %% [markdown]
# # 📚 Kapitola 24: Cloud deployment základy
#
# <div style="background: linear-gradient(90deg, #667eea 0%, #764ba2 100%); padding: 20px; border-radius: 10px; margin: 20px 0;">
#     <h2 style="color: white; margin: 0;">Blok 3 | ADVANCED</h2>
#     <p style="color: white; margin: 10px 0;">📖 Výuková kapitola</p>
# </div>
#
# ## 🎯 Co se naučíte
#
# V této kapitole se zaměříme na následující témata:
#
# - **Cloud providers: AWS, GCP, Azure**
# - **Heroku deployment**
# - **DigitalOcean droplets**
# - **Railway, Render, Fly.io**
# - **Domain management a DNS**
# - **SSL certificates (Let's Encrypt)**
# - **Monitoring a logging**
#
# ## ⚠️ Předpoklady
# Tato kapitola navazuje na kapitoly: 21, 22
#
# ---

# %%
# ⚙️ Inicializace prostředí
# Tento kód nastavuje prostředí pro kapitolu 24

import sys
import os
from datetime import datetime

# Informace o prostředí
print("=" * 60)
print(f"📚 KAPITOLA 24: Cloud deployment základy")
print("=" * 60)
print(f"🐍 Python verze: {sys.version}")
print(f"📅 Datum spuštění: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
print(f"💻 OS: {os.name}")
print(f"📁 Pracovní adresář: {os.getcwd()}")
print("=" * 60)

# Instalace potřebných knihoven (odkomentujte podle potřeby)
# !pip install requests pandas numpy matplotlib
# !pip install beautifulsoup4 sqlalchemy fastapi

# Import základních knihoven
import json
import csv
import time
import random
from pathlib import Path
from typing import List, Dict, Optional, Any

print("✅ Prostředí připraveno!")

# %% [markdown]
# ## 📖 Teoretická část
#
# <div style="background: #f0f4ff; padding: 20px; border-left: 5px solid #4a69bd; margin: 20px 0; border-radius: 5px;">
#     <h3 style="color: #2c3e50; margin-top: 0;">🎓 Základní teorie a koncepty</h3>
# </div>
#
# # Cloud Deployment – Základy
#
# ## 1. Úvod a motivace
#
# Cloud deployment je klíčová součást moderního vývoje softwaru, která umožňuje nasazovat a provozovat aplikace na dálkových serverech, což znamená, že nezávisíme na lokálním hardware. Je to zásadní téma pro každého vývojáře, který chce své aplikace dostat do praxe a udržovat je v provozu. V praxi se cloud deployment používá všude – od malých startupů po velké korporace, které potřebují škálovatelné a spolehlivé řešení. Naučit se správně nasazovat aplikace do cloudu je nezbytné pro úspěšný vývoj a provoz softwaru.
#
# V tomto kurzu se naučíte pracovat s různými cloudovými poskytovateli, jako jsou AWS, GCP a Azure. Vysvětlíme i jednodušší nástroje jako Heroku, Railway nebo Fly.io – které jsou ideální pro začátečníky. Také se naučíte spravovat domény, nastavovat SSL certifikáty a vytvářet monitoring a logování. Tyto znalosti vám umožní základně nasazovat aplikace a zajistit jejich bezpečný a spolehlivý provoz.
#
# ---
#
# ## 2. Hlavní koncepty
#
# ### Cloud providers: AWS, GCP, Azure
#
# Cloudové poskytovatele (Cloud Providers) si můžeme představit jako „obchodníky“ s výpočetními kapacitami a službami – většinou jsou to velké korporace, které nabízejí různé typy cloudových služeb, od jednoduchého hostování aplikací až po pokročilé řešení pro strojové učení.
#
# #### AWS (Amazon Web Services)
# AWS je nejrozšířenější cloudový poskytovatel na světě. Nabízí nejširší škálu služeb, včetně výpočetních instancí (EC2), databází (RDS), úložiště (S3) a mnoha dalších. Je vhodný pro pokročilé projekty, ale také se dá použít i na jednodušší aplikace.
#
# #### GCP (Google Cloud Platform)
# GCP je oblíbené prostředí pro vývojáře, kteří chtějí využít silnou sílu Google – například v oblasti AI/ML. Nabízí výkonné nástroje pro zpracování dat a velmi dobrou integraci s nástroji jako Kubernetes nebo TensorFlow.
#
# #### Azure (Microsoft Azure)
# Azure se nejčastěji používá v korporacích, které již využívají Microsoft produkty. Je velmi uživatelsky přívětivý a nabízí širokou škálu služeb, které se dobře integrují s Windows servery, .NET aplikacemi a dalšími MS nástroji.
#
# ---
#
# ### Heroku deployment
#
# Heroku je jedna z nejznámějších platform pro jednoduché nasazování aplikací. Je to PaaS (Platform as a Service), což znamená, že vývojář nemusí řešit infrastrukturu – vše se automaticky nastaví.
#
# #### Výhody:
# - Jednoduché nasazení pomocí Gitu
# - Automatická škálovatelnost
# - Dobrá integrace s mnoha databázemi
#
# #### Nevýhody:
# - Může být drahé pro velké aplikace
# - Má omezení na některé typy aplikací (např. vlastní systémové knihovny)
#
# ---
#
# ### DigitalOcean droplets
#
# DigitalOcean je jednoduchá a přívětivá platforma, která se zaměřuje na jednoduché droplets – což jsou virtuální servery, které můžete nakonfigurovat dle potřeby. Vhodné hlavně pro vývojáře, kteří chtějí plnou kontrolu nad systémem.
#
# #### Výhody:
# - Nízká cena
# - Jednoduchá správa
# - Vhodné pro učení a malé projekty
#
# ---
#
# ### Railway, Render, Fly.io
#
# Tyto platformy jsou moderní a přívětivé pro začátečníky i pokročilé vývojáře. Nabízí jednoduché nasazení a automatické škálování.
#
# #### Railway
# - Vhodné pro rychlé nasazení Node.js, Python, Docker aplikací
# - Intuitivní rozhraní
# - Automatické zpracování CI/CD
#
# #### Render
# - Výborná podpora pro web aplikace a API
# - Podpora Gitu a Dockeru
# - Velmi jednoduché nastavení
#
# #### Fly.io
# - Fokus na škálovatelnost a rychlost
# - Vhodné i pro globální nasazení (např. zákazníci z Evropy, USA)
# - Podpora Dockeru a několika programovacích jazyků
#
# ---
#
# ### Domain management a DNS
#
# Domain je adresa, pod kterou se vaše aplikace dostane k uživatelům – například `www.mojepriklad.cz`. Správa domény znamená vytvoření, nastavení a správu DNS záznamů.
#
# #### DNS záznamy:
# - **A** záznam – přesměrování domény na IP adresu
# - **CNAME** – alias pro jinou doménu (např. `www.example.com` → `example.com`)
# - **MX** – nastavení e-mailových serverů
#
# Nástroje:
# - Cloudflare
# - Namecheap
# - GoDaddy
# - AWS Route 53
#
# ---
#
# ### SSL certificates (Let's Encrypt)
#
# SSL certifikát zajišťuje šifrování komunikace mezi klientem a serverem – tedy, že data nejsou přenášena v čitelné podobě. V praxi znamená to, že vaše aplikace bude dostupná přes `https://`.
#
# #### Let's Encrypt
# - Je bezplatný SSL certifikát
# - Automaticky obnovovaný (pomocí nástrojů jako Certbot)
# - Vhodné pro většinu webových aplikací
#
# #### Jak nastavit:
# 1. Nainstalujte Certbot
# 2. Přidělte certifikát ke svému serveru (např. Nginx, Apache)
# 3. Automaticky se obnovuje každých 90 dní
#
# ---
#
# ### Monitoring a logging
#
# Monitoring a logování jsou klíčové pro zajištění stability aplikace. Monitoring sleduje stav systému, zatímco logování ukládá informace o chodu aplikace.
#
# #### Monitorovací nástroje:
# - **Prometheus** – populární nástroj pro sběr metrik
# - **Grafana** – vizualizace dat z Prometheusu nebo jiných zdrojů
# - **New Relic, Datadog, Sentry**
#
# #### Logging:
# - Logy by měly být strukturované a čitelné
# - Měly by obsahovat informace o chybách, přístupu, výkonech
# - Používají se nástroje jako Winston (Node.js), Log4j (Java)
#
# ---
#
# ## 3. Důležité detaily
#
# ### Časté chyby a jak se jim vyhnout
#
# 1. **Nepřesné nastavení DNS** – aplikace může být nedostupná, protože nejsou správně přesměrovány.
# 2. **Neškálovatelné nasazení** – pokud se aplikace zvýší, nemusí fungovat správně bez škálování.
# 3. **Nevhodné nastavení SSL** – může vést k varováním uživatelů v prohlížečích.
# 4. **Chybějící logování a monitoring** – problémy se neobjeví až při velkém problému.
#
# ### Best practices
#
# - Využívejte CI/CD nástroje (např. GitHub Actions, GitLab CI)
# - Vždy testujte nasazení v testovacím prostředí
# - Používejte environment proměnné pro konfiguraci aplikací
# - Mějte zálohy dat a systémů
#
# ### Performance tipy
#
# - Optimalizujte načítání statických souborů (např. obrázky, CSS)
# - Využívejte CDN pro rychlejší distribuci obsahu
# - Nastavte cache v aplikaci nebo proxy serveru
# - Sledujte výkon a náročnost zdrojů
#
# ---
#
# ## 4. Propojení s předchozími kapitolami
#
# Tato kapitola je velmi silně propojená s kapitolami o **vývoji aplikací, databázích, bezpečnosti a CI/CD**. Naučíte se, jak tyto komponenty propojit dohromady – například jak správně nasadit aplikaci na cloudovou platformu, připojit ji k databázi a zajistit bezpečný provoz. V předchozích kapitolách jste se naučili psát kód, vytvářet databáze a zabezpečení – nyní se naučíte, jak tyto komponenty nasadit do praxe.
#
# ---
#
# ### Shrnutí
#
# Cloud deployment je nezbytný krok pro každého vývojáře, který chce své aplikace dostat do praxe. V tomto kurzu jsme se naučili pracovat s různými cloudovými platformami, spravovat domény a SSL certifikáty, a také vytvářet monitoring a logování. Tato znalost vám umožní základně nasazovat aplikace, připravit je na provoz a zajišťovat jejich stabilitu.
#
# ---

# %% [markdown]
# ## 💻 Praktické příklady
#
# <div style="background: #e8f5e9; padding: 20px; border-left: 5px solid #4caf50; margin: 20px 0; border-radius: 5px;">
#     <h3 style="color: #2c3e50; margin-top: 0;">👨‍💻 Hands-on příklady ke spuštění</h3>
#     <p>Následující příklady si můžete hned vyzkoušet. Každý příklad je samostatně spustitelný.</p>
# </div>

# %% [markdown]
# ### Příklad 1
#
# Příklad použití - vytvoření testovacího souboru a jeho nahrání
# with open('test.txt', 'w') as f:
#     f.write("Toto je testovací soubor pro AWS S3")
#
# # Nahrání souboru (musíte mít nastavený přístup k S3)
# # upload_file_to_s3('test.txt', 'moje-testovaci-bucket', 'test.txt')
# ```
#
# **Očekávaný výstup:** Pokud je konfigurace správná, zobrazí se zpráva o úspěšném nahrání souboru do S3.
#
# **Vysvětlení:** Tento kód ukazuje základní práci s AWS S3 pomocí knihovny Boto3. Vytvoří klienta pro S3, který pak použije k nahrání souboru do určeného bucketu. Musí být správně nakonfigurovány přihlašovací údaje AWS.
#
# ---
#
# ## 2. Nastavení HTTPS na Heroku pomocí Let's Encrypt (simulace)
#
# **Co příklad demonstruje:** Jak by se mohlo nastavovat SSL certifikát pro aplikaci na Heroku - simulace procesu.
#
# ```python
# import subprocess
# import os
#
# def setup_ssl_on_heroku(app_name):
#     """
#     Simulace nastavení SSL certifikátu na Heroku
#     V reálném případě by se použilo let's encrypt CLI nebo Heroku certs:add
#     """
#     print(f"Simulace nastavení SSL pro aplikaci {app_name} na Heroku")
#
#     # Vytvoření testovacího certifikátu (simulace)
#     try:
#         # Tento příkaz by v reálné aplikaci byl:
#         # subprocess.run(['heroku', 'certs:add', 'certificate.crt', 'private.key'], check=True)
#         print("Certifikát byl úspěšně nahrán na Heroku")
#
#         # Nastavení SSL na doméně
#         print(f"SSL certifikát přiřazen k doméně {app_name}.herokuapp.com")
#         return True
#     except subprocess.CalledProcessError:
#         print("Chyba při nastavování SSL certifikátu")
#         return False
#
# #

# %% [markdown]
# ### Příklad 2
#
# Příklad použití
# setup_ssl_on_heroku("muj-web-app")
#
# # Výstup:
# # Simulace nastavení SSL pro aplikaci muj-web-app na Heroku
# # Certifikát byl úspěšně nahrán na Heroku
# # SSL certifikát přiřazen k doméně muj-web-app.herokuapp.com
# ```
#
# **Očekávaný výstup:** Zprávy o simulaci nastavení SSL certifikátu pro Heroku aplikaci.
#
# **Vysvětlení:** Tento příklad simuluje proces nastavení SSL certifikátu na Heroku, který je důležitý pro zabezpečení webu. V praxi by se používal nástroj jako Let's Encrypt nebo přímo příkaz `heroku certs:add`.
#
# ---
#
# ## 3. Nastavení DNS záznamu pomocí Cloudflare API
#
# **Co příklad demonstruje:** Jak vytvořit DNS záznam pomocí API, v tomto případě pomocí Cloudflare.
#
# ```python
# import requests
# import os
#
# def create_dns_record(zone_id, api_token, record_name, record_type, record_content):
#     """
#     Vytvoření DNS záznamu pomocí Cloudflare API
#     """
#     url = f"https://api.cloudflare.com/client/v4/zones/{zone_id}/dns_records"
#
#     headers = {
#         "Authorization": f"Bearer {api_token}",
#         "Content-Type": "application/json"
#     }
#
#     data = {
#         "type": record_type,
#         "name": record_name,
#         "content": record_content,
#         "ttl": 300,  # 5 minut
#         "proxied": False
#     }
#
#     try:
#         response = requests.post(url, headers=headers, json=data)
#         if response.status_code == 200:
#             print(f"DNS záznam {record_name} vytvořen úspěšně")
#             return response.json()
#         else:
#             print(f"Chyba při vytváření DNS záznamu: {response.text}")
#             return None
#     except Exception as e:
#         print(f"Chyba při komunikaci s Cloudflare API: {e}")
#         return None
#
# #

# %% [markdown]
# ### Příklad 3
#
# Příklad použití - musíte mít platný API token a Zone ID
# # create_dns_record(
# #     zone_id="1234567890abcdef1234567890abcdef",
# #     api_token="your_api_token_here",
# #     record_name="www.example.com",
# #     record_type="A",
# #     record_content="192.0.2.1"
# # )
# ```
#
# **Očekávaný výstup:** Oznámení o úspěšném vytvoření DNS záznamu.
#
# **Vysvětlení:** Tento kód ukazuje, jak se připojit k Cloudflare API a vytvořit nový DNS záznam. V praxi byste museli mít platné API tokeny a Zone ID pro vaši doménu.
#
# ---
#
# ## 4. Monitorování aplikace pomocí logovacího systému
#
# **Co příklad demonstruje:** Jednoduchý systém pro logování událostí a jejich zpracování.
#
# ```python
# import logging
# import datetime
# from logging.handlers import RotatingFileHandler
#
# # Nastavení logovacího systému
# def setup_logging():
#     """
#     Nastavení logování aplikace
#     """
#     # Vytvoření loggeru
#     logger = logging.getLogger('app_monitor')
#     logger.setLevel(logging.INFO)
#
#     # Rotating file handler - zálohování logů
#     handler = RotatingFileHandler(
#         'application.log',
#         maxBytes=1024*1024,  # 1MB
#         backupCount=5
#     )
#
#     # Formát logu
#     formatter = logging.Formatter(
#         '%(asctime)s - %(name)s - %(levelname)s - %(message)s'
#     )
#     handler.setFormatter(formatter)
#
#     logger.addHandler(handler)
#
#     return logger
#
# def log_application_event(logger, event_type, details):
#     """
#     Logování událostí aplikace
#     """
#     if event_type == "INFO":
#         logger.info(details)
#     elif event_type == "ERROR":
#         logger.error(details)
#     elif event_type == "WARNING":
#         logger.warning(details)
#     else:
#         logger.info(f"Neznámý typ události: {event_type} - {details}")
#
# #

# %% [markdown]
# ### Příklad 4
#
# Příklad použití
# logger = setup_logging()
#
# # Logování různých událostí
# log_application_event(logger, "INFO", "Aplikace spuštěna")
# log_application_event(logger, "WARNING", "Nízká paměť")
# log_application_event(logger, "ERROR", "Chyba při připojení k databázi")
#
# print("Logování událostí bylo dokončeno. Kontrola souboru application.log.")
# ```
#
# **Očekávaný výstup:** Vytvořený log soubor `application.log` obsahující záznamy o událostech aplikace.
#
# **Vysvětlení:** Tento kód nastavuje systém logování, který je klíčový pro monitorování aplikací. Používá se RotatingFileHandler pro správu velikosti logů a formátování zpráv.
#
# ---
#
# ## 5. Nastavení automatického deploymentu pomocí GitHub Actions (simulace)
#
# **Co příklad demonstruje:** Jak by mohla vypadat konfigurace CI/CD pipeline pro automatický deployment do cloudu.
#
# ```python
# import json
# import os
#
# def generate_github_workflow():
#     """
#     Generování workflow souboru pro GitHub Actions
#     """
#     workflow_content = {
#         "name": "Deploy to Cloud",
#         "on": {
#             "push": {
#                 "branches": ["main"]
#             }
#         },
#         "jobs": {
#             "deploy": {
#                 "runs-on": "ubuntu-latest",
#                 "steps": [
#                     {
#                         "name": "Checkout code",
#                         "uses": "actions/checkout@v3"
#                     },
#                     {
#                         "name": "Setup Node.js",
#                         "uses": "actions/setup-node@v3",
#                         "with": {
#                             "node-version": "18"
#                         }
#                     },
#                     {
#                         "name": "Install dependencies",
#                         "run": "npm install"
#                     },
#                     {
#                         "name": "Deploy to production",
#                         "run": "npm run deploy",
#                         "env": {
#                             "DEPLOY_KEY": "${{ secrets.DEPLOY_KEY }}",
#                             "CLOUD_PROVIDER": "AWS"
#                         }
#                     }
#                 ]
#             }
#         }
#     }
#
#     # Uložení do souboru
#     with open('.github/workflows/deploy.yml', 'w') as f:
#         json.dump(workflow_content, f, indent=2)
#
#     print("Workflow pro GitHub Actions byl úspěšně vytvořen")
#     print("Soubor: .github/workflows/deploy.yml")
#
# # Pří

# %% [markdown]
# ## 🎯 Cvičení a úkoly
#
# <div style="background: #fff3e0; padding: 20px; border-left: 5px solid #ff9800; margin: 20px 0; border-radius: 5px;">
#     <h3 style="color: #2c3e50; margin-top: 0;">✍️ Praktická cvičení k procvičení</h3>
#     <p>Vyřešte následující úkoly. Začněte od jednoduššších a postupujte k složitějším.</p>
# </div>
#
# # Cvičení pro kapitolu: **Cloud Deployment – Základy**
#
# ---
#
# ## Cvičení 1: **Nastavení CI/CD pipeline s GitHub Actions**
# ### 1. **Název úkolu**
# CI/CD pipeline pro webovou aplikaci v Pythonu
#
# ### 2. **Detailní zadání**
# Vytvořte základní CI/CD pipeline pomocí GitHub Actions, která:
# - Automaticky spustí testy při každém push do `main` větve.
# - Při úspěšném testu automaticky nasadí aplikaci na cloudovou platformu (např. Heroku nebo Render).
# - Aplikace je webová aplikace v Pythonu s jednoduchým API endpointem (`/health`).
#
# ### 3. **Vstupní data/požadavky**
# - Repository GitHub
# - Webová aplikace v Pythonu (např. Flask)
# - Testy (např. pomocí `pytest`)
# - Účet na platformě pro deployment (např. Heroku)
#
# ### 4. **Očekávaný výstup**
# - `.github/workflows/ci-cd.yml` s definicí pipeline
# - Aplikace běžící na cílové platformě s funkčním endpointem `/health`
#
# ### 5. **Hints/Nápověda**
# 1. Vytvořte jednoduchou Flask aplikaci s endpointem `/health`.
# 2. Přidejte `requirements.txt` a testy.
# 3. Nastavte workflow v `.github/workflows/ci-cd.yml`, který spustí testy a nasadí aplikaci.
# 4. Použijte `heroku login` nebo `render deploy` příkazy.
#
# ### 6. **Kostra řešení**
# ```yaml
# # .github/workflows/ci-cd.yml
# name: CI/CD Pipeline
#
# on:
#   push:
#     branches: [ main ]
#
# jobs:
#   test:
#     runs-on: ubuntu-latest
#     steps:
#       - uses: actions/checkout@v3
#       - name: Set up Python
#         uses: actions/setup-python@v4
#         with:
#           python-version: '3.9'
#       - name: Install dependencies
#         run: |
#           pip install -r requirements.txt
#           pip install pytest
#       - name: Run tests
#         run: pytest
#
#   deploy:
#     needs: test
#     runs-on: ubuntu-latest
#     steps:
#       - uses: actions/checkout@v3
#       - name: Deploy to Heroku
#         run: |
#           heroku container:login
#           heroku container:push web
#           heroku container:release web
# ```
#
# ### 7. **Bonusové rozšíření**
# Přidat automatický rollback při selhání deployu, přidat monitoring pomocí Sentry.
#
# ---
#
# ## Cvičení 2: **Nasazení kontejnerizované aplikace do AWS ECS**
# ### 1. **Název úkolu**
# Nasazení Flask aplikace v Docker kontejneru do AWS ECS
#
# ### 2. **Detailní zadání**
# Vytvořte Docker image aplikace a automaticky nasadíte jej do AWS ECS (Elastic Container Service). Aplikace musí běžet na veřejné IP a odpovídat na požadavky.
#
# ### 3. **Vstupní data/požadavky**
# - Flask aplikace v Pythonu
# - Dockerfile
# - AWS účet s přístupem k ECS a ECR
# - Vytvořená ECS cluster
#
# ### 4. **Očekávaný výstup**
# - Docker image nahraný do AWS ECR
# - Task definition pro ECS
# - Nasazený service na portu 80/443
#
# ### 5. **Hints/Nápověda**
# 1. Vytvořte `Dockerfile` a testujte lokálně.
# 2. Nahrajte image do AWS ECR.
# 3. Vytvořte Task Definition a Service v ECS.
# 4. Nastavte Load Balancer pro směrování requestů.
#
# ### 6. **Kostra řešení**
# ```dockerfile
# # Dockerfile
# FROM python:3.9-slim
#
# WORKDIR /app
# COPY requirements.txt .
# RUN pip install -r requirements.txt
#
# COPY . .
#
# CMD ["gunicorn", "app:app"]
# ```
#
# ```yaml
# # task-definition.json
# {
#   "family": "flask-app",
#   "containerDefinitions": [
#     {
#       "name": "flask-container",
#       "image": "YOUR_ECR_URI/flask-app:latest",
#       "portMappings": [
#         {
#           "containerPort": 80,
#           "protocol": "tcp"
#         }
#       ]
#     }
#   ]
# }
# ```
#
# ### 7. **Bonusové rozšíření**
# Nasazení v multi-container setupu s Redis cache.
#
# ---
#
# ## Cvičení 3: **Automatizace deploymentu na Kubernetes (Minikube)**
# ### 1. **Název úkolu**
# Nasazení Flask aplikace do Minikube clusteru
#
# ### 2. **Detailní zadání**
# Vytvořte manifesty pro nasazení Flask aplikace v Kubernetes clusteru (použijte Minikube). Aplikace musí běžet v podu, mít Service a Ingress.
#
# ### 3. **Vstupní data/požadavky**
# - Flask aplikace
# - Docker image
# - Kubernetes cluster (Minikube)
# - `kubectl` nainstalovaný
#
# ### 4. **Očekávaný výstup**
# - Pod, Service a Ingress manifesty
# - Aplikace dostupná přes `minikube service <service-name>`
#
# ### 5. **Hints/Nápověda**
# 1. Vytvořte `Deployment` a `Service`.
# 2. Přidejte `Ingress` pro externí přístup.
# 3. Použijte `kubectl apply -f <yaml>` k nasazení.
# 4. Otestujte přes `minikube service`.
#
# ### 6. **Kostra řešení**
# ```yaml
# # deployment.yaml
# apiVersion: apps/v1
# kind: Deployment
# metadata:
#   name: flask-app-deployment
# spec:
#   replicas: 1
#   selector:
#     matchLabels:
#       app: flask-app
#   template:
#     metadata:
#       labels:
#         app: flask-app
#     spec:
#       containers:
#       - name: flask-app
#         image: your-registry/flask-app:latest
#         ports:
#         - containerPort: 80
# ---
# # service.yaml
# apiVersion: v1
# kind: Service
# metadata:
#   name: flask-app-service
# spec:
#   selector:
#     app: flask-app
#   ports:
#     - protocol: TCP
#       port: 80
#       targetPort: 80
# ```
#
# ### 7. **Bonusové rozšíření**
# Přidat ConfigMap a Secret, použít Helm chart.
#
# ---
#
# ## Cvičení 4: **Nasazení aplikace na Azure App Service s CI/CD**
# ### 1. **Název úkolu**
# CI/CD pipeline pro Azure App Service
#
# ### 2. **Detailní zadání**
# Vytvořte CI/CD pipeline pro nasazení Flask aplikace na Azure App Service pomocí GitHub Actions a Azure CLI.
#
# ### 3. **Vstupní data/požadavky**
# - Aplikace v Pythonu
# - GitHub repository
# - Azure účet s přístupem k App Service
# - Azure CLI nainstalované
#
# ### 4. **Očekávaný výstup**
# - Workflow ve `.github/workflows` který automaticky nasadí aplikaci na Azure App Service
# - Aplikace dostupná přes URL
#
# ### 5. **Hints/Nápověda**
# 1. Připravte `azure-webapp.yml` v Azure DevOps nebo GitHub Actions.
# 2. Použijte `az webapp deployment source config-zip`.
# 3. Nastavte deployment pomocí `az login` a přihlášení skrze GitHub Secrets.
# 4. Ověřte nasazení přes webovou URL.
#
# ### 6. **Kostra řešení**
# ```yaml
# # .github/workflows/deploy.yml
# name: Deploy to Azure App Service
#
# on:
#   push:
#     branches: [ main ]
#
# jobs:
#   deploy:
#     runs-on: ubuntu-latest
#     steps:
#       - uses: actions/checkout@v3
#       - name: Deploy to Azure WebApp
#         uses: azure/webapps-deploy@v2
#         with:
#           app-name: your

# %% [markdown]
# ## 📚 Další zdroje a materiály
#
# <div style="background: #e3f2fd; padding: 20px; border-left: 5px solid #2196f3; margin: 20px 0; border-radius: 5px;">
#     <h3 style="color: #2c3e50; margin-top: 0;">🔗 Doporučené materiály k dalšímu studiu</h3>
# </div>
#
# # Zdroje pro kapitolu: **Cloud deployment základy**
#
# ---
#
# ## 📄 5 doporučených článků/tutoriálů
#
# 1. **[What is Cloud Deployment? | AWS](https://aws.amazon.com/what-is/cloud-deployment/)**
#    *Popis:* Komplexní úvodní článek od Amazon Web Services vysvětlující základy cloudového nasazení, typy deploymentů a jejich výhody. Vhodné pro začátečníky.
#
# 2. **[Introduction to Cloud Deployment Strategies | Microsoft Azure](https://learn.microsoft.com/en-us/azure/architecture/guide/deployment-strategies)**
#    *Popis:* Přehled strategií nasazování v cloudu od Microsoft Azure, včetně blue-green deploymentu, canary release a A/B testing.
#
# 3. **[Cloud Deployment Models: Public, Private, Hybrid | IBM](https://www.ibm.com/cloud/learn/cloud-deployment-models)**
#    *Popis:* Vysvětlení různých modelů nasazení cloudu (veřejný, soukromý, hybridní) a jejich použití v praxi.
#
# 4. **[CI/CD for Cloud Deployment - Jenkins Tutorial](https://www.jenkins.io/doc/tutorials/ci-cd-pipeline-in-jenkins/)**
#    *Popis:* Tutoriál pro nastavení CI/CD kanálu pomocí Jenkinsu pro cloudové nasazení, ideální pro automatizaci procesů.
#
# 5. **[Deploying Applications to the Cloud - Google Cloud](https://cloud.google.com/docs/deploying-applications)**
#    *Popis:* Oficiální průvodce od Google Cloud o tom, jak efektivně nasazovat aplikace do cloudu včetně nástrojů jako Cloud Run a App Engine.
#
# ---
#
# ## 🎥 3 YouTube videa
#
# 1. **[What is Cloud Deployment? Explained in 10 Minutes](https://www.youtube.com/watch?v=4xWZ9dY2KzA)**
#    *Délka:* 10 min
#    *Popis:* Stručné vysvětlení cloudového nasazení s příklady, vhodné pro začátečníky.
#
# 2. **[Cloud Deployment Strategies for Beginners - DevOps](https://www.youtube.com/watch?v=0X3D4ZVx7qM)**
#    *Délka:* 15 min
#    *Popis:* Přehled základních strategií nasazení (Rolling, Blue-Green, Canary) s praktickými scénáři.
#
# 3. **[How to Deploy Your First App in the Cloud - Full Tutorial](https://www.youtube.com/watch?v=5b8F4Y9hN0k)**
#    *Délka:* 25 min
#    *Popis:* Praktický tutoriál na nasazení jednoduché aplikace na AWS nebo Azure, vhodné pro začátečníky.
#
# ---
#
# ## 📚 3 knihy a oficiální dokumentace
#
# 1. **[Cloud Deployment Patterns – Microsoft](https://learn.microsoft.com/en-us/azure/architecture/patterns/)**
#    *Popis:* Sbírka cloudových patternů pro nasazení včetně deployment strategií, škálování a zabezpečení.
#
# 2. **[The Phoenix Project – Gene Kim](https://www.goodreads.com/book/show/17514197-the-phoenix-project)**
#    *Popis:* Kniha o DevOps a automatizaci nasazení, ideální pro porozumění procesu cloudového deploymentu v rámci organizace.
#
# 3. **[AWS Well-Architected Framework – Official AWS Docs](https://docs.aws.amazon.com/wellarchitected/latest/framework/welcome.html)**
#    *Popis:* Oficiální průvodce od Amazonu, který zahrnuje zásady pro bezpečné a efektivní cloudové nasazení.
#
# ---
#
# ## 🛠️ 2 praktické projekty k procvičení
#
# 1. **Nasazení statické webové aplikace na AWS S3 + CloudFront**

# %% [markdown]
# ## 📝 Shrnutí kapitoly
#
# <div style="background: linear-gradient(135deg, #667eea 0%, #764ba2 100%); padding: 30px; border-radius: 10px; color: white; margin: 30px 0;">
#     <h3 style="color: white; margin-top: 0;">✅ Co jste se naučili</h3>
#     <ul style="list-style: none; padding-left: 0;">
#         <li>✓ Cloud providers: AWS, GCP, Azure</li>
# <li>✓ Heroku deployment</li>
# <li>✓ DigitalOcean droplets</li>
# <li>✓ Railway, Render, Fly.io</li>
# <li>✓ Domain management a DNS</li>
#     </ul>
#
#     <h3 style="color: white;">🎯 Klíčové dovednosti</h3>
#     <p>Po dokončení této kapitoly byste měli být schopni prakticky použít všechny probrané koncepty.</p>
#
#     <h3 style='color: white;'>➡️ Další kapitola</h3><p>Kapitola 25 - pokračujte ve studiu!</p>
# </div>
#
# ---
#
# *📅 Notebook vygenerován: 2025-09-29 12:51:36*
# *🤖 Generátor: Comprehensive Colab Generator v2.0*
# *📚 Učebnice programování - Od základů k AI*

# %% [markdown]
# ## 🧪 Sandbox - Prostor pro experimenty
#
# Použijte následující buňky pro vlastní experimenty a testování:

# %%
# 🧪 Zde můžete experimentovat s kódem z kapitoly
# Napište svůj kód zde:
