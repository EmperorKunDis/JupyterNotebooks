# %% [markdown]
# # 📚 Kapitola 23: CI/CD pipeline
#
# <div style="background: linear-gradient(90deg, #667eea 0%, #764ba2 100%); padding: 20px; border-radius: 10px; margin: 20px 0;">
#     <h2 style="color: white; margin: 0;">Blok 3 | ADVANCED</h2>
#     <p style="color: white; margin: 10px 0;">📖 Výuková kapitola</p>
# </div>
#
# ## 🎯 Co se naučíte
#
# V této kapitole se zaměříme na následující témata:
#
# - **GitHub Actions workflows**
# - **GitLab CI/CD pipelines**
# - **Jenkins basics**
# - **Automated testing**
# - **Build a deployment stages**
# - **Secrets management**
# - **Artifacts a caching**
#
# ## ⚠️ Předpoklady
# Tato kapitola navazuje na kapitoly: 3, 21
#
# ---

# %%
# ⚙️ Inicializace prostředí
# Tento kód nastavuje prostředí pro kapitolu 23

import sys
import os
from datetime import datetime

# Informace o prostředí
print("=" * 60)
print(f"📚 KAPITOLA 23: CI/CD pipeline")
print("=" * 60)
print(f"🐍 Python verze: {sys.version}")
print(f"📅 Datum spuštění: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
print(f"💻 OS: {os.name}")
print(f"📁 Pracovní adresář: {os.getcwd()}")
print("=" * 60)

# Instalace potřebných knihoven (odkomentujte podle potřeby)
# !pip install requests pandas numpy matplotlib
# !pip install beautifulsoup4 sqlalchemy fastapi

# Import základních knihoven
import json
import csv
import time
import random
from pathlib import Path
from typing import List, Dict, Optional, Any

print("✅ Prostředí připraveno!")

# %% [markdown]
# ## 📖 Teoretická část
#
# <div style="background: #f0f4ff; padding: 20px; border-left: 5px solid #4a69bd; margin: 20px 0; border-radius: 5px;">
#     <h3 style="color: #2c3e50; margin-top: 0;">🎓 Základní teorie a koncepty</h3>
# </div>
#
# # CI/CD Pipeline – Detailní teoretický výklad
#
# ## 1. Úvod a motivace
#
# CI/CD (Continuous Integration / Continuous Deployment) je základní prvek moderního softwarového inženýrství, který automatizuje procesy integrace kódu, testování a nasazování aplikací. V dnešním rychle se vyvíjejícím prostředí je vývoj software založen na průběžné integraci změn a rychlém zpětném vazbě – CI/CD zajišťuje, že každá změna se dostane do produkčního prostředí co nejrychleji, bez chyb.
#
# Toto téma je důležité protože v moderním vývojovém procesu je potřeba zajišťovat stabilní a spolehlivé nasazování aplikací, často i několikrát denně. CI/CD se používá jak ve velkých korporacích (např. Amazon, Netflix), tak v malých týmech i startupech. V praxi se díky CI/CD zvyšuje kvalita softwaru, snižují se chyby a rychlost vývoje se zvyšuje.
#
# Po absolvování této kapitoly se student naučí:
# - Návrh a implementaci CI/CD pipeline v různých nástrojích (GitHub Actions, GitLab, Jenkins),
# - Automatizaci testování a nasazování,
# - Správu tajných informací (secrets) a artefaktů,
# - Praktické aplikace CI/CD ve vývojovém procesu.
#
# ---
#
# ## 2. Hlavní koncepty
#
# ### GitHub Actions workflows
#
# GitHub Actions je cloudová služba, která umožňuje automatizaci vývojových procesů přímo z repozitáře na GitHubu. Workflow je definovaný ve formátu YAML a může obsahovat více jobů (úkolů), které se spouštějí na určité události, například push do větve `main`.
#
# **Příklad workflow:**
#
# ```yaml
# name: CI Pipeline
#
# on:
#   push:
#     branches: [ main ]
#
# jobs:
#   build:
#     runs-on: ubuntu-latest
#     steps:
#       - uses: actions/checkout@v3
#       - name: Setup Node.js
#         uses: actions/setup-node@v3
#         with:
#           node-version: '16'
#       - run: npm install
#       - run: npm test
# ```
#
# Workflow spustí testy při každém pushi do `main` větve. GitHub Actions je velmi flexibilní a umožňuje použít různé akce (např. `checkout`, `setup-node`, `deploy`) pro různé úkoly.
#
# ---
#
# ### GitLab CI/CD pipelines
#
# GitLab CI/CD funguje podobně jako GitHub Actions, ale je integrován přímo do GitLabu. Definice pipeline je uložena v souboru `.gitlab-ci.yml` ve kořenovém adresáři repozitáře.
#
# **Příklad .gitlab-ci.yml:**
#
# ```yaml
# stages:
#   - test
#   - build
#   - deploy
#
# test:
#   stage: test
#   script:
#     - npm install
#     - npm test
#
# build:
#   stage: build
#   script:
#     - npm run build
#   artifacts:
#     paths:
#       - dist/
#
# deploy:
#   stage: deploy
#   script:
#     - echo "Deploying..."
# ```
#
# Tato pipeline má tři fáze: test, build a deploy. V každé fázi se spouští určitý skript. Artefakty (např. sestavené balíčky) mohou být předány mezi fázemi.
#
# ---
#
# ### Jenkins basics
#
# Jenkins je open-source automatizační nástroj, který se používá pro CI/CD procesy. Vyznačuje se vysokou flexibilitou a širokou kompatibilitou s různými nástroji.
#
# **Základní koncepty Jenkins:**
# - **Job** – definice jedné úlohy (např. build, test),
# - **Pipeline** – definice toku práce v YAML nebo Groovy,
# - **Node / Agent** – počítač, kde se job spouští.
#
# Použití Jenkinsu:
# ```groovy
# pipeline {
#     agent any
#     stages {
#         stage('Build') {
#             steps {
#                 sh 'npm install'
#             }
#         }
#         stage('Test') {
#             steps {
#                 sh 'npm test'
#             }
#         }
#     }
# }
# ```
#
# Jenkins je výkonný, ale vyžaduje více konfigurace a správy.
#
# ---
#
# ### Automated testing
#
# Automatizované testování je klíčová součást CI/CD pipeline. Testy se spouští automaticky při každé změně kódu, aby bylo zajištěno, že nový kód nezhorší stávající funkčnost.
#
# Typy testů:
# - **Unit test** – test jednotlivých funkcí,
# - **Integration test** – test interakce mezi moduly,
# - **End-to-end test** – test celé aplikace z pohledu uživatele.
#
# Nástroje:
# - **Jest**, **Mocha**, **PyTest**, **Selenium**
#
# Příklad v CI/CD:
# ```yaml
# script:
#   - npm install
#   - npm run test
# ```
#
# ---
#
# ### Build a deployment stages
#
# Build fáze se zaměřuje na překlad kódu, sestavení aplikace a generování artefaktů. Deployment fáze pak zajišťuje nasazení do určitého prostředí (např. testovací, produkční).
#
# **Typické kroky:**
# 1. Build – kompilace, sestavení balíčku,
# 2. Test – spuštění automatizovaných testů,
# 3. Deploy – nasazení do prostředí.
#
# Příklad:
#
# ```yaml
# deploy:
#   stage: deploy
#   script:
#     - echo "Deploy to production"
#     - rsync -av dist/ user@server:/var/www/
# ```
#
# ---
#
# ### Secrets management
#
# Tajné informace jako API klíče, hesla nebo certifikáty musí být bezpečně uloženy a předány do CI/CD pipeline. Použití tajných proměnných (secrets) je důležité pro zamezení úniku citlivých dat.
#
# **Příklad v GitHub Actions:**
# ```yaml
# - name: Deploy to server
#   run: |
#     ssh user@server "export API_KEY=${{ secrets.API_KEY }}; deploy_script.sh"
# ```
#
# V GitLab:
# ```yaml
# deploy:
#   script:
#     - echo $API_KEY > key.txt
# ```
#
# ---
#
# ### Artifacts a caching
#
# **Artefakty** jsou výstupy z buildu – např. sestavené aplikace, testovací reporty, dokumentace.
#
# **Caching** umožňuje ukládat a znovu používat data mezi spuštěními (např. stahované knihovny), což zrychluje pipeline.
#
# Příklad GitHub Actions s cachingem:
# ```yaml
# - name: Cache node modules
#   uses: actions/cache@v3
#   with:
#     path: ~/.npm
#     key: ${{ runner.os }}-node-${{ hashFiles('**/package-lock.json') }}
# ```
#
# ---
#
# ## 3. Důležité detaily
#
# ### Časté chyby a jak se jim vyhnout
#
# - **Chybějící testování v CI/CD** – při absenci testů se mohou chyby dostat do produkce.
# - **Nesprávný management secrets** – tajné informace nejsou chráněny, způsobují bezpečnostní rizika.
# - **Neefektivní caching** – zbytečné opakované stahování balíčků.
#
# ### Best practices
#
# - Vždy používat testy v CI/CD,
# - Ukládat tajné informace v bezpečných proměnných,
# - Přidávat validaci před deploy,
# - Dělit pipeline na menší fáze (stage) pro snazší ladění.
#
# ### Performance tipy
#
# - Využívejte caching a paralelizaci jobů,
# - Zmenšujte velikost image (např. Alpine Linux),
# - Předávejte artefakty mezi fázemi, ne vytvářejte znovu.
#
# ---
#
# ## 4. Propojení s předchozími kapitolami
#
# Tato kapitola navazuje na předchozí znalosti z verzování (Git), testování a kontejnerizace (Docker). CI/CD pipeline je tedy logickým rozšířením těchto témat – využívá Git pro sledování změn, Docker pro build a testovací prostředí, a automatizuje celý proces nasazování.
#
# Toto téma rozšiřuje již naučené koncepty o praxe a praktické implementaci, což je klíčové pro profesionální vývoj softwaru. CI/CD tedy přináší zpětnou vazbu mezi vývojem a nasazením, čímž zvyšuje kvalitu a rychlost vývoje.
#
# ---
#
# *Závěr:* CI/CD pipeline je nezbytný nástroj pro moderní software development. Ať už používáte GitHub Actions, GitLab nebo Jenkins, automatizace zajišťuje stabilní, rychlé a bezpečné nasazování aplikací – což je klíč k úspěšnému vývoji v současné době.

# %% [markdown]
# ## 💻 Praktické příklady
#
# <div style="background: #e8f5e9; padding: 20px; border-left: 5px solid #4caf50; margin: 20px 0; border-radius: 5px;">
#     <h3 style="color: #2c3e50; margin-top: 0;">👨‍💻 Hands-on příklady ke spuštění</h3>
#     <p>Následující příklady si můžete hned vyzkoušet. Každý příklad je samostatně spustitelný.</p>
# </div>

# %% [markdown]
# ### Příklad 1
#
# Příklad 1: GitHub Actions workflow pro jednoduché testování Python aplikace

# %% [markdown]
# ### Příklad 2
#
# ### Název příkladu:
# **GitHub Actions workflow pro testování Python skriptu**

# %% [markdown]
# ### Příklad 3
#
# ### Co příklad demonstruje:
# Tento příklad ukazuje základní workflow pro CI/CD pomocí GitHub Actions, který spouští unit testy na změně kódu.

# %% [markdown]
# ### Příklad 4
#
# ### Kompletní spustitelný kód:
# ```yaml
# # .github/workflows/python-test.yml
# name: Python Test
#
# on:
#   push:
#     branches: [ main ]
#   pull_request:
#     branches: [ main ]
#
# jobs:
#   test:
#     runs-on: ubuntu-latest
#
#     steps:
#     # Klonování repozitáře
#     - name: Checkout code
#       uses: actions/checkout@v3
#
#     # Nastavení Python prostředí
#     - name: Set up Python
#       uses: actions/setup-python@v4
#       with:
#         python-version: '3.9'
#
#     # Instalace závislostí
#     - name: Install dependencies
#       run: |
#         python -m pip install --upgrade pip
#         pip install pytest
#
#     # Spuštění testů
#     - name: Run tests
#       run: |
#         pytest tests/
#
#     # Nahrání výsledků testování
#     - name: Upload test results
#       uses: actions/upload-artifact@v3
#       with:
#         name: test-results
#         path: test-results.xml
# ```

# %% [markdown]
# ### Příklad 5
#
# ### Očekávaný výstup:
# Workflow se spustí při každém push nebo pull requestu do hlavní větve. Výsledky testů budou zobrazeny v GitHub Actions logu a výsledky testů budou uloženy jako artefakt.

# %% [markdown]
# ### Příklad 6
#
# ### Vysvětlení jak kód funguje:
# - `name: Python Test` - Název workflow
# - `on:` - Určuje, kdy se workflow spustí (push/pull request do main větve)
# - `jobs.test` - Definuje job pro testování
# - `runs-on: ubuntu-latest` - Použití Linux prostředí
# - `actions/checkout@v3` - Stáhne kód z repozitáře
# - `actions/setup-python@v4` - Nastaví Python 3.9 prostředí
# - `pip install pytest` - Nainstaluje testovací nástroj pytest
# - `pytest tests/` - Spustí všechny testy ve složce tests
# - `actions/upload-artifact@v3` - Uloží výsledky testů jako artefakt
#
# ---
#
# ##

# %% [markdown]
# ### Příklad 7
#
# Příklad 2: GitLab CI/CD pipeline pro sestavení a testování aplikace

# %% [markdown]
# ### Příklad 8
#
# ### Název příkladu:
# **GitLab CI/CD pipeline s více fázemi**

# %% [markdown]
# ### Příklad 9
#
# ### Co příklad demonstruje:
# Tento příklad ukazuje pipeline s více fázemi (test, build, deploy) ve stylu GitLab CI/CD.

# %% [markdown]
# ### Příklad 10
#
# ### Kompletní spustitelný kód:
# ```yaml
# # .gitlab-ci.yml
# stages:
#   - test
#   - build
#   - deploy
#
# variables:
#   PYTHON_VERSION: '3.9'
#   IMAGE_NAME: 'my-app'
#
# before_script:
#   - echo "Start pipeline"
#   - python -m pip install --upgrade pip
#   - pip install pytest requests
#
# test_job:
#   stage: test
#   image: python:${PYTHON_VERSION}
#   script:
#     - echo "Running tests..."
#     - pytest tests/ -v
#     - echo "Tests completed successfully"
#   artifacts:
#     reports:
#       junit: test-results.xml
#     paths:
#       - test-results.xml
#   only:
#     - main
#
# build_job:
#   stage: build
#   image: python:${PYTHON_VERSION}
#   script:
#     - echo "Building application..."
#     - pip install -r requirements.txt
#     - echo "Build completed"
#   artifacts:
#     paths:
#       - dist/
#   only:
#     - main
#
# deploy_job:
#   stage: deploy
#   image: alpine:latest
#   script:
#     - echo "Deploying to production..."
#     - echo "Deployment successful"
#   environment:
#     name: production
#     url: https://myapp.com
#   only:
#     - main
# ```

# %% [markdown]
# ### Příklad 11
#
# ### Očekávaný výstup:
# Pipeline se spustí při každém push do main větve a provede testy, sestavení a nasazení aplikace. Výsledky budou viditelné ve GitLab CI/CD UI.

# %% [markdown]
# ### Příklad 12
#
# ### Vysvětlení jak kód funguje:
# - `stages:` - Definuje sekvenční fáze pipeline
# - `variables:` - Globální proměnné pro konfiguraci
# - `before_script:` - Spuštěn před každým jobem
# - `test_job:` - Testovací fáze s pytest
# - `artifacts:` - Ukládání výsledků testů a buildu
# - `only:` - Omezuje spouštění na konkrétní věte
# - `deploy_job:` - Nasazovací fáze s prostředím
#
# ---
#
# ##

# %% [markdown]
# ### Příklad 13
#
# Příklad 3: Základy Jenkins pipeline (Jenkinsfile)

# %% [markdown]
# ### Příklad 14
#
# ### Název příkladu:
# **Základní Jenkins pipeline s testy a buildem**

# %% [markdown]
# ### Příklad 15
#
# ### Co příklad demonstruje:
# Tento příklad ukazuje základní Jenkins pipeline script, který provádí testování a sestavení aplikace.

# %% [markdown]
# ### Příklad 16
#
# ### Kompletní spustitelný kód:
# ```groovy
# // Jenkinsfile
# pipeline {
#     agent any
#
#     environment {
#         PYTHON_VERSION = '3.9'
#         APP_NAME = 'my-python-app'
#     }
#
#     stages {
#         stage('Checkout') {
#             steps {
#                 echo 'Checking out code from repository'
#                 git branch: 'main', url: 'https://github.com/user/repo.git'
#             }
#         }
#
#         stage('Setup Python') {
#             steps {
#                 echo 'Setting up Python environment'
#                 sh '''
#                     python -m pip install --upgrade pip
#                     pip install pytest
#                 '''
#             }
#         }
#
#         stage('Run Tests') {
#             steps {
#                 echo 'Running unit tests'
#                 sh '''
#                     pytest tests/ -v --tb=short
#                 '''
#             }
#             post {
#                 always {
#                     junit 'test-results.xml'
#                 }
#             }
#         }
#
#         stage('Build Application') {
#             steps {
#                 echo 'Building application'
#                 sh '''
#                     python setup.py sdist bdist_wheel
#                 '''
#             }
#             post {
#                 success {
#                     archiveArtifacts artifacts: 'dist/*', fingerprint: true
#                 }
#             }
#         }
#     }
#
#     post {
#         always {
#             echo 'Pipeline completed'
#         }
#         success {
#             echo 'Pipeline succeeded!'
#         }
#         failure {
#             echo 'Pipeline failed!'
#         }
#     }
# }
# ```

# %% [markdown]
# ### Příklad 17
#
# ### Očekávaný výstup:
# Jenkins pipeline se spustí a provede checkout, testování, build a archivaci artefaktů. Výsledky budou viditelné v Jenkins UI.

# %% [markdown]
# ### Příklad 18
#
# ### Vysvětlení jak kód funguje:
# - `pipeline { }` - Definice pipeline
# - `agent any` - Spuštění na libovolném agentovi
# - `environment` - Nastavení prostředí proměnných
# - `stages` - Sekvenční fáze pipeline
# - `stage()` - Jednotlivé fáze (checkout, setup, test, build)
# - `sh` - Spouštění shell příkazů
# - `junit` - Nahrání testovacích výsledků
# - `archiveArtifacts` - Uložení artefaktů
# - `post` - Akce po dokončení pipeline
#
# ---
#
# ##

# %% [markdown]
# ### Příklad 19
#
# Příklad 4: Automatizované testy s cache a správou tajných informací

# %% [markdown]
# ### Příklad 20
#
# ### Název příkladu:
# **Automatizované testy s cachingem a tajnými informacemi**

# %% [markdown]
# ### Příklad 21
#
# ### Co příklad demonstruje:
# Tento příklad ukazuje pokročilé CI/CD nastavení s cachingem, sekret managementem a automatickým testováním.

# %% [markdown]
# ### Příklad 22
#
# ### Kompletní spustitelný kód:
# ```yaml
# # .github/workflows/advanced-ci.yml
# name: Advanced CI Pipeline
#
# on:
#   push:
#     branches: [ main, develop ]
#   pull_request:
#     branches: [ main ]
#
# jobs:
#   build-and-test:
#     runs-on: ubuntu-latest
#
#     steps:
#     # Checkout kódu
#     - name: Checkout code
#       uses: actions/checkout@v3
#
#     # Cache Python dependencies
#     - name: Cache pip dependencies
#       uses: actions/cache@v3
#       with:
#         path: ~/.cache/pip
#         key: ${{ runner.os }}-pip-${{ hashFiles('**/requirements.txt') }}
#         restore-keys: |
#           ${{ runner.os }}-pip-
#
#     # Nastavení Python prostředí
#     - name: Set up Python
#       uses: actions/setup-python@v4
#       with:
#         python-version: '3.9'
#
#     # Instalace závislostí
#     - name: Install dependencies
#       run: |
#         python -m pip install --upgrade pip
#         pip install -r requirements.txt
#
#     # Spuštění testů s coverage
#     - name: Run tests with coverage
#       run: |
#         pip install pytest-cov
#         pytest tests/ --cov=src --cov-report=xml --cov-report=html
#
#     # Nahrání coverage reportu
#     - name: Upload coverage to Codecov
#       uses: codecov/codecov-action@v3
#       with:
#         file: ./coverage.xml
#         flags: unittests
#         name: codecov-umbrella
#
#     # Nahrání artefaktů
#     - name: Upload test results
#       uses: actions/upload-artifact@v3
#       with:
#         name: coverage-report
#         path: htmlcov/
#
#     # Použití tajných informací
#     - name: Use secret variables
#       run: |
#         echo "Database URL: ${{ secrets.DB_URL }}"
#         echo "API Key: ${{ secrets.API_KEY }}"
# ```

# %% [markdown]
# ### Příklad 23
#
# ### Očekávaný výstup:
# Pipeline spustí testy s coverage, použije caching pro zrychlení instalace a nahrává výsledky do Codecov. Tajné informace jsou dostupné jako proměnné prostředí.

# %% [markdown]
# ### Příklad 24
#
# ### Vysvětlení jak kód funguje

# %% [markdown]
# ## 🎯 Cvičení a úkoly
#
# <div style="background: #fff3e0; padding: 20px; border-left: 5px solid #ff9800; margin: 20px 0; border-radius: 5px;">
#     <h3 style="color: #2c3e50; margin-top: 0;">✍️ Praktická cvičení k procvičení</h3>
#     <p>Vyřešte následující úkoly. Začněte od jednoduššších a postupujte k složitějším.</p>
# </div>
#
# # CI/CD Pipeline – 5 praktických cvičení
#
# ---
#
# ## Cvičení 1: **Název úkolu**
# **Vytvoření základního CI/CD pipeline v GitHub Actions**
#
# ### **Detailní zadání**
# Vytvoř konfigurační soubor pro GitHub Actions, který spustí testy a build aplikace při každém push do větve `main`. Aplikace je jednoduchá Node.js aplikace, která má jednoduchý test.
#
# ### **Vstupní data/požadavky**
# - Repository s Node.js aplikací
# - Soubor `package.json` s přidaným testem (např. pomocí Jest)
# - Základní soubor `index.js`, který exportuje funkci
#
# ### **Očekávaný výstup**
# - Working GitHub Actions workflow (`.github/workflows/ci.yml`)
# - Workflow spouští:
#   - Instalaci závislostí
#   - Spuštění testů
#   - Build aplikace
#
# ### **Hints/Nápověda**
# 1. Vytvoř soubor `.github/workflows/ci.yml`.
# 2. Použij `on: push` na věte `main`.
# 3. Vlož joby pro instalaci, testování a build.
# 4. Ujisti se, že používáš správné akce (`actions/setup-node`, `npm install`, atd.)
#
# ### **Kostra řešení**
# ```yaml
# name: CI Pipeline
#
# on:
#   push:
#     branches: [ main ]
#
# jobs:
#   build:
#     runs-on: ubuntu-latest
#
#     steps:
#       - uses: actions/checkout@v3
#       - name: Use Node.js
#         uses: actions/setup-node@v3
#         with:
#           node-version: '18'
#       - run: npm install
#       - run: npm test
#       - run: npm run build
# ```
#
# ### **Bonusové rozšíření**
# Přidej možnost automatického deployu na Vercel nebo Netlify po úspěšném buildu.
#
# ---
#
# ## Cvičení 2: **Název úkolu**
# **Vytvoření CI/CD pipeline s Docker buildem a pushem do registry**
#
# ### **Detailní zadání**
# Vytvoř workflow, který:
# 1. Při push do `main` vytvoří Docker image
# 2. Otestuje image (např. pomocí `docker run`)
# 3. Nahraje image do Docker registry (např. Docker Hub)
#
# ### **Vstupní data/požadavky**
# - Soubor `Dockerfile`
# - Repository s aplikací (např. Node.js)
# - Přístup k Docker registry (např. Docker Hub)
#
# ### **Očekávaný výstup**
# - Workflow, který:
#   - Vytváří Docker image
#   - Spouští testy na obrazu
#   - Pushuje image do registry
#
# ### **Hints/Nápověda**
# 1. Použij `docker/build-push-action`
# 2. Přidej kroky pro build a push.
# 3. Zkontroluj, že je nastaven token pro Docker Hub.
# 4. Přidej test na spuštění image přes `docker run`.
#
# ### **Kostra řešení**
# ```yaml
# name: CI/CD with Docker
#
# on:
#   push:
#     branches: [ main ]
#
# jobs:
#   build:
#     runs-on: ubuntu-latest
#
#     steps:
#       - uses: actions/checkout@v3
#
#       - name: Set up Docker Buildx
#         uses: docker/setup-buildx-action@v2
#
#       - name: Login to DockerHub
#         uses: docker/login-action@v2
#         with:
#           username: ${{ secrets.DOCKER_USERNAME }}
#           password: ${{ secrets.DOCKER_PASSWORD }}
#
#       - name: Build and push
#         uses: docker/build-push-action@v4
#         with:
#           context: .
#           push: true
#           tags: your-username/your-app:latest
# ```
#
# ### **Bonusové rozšíření**
# Přidej možnost deployu image přes Docker Compose do vlastního serveru.
#
# ---
#
# ## Cvičení 3: **Název úkolu**
# **Vytvoření CI/CD pipeline s multi-stage buildem a testy na více platformách**
#
# ### **Detailní zadání**
# Vytvoř workflow, který:
# 1. Spustí testy na více operačních systémech (Linux, macOS, Windows)
# 2. Vytvoří multi-stage Docker image
# 3. Spustí integrační testy pomocí `docker-compose`
#
# ### **Vstupní data/požadavky**
# - Soubor `Dockerfile` s více fázemi
# - `docker-compose.yml` pro testování
# - Testy v aplikaci (např. E2E testy)
#
# ### **Očekávaný výstup**
# - Workflow, který:
#   - Spouští testy na více OS
#   - Builduje multi-stage Docker image
#   - Spouští `docker-compose` a testy
#
# ### **Hints/Nápověda**
# 1. Použij `strategy.matrix` pro více OS.
# 2. Vlož `docker-compose up` v jobu.
# 3. Testuj, že obraz je správně sestaven.
# 4. Nastav `services` v `docker-compose.yml`.
#
# ### **Kostra řešení**
# ```yaml
# name: Multi-Platform CI/CD
#
# on:
#   push:
#     branches: [ main ]
#
# jobs:
#   test:
#     runs-on: ${{ matrix.os }}
#     strategy:
#       matrix:
#         os: [ubuntu-latest, macos-latest, windows-latest]
#
#     steps:
#       - uses: actions/checkout@v3
#
#       - name: Setup Node.js
#         uses: actions/setup-node@v3
#         with:
#           node-version: '18'
#
#       - run: npm install
#
#       - run: npm test
#
#       - name: Docker Compose Test
#         run: |
#           docker-compose up -d
#           sleep 10
#           curl http://localhost:3000
# ```
#
# ### **Bonusové rozšíření**
# Přidej možnost automatického reportování pokud nějaký test selže (např. pomocí Slack webhooku).
#
# ---
#
# ## Cvičení 4: **Název úkolu**
# **Vytvoření CI/CD pipeline s kvalitou kódu a security checky**
#
# ### **Detailní zadání**
# Vytvoř workflow, který:
# 1. Spustí linting (např. ESLint)
# 2. Spustí testovací pokrytí (např. Istanbul + NYC)
# 3. Spustí bezpečnostní skenování (např. `npm audit` nebo Snyk)
#
# ### **Vstupní data/požadavky**
# - Aplikace s přidanými nástroji pro testy a linting
# - Nastavené ESLint, Istanbul, Snyk atd.
#
# ### **Očekávaný výstup**
# - Workflow, který:
#   - Lintuje kód
#   - Kontroluje pokrytí testů
#   - Spouští bezpečnostní skenování
#
# ### **Hints/Nápověda**
# 1. Použij `npm run lint` a podobné skripty.
# 2. Vlož `npm run coverage` pro pokrytí.
# 3. Spusť `npm audit` nebo Snyk jako krok workflow.
# 4. Nastav prahy pro pokrytí nebo počet chyb.
#
# ### **Kostra řešení**
# ```yaml
# name: Quality & Security Checks
#
# on:
#   push:
#     branches: [ main ]
#
# jobs:
#   quality:
#     runs-on: ubuntu-latest
#
#     steps:
#       - uses: actions/checkout@v3
#
#       - name: Setup Node.js
#         uses: actions/setup-node@v3
#         with:
#           node-version: '18'
#
#       - run: npm install
#
#       - run: npm run lint
#
#       - run: npm run test:coverage
#
#       - run: npm audit
# ```
#
# ### **Bonusové rozšíření**
# Přidej automatizované oznámení o selhání na Slacku, pokud nějaký kontrolní test selže.
#
# ---
#
# ## Cvičení 5: **Název úkolu**
# **Automatizace CI/CD pipeline s deploymentem do cloudového prostředí**
#
# ### **Detailní zadání**
# Vytvoř workflow, kter

# %% [markdown]
# ## 📚 Další zdroje a materiály
#
# <div style="background: #e3f2fd; padding: 20px; border-left: 5px solid #2196f3; margin: 20px 0; border-radius: 5px;">
#     <h3 style="color: #2c3e50; margin-top: 0;">🔗 Doporučené materiály k dalšímu studiu</h3>
# </div>
#
# # Zdroje pro kapitolu: CI/CD pipeline
#
# ## Články a tutoriály
#
# 1. **[What is CI/CD? A Complete Guide](https://www.atlassian.com/continuous-delivery/cicd)**
#    Komplexní průvodce konceptem CI/CD od Atlassian. Vysvětluje základní principy, výhody a nejčastější použití v praxi.
#
# 2. **[CI/CD Pipeline: What It Is and How to Build One](https://www.redhat.com/en/topics/automation/what-is-ci-cd-pipeline)**
#    Red Hat poskytuje jasný výklad toho, co je CI/CD pipeline a jak ho sestavit krok za krokem – vhodné pro začátečníky i pokročilé.
#
# 3. **[Understanding CI/CD Pipeline Concepts with Jenkins](https://www.jenkins.io/doc/book/pipeline/)**
#    Oficiální dokumentace Jenkinsu o konceptech a implementaci CI/CD pipeline – ideální pro základní orientaci v nástrojích.
#
# 4. **[GitLab CI/CD Documentation](https://docs.gitlab.com/ee/ci/)**
#    Dokumentace GitLabu k CI/CD – velmi detailní a užitečný zdroj pro nastavení pipeline přímo v GitLabu.
#
# 5. **[CI/CD with GitHub Actions](https://docs.github.com/en/actions)**
#    Oficiální dokumentace GitHub Actions, která vysvětluje, jak vytvářet CI/CD potrubí přímo v rámci GitHubu.
#
# ## YouTube videa
#
# 1. **[CI/CD Pipeline Tutorial - Full Course for Beginners](https://www.youtube.com/watch?v=7CqJlTxq34E)** (Délka: 2 hodiny 15 minut)
#    Úvodní kurz pro začátečníky vytvářející CI/CD pipeline pomocí Jenkins a Dockeru.
#
# 2. **[What is Continuous Integration & Delivery?](https://www.youtube.com/watch?v=476382974)** (Délka: 12 minut)
#    Stručný výklad konceptů CI/CD v anglickém jazyce – vhodné pro rychlé pochopení základního principu.
#
# 3. **[CI/CD with GitHub Actions - Full Beginner Tutorial](https://www.youtube.com/watch?v=4hX6x8Dy2Qo)** (Délka: 1 hodina 30 minut)
#    Praktický návod na vytvoření CI/CD pipeline pomocí GitHub Actions, vhodné pro začátečníky.
#
# ## Knihy a oficiální dokumentace
#
# 1. **"Continuous Delivery: Reliable Software Releases through Build, Test, and Deployment Automation"** – Jez Humble & David Farley
#    Klasická kniha o CI/CD, která vysvětluje filozofii a praxe společnosti v oblasti automatizace nasazování software.
#
# 2. **"The DevOps Handbook: How to Create World-Class Agility, Reliability, and Security in Technology Organizations"** – Gene Kim, Patrick Debois, John Willis, Jez Humble
#    Komplexní příručka o DevOps, která zahrnuje i vývoj CI/CD pipeline jako klíčovou součást.
#
# 3. **[Official Kubernetes Documentation - CI/CD Integration](https://kubernetes.io/docs/concepts/extend-kubernetes/ci-cd/)**
#    Oficiální dokumentace Kubernetes, která uvádí možnosti integrace CI/CD nástrojů s Kubernetes clustery.
#
# ## Praktické projekty
#
# 1. **Vytvořit CI/CD pipeline pro webovou aplikaci (např. Node.js nebo Python)**
#    Vytvoření základní pipeline, která automaticky testuje kód, buildí aplikaci a nasazuje ji na server (např. Heroku nebo AWS).
#
# 2. **CI/CD pipeline pro Docker kontejner**
#    Nastavit pipeline pro build a push Docker image do registry (např. Docker Hub), př

# %% [markdown]
# ## 📝 Shrnutí kapitoly
#
# <div style="background: linear-gradient(135deg, #667eea 0%, #764ba2 100%); padding: 30px; border-radius: 10px; color: white; margin: 30px 0;">
#     <h3 style="color: white; margin-top: 0;">✅ Co jste se naučili</h3>
#     <ul style="list-style: none; padding-left: 0;">
#         <li>✓ GitHub Actions workflows</li>
# <li>✓ GitLab CI/CD pipelines</li>
# <li>✓ Jenkins basics</li>
# <li>✓ Automated testing</li>
# <li>✓ Build a deployment stages</li>
#     </ul>
#
#     <h3 style="color: white;">🎯 Klíčové dovednosti</h3>
#     <p>Po dokončení této kapitoly byste měli být schopni prakticky použít všechny probrané koncepty.</p>
#
#     <h3 style='color: white;'>➡️ Další kapitola</h3><p>Kapitola 24 - pokračujte ve studiu!</p>
# </div>
#
# ---
#
# *📅 Notebook vygenerován: 2025-09-29 12:48:22*
# *🤖 Generátor: Comprehensive Colab Generator v2.0*
# *📚 Učebnice programování - Od základů k AI*

# %% [markdown]
# ## 🧪 Sandbox - Prostor pro experimenty
#
# Použijte následující buňky pro vlastní experimenty a testování:

# %%
# 🧪 Zde můžete experimentovat s kódem z kapitoly
# Napište svůj kód zde:
