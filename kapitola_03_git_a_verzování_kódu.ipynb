# %% [markdown]
# # 📚 Kapitola 3: Git a verzování kódu
#
# <div style="background: linear-gradient(90deg, #667eea 0%, #764ba2 100%); padding: 20px; border-radius: 10px; margin: 20px 0;">
#     <h2 style="color: white; margin: 0;">Blok 1 | BEGINNER</h2>
#     <p style="color: white; margin: 10px 0;">📖 Výuková kapitola</p>
# </div>
#
# ## 🎯 Co se naučíte
#
# V této kapitole se zaměříme na následující témata:
#
# - **Git instalace a konfigurace**
# - **Základní příkazy: init, add, commit, status, log**
# - **Branching: branch, checkout, merge**
# - **Remote repositories: clone, push, pull, fetch**
# - **GitHub, GitLab, Bitbucket**
# - **SSH klíče generování a použití**
# - **.gitignore a .gitattributes**
#
# ## ⚠️ Předpoklady
# Tato kapitola navazuje na kapitoly: 1, 2
#
# ---

# %%
# ⚙️ Inicializace prostředí
# Tento kód nastavuje prostředí pro kapitolu 3

import sys
import os
from datetime import datetime

# Informace o prostředí
print("=" * 60)
print(f"📚 KAPITOLA 3: Git a verzování kódu")
print("=" * 60)
print(f"🐍 Python verze: {sys.version}")
print(f"📅 Datum spuštění: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
print(f"💻 OS: {os.name}")
print(f"📁 Pracovní adresář: {os.getcwd()}")
print("=" * 60)

# Instalace potřebných knihoven (odkomentujte podle potřeby)
# !pip install requests pandas numpy matplotlib
# !pip install beautifulsoup4 sqlalchemy fastapi

# Import základních knihoven
import json
import csv
import time
import random
from pathlib import Path
from typing import List, Dict, Optional, Any

print("✅ Prostředí připraveno!")

# %% [markdown]
# ## 📖 Teoretická část
#
# <div style="background: #f0f4ff; padding: 20px; border-left: 5px solid #4a69bd; margin: 20px 0; border-radius: 5px;">
#     <h3 style="color: #2c3e50; margin-top: 0;">🎓 Základní teorie a koncepty</h3>
# </div>
#
# # Git a verzování kódu – Detailní teoretický výklad
#
# ## 1. Úvod a motivace
#
# Verzování kódu je klíčová součást každého softwarového vývoje, a to jak individuálního, tak týmového. Představte si, že pracujete na projektu, který může během několika dní přibýt o stovky řádků kódu – bez kontroly verzí byste rychle ztratili přehled. Git je jedna z nejpokročilejších a nejrozšířenějších systémů pro správu verzí, který vám umožňuje uchovávat historii změn ve vašem kódu, pracovat paralelně s ostatními, vrátit se zpět ke staršímu stavu a efektivně řešit konflikty při spolupráci.
#
# V praxi Git používají téměř všechny softwarové vývojářské týmy – od malých startupů až po velké firmy jako Google, Microsoft nebo Amazon. V současnosti je Git přítomen i v mnoha online platformách jako GitHub, GitLab či Bitbucket, které poskytují rozhraní pro spolupráci na kódu a správu projektů.
#
# Tato kapitola vás naučí základním konceptům a příkazům Gitu. Po jejím prostudování budete schopni:
# - Vytvářet a spravovat lokální repozitáře,
# - Pracovat s větvemi (branching),
# - Stahovat a nahrávat změny na vzdálené servery,
# - Řešit konflikty ve spolupráci.
#
# ---
#
# ## 2. Hlavní koncepty
#
# ### Git instalace a konfigurace
#
# Než začnete pracovat s Gitem, musíte ho nainstalovat a nakonfigurovat. Instalace je jednoduchá – stačí navštívit [oficiální web Gitu](https://git-scm.com/) a stáhnout si verzi pro váš operační systém.
#
# Po instalaci je třeba nastavit vaše uživatelské jméno a e-mail, které budou použity v každém commitu:
#
# ```bash
# git config --global user.name "Váš Jméno"
# git config --global user.email "vas@email.cz"
# ```
#
# Tyto nastavení jsou uložena globálně a použijí se pro všechny vaše repozitáře.
#
# ---
#
# ### Základní příkazy: `init`, `add`, `commit`, `status`, `log`
#
# #### `git init`
# Používá se pro inicializaci nového Git repozitáře v aktuálním adresáři:
#
# ```bash
# git init
# ```
#
# Po této akci se ve složce objeví skrytý adresář `.git`, který obsahuje všechny informace o verzích a historii.
#
# #### `git add`
# Přidává soubory do "staging" oblasti – připravuje je k commitu. Můžete přidat konkrétní soubor:
#
# ```bash
# git add nazev_souboru.txt
# ```
#
# nebo všechny změny:
#
# ```bash
# git add .
# ```
#
# #### `git commit`
# Uloží změny z staging oblasti do historie repozitáře. Musíte přidat zprávu, která popisuje co bylo změněno:
#
# ```bash
# git commit -m "Přidal jsem novou funkci"
# ```
#
# #### `git status`
# Zobrazuje aktuální stav repozitáře – které soubory jsou změněné, připravené k commitu a co ještě není sledováno:
#
# ```bash
# git status
# ```
#
# #### `git log`
# Zobrazuje historii commitů, včetně autora a data:
#
# ```bash
# git log --oneline
# ```
#
# ---
#
# ### Branching: `branch`, `checkout`, `merge`
#
# Větvení (branching) umožňuje pracovat na různých funkcích nezávisle. Výchozí větev se obvykle jmenuje `main` nebo `master`.
#
# #### `git branch`
# Zobrazí seznam větví:
#
# ```bash
# git branch
# ```
#
# Vytvoření nové větve:
#
# ```bash
# git branch novy_branch
# ```
#
# #### `git checkout`
# Přepne mezi větvemi:
#
# ```bash
# git checkout novy_branch
# ```
#
# Nový příkaz `git switch` (v novějších verzích Gitu) je alternativou:
#
# ```bash
# git switch novy_branch
# ```
#
# #### `git merge`
# Spojí změny z jedné větve do druhé:
#
# ```bash
# git checkout main
# git merge novy_branch
# ```
#
# ---
#
# ### Remote repositories: `clone`, `push`, `pull`, `fetch`
#
# Vzdálené repozitáře se nachází například na GitHubu nebo GitLabu. Pracujete s nimi pomocí těchto příkazů:
#
# #### `git clone`
# Stáhne celý repozitář z vzdáleného serveru:
#
# ```bash
# git clone https://github.com/uzivatel/nazev_repo.git
# ```
#
# #### `git push`
# Nahraje lokální změny na vzdálený repozitář:
#
# ```bash
# git push origin main
# ```
#
# #### `git pull`
# Stáhne změny z vzdáleného repozitáře a automaticky sloučí s vaší pracovní verzí:
#
# ```bash
# git pull origin main
# ```
#
# #### `git fetch`
# Stáhne změny, ale **nesloučí** je – umožňuje si přečíst změny před merge:
#
# ```bash
# git fetch origin
# ```
#
# ---
#
# ### GitHub, GitLab, Bitbucket
#
# Tyto platformy jsou online servery pro Git repozitáře. Poskytují:
# - Grafické rozhraní pro správu projektů,
# - Spolupráci mezi vývojáři,
# - Systém pull requestů (pro kontrolu kódu),
# - CI/CD nástroje a další funkce.
#
# #### GitHub
# Nejoblíbenější platforma, ideální pro open-source projekty.
#
# #### GitLab
# Velmi funkcionalní řešení s možností vlastního hostování.
#
# #### Bitbucket
# Zaměřený na týmovou spolupráci a integraci s Atlassian produkty.
#
# ---
#
# ### SSH klíče – generování a použití
#
# Pro bezpečné připojení k vzdálenému repozitáři (např. GitHubu) používáme SSH klíče.
#
# #### Generování SSH klíče:
#
# ```bash
# ssh-keygen -t rsa -b 4096 -C "vas@email.cz"
# ```
#
# Po zobrazení otázek stiskněte Enter pro výchozí nastavení. Klíč se uloží do adresáře `~/.ssh`.
#
# #### Přidání klíče do SSH agenta:
#
# ```bash
# eval "$(ssh-agent -s)"
# ssh-add ~/.ssh/id_rsa
# ```
#
# Poté přidejte veřejný klíč (např. `id_rsa.pub`) na GitHubu v nastavení účtu.
#
# ---
#
# ### `.gitignore` a `.gitattributes`
#
# #### `.gitignore`
# Soubor, který určuje, které soubory nebo složky se nemají ukládat do Gitu (např. logy, cache, binárky):
#
# ```plaintext
# *.log
# node_modules/
# .env
# ```
#
# #### `.gitattributes`
# Používá se pro nastavení vlastností souborů – např. jak se mají řešit konflikty při merge:
#
# ```plaintext
# *.md text eol=lf
# ```
#
# ---
#
# ## 3. Důležité detaily
#
# ### Časté chyby a jak se jim vyhnout
#
# - **Nepřidání souboru do stagingu:** Zapomeňte na `git add` – změny se neuloží.
# - **Nezadání zprávy k commitu:** Příkaz `git commit` bez `-m` otevře editor, který může být nepřehledný.
# - **Nesprávné větvení:** Používání `git merge` bez kontroly změn může způsobit konflikty.
#
# ### Best practices
#
# 1. Vytvářejte krátké a srozumitelné commit zprávy.
# 2. Pravidelně používejte `git pull` před práci, aby bylo možné detekovat konflikty dříve.
# 3. Vytvářejte větve pro jednotlivé funkce nebo opravy chyb.
# 4. Používejte `.gitignore`, aby se neposílaly citlivé nebo zbytečné soubory.
#
# ### Performance tipy
#
# - Nepoužívejte Git na velké binární soubory – použijte jiné nástroje.
# - Používejte `git gc` pro optimalizaci repozitáře (vyčištění nepotřebných dat).
# - Používejte `git clone --depth 1` pro rychlé stahování jen posledního stavu.
#
# ---
#
# ## 4. Propojení s předchozími kapitolami
#
# Tato kapitola navazuje na předchozí znalosti o práci s terminálem a základním programování. Git používá terminálové příkazy, takže je důležité mít základní orientaci v práci s operačním systémem (např. Linux/macOS/Windows). Naučení se Gitu rozšiřuje vaše schopnosti efektivně spravovat a sdílet kód, což je klíčové pro vývoj v týmu nebo profesionálním prostředí.
#
# Git není jen nástroj, ale způsob myšlení – otevírá cestu k lepší spolupráci, organizaci a řešení problémů.

# %% [markdown]
# ## 💻 Praktické příklady
#
# <div style="background: #e8f5e9; padding: 20px; border-left: 5px solid #4caf50; margin: 20px 0; border-radius: 5px;">
#     <h3 style="color: #2c3e50; margin-top: 0;">👨‍💻 Hands-on příklady ke spuštění</h3>
#     <p>Následující příklady si můžete hned vyzkoušet. Každý příklad je samostatně spustitelný.</p>
# </div>

# %% [markdown]
# ### Příklad 1
#
# Příklad 1: Instalace a konfigurace Gitu
# """
# Název příkladu: Instalace a konfigurace Gitu
# Co demonstruje: Základní nastavení Gitu pro uživatele
# Kompletní kód s českými komentáři:
# """
#
# # Tento příklad ukazuje, jak nastavit Git na počítači
# # V praxi by se spouštělo v terminálu, ne v Pythonu
# print("=== Instalace a konfigurace Gitu ===")
# print("# 1. Ověření instalace Gitu:")
# print("git --version")
# print("")
# print("# 2. Nastavení uživatelského jména:")
# print("git config --global user.name \"Jan Novák\"")
# print("")
# print("# 3. Nastavení e-mailové adresy:")
# print("git config --global user.email \"jan.novak@example.com\"")
# print("")
# print("# 4. Zobrazení konfigurace:")
# print("git config --list")
# print("")
# print("# 5. Nastavení výchozího editoru (např. VS Code):")
# print("git config --global core.editor \"code --wait\"")
# print("")
# print("Očekávaný výstup:")
# print("git version 2.40.0")
# print("user.name = Jan Novák")
# print("user.email = jan.novak@example.com")
#
# # Vysvětlení:
# print("\nVysvětlení jak kód funguje:")
# print("- Příkaz git --version ověřuje, že Git je nainstalovaný")
# print("- Nastavení uživatelského jména a e-mailu je nutné pro identifikaci commitů")
# print("- git config --list zobrazuje všechna nastavení")
# print("- Nastavení editoru umožňuje jednodušší práci s commit zprávami")
# ```

# %% [markdown]
# ## 🎯 Cvičení a úkoly
#
# <div style="background: #fff3e0; padding: 20px; border-left: 5px solid #ff9800; margin: 20px 0; border-radius: 5px;">
#     <h3 style="color: #2c3e50; margin-top: 0;">✍️ Praktická cvičení k procvičení</h3>
#     <p>Vyřešte následující úkoly. Začněte od jednoduššších a postupujte k složitějším.</p>
# </div>
#
# # Cvičení: Git a verzování kódu
#
# ---
#
# ## 1. **Název úkolu:** Vytvoření nového repozitáře a první commit
#
# ### **Detailní zadání**
# Vytvoř nový adresář s názvem `my-first-project`, inicializuj v něm Git repozitář, vytvoř soubor `README.md` s textem „Ahoj světe! Toto je můj první projekt.“ a proveď první commit.
#
# ### **Vstupní data/požadavky**
# - Prázdný adresář `my-first-project`
# - Soubor `README.md` (bez obsahu, případně s textem)
#
# ### **Očekávaný výstup**
# - Inicializovaný Git repozitář
# - Soubor `README.md` v repozitáři
# - První commit s názvem „Initial commit“
#
# ### **Hints/Nápověda**
# 1. Použij příkaz `git init`, abys inicializoval repozitář.
# 2. Pomocí `echo` nebo textového editoru vytvoř soubor `README.md`.
# 3. Použij `git add .` a poté `git commit -m "Initial commit"`.
#
# ### **Kostra řešení**
# ```bash
# mkdir my-first-project
# cd my-first-project
# git init
# echo "Ahoj světe! Toto je můj první projekt." > README.md
# git add .
# git commit -m "Initial commit"
# ```
#
# ### **Bonusové rozšíření**
# Přidej soubor `main.js` s jednoduchým kódem a proveď druhý commit.
#
# ---
#
# ## 2. **Název úkolu:** Vytvoření a přepínání mezi větvemi
#
# ### **Detailní zadání**
# Vytvoř novou větev `feature/new-feature` a v ní uprav soubor `README.md` tak, že přidáš sekci „Nová funkce“. Poté se přepni zpět do hlavní větve `main`, kde uprav stejný soubor a proveď commit.
#
# ### **Vstupní data/požadavky**
# - Existující Git repozitář s nějakým obsahem (např. `README.md`)
#
# ### **Očekávaný výstup**
# - Větev `feature/new-feature` s upraveným `README.md`
# - Hlavní větev `main` s jiným obsahem
# - Obě větě by měly mít své commity
#
# ### **Hints/Nápověda**
# 1. Použij `git branch feature/new-feature`, abys vytvořil novou větev.
# 2. Přepni se do nové větve příkazem `git checkout feature/new-feature`.
# 3. Po úpravách proveď commit a vrať se zpět do `main` příkazem `git checkout main`.
#
# ### **Kostra řešení**
# ```bash
# git branch feature/new-feature
# git checkout feature/new-feature
# echo -e "\n## Nová funkce" >> README.md
# git add .
# git commit -m "Přidání sekce nová funkce"
# git checkout main
# echo -e "\n## Úprava v hlavní větě" >> README.md
# git add .
# git commit -m "Úprava v hlavní větě"
# ```
#
# ### **Bonusové rozšíření**
# Slouči (`merge`) větev `feature/new-feature` do `main`.
#
# ---
#
# ## 3. **Název úkolu:** Návrat k předchozí verzi (reset a revert)
#
# ### **Detailní zadání**
# Uprav soubor `README.md`, provedi commit, poté proveď další změny a opět commit. Vrať se zpět k prvnímu commitu příkazem `git reset` a poté proveď `git revert` na druhý commit.
#
# ### **Vstupní data/požadavky**
# - Repo s existujícím `README.md`
# - Alespoň dva commity
#
# ### **Očekávaný výstup**
# - Repository se vrátí zpět k prvnímu commitu
# - Commit druhé verze bude revertnut
#
# ### **Hints/Nápověda**
# 1. Použij `git log`, abys viděl historii commitů.
# 2. Použij `git reset --hard <hash>` pro vrácení zpět.
# 3. `git revert <hash>` obnoví změny daného commitu.
#
# ### **Kostra řešení**
# ```bash
# echo "První verze" >> README.md
# git add .
# git commit -m "První commit"
# echo "Druhá verze" >> README.md
# git add .
# git commit -m "Druhý commit"
# git reset --hard HEAD~1
# git revert HEAD
# ```
#
# ### **Bonusové rozšíření**
# Zkuste použít `git reset --soft` a porovnejte chování.
#
# ---
#
# ## 4. **Název úkolu:** Vytvoření tagu a práce s ním
#
# ### **Detailní zadání**
# Uprav `README.md`, proveď commit, pak vytvoř tag `v1.0.0` a zkontroluj, že tag byl vytvořen. Poté uprav soubor znovu a proveď další commit.
#
# ### **Vstupní data/požadavky**
# - Git repozitář s nějakým obsahem
#
# ### **Očekávaný výstup**
# - Tag `v1.0.0` spojený s konkrétním commitem
# - Nový commit po tagu
#
# ### **Hints/Nápověda**
# 1. Použij `git tag v1.0.0`, abys vytvořil tag.
# 2. Použij `git tag -l`, abys viděl všechny tagy.
# 3. Tag je spojen s konkrétním commitem – použij `git show` pro kontrolu.
#
# ### **Kostra řešení**
# ```bash
# echo "Verze 1" >> README.md
# git add .
# git commit -m "Verze 1"
# git tag v1.0.0
# echo "Verze 2" >> README.md
# git add .
# git commit -m "Verze 2"
# ```
#
# ### **Bonusové rozšíření**
# Vytvoř tag `v2.0.0` pro nový commit a použij `git checkout v1.0.0`, abys se přepnul do této verze.
#
# ---
#
# ## 5. **Název úkolu:** Vytvoření a použití .gitignore
#
# ### **Detailní zadání**
# Vytvoř nový projekt, vytvoř soubory `main.js`, `config.json`, `temp.txt`, `logs/` a `node_modules/`. Vytvoř soubor `.gitignore`, který bude ignorovat `temp.txt`, `logs/` a `node_modules/`. Poté proveď commit a zkontroluj, že ignorované soubory nejsou v repozitáři.
#
# ### **Vstupní data/požadavky**
# - Prázdný nebo existující Git repozitář
#
# ### **Očekávaný výstup**
# - `.gitignore` s definicemi ignorovaných souborů
# - Soubory `temp.txt`, `logs/`, `node_modules/` nejsou přidány do Gitu
#
# ### **Hints/Nápověda**
# 1. Vytvoř `.gitignore` s obsahem: `temp.txt`, `logs/`, `node_modules/`.
# 2. Použij `git status`, abys zkontroloval, co je ignorováno.
# 3. `git add .` by měl přeskočit ignorované soubory.
#
# ### **Kostra řešení**
# ```bash
# echo "console.log('Hello world!');" > main.js
# echo '{"debug": true}' > config.json
# echo "temp data" > temp.txt
# mkdir logs
# touch logs/log.txt
# mkdir node_modules
# git init
# echo -e "

# %% [markdown]
# ## 📚 Další zdroje a materiály
#
# <div style="background: #e3f2fd; padding: 20px; border-left: 5px solid #2196f3; margin: 20px 0; border-radius: 5px;">
#     <h3 style="color: #2c3e50; margin-top: 0;">🔗 Doporučené materiály k dalšímu studiu</h3>
# </div>
#
# # Git a verzování kódu – Seznam zdrojů
#
# ## 1. Doporučené články / Tutoriály
#
# 1. **[Pro Git (official book)](https://git-scm.com/book/en/v2)**
#    Oficiální příručka k Gitu od vývojářů Gitu. Výčet základních i pokročilých konceptů Gitu – ideální pro začátečníky i pokročilé uživatele.
#
# 2. **[Git Immersion](https://gitimmersion.com/)**
#    Interaktivní tutoriál, který vás provede základními příkazy Gitu prostřednictvím praktických cvičení. Skvělý způsob, jak se naučit Git na praxi.
#
# 3. **[Atlassian Git Tutorial](https://www.atlassian.com/git)**
#    Komplexní výukový obsah od Atlassianu. Obsahuje i grafické ilustrace a příklady práce s Gitem v reálných scénářích.
#
# 4. **[How to Use Git and GitHub](https://www.freecodecamp.org/news/how-to-use-git-and-github/)**
#    Kvalitní článek od FreeCodeCampu, který vysvětluje Git a GitHub pro začátečníky s jasnými příklady.
#
# 5. **[Git Cheat Sheet (GitHub)](https://education.github.com/git-cheat-sheet-education.pdf)**
#    Stručný průvodce příkazy Gitu. Vhodné jako rychlý přehled pro pravidelné uživatele Gitu.
#
# ---
#
# ## 2. YouTube videa
#
# 1. **[Git and GitHub for Beginners - Crash Course](https://www.youtube.com/watch?v=RGOj5yH7eKo)**
#    Délka: 16 min
#    Video od The Net Ninja, které vysvětluje Git a GitHub základy pro úplné začátečníky – jasně a s praktickými příklady.
#
# 2. **[Git and GitHub Tutorial for Beginners](https://www.youtube.com/watch?v=SWYqp7iXHlU)**
#    Délka: 30 min
#    Výukové video od Programming with Mosh – ideální pro ty, kdo chtějí rychle začít s Gitem a GitHubem.
#
# 3. **[Git Tutorial for Beginners - Full Course in 1 Hour](https://www.youtube.com/watch?v=8JJ109s85hI)**
#    Délka: 1 hodina
#    Detailní tutoriál od freeCodeCamp, který pokrývá všechny základy Gitu – od inicializace a commitu po práci s větvemi a merge.
#
# ---
#
# ## 3. Knihy a oficiální dokumentace
#
# 1. **[Pro Git – book](https://git-scm.com/book/en/v2)**
#    Oficiální online kniha o Gitu od vývojářů. Vhodná pro uživatele různých úrovní, od začátečníků po pokročilé.
#
# 2. **[Git in Practice](https://www.amazon.com/Git-Practice-Benjamin-Hawkes/dp/1617293869)**
#    Praktický průvodce Gitem, který se zaměřuje na běžné problémy a scénáře použití Gitu v praxi.
#
# 3. **[Official Git Documentation](https://git-scm.com/docs)**
#    Oficiální dokumentace projektu Git. Obsahuje detailní popis příkazů, konfigurací a vývojářských funkcí Gitu.
#
# ---
#
# ## 4. Praktické projekty
#
# 1. **Vytvořit osobní portfolio s použitím Gitu a GitHub Pages**
#    Vytvořte jednoduchou webovou stránku (např. HTML/CSS) a hostujte ji na GitHub Pages. Pracujte s větvemi, commitov

# %% [markdown]
# ## 📝 Shrnutí kapitoly
#
# <div style="background: linear-gradient(135deg, #667eea 0%, #764ba2 100%); padding: 30px; border-radius: 10px; color: white; margin: 30px 0;">
#     <h3 style="color: white; margin-top: 0;">✅ Co jste se naučili</h3>
#     <ul style="list-style: none; padding-left: 0;">
#         <li>✓ Git instalace a konfigurace</li>
# <li>✓ Základní příkazy: init, add, commit, status, log</li>
# <li>✓ Branching: branch, checkout, merge</li>
# <li>✓ Remote repositories: clone, push, pull, fetch</li>
# <li>✓ GitHub, GitLab, Bitbucket</li>
#     </ul>
#
#     <h3 style="color: white;">🎯 Klíčové dovednosti</h3>
#     <p>Po dokončení této kapitoly byste měli být schopni prakticky použít všechny probrané koncepty.</p>
#
#     <h3 style='color: white;'>➡️ Další kapitola</h3><p>Kapitola 4 - pokračujte ve studiu!</p>
# </div>
#
# ---
#
# *📅 Notebook vygenerován: 2025-09-29 11:43:07*
# *🤖 Generátor: Comprehensive Colab Generator v2.0*
# *📚 Učebnice programování - Od základů k AI*

# %% [markdown]
# ## 🧪 Sandbox - Prostor pro experimenty
#
# Použijte následující buňky pro vlastní experimenty a testování:

# %%
# 🧪 Zde můžete experimentovat s kódem z kapitoly
# Napište svůj kód zde:
