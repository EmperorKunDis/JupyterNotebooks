# %% [markdown]
# # 📚 Kapitola 1: Úvod do terminálu a příkazové řádky
#
# <div style="background: linear-gradient(90deg, #667eea 0%, #764ba2 100%); padding: 20px; border-radius: 10px; margin: 20px 0;">
#     <h2 style="color: white; margin: 0;">Blok 1 | BEGINNER</h2>
#     <p style="color: white; margin: 10px 0;">📖 Výuková kapitola</p>
# </div>
#
# ## 🎯 Co se naučíte
#
# V této kapitole se zaměříme na následující témata:
#
# - **Windows: Command Prompt, PowerShell, Windows Terminal**
# - **MacOS: Terminal.app, iTerm2, zsh/bash shell**
# - **Ubuntu: GNOME Terminal, Konsole, Terminator**
# - **Základní příkazy: pwd, ls/dir, cd, mkdir, rm/del, cp/copy, mv/move**
# - **Absolutní vs. relativní cesty**
# - **Pipes a redirections**
# - **Environment variables**
#
#
#
# ---

# %%
# ⚙️ Inicializace prostředí
# Tento kód nastavuje prostředí pro kapitolu 1

import sys
import os
from datetime import datetime

# Informace o prostředí
print("=" * 60)
print(f"📚 KAPITOLA 1: Úvod do terminálu a příkazové řádky")
print("=" * 60)
print(f"🐍 Python verze: {sys.version}")
print(f"📅 Datum spuštění: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
print(f"💻 OS: {os.name}")
print(f"📁 Pracovní adresář: {os.getcwd()}")
print("=" * 60)

# Instalace potřebných knihoven (odkomentujte podle potřeby)
# !pip install requests pandas numpy matplotlib
# !pip install beautifulsoup4 sqlalchemy fastapi

# Import základních knihoven
import json
import csv
import time
import random
from pathlib import Path
from typing import List, Dict, Optional, Any

print("✅ Prostředí připraveno!")

# %% [markdown]
# ## 📖 Teoretická část
#
# <div style="background: #f0f4ff; padding: 20px; border-left: 5px solid #4a69bd; margin: 20px 0; border-radius: 5px;">
#     <h3 style="color: #2c3e50; margin-top: 0;">🎓 Základní teorie a koncepty</h3>
# </div>
#
# # Úvod do terminálu a příkazové řádky
#
# ## 1. Úvod a motivace
#
# V dnešním digitálním světě je práce s počítačem často spjata s výpočetním výkonem, automatizací a efektivním řízením systému. Příkazová řádka nebo terminál je základní nástroj pro práci s operačními systémy na úrovni příkazů. Je to textové rozhraní, které umožňuje komunikovat s operačním systémem přímo pomocí příkazů – bez grafického rozhraní.
#
# Znát terminál je pro každého programátora, IT specialistu nebo technického pracovníka klíčové. V praxi se používá například při instalaci softwaru, správě souborů, spouštění skriptů, práci s verzemi kódu (např. Git), nebo při řešení problémů systému. Navíc se v terminálu dají provádět složité operace rychleji a efektivněji než v grafickém prostředí – například hromadné přejmenování souborů, vytváření složek, kopírování nebo přesunování souborů.
#
# Student se v této kapitole naučí základní příkazy, které mu umožní efektivně pracovat s operačním systémem pomocí příkazové řádky. Získá přehled o tom, jak fungují různé terminály v jednotlivých operačních systémech a jak se vyhýbat běžným chybám. Tato kapitola je základem pro další pokročilé téma jako např. skriptování, automatizace a práce s vzdálenými servery.
#
# ---
#
# ## 2. Hlavní koncepty
#
# ### Terminály podle operačního systému
#
# #### Windows: Command Prompt, PowerShell, Windows Terminal
#
# Ve Windows existují tři hlavní prostředí pro práci s příkazovou řádkou:
#
# - **Command Prompt (cmd)** – tradiční příkazový řádek. Používá se ke spouštění základních příkazů, ale nemá pokročilé funkce.
#
#   Příklad:
#   ```bash
#   dir
#   ```
#
# - **PowerShell** – modernější a výkonnější nástroj, který je schopen provádět skripty a automatizovat úkoly. Umí i práci s různými objekty (např. soubory, procesy).
#
#   Příklad:
#   ```powershell
#   Get-ChildItem
#   ```
#
# - **Windows Terminal** – moderní terminál od Microsoftu, který umožňuje používat více panelů najednou a podporuje různé příkazové řádky (cmd, PowerShell, WSL).
#
# #### MacOS: Terminal.app, iTerm2, zsh/bash shell
#
# MacOS používá výchozí aplikaci **Terminal.app**, která umožňuje spouštět příkazy v rámci **shellu** – výpočetního prostředí. V posledních verzích macOS je standardně nastavený shell **zsh** (Z Shell). Alternativně může být použit i **bash**.
#
# - **iTerm2** – vylepšená verze terminálu s dalšími funkcemi jako například rozdělení obrazovky, vyhledávání, zvukové notifikace.
#
# #### Ubuntu: GNOME Terminal, Konsole, Terminator
#
# V Linuxu (např. Ubuntu) je výchozí terminál **GNOME Terminal**, ale existují i další nástroje jako:
#
# - **Konsole** – používaný v KDE prostředí
# - **Terminator** – podobně jako iTerm2, umožňuje rozdělení panelů
#
# Linuxové terminály fungují podobně jako terminály ve Windows nebo Macu, ale používají **bash shell** jako výchozí.
#
# ---
#
# ### Základní příkazy
#
# #### `pwd` – zobrazení aktuálního adresáře
#
# Příkaz **pwd** (print working directory) vypíše cestu k aktuálnímu pracovnímu adresáři.
#
# ```bash
# pwd
# ```
#
# #### `ls` / `dir` – zobrazení obsahu adresáře
#
# Příkaz **ls** (list) zobrazuje soubory a složky v aktuálním adresáři. V systémech Windows se používá příkaz **dir**.
#
# ```bash
# ls
# dir
# ```
#
# #### `cd` – změna adresáře
#
# Příkaz **cd** (change directory) umožňuje přejít do jiného adresáře.
#
# ```bash
# cd Documents
# cd ..
# cd ~        # přejde do domovské složky
# ```
#
# #### `mkdir` – vytvoření nové složky
#
# Vytvoří nový adresář.
#
# ```bash
# mkdir my_new_folder
# ```
#
# #### `rm` / `del` – odstranění souborů a složek
#
# Odstraní soubory nebo adresáře. V systémech Windows se používá **del**, v Linuxu a Macu **rm**.
#
# ```bash
# rm file.txt
# rm -r folder_name    # smazání složky i jejího obsahu
# ```
#
# #### `cp` / `copy` – kopírování souborů
#
# Příkaz **cp** (copy) kopíruje soubory nebo složky.
#
# ```bash
# cp file.txt backup.txt
# cp -r folder1 folder2    # rekurzivní kopírování složky
# ```
#
# #### `mv` / `move` – přesunutí a přejmenování
#
# Přesune soubory nebo složky, nebo je přejmenuje.
#
# ```bash
# mv old_name.txt new_name.txt    # přejmenování
# mv file.txt /path/to/destination/
# ```
#
# ---
#
# ### Absolutní vs. relativní cesty
#
# **Absolutní cesta** začíná od kořenového adresáře a vždy uvádí celou cestu k souboru nebo složce.
#
# Příklad:
# ```bash
# /home/user/Documents/file.txt
# ```
#
# **Relativní cesta** se vztahuje k aktuálnímu pracovnímu adresáři a je krátcejší.
#
# Příklad:
# ```bash
# Documents/file.txt    # relativní cesta z domovské složky
# ../folder/file.txt    # přejde o jednu úroveň výš
# ```
#
# ---
#
# ### Pipes a redirections
#
# **Pipes (|)** umožňují spojit několik příkazů, kdy výstup jednoho příkazu je vstupem druhého.
#
# Příklad:
# ```bash
# ls | grep .txt    # vypíše jen soubory s příponou .txt
# ```
#
# **Redirections** slouží k přesměrování výstupu nebo vstupu příkazů.
#
# - `>` – přepíše obsah souboru
# - `>>` – přidá do souboru (append)
#
# Příklad:
# ```bash
# ls > file_list.txt    # uloží seznam souborů do souboru
# echo "Hello" >> log.txt    # přidá text do souboru
# ```
#
# ---
#
# ### Environment variables
#
# **Environment variables** (proměnné prostředí) jsou hodnoty, které ovlivňují chování systému. Například proměnná `PATH` určuje, kde systém hledá spustitelné soubory.
#
# V Linuxu a Macu:
# ```bash
# echo $PATH    # vypíše hodnotu PATH
# export MY_VAR="value"    # nastaví novou proměnnou
# ```
#
# Ve Windows:
# ```cmd
# echo %PATH%
# set MY_VAR=value
# ```
#
# ---
#
# ## 3. Důležité detaily
#
# ### Časté chyby a jak se jim vyhnout
#
# - **Nesprávný příkaz nebo cesta**: Vždy zkontroluj, zda jsi zadával správnou cestu nebo příkaz. Použij `ls` pro kontrolu obsahu adresáře.
# - **Chybějící práva k souboru**: Některé operace (např. smazání) vyžadují administrátorská práva.
# - **Nepoužití příznaků** (`-r`, `-f`, atd.): Např. `rm` bez `-r` neodstraní složku s obsahem.
#
# ### Best practices
#
# - Vždy používej **relativní cesty**, pokud je to možné.
# - Používej **příkazy bezpečně** – např. používej `cp -i` nebo `mv -i` pro potvrzení přepsání souborů.
# - Vytvářej zálohy před provedením velkých změn.
#
# ### Performance tipy
#
# - Používej **tabulátor** pro automatické dokončování cest.
# - Využívej **historii příkazů** (šipky nahoru/dolů).
# - Nepoužívej příkazy `rm -rf` bez kontroly – může smazat celý systém.
#
# ---
#
# ## 4. Propojení s předchozími kapitolami
#
# Tato kapitola je založena na základních znalostech o operačních systémech, práci se soubory a složkami. V předchozích kapitolách jste se naučili rozlišovat mezi různými typy souborů, vytvářet a mazat složky – teď se naučíte tyto operace provádět pomocí příkazové řádky.
#
# Znalosti z této kapitoly jsou klíčové pro práci s **automatizací**, **skriptováním** a **vzdáleným přístupem k systémům**, což vás připraví na další pokročilé téma – např. práce se skripty, Git, nebo Linuxové servery.
#
# ---
#
# **Závěr:** Práce s příkazovou řádkou není jen způsob, jak vytvářet a mazat soubory – je to základ pro efektivní práci s počítačem. Jakmile se naučíte používat základní příkazy, budete schopni rychleji a bezpečněji řešit problémy, automatizovat úkoly a pracovat v různých prostředích.

# %% [markdown]
# ## 💻 Praktické příklady
#
# <div style="background: #e8f5e9; padding: 20px; border-left: 5px solid #4caf50; margin: 20px 0; border-radius: 5px;">
#     <h3 style="color: #2c3e50; margin-top: 0;">👨‍💻 Hands-on příklady ke spuštění</h3>
#     <p>Následující příklady si můžete hned vyzkoušet. Každý příklad je samostatně spustitelný.</p>
# </div>

# %% [markdown]
# ### Příklad 1
#
# ### Co příklad demonstruje:
# Základní příkazy pro práci s adresáři: `pwd`, `ls` (nebo `dir`), `cd`.
#
# ```bash
# # Nastaví pracovní adresář a zobrazí jeho cestu
# pwd
#
# # Zobrazí obsah aktuálního adresáře
# ls
#
# # Přejde do nového adresáře (pokud existuje)
# cd Documents
#
# # Znovu se podíváme na obsah adresáře
# ls
#
# # Návrat zpět o jeden adresář
# cd ..
# ```

# %% [markdown]
# ### Příklad 2
#
# ### Očekávaný výstup:
# ```bash
# /home/user
# Desktop  Documents  Downloads  Music
# Documents
# Desktop  Documents  Downloads  Music
# ```

# %% [markdown]
# ### Příklad 3
#
# ### Vysvětlení:
# Příkaz `pwd` (print working directory) vypíše aktuální cestu.
# `ls` (list) zobrazí soubory a složky v aktuálním adresáři.
# `cd` (change directory) umožňuje přejít do jiného adresáře.
# Pomocí `..` se můžeme vrátit zpět o jeden úroveň.
#
# ---
#
# ## 2. Název příkladu: Vytvoření a odstranění složek

# %% [markdown]
# ### Příklad 4
#
# ### Co příklad demonstruje:
# Vytváření nových složek (`mkdir`) a jejich odstraňování (`rm` nebo `del`).
#
# ```bash
# # Vytvoří novou složku test_dir
# mkdir test_dir
#
# # Zobrazí obsah adresáře, kde byla složka vytvořena
# ls
#
# # Odstraní složku test_dir (musí být prázdná)
# rmdir test_dir
#
# # Znovu zkontroluje obsah
# ls
# ```

# %% [markdown]
# ### Příklad 5
#
# ### Očekávaný výstup:
# ```bash
# Desktop  Documents  Downloads  Music  test_dir
# Desktop  Documents  Downloads  Music
# ```

# %% [markdown]
# ### Příklad 6
#
# ### Vysvětlení:
# Příkaz `mkdir` (make directory) vytvoří nový adresář.
# `rmdir` odstraní prázdný adresář.
# Pokud by složka obsahovala soubory, použijeme `rm -rf` (ale to je pokročilé).
#
# ---
#
# ## 3. Název příkladu: Kopírování a přesunování souborů

# %% [markdown]
# ### Příklad 7
#
# ### Co příklad demonstruje:
# Kopírování (`cp`) a přesunování (`mv`) souborů a složek.
#
# ```bash
# # Vytvoří soubor test.txt
# touch test.txt
#
# # Zkopíruje soubor do jiného adresáře (např. Documents)
# cp test.txt Documents/
#
# # Přesune soubor do složky tmp
# mv test.txt tmp/
#
# # Zkontroluje obsah tmp složky
# ls tmp/
# ```

# %% [markdown]
# ### Příklad 8
#
# ### Očekávaný výstup:
# ```bash
# test.txt
# ```

# %% [markdown]
# ### Příklad 9
#
# ### Vysvětlení:
# Příkaz `cp` kopíruje soubor nebo adresář.
# `mv` přesune nebo přejmenuje soubory.
# V tomto případě se soubor přesune z aktuálního adresáře do složky `tmp`.
#
# ---
#
# ## 4. Název příkladu: Absolutní vs. relativní cesty

# %% [markdown]
# ### Příklad 10
#
# ### Co příklad demonstruje:
# Rozdíl mezi absolutní a relativní cestou.
#
# ```bash
# # Zobrazí absolutní cestu k aktuálnímu adresáři
# pwd
#
# # Přejde do složky Documents pomocí relativní cesty
# cd Documents
#
# # Nyní se přesuneme zpět pomocí absolutní cesty
# cd /home/user
#
# # Zkontrolujeme, že jsme zpátky
# pwd
# ```

# %% [markdown]
# ### Příklad 11
#
# ### Očekávaný výstup:
# ```bash
# /home/user/Documents
# /home/user
# ```

# %% [markdown]
# ### Příklad 12
#
# ### Vysvětlení:
# Relativní cesta je vztahovaná k aktuálnímu adresáři (`cd Documents`).
# Absolutní cesta začíná znakem `/` a je přesná – např. `/home/user/Documents`.
#
# ---
#
# ## 5. Název příkladu: Použití pipe a přesměrování výstupu

# %% [markdown]
# ### Příklad 13
#
# ### Co příklad demonstruje:
# Použití pipe (`|`) a přesměrování (`>`).
#
# ```bash
# # Vytvoří nový soubor a naplní ho seznamem souborů
# ls > file_list.txt
#
# # Zobrazí obsah souboru file_list.txt
# cat file_list.txt
#
# # Použije pipe pro výpis počtu souborů
# ls | wc -l
# ```

# %% [markdown]
# ### Příklad 14
#
# ### Očekávaný výstup:
# ```bash
# Desktop  Documents  Downloads  Music
# file_list.txt
# 5
# ```

# %% [markdown]
# ### Příklad 15
#
# ### Vysvětlení:
# `>` přesměruje výstup příkazu do souboru (např. `ls > file_list.txt`).
# `|` (pipe) propojuje výstup jednoho příkazu s vstupem druhého (`ls | wc -l`).
# Příkaz `wc -l` spočítá řádky ve výstupu.
#
# ---
#
# ## 6. Název příkladu: Práce s proměnnými prostředí

# %% [markdown]
# ### Příklad 16
#
# ### Co příklad demonstruje:
# Zobrazení a nastavení proměnných prostředí.
#
# ```bash
# # Zobrazí proměnnou PATH (obsahuje cesty k programům)
# echo $PATH
#
# # Nastaví novou proměnnou prostředí
# export MY_VAR="Hello World"
#
# # Znovu zkontroluje hodnotu proměnné
# echo $MY_VAR
#
# # Vytvoří soubor s použitím proměnné
# touch "$MY_VAR.txt"
# ls | grep "Hello"
# ```

# %% [markdown]
# ### Příklad 17
#
# ### Očekávaný výstup:
# ```bash
# /usr/local/bin:/usr/bin:/bin
# Hello World
# Hello World.txt
# ```

# %% [markdown]
# ### Příklad 18
#
# ### Vysvětlení:
# `$PATH` je proměnná, která určuje, kde systém hledá spustitelné soubory.
# `export` nastaví proměnnou prostředí, která bude dostupná v dalších příkazech.
# Proměnné se používají v uvozovkách (`"$MY_VAR.txt"`), aby bylo zachyceno jejich obsah.
#
# ---
#
# Tato sada příkladů vám pomůže získat praktické zkušenosti s terminálem, bez ohledu na operační systém.

# %% [markdown]
# ## 🎯 Cvičení a úkoly
#
# <div style="background: #fff3e0; padding: 20px; border-left: 5px solid #ff9800; margin: 20px 0; border-radius: 5px;">
#     <h3 style="color: #2c3e50; margin-top: 0;">✍️ Praktická cvičení k procvičení</h3>
#     <p>Vyřešte následující úkoly. Začněte od jednoduššších a postupujte k složitějším.</p>
# </div>
#
# # Úvod do terminálu a příkazové řádky – 5 praktických cvičení
#
# ---
#
# ## Cvičení 1: **Základní navigace v terminálu**
#
# ### 1. **Název úkolu**
# Navigace v systému souborů pomocí příkazů `pwd`, `ls`, `cd`
#
# ### 2. **Detailní zadání**
# Vytvoř si ve svém terminálu složku nazvanou `moje_prace`, v ní vytvoř podsložky `dokumenty`, `obrazky` a `zdrojaky`. Poté se přesuň do složky `dokumenty` a zkontroluj svou aktuální pozici.
#
# ### 3. **Vstupní data/požadavky**
# - Prázdný pracovní adresář (nebo vytvoř novou složku pro testování)
# - Přístup k terminálu
#
# ### 4. **Očekávaný výstup**
# Výstup příkazů:
# ```bash
# pwd
# ls -la
# cd dokumenty
# pwd
# ```
#
# ### 5. **Hints/Nápověda**
# 1. Použij `mkdir` pro vytvoření složek.
# 2. Příkaz `cd` slouží k přechodu mezi složkami.
# 3. Příkaz `pwd` ti ukáže aktuální cestu.
# 4. Použij `ls -la`, abys viděl všechny soubory i skryté.
#
# ### 6. **Kostra řešení**
# ```bash
# mkdir moje_prace
# cd moje_prace
# mkdir dokumenty obrazky zdrojaky
# cd dokumenty
# pwd
# ```
#
# ### 7. **Bonusové rozšíření**
# - Vytvoř v podsložce `dokumenty` soubor `README.md`
# - Použij `ls -R` pro zobrazení celého stromu složek.
#
# ---
#
# ## Cvičení 2: **Práce se soubory a příkazy `cat`, `echo`, `touch`**
#
# ### 1. **Název úkolu**
# Vytváření, čtení a úprava souborů v terminálu
#
# ### 2. **Detailní zadání**
# Vytvoř soubor `vitejte.txt` ve složce `dokumenty`. Do souboru přidej text: "Vítejte v terminálu!". Otevři obsah souboru pomocí příkazu `cat` a poté uprav jeho obsah na "Dnes se učíme Linux!".
#
# ### 3. **Vstupní data/požadavky**
# - Přístup k terminálu
# - Vytvořený adresář `dokumenty` z předchozího cvičení
#
# ### 4. **Očekávaný výstup**
# ```bash
# echo "Vítejte v terminálu!" > vitejte.txt
# cat vitejte.txt
# echo "Dnes se učíme Linux!" > vitejte.txt
# cat vitejte.txt
# ```
#
# ### 5. **Hints/Nápověda**
# 1. Použij `touch` pro vytvoření souboru.
# 2. Příkaz `>` přepisuje obsah souboru.
# 3. `cat` zobrazuje obsah souboru.
# 4. Můžeš použít příkaz `>>` pro přidání textu na konec.
#
# ### 6. **Kostra řešení**
# ```bash
# cd dokumenty
# echo "Vítejte v terminálu!" > vitejte.txt
# cat vitejte.txt
# echo "Dnes se učíme Linux!" > vitejte.txt
# cat vitejte.txt
# ```
#
# ### 7. **Bonusové rozšíření**
# - Přidej do souboru více řádků pomocí `echo` a `>>`
# - Vytvoř skript v jazyce Bash, který vytvoří tento soubor automaticky
#
# ---
#
# ## Cvičení 3: **Použití příkazu `cp`, `mv`, `rm`**
#
# ### 1. **Název úkolu**
# Kopírování a přesouvání souborů a složek
#
# ### 2. **Detailní zadání**
# Vytvoř v adresáři `zdrojaky` několik testovacích souborů. Poté je zkopíruj do `obrazky`. Po tomto přesuň jednu složku do `dokumenty`, následně smaž jeden soubor.
#
# ### 3. **Vstupní data/požadavky**
# - Vytvořené složky `zdrojaky`, `obrazky`, `dokumenty` (například z předchozích cvičení)
#
# ### 4. **Očekávaný výstup**
# Po příkazech:
# ```bash
# cp zdrojaky/* obrazky/
# mv obrazky/soubor1.txt dokumenty/
# rm zdrojaky/soubor2.txt
# ```
#
# ### 5. **Hints/Nápověda**
# 1. `cp` kopíruje soubory.
# 2. `mv` přesouvá nebo přejmenovává.
# 3. `rm` odstraňuje soubory (použij `-r` pro složky).
# 4. Výběr více souborů lze provést pomocí `*`.
#
# ### 6. **Kostra řešení**
# ```bash
# cd zdrojaky
# touch soubor1.txt soubor2.txt
# cp * ../obrazky/
# mv ../obrazky/soubor1.txt ../dokumenty/
# rm soubor2.txt
# ```
#
# ### 7. **Bonusové rozšíření**
# - Vytvoř skript, který automaticky kopíruje soubory podle jejich přípony (např. `.txt` do `text/`, `.jpg` do `obrazky/`)
# - Použij příkaz `find` pro vyhledání konkrétních souborů
#
# ---
#
# ## Cvičení 4: **Základní příkazy pro práci s textem**
#
# ### 1. **Název úkolu**
# Použití příkazů `head`, `tail`, `less`, `grep`
#
# ### 2. **Detailní zadání**
# Vytvoř v adresáři `dokumenty` soubor `log.txt`, který obsahuje několik řádků logu (například názvy příkazů). Pomocí příkazů `head`, `tail` a `grep` najdi konkrétní záznamy.
#
# ### 3. **Vstupní data/požadavky**
# - Vytvořený adresář `dokumenty`
# - Textový soubor s logy
#
# ### 4. **Očekávaný výstup**
# ```bash
# echo -e "ls\npwd\ncd\nls\nps" > log.txt
# head -n 3 log.txt
# tail -n 2 log.txt
# grep "cd" log.txt
# ```
#
# ### 5. **Hints/Nápověda**
# 1. `head` vypíše prvních n řádků.
# 2. `tail` vypíše poslední n řádků.
# 3. `grep` hledá řetězce v souboru.
# 4. Příkaz `less` umožňuje procházet soubor stránka po stránce.
#
# ### 6. **Kostra řešení**
# ```bash
# cd dokumenty
# echo -e "ls\npwd\ncd\nls\nps" > log.txt
# head -n 3 log.txt
# tail -n 2 log.txt
# grep "cd" log.txt
# ```
#
# ### 7. **Bonusové rozšíření**
# - Vytvoř velký textový soubor a vyhledej konkrétní slova nebo řádky pomocí `grep` s přepína

# %% [markdown]
# ## 📚 Další zdroje a materiály
#
# <div style="background: #e3f2fd; padding: 20px; border-left: 5px solid #2196f3; margin: 20px 0; border-radius: 5px;">
#     <h3 style="color: #2c3e50; margin-top: 0;">🔗 Doporučené materiály k dalšímu studiu</h3>
# </div>
#
# # Zdroje pro kapitolu: Úvod do terminálu a příkazové řádky
#
# ## 1. Články a tutoriály
#
# 1. **[The Absolute Beginner's Guide to the Linux Command Line](https://www.linode.com/docs/guides/linux-command-line/)**
#    Rozsáhlý úvod do příkazové řádky pro začátečníky, který vysvětluje základní příkazy a práci s terminálem. Vhodný pro začátečníky i ti, kdo se učí Linux.
#
# 2. **[Command Line Crash Course - Learn Shell Scripting](https://learnxinyminutes.com/docs/bash/)**
#    Stručné a přehledné vysvětlení základních příkazů shellu. Obsahuje i příklady kódů a praktické ukázky pro rychlé osvojení.
#
# 3. **[Introduction to the Bash Command Line - Linux Journal](https://www.linuxjournal.com/content/introduction-bash-command-line)**
#    Tento článek podrobně vysvětluje základní koncepty příkazové řádky a jak pracovat s příkazy, adresáři a soubory ve shellu.
#
# 4. **[The Linux Command Line - William Shotts](https://linuxcommand.org/tlcl.php)**
#    Online verze knihy „The Linux Command Line“, která je považována za jednu z nejlepších učebnic pro začátečníky v oblasti práce s terminálem.
#
# 5. **[A Guide to the Bash Command Line - Tutorials Point](https://www.tutorialspoint.com/unix/index.htm)**
#    Komplexní průvodce příkazové řádky, který zahrnuje všechny základní a pokročilé příkazy. Vhodné pro výukové účely i jako referenční dokument.
#
# ## 2. YouTube videa
#
# 1. **[Linux Command Line Tutorial for Beginners - freeCodeCamp.org (3:42:50)](https://www.youtube.com/watch?v=18R48q9YF7g)**
#    Rozsáhlé video pro začátečníky, které vysvětluje základní příkazy a práci s terminálem. Vhodné pro osvojení praxe a interaktivního učení.
#
# 2. **[The Command Line Crash Course - Corey Schafer (17:48)](https://www.youtube.com/watch?v=J6N0q3sQD4U)**
#    Krátké, ale informativní video, které se zaměřuje na klíčové příkazy a jejich použití v praxi. Skvělé pro rychlé opakování nebo zopakování.
#
# 3. **[Linux Terminal for Beginners - Neso Academy (28:15)](https://www.youtube.com/watch?v=Q6V4D0FkKZU)**
#    Přehledné video pro začátečníky, které vysvětluje základní koncepty a příkazy v terminálu. Vhodné pro ty, kdo preferují vizuální učení.
#
# ## 3. Knihy a oficiální dokumentace
#
# 1. **The Linux Command Line – William Shotts**
#    Nejznámější a nejrozšířenější kniha o práci s terminálem v Linuxu, která se zaměřuje na výukové účely a příklady pro začátečníky.
#
# 2. **Bash Guide for Beginners – Machtelt Garrels**
#    Dokumentace a příručka zaměřená na práci s Bashem. Vhodná pro uživatele, kteří chtějí seznámit se s podrobnostmi příkazové řádky.
#
# 3. **GNU Coreutils

# %% [markdown]
# ## 📝 Shrnutí kapitoly
#
# <div style="background: linear-gradient(135deg, #667eea 0%, #764ba2 100%); padding: 30px; border-radius: 10px; color: white; margin: 30px 0;">
#     <h3 style="color: white; margin-top: 0;">✅ Co jste se naučili</h3>
#     <ul style="list-style: none; padding-left: 0;">
#         <li>✓ Windows: Command Prompt, PowerShell, Windows Terminal</li>
# <li>✓ MacOS: Terminal.app, iTerm2, zsh/bash shell</li>
# <li>✓ Ubuntu: GNOME Terminal, Konsole, Terminator</li>
# <li>✓ Základní příkazy: pwd, ls/dir, cd, mkdir, rm/del, cp/copy, mv/move</li>
# <li>✓ Absolutní vs. relativní cesty</li>
#     </ul>
#
#     <h3 style="color: white;">🎯 Klíčové dovednosti</h3>
#     <p>Po dokončení této kapitoly byste měli být schopni prakticky použít všechny probrané koncepty.</p>
#
#     <h3 style='color: white;'>➡️ Další kapitola</h3><p>Kapitola 2 - pokračujte ve studiu!</p>
# </div>
#
# ---
#
# *📅 Notebook vygenerován: 2025-09-29 11:37:42*
# *🤖 Generátor: Comprehensive Colab Generator v2.0*
# *📚 Učebnice programování - Od základů k AI*

# %% [markdown]
# ## 🧪 Sandbox - Prostor pro experimenty
#
# Použijte následující buňky pro vlastní experimenty a testování:

# %%
# 🧪 Zde můžete experimentovat s kódem z kapitoly
# Napište svůj kód zde:
