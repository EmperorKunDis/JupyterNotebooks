# %% [markdown]
# # 📚 Kapitola 2: Instalace vývojových nástrojů
#
# <div style="background: linear-gradient(90deg, #667eea 0%, #764ba2 100%); padding: 20px; border-radius: 10px; margin: 20px 0;">
#     <h2 style="color: white; margin: 0;">Blok 1 | BEGINNER</h2>
#     <p style="color: white; margin: 10px 0;">📖 Výuková kapitola</p>
# </div>
#
# ## 🎯 Co se naučíte
#
# V této kapitole se zaměříme na následující témata:
#
# - **Windows: Chocolatey, Scoop, winget**
# - **MacOS: Homebrew, MacPorts**
# - **Ubuntu/Debian: APT, snap packages**
# - **VS Code instalace a konfigurace**
# - **Sublime Text, Atom, Notepad++**
# - **PATH proměnná na všech OS**
# - **Správa verzí nástrojů**
#
# ## ⚠️ Předpoklady
# Tato kapitola navazuje na kapitoly: 1
#
# ---

# %%
# ⚙️ Inicializace prostředí
# Tento kód nastavuje prostředí pro kapitolu 2

import sys
import os
from datetime import datetime

# Informace o prostředí
print("=" * 60)
print(f"📚 KAPITOLA 2: Instalace vývojových nástrojů")
print("=" * 60)
print(f"🐍 Python verze: {sys.version}")
print(f"📅 Datum spuštění: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
print(f"💻 OS: {os.name}")
print(f"📁 Pracovní adresář: {os.getcwd()}")
print("=" * 60)

# Instalace potřebných knihoven (odkomentujte podle potřeby)
# !pip install requests pandas numpy matplotlib
# !pip install beautifulsoup4 sqlalchemy fastapi

# Import základních knihoven
import json
import csv
import time
import random
from pathlib import Path
from typing import List, Dict, Optional, Any

print("✅ Prostředí připraveno!")

# %% [markdown]
# ## 📖 Teoretická část
#
# <div style="background: #f0f4ff; padding: 20px; border-left: 5px solid #4a69bd; margin: 20px 0; border-radius: 5px;">
#     <h3 style="color: #2c3e50; margin-top: 0;">🎓 Základní teorie a koncepty</h3>
# </div>
#
# # Instalace vývojových nástrojů
#
# ## 1. Úvod a motivace
#
# Instalace vývojových nástrojů je základním krokem na cestě k tomu, abys se stal skutečným programátorem nebo vývojářem. Bez správně nastaveného prostředí nemůžeš efektivně pracovat s kódem, testovat aplikace ani spravovat projekt. Tato kapitola tě naučí, jak instalovat a nakonfigurovat nejčastější nástroje pro vývoj v různých operačních systémech – od Windows přes macOS až po Linux.
#
# V praxi se tyto nástroje používají každý den profesionálními vývojáři. Například pro instalaci závislostí, ladění chyb, spouštění testů a správu verzí. Zvládnutí instalace a správy nástrojů ti umožní rychleji přejít k vlastnímu programování a neztrácet čas na řešení technických problémů.
#
# Tento kurz tě naučí:
# - Jak nainstalovat základní vývojové prostředí
# - Jak spravovat software na různých operačních systémech
# - Jak nakonfigurovat své prostředí pro efektivní práci
#
# ---
#
# ## 2. Hlavní koncepty
#
# ### Windows: Chocolatey, Scoop, winget
#
# Na Windows existuje několik způsobů, jak snadno instalovat a spravovat software – ať už je to vývojové prostředí, editor nebo nástroje pro testování.
#
# #### Chocolatey
# **Chocolatey** je správce balíčků pro Windows, který umožňuje instalaci softwaru z příkazové řádky. Je to velmi užitečné, protože umožňuje rychlé a opakovatelné instalace.
#
# Příklad:
# ```powershell
# choco install git
# ```
#
# #### Scoop
# **Scoop** je další alternativa k Chocolatey. Funguje podobně, ale je více zaměřený na uživatele, kteří chtějí mít všechny nástroje v jednom umístění (např. ve složce `~/scoop`).
#
# Příklad:
# ```powershell
# scoop install git
# ```
#
# #### winget
# **winget** je oficiální správce balíčků od Microsoftu, který je integrovaný do Windows 10 i 11. Je to jednoduchý způsob, jak instalovat softwarové balíčky přímo z příkazové řádky.
#
# Příklad:
# ```powershell
# winget install Git.Git
# ```
#
# ### MacOS: Homebrew, MacPorts
#
# Na macOS je běžné používat správce balíčků pro instalaci nástrojů, které potřebuješ pro vývoj.
#
# #### Homebrew
# **Homebrew** je nejoblíbenější správce balíčků na macOS. Je to prostý způsob, jak nainstalovat softwarové nástroje přes příkazovou řádku.
#
# Příklad:
# ```bash
# brew install node
# ```
#
# #### MacPorts
# **MacPorts** je alternativa k Homebrewu. Je to více komplexní systém, který umožňuje spravovat balíčky i vývojové prostředí.
#
# Příklad:
# ```bash
# sudo port install python3
# ```
#
# ### Ubuntu/Debian: APT, snap packages
#
# Na Linuxu (zejména distribucích jako Ubuntu nebo Debian) se používají správce balíčků typu **APT**.
#
# #### APT
# **APT** je standardní správce balíčků v Debianu a jeho derivacích. Umožňuje instalovat software přes příkazovou řádku.
#
# Příklad:
# ```bash
# sudo apt update
# sudo apt install git
# ```
#
# #### Snap packages
# **Snap** je další forma balíčků, které jsou k dispozici na Linuxu. Jsou kompatibilní s různými distribucemi a mohou být instalovány bez zásahu do systému.
#
# Příklad:
# ```bash
# sudo snap install code --classic
# ```
#
# ### VS Code instalace a konfigurace
#
# **Visual Studio Code (VS Code)** je populární editor kódu, který se používá všude – od začátečníků až po profesionální vývojáře.
#
# #### Instalace
# Na Windows:
# 1. Stáhni instalační soubor z [https://code.visualstudio.com](https://code.visualstudio.com)
# 2. Spusť instalaci
#
# Na macOS:
# 1. Přejdi na [https://code.visualstudio.com](https://code.visualstudio.com)
# 2. Stáhni `.dmg` soubor a nainstaluj ho
#
# Na Linuxu:
# ```bash
# sudo apt install code
# ```
#
# #### Konfigurace
# VS Code je velmi konfigurovatelný. Můžeš přidat rozšíření, změnit motivy nebo nastavit klávesové zkratky.
#
# Příklad:
# - Nainstaluj rozšíření pro tvůj jazyk (např. Python, JavaScript)
# - Přidej `settings.json` s vlastními předvolbami
#
# ### Sublime Text, Atom, Notepad++
#
# #### Sublime Text
# **Sublime Text** je jednoduchý, ale velmi výkonný editor kódu, který se osvědčil u mnoha programátorů.
#
# #### Atom
# **Atom** je open-source editor od GitHubu. Je velmi přizpůsobitelný a podporuje řadu rozšíření.
#
# #### Notepad++
# **Notepad++** je jednoduchý, rychlý a lehký editor pro Windows. Používá se hlavně pro rychlé editace a testování kódu.
#
# ### PATH proměnná na všech OS
#
# **PATH** je proměnná prostředí, která říká operačnímu systému, kde hledat spustitelné soubory (např. `git`, `node`, `python`).
#
# #### Windows
# 1. Otevři "Nastavení" → "Systém" → "Pokročilé nastavení systému"
# 2. Klikni na "Proměnné prostředí"
# 3. V části "Systémové proměnné" najdi `Path` a přidej novou cestu
#
# #### macOS/Linux
# Otevři soubor `.bashrc`, `.zshrc` nebo podobný a přidej:
#
# ```bash
# export PATH=$PATH:/usr/local/bin
# ```
#
# Poté spusť:
# ```bash
# source ~/.bashrc
# ```
#
# ### Správa verzí nástrojů
#
# Správa verzí nástrojů je velmi důležitá – můžeš nainstalovat starší verzi nástroje, pokud potřebuješ kompatibilitu.
#
# #### Nástroje:
# - **nvm** (Node Version Manager) pro Node.js
# - **pyenv** pro Python
# - **rbenv** pro Ruby
#
# Příklad použití `nvm`:
# ```bash
# nvm install 18
# nvm use 18
# ```
#
# ---
#
# ## 3. Důležité detaily
#
# ### Časté chyby a jak se jim vyhnout
#
# - **Chyba při instalaci z důvodu nedostatečných oprávnění** – používej `sudo` nebo spusť příkaz jako administrátor.
# - **Nefungující PATH** – ověř, že jsi správně nastavil proměnné prostředí.
# - **Zastaralé balíčky** – pravidelně aktualizuj své nástroje.
#
# ### Best practices
#
# - Vždy používej správce balíčků (např. `brew`, `apt`, `choco`) – zamezíš ruční instalaci a závislosti.
# - Udržuj své prostředí aktuální – pravidelně aktualizuj nástroje.
# - Používej virtuální prostředí pro Python nebo jiné jazyky.
#
# ### Performance tipy
#
# - Vyplň si `PATH` pouze s potřebnými cestami
# - Nepoužívej příliš mnoho rozšíření ve VS Code – může to zpomalit editor
# - Při instalaci balíčků používej oficiální repozitáře a verze
#
# ---
#
# ## 4. Propojení s předchozími kapitolami
#
# Tato kapitola se přirozeně propojuje s předchozím tématem o instalaci operačního systému a základním prostředí. Naučíš se, jak nastavit svůj počítač tak, aby byl připravený pro vývoj – tedy jak nainstalovat všechny potřebné nástroje a správně je nakonfigurovat. Tato znalost je základní pro další práci s programovacími jazyky, verzemi a vývojovými prostředími.
#
# Tento obsah rozšiřuje užití předchozích poznatků o práci s příkazovou řádkou a instalaci software – nyní už víš, jak to správně udělat na každém operačním systému.

# %% [markdown]
# ## 💻 Praktické příklady
#
# <div style="background: #e8f5e9; padding: 20px; border-left: 5px solid #4caf50; margin: 20px 0; border-radius: 5px;">
#     <h3 style="color: #2c3e50; margin-top: 0;">👨‍💻 Hands-on příklady ke spuštění</h3>
#     <p>Následující příklady si můžete hned vyzkoušet. Každý příklad je samostatně spustitelný.</p>
# </div>

# %% [markdown]
# ### Příklad 1
#
# ### 1. Název příkladu: Instalace VS Code pomocí Chocolatey na Windows

# %% [markdown]
# ### Příklad 2
#
# ### Co příklad demonstruje:
# Tento příklad ukazuje, jak jednoduše nainstalovat Visual Studio Code pomocí správce balíčků Chocolatey na systému Windows.
#
# ```powershell
# # Název: Instalace VS Code pomocí Chocolatey na Windows
# # Co demonstruje: Instalace editoru kódu pomocí nástroje Chocolatey
#
# # Ověření, zda je Chocolatey nainstalovaný (pokud ne, instalace není možná)
# if (!(Get-Command choco -ErrorAction SilentlyContinue)) {
#     Write-Host "Chocolatey není nainstalované. Nainstalujte jej nejprve z https://chocolatey.org/install"
#     exit 1
# }
#
# # Instalace VS Code pomocí Chocolatey
# Write-Host "Instaluji Visual Studio Code pomocí Chocolatey..."
# choco install vscode -y
#
# # Ověření instalace
# if (Get-Command code -ErrorAction SilentlyContinue) {
#     Write-Host "VS Code byl úspěšně nainstalován."
# } else {
#     Write-Host "Instalace VS Code se nezdařila."
# }
# ```

# %% [markdown]
# ### Příklad 3
#
# ### Očekávaný výstup:
# ```
# Instaluji Visual Studio Code pomocí Chocolatey...
# [...]
# VS Code byl úspěšně nainstalován.
# ```

# %% [markdown]
# ### Příklad 4
#
# ### Vysvětlení:
# Tento skript nejprve zkontroluje, zda je nástroj `choco` dostupný. Pokud ano, provede instalaci editoru VS Code a poté ověří, jestli byl spuštěný příkaz `code` úspěšně nainstalován.
#
# ---

# %% [markdown]
# ### Příklad 5
#
# ### 2. Název příkladu: Instalace Notepad++ pomocí winget na Windows

# %% [markdown]
# ### Příklad 6
#
# ### Co příklad demonstruje:
# Tento příklad ukazuje instalaci editoru Notepad++ pomocí `winget` – oficiálního nástroje pro správu balíčků od Microsoftu.
#
# ```powershell
# # Název: Instalace Notepad++ pomocí winget na Windows
# # Co demonstruje: Použití nástroje winget k instalaci aplikací
#
# # Zkontrolujeme, zda je winget dostupný
# if (!(Get-Command winget -ErrorAction SilentlyContinue)) {
#     Write-Host "winget není dostupný. Nainstalujte ho z https://learn.microsoft.com/en-us/windows/package-manager/winget/"
#     exit 1
# }
#
# # Instalace Notepad++
# Write-Host "Instaluji Notepad++ pomocí winget..."
# winget install Notepad++.Notepad++ -y
#
# # Ověření instalace
# if (Get-Command notepad++ -ErrorAction SilentlyContinue) {
#     Write-Host "Notepad++ byl úspěšně nainstalován."
# } else {
#     Write-Host "Instalace Notepad++ se nezdařila."
# }
# ```

# %% [markdown]
# ### Příklad 7
#
# ### Očekávaný výstup:
# ```
# Instaluji Notepad++ pomocí winget...
# [...]
# Notepad++ byl úspěšně nainstalován.
# ```

# %% [markdown]
# ### Příklad 8
#
# ### Vysvětlení:
# Příkaz `winget install` stáhne a nainstaluje Notepad++. Skript ověřuje, zda byl nástroj úspěšně nainstalován.
#
# ---

# %% [markdown]
# ### Příklad 9
#
# ### 3. Název příkladu: Instalace Homebrew na macOS

# %% [markdown]
# ### Příklad 10
#
# ### Co příklad demonstruje:
# Tento příklad ukazuje instalaci Homebrew, populárního správce balíčků pro macOS.
#
# ```bash
# #!/bin/bash
# # Název: Instalace Homebrew na macOS
# # Co demonstruje: Instalace správce balíčků Homebrew
#
# # Zkontrolujeme, zda Homebrew není již nainstalovaný
# if command -v brew &> /dev/null; then
#     echo "Homebrew je již nainstalován."
# else
#     echo "Instaluji Homebrew..."
#     # Spustíme instalační skript z oficiálního webu
#     /bin/bash -c "$(curl -fsSL https://raw.githubusercontent.com/Homebrew/install/HEAD/install.sh)"
# fi
#
# # Ověření instalace
# if command -v brew &> /dev/null; then
#     echo "Homebrew byl úspěšně nainstalován."
# else
#     echo "Instalace Homebrew se nezdařila."
# fi
# ```

# %% [markdown]
# ### Příklad 11
#
# ### Očekávaný výstup:
# ```
# Instaluji Homebrew...
# [...]
# Homebrew byl úspěšně nainstalován.
# ```

# %% [markdown]
# ### Příklad 12
#
# ### Vysvětlení:
# Skript zkontroluje, zda je `brew` již nainstalovaný. Pokud ne, spustí instalační skript z GitHubu a poté ověří instalaci.
#
# ---

# %% [markdown]
# ### Příklad 13
#
# ### 4. Název příkladu: Instalace Sublime Text pomocí APT na Ubuntu

# %% [markdown]
# ### Příklad 14
#
# ### Co příklad demonstruje:
# Tento příklad ukazuje instalaci editoru Sublime Text pomocí správce balíčků `apt` na systémech založených na Debianu.
#
# ```bash
# #!/bin/bash
# # Název: Instalace Sublime Text pomocí APT na Ubuntu
# # Co demonstruje: Instalace aplikace přes APT správce balíčků
#
# # Aktualizujeme seznam balíčků
# echo "Aktualizuji seznam balíčků..."
# sudo apt update
#
# # Instalace Sublime Text
# echo "Instaluji Sublime Text..."
# sudo apt install sublime-text -y
#
# # Ověření instalace
# if command -v subl &> /dev/null; then
#     echo "Sublime Text byl úspěšně nainstalován."
# else
#     echo "Instalace Sublime Text se nezdařila."
# fi
# ```

# %% [markdown]
# ### Příklad 15
#
# ### Očekávaný výstup:
# ```
# Aktualizuji seznam balíčků...
# [...]
# Instaluji Sublime Text...
# [...]
# Sublime Text byl úspěšně nainstalován.
# ```

# %% [markdown]
# ### Příklad 16
#
# ### Vysvětlení:
# Skript aktualizuje seznam dostupných balíčků a poté nainstaluje Sublime Text přes `apt install`. Po instalaci ověří, že byl příkaz `subl` dostupný.
#
# ---

# %% [markdown]
# ### Příklad 17
#
# ### 5. Název příkladu: Správa verzí nástrojů a nastavení PATH na všech OS

# %% [markdown]
# ### Příklad 18
#
# ### Co příklad demonstruje:
# Tento příklad ukazuje, jak nastavit proměnnou `PATH` pro různé operační systémy a jak spravovat verze nástrojů (např. Node.js) pomocí nástrojů jako `nvm`.
#
# ```powershell
# # Název: Správa verzí nástrojů a nastavení PATH na všech OS
# # Co demonstruje: Nastavení PATH a správa verzí nástrojů (např. Node.js)
#
# # Zkontrolujeme, zda je nástroj nvm (Node Version Manager) dostupný
# if (!(Get-Command nvm -ErrorAction SilentlyContinue)) {
#     Write-Host "Nástroj nvm není dostupný. Instalujte ho např. pomocí https://github.com/coreybutler/nvm-windows"
#     exit 1
# }
#
# # Nainstalujeme aktuální verzi Node.js (pokud není již nainstalovaná)
# Write-Host "Instaluji nejnovější verzi Node.js..."
# nvm install node
#
# # Zkontrolujeme, zda je Node.js dostupný
# if (Get-Command node -ErrorAction SilentlyContinue) {
#     Write-Host "Node.js byl úspěšně nainstalován."
#     node --version
# } else {
#     Write-Host "Instalace Node.js se nezdařila."
# }
#
# # Nastavení PATH (pokud je potřeba)
# Write-Host "Nastavuji PATH proměnnou..."
# $env:PATH = "$env:PATH;C:\Program Files\nodejs\"
# Write-Host "Aktuální PATH: $env:PATH"
# ```

# %% [markdown]
# ### Příklad 19
#
# ### Očekávaný výstup:
# ```
# Instaluji nejnovější verzi Node.js...
# [...]
# Node.js byl úspěšně nainstalován.
# v18.17.0
# Nastavuji PATH proměnnou...
# Aktuální PATH: C:\Users\...\;C:\Program Files\nodejs\;
# ```

# %% [markdown]
# ### Příklad 20
#
# ### Vysvětlení:
# Skript zkontroluje, zda je nástroj `nvm` dostupný. Pokud ano, nainstaluje nejnovější verzi Node.js a poté ověří, že je dostupná (`node --version`). Nakonec nastaví proměnnou `PATH`, aby byl příkaz `node` dostupný v terminálu.

# %% [markdown]
# ## 🎯 Cvičení a úkoly
#
# <div style="background: #fff3e0; padding: 20px; border-left: 5px solid #ff9800; margin: 20px 0; border-radius: 5px;">
#     <h3 style="color: #2c3e50; margin-top: 0;">✍️ Praktická cvičení k procvičení</h3>
#     <p>Vyřešte následující úkoly. Začněte od jednoduššších a postupujte k složitějším.</p>
# </div>
#
# # Cvičení pro kapitolu: Instalace vývojových nástrojů
#
# ---
#
# ## 1. Název úkolu
# **Instalace a ověření Node.js a npm**
#
# ### **Detailní zadání**
# Student si nainstaluje Node.js a npm na svůj počítač, poté ověří správnost instalace pomocí příkazové řádky.
#
# ### **Vstupní data/požadavky**
# - Student má přístup k příkazové řádce (Command Prompt nebo PowerShell na Windows, Terminal na macOS/Linux)
# - Musí být možné spouštět příkazy `node -v` a `npm -v`
#
# ### **Očekávaný výstup**
# - Výstup příkazů `node -v` a `npm -v` ukazuje verze Node.js a npm
# - Případně je možné vytvořit jednoduchý soubor `hello.js`, který vypíše "Hello, World!" a spustí jej příkazem `node hello.js`
#
# ### **Hints/Nápověda**
# 1. Navštivte oficiální stránku [https://nodejs.org](https://nodejs.org) a stáhněte instalační soubor pro váš operační systém.
# 2. Po instalaci otevřete příkazovou řádku a zadejte `node -v` (mělo by se zobrazit verze Node.js).
# 3. Zkontrolujte také správnost instalace npm příkazem `npm -v`.
# 4. Vytvořte soubor `hello.js` s obsahem `console.log("Hello, World!");` a spusťte ho pomocí `node hello.js`.
#
# ### **Kostra řešení**
# ```javascript
# // hello.js
# console.log("Hello, World!");
# ```
#
# ### **Bonusové rozšíření**
# Vytvořte jednoduchý projekt npm:
# 1. Vytvořte složku pro projekt
# 2. Spusťte příkaz `npm init -y`
# 3. Nainstalujte balíček `lodash` pomocí `npm install lodash`
# 4. Použijte ho v souboru `main.js`
#
# ---
#
# ## 2. Název úkolu
# **Instalace a použití Visual Studio Code**
#
# ### **Detailní zadání**
# Student si nainstaluje Visual Studio Code (VS Code) a přidá základní rozšíření, která pomáhají s vývojem JavaScriptu.
#
# ### **Vstupní data/požadavky**
# - Student má přístup k internetu
# - Musí být možné spustit VS Code po instalaci
#
# ### **Očekávaný výstup**
# - VS Code je nainstalované a otevřené
# - Přidaná rozšíření: "ESLint", "Prettier - Code formatter"
# - Vytvořený jednoduchý soubor `index.js` a uložený v projektové složce
#
# ### **Hints/Nápověda**
# 1. Stáhněte VS Code z [https://code.visualstudio.com](https://code.visualstudio.com)
# 2. Po spuštění otevřete rozšíření (Ctrl+Shift+X) a vyhledejte "ESLint" a "Prettier"
# 3. Nainstalujte obě rozšíření
# 4. Vytvořte nový soubor `index.js` a napište základní kód, např. `console.log("Hello from VS Code!");`
#
# ### **Kostra řešení**
# ```javascript
# // index.js
# console.log("Hello from VS Code!");
# ```
#
# ### **Bonusové rozšíření**
# Použijte příkaz `Ctrl+Shift+P` a vyhledejte "ESLint: Fix All Auto-fixable Problems" a aplikujte opravy na soubor.
#
# ---
#
# ## 3. Název úkolu
# **Instalace Git a založení repozitáře**
#
# ### **Detailní zadání**
# Student si nainstaluje Git a vytvoří svůj první lokální repozitář.
#
# ### **Vstupní data/požadavky**
# - Přístup k příkazové řádce
# - Nainstalovaný Git (může být ověřen příkazem `git --version`)
#
# ### **Očekávaný výstup**
# - Instalace Gitu proběhla úspěšně (`git --version`)
# - Vytvořen repozitář ve složce
# - Vytvořený a commitnutý jednoduchý soubor `README.md`
#
# ### **Hints/Nápověda**
# 1. Stáhněte Git z [https://git-scm.com](https://git-scm.com)
# 2. Otevřete příkazovou řádku a vytvořte složku pro projekt
# 3. V této složce spusťte `git init`
# 4. Vytvořte soubor `README.md` a proveďte commit
#
# ### **Kostra řešení**
# ```bash
# # Příkazy v příkazové řádce
# mkdir my-first-project
# cd my-first-project
# git init
# echo "# My First Project" > README.md
# git add README.md
# git commit -m "Initial commit"
# ```
#
# ### **Bonusové rozšíření**
# Vytvořte vlastní Git konfiguraci:
# ```bash
# git config --global user.name "Váš Jméno"
# git config --global user.email "vas@email.cz"
# ```
#
# ---
#
# ## 4. Název úkolu
# **Instalace a testování nástroje Node Version Manager (nvm)**
#
# ### **Detailní zadání**
# Student si nainstaluje nvm (Node Version Manager) a pomocí něj nainstaluje a přepne mezi různými verzemi Node.js.
#
# ### **Vstupní data/požadavky**
# - Přístup k příkazové řádce
# - Instalace nvm podle instrukcí pro váš OS
#
# ### **Očekávaný výstup**
# - Nainstalované nvm
# - Instalace dvou verzí Node.js (např. 14.x a 18.x)
# - Přepnutí mezi verzemi a ověření pomocí `node -v`
#
# ### **Hints/Nápověda**
# 1. Stáhněte nvm podle [https://github.com/nvm-sh/nvm](https://github.com/nvm-sh/nvm)
# 2. Po instalaci spusťte `nvm install 14`
# 3. Poté `nvm install 18` a `nvm use 18`
# 4. Ověřte verzi příkazem `node -v`
#
# ### **Kostra řešení**
# ```bash
# # Příkazy v příkazové řádce
# nvm install 14
# nvm install 18
# nvm use 18
# node -v
# ```
#
# ### **Bonusové rozšíření**
# Vytvořte skript `check-versions.sh`, který vypíše všechny nainstalované verze Node.js příkazem `nvm list`.
#
# ---
#
# ## 5. Název úkolu
# **Instalace a konfigurace GitHub účtu a vytvoření prvního repozitáře na GitHubu**
#
# ### **Detailní zadání**
# Student si vytvoří účet na GitHubu, připojí Git ke svému účtu a vytvoří první repozitář.
#
# ### **Vstupní data/požadavky**
# - Vytvořený lokální repozitář (z předchozího cvičení)
# - Přístup k internetu a GitHub účtu
#
# ### **Očekávaný výst

# %% [markdown]
# ## 📚 Další zdroje a materiály
#
# <div style="background: #e3f2fd; padding: 20px; border-left: 5px solid #2196f3; margin: 20px 0; border-radius: 5px;">
#     <h3 style="color: #2c3e50; margin-top: 0;">🔗 Doporučené materiály k dalšímu studiu</h3>
# </div>
#
# # Seznam zdrojů pro kapitolu: **Instalace vývojových nástrojů**
#
# ## 1. **Články a tutoriály**
# 1. **[How to Install Node.js and npm on Windows, Mac, and Linux](https://www.freecodecamp.org/news/how-to-install-node-js-and-npm-on-windows-mac-and-linux/)**
#    *Popis:* Komplexní průvodce instalací Node.js a npm na různé operační systémy. Vhodný pro začátečníky i pokročilé uživatele.
#
# 2. **[Installing VS Code Extensions for Web Development](https://code.visualstudio.com/docs/editor/extension-gallery)**
#    *Popis:* Oficiální příručka k instalaci a používání rozšíření v editoru Visual Studio Code pro vývoj webových aplikací.
#
# 3. **[Guide to Installing Git on Different Operating Systems](https://www.atlassian.com/git/tutorials/install-git)**
#    *Popis:* Detailní průvodce instalací systému správy verzí Git na různých operačních systémech s vysvětlením základních příkazů.
#
# 4. **[Setting up a Local Development Environment (Linux, macOS, Windows)](https://developer.mozilla.org/en-US/docs/Learn/Getting_started_with_the_web/Installing_basic_software)**
#    *Popis:* Průvodce nastavením vývojového prostředí pro webový vývoj podle MDN Web Docs, vhodný pro začátečníky.
#
# 5. **[Installing and Using Docker for Beginners](https://docs.docker.com/get-started/)**
#    *Popis:* Úvodní příručka k instalaci a základnímu používání Dockeru, ideální pro začátečníky v kontejnerizaci.
#
# ---
#
# ## 2. **YouTube videa**
# 1. **[How to Install Node.js on Windows (2023 Tutorial)](https://www.youtube.com/watch?v=9U87s74JwYc)**
#    *Délka:* 6:25
#    *Popis:* Krok za krokem video s instalací Node.js na Windows. Vhodné pro začátečníky.
#
# 2. **[Installing VS Code on Mac and Windows - Beginner Tutorial](https://www.youtube.com/watch?v=17jZcJG3XQ0)**
#    *Délka:* 10:42
#    *Popis:* Průvodce instalací Visual Studio Code a jeho základním nastavením na Macu i Windows.
#
# 3. **[How to Install Git on Windows, Mac, and Linux - Step-by-Step](https://www.youtube.com/watch?v=05wX714s5Yc)**
#    *Délka:* 8:10
#    *Popis:* Video s instalací Gitu na různých operačních systémech a základním použitím v příkazové řádce.
#
# ---
#
# ## 3. **Knihy a oficiální dokumentace**
# 1. **[Official Node.js Documentation](https://nodejs.org/en/docs/)**
#    *Popis:* Oficiální dokumentace k Node.js, která zahrnuje sekci o instalaci na různých platformách.
#
# 2. **[Visual Studio Code Documentation](https://code.visualstudio.com/docs)**
#    *Popis:* Kompletní dokumentace k VS Code, včetně návodů na instalaci rozšíření a konfiguraci prostředí.
#
# 3. **[Git Documentation (Pro Git Book)](https://git-scm.com/book/en/v2)**
#    *Popis:* Průvodce Gitem od základů po pokročilé techniky, oficiální dokumentace k systému správy verzí.
#
# ---
#
# ## 4. **Praktické projekty**
# 1. **Nastav vlastní vývojové prostředí pro webovou aplikaci**
#    *Popis:* Nainstaluj a nakonfiguruj Node.js, npm

# %% [markdown]
# ## 📝 Shrnutí kapitoly
#
# <div style="background: linear-gradient(135deg, #667eea 0%, #764ba2 100%); padding: 30px; border-radius: 10px; color: white; margin: 30px 0;">
#     <h3 style="color: white; margin-top: 0;">✅ Co jste se naučili</h3>
#     <ul style="list-style: none; padding-left: 0;">
#         <li>✓ Windows: Chocolatey, Scoop, winget</li>
# <li>✓ MacOS: Homebrew, MacPorts</li>
# <li>✓ Ubuntu/Debian: APT, snap packages</li>
# <li>✓ VS Code instalace a konfigurace</li>
# <li>✓ Sublime Text, Atom, Notepad++</li>
#     </ul>
#
#     <h3 style="color: white;">🎯 Klíčové dovednosti</h3>
#     <p>Po dokončení této kapitoly byste měli být schopni prakticky použít všechny probrané koncepty.</p>
#
#     <h3 style='color: white;'>➡️ Další kapitola</h3><p>Kapitola 3 - pokračujte ve studiu!</p>
# </div>
#
# ---
#
# *📅 Notebook vygenerován: 2025-09-29 11:40:46*
# *🤖 Generátor: Comprehensive Colab Generator v2.0*
# *📚 Učebnice programování - Od základů k AI*

# %% [markdown]
# ## 🧪 Sandbox - Prostor pro experimenty
#
# Použijte následující buňky pro vlastní experimenty a testování:

# %%
# 🧪 Zde můžete experimentovat s kódem z kapitoly
# Napište svůj kód zde:
