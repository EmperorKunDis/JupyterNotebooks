# %% [markdown]
# # 📚 Kapitola 35: RAG (Retrieval Augmented Generation)
#
# <div style="background: linear-gradient(90deg, #667eea 0%, #764ba2 100%); padding: 20px; border-radius: 10px; margin: 20px 0;">
#     <h2 style="color: white; margin: 0;">Blok 4 | EXPERT</h2>
#     <p style="color: white; margin: 10px 0;">📖 Výuková kapitola</p>
# </div>
#
# ## 🎯 Co se naučíte
#
# V této kapitole se zaměříme na následující témata:
#
# - **RAG architecture**
# - **Vector databases: ChromaDB, Pinecone, Weaviate**
# - **Embeddings models**
# - **Document chunking strategies**
# - **Similarity search algorithms**
# - **Reranking techniques**
# - **Hybrid search implementation**
#
# ## ⚠️ Předpoklady
# Tato kapitola navazuje na kapitoly: 33
#
# ---

# %%
# ⚙️ Inicializace prostředí
# Tento kód nastavuje prostředí pro kapitolu 35

import sys
import os
from datetime import datetime

# Informace o prostředí
print("=" * 60)
print(f"📚 KAPITOLA 35: RAG (Retrieval Augmented Generation)")
print("=" * 60)
print(f"🐍 Python verze: {sys.version}")
print(f"📅 Datum spuštění: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}")
print(f"💻 OS: {os.name}")
print(f"📁 Pracovní adresář: {os.getcwd()}")
print("=" * 60)

# Instalace potřebných knihoven (odkomentujte podle potřeby)
# !pip install requests pandas numpy matplotlib
# !pip install beautifulsoup4 sqlalchemy fastapi

# Import základních knihoven
import json
import csv
import time
import random
from pathlib import Path
from typing import List, Dict, Optional, Any

print("✅ Prostředí připraveno!")

# %% [markdown]
# ## 📖 Teoretická část
#
# <div style="background: #f0f4ff; padding: 20px; border-left: 5px solid #4a69bd; margin: 20px 0; border-radius: 5px;">
#     <h3 style="color: #2c3e50; margin-top: 0;">🎓 Základní teorie a koncepty</h3>
# </div>
#
# # RAG (Retrieval Augmented Generation) – Detailní teoretický výklad
#
# ---
#
# ## 1. Úvod a motivace
#
# RAG (Retrieval Augmented Generation) je moderní přístup k generování textu, který kombinuje silné stránky vyhledávacích systémů s pokročilými modely jazykového zpracování. V současné době je klíčový pro vytváření přesných, kontextuálně relevantních a aktualizovaných odpovědí, zejména ve velkých jazykových modelech (LLMs). RAG je zásadní pro aplikace jako například inteligentní asistenti, automatická dokumentace, podpora vývojářů nebo výzkumné nástroje.
#
# V praxi se RAG používá v systémech typu chatbotů, kde je důležité, aby odpovědi byly nejen gramaticky správné, ale také založené na aktuálních datech – tedy například vnitřní databázi firemních dokumentů, technické dokumentace, nebo novinky z oboru. Student po prozkoumání této kapitoly naučí:
#
# - Jak funguje architektura RAG
# - Jakým způsobem se využívají embeddingy a databáze vektorů
# - Jaké algoritmy se používají pro vyhledávání podobných dokumentů
# - Jak implementovat efektivní hybridní vyhledávání
#
# ---
#
# ## 2. Hlavní koncepty
#
# ### RAG Architecture
#
# RAG architektura je složena ze dvou hlavních součástí:
#
# 1. **Retrieval (vyhledávání)** – systém, který najde relevantní dokumenty z databáze podle zadání uživatele.
# 2. **Generation (generování)** – model, který vytvoří odpověď na základě vstupu a relevantního kontextu.
#
# Struktura RAG systému může být znázorněna následujícím způsobem:
#
# ```
# [User Query] → [Embedding Model] → [Vector Database] → [Retrieved Docs]
#                               ↓
#                         [LLM Input] → [LLM] → [Response]
# ```
#
# Klíčová výhoda RAG je schopnost použít aktuální informace z externích zdrojů, a ne jen informace, které byly před tréninkem modelu. To umožňuje generovat odpovědi s vysokou přesností a aktualizovaností.
#
# ---
#
# ### Vector Databases: ChromaDB, Pinecone, Weaviate
#
# Pro ukládání a vyhledávání vektorových reprezentací dokumentů se používají tzv. **vector databases**. Mezi nejrozšířenější patří:
#
# - **ChromaDB**: Open-source řešení, vhodné pro lokální a vývojové prostředí.
# - **Pinecone**: Cloudová platforma pro vyhledávání vektorů s velkou škálou a integrací s LLM modely.
# - **Weaviate**: Rozšiřitelný systém, který podporuje semantické vyhledávání a plné textové indexy.
#
# Každá z těchto databází má vlastní silné stránky – např. Pinecone pro rychlé vyhledávání v velkých datech, ChromaDB pro jednoduchou integraci do lokálních projektů.
#
# ---
#
# ### Embeddings Models
#
# Embeddings jsou číselné reprezentace textu ve vektorovém prostoru. Jejich úkolem je zachytit významovou podobnost mezi dokumenty nebo frázemi. V RAG systémech se používají modely jako:
#
# - **Sentence Transformers** (např. `all-MiniLM-L6-v2`)
# - **OpenAI Embeddings**
# - **BGE (Bidirectional Guided Embeddings)**
#
# Tyto modely převádějí text na vektorové reprezentace, které jsou pak ukládány do databáze a slouží k vyhledávání podobných dokumentů.
#
# ---
#
# ### Document Chunking Strategies
#
# Dokumenty se před uložením rozdělují na **chunky** (úseky), které se následně vektorizují. Časté strategie:
#
# - **Přesné dělení podle délky (fixed-length chunking)**
# - **Dělení podle oddělovačů (e.g., odstavce, novely)**
# - **Dynamické dělení (semantic chunking)** – využití modelu k vytvoření smysluplných úseků
#
# První dvě strategie jsou jednoduché, ale mohou vést ke ztrátě kontextu. Semantic chunking je efektivnější, protože udržuje významovou spojitost.
#
# ---
#
# ### Similarity Search Algorithms
#
# Vektorová databáze používá algoritmy na hledání podobných vektorů. Mezi nejčastější patří:
#
# - **Cosine similarity**: Nejčastější metoda pro porovnání vektorů.
# - **Euclidean distance**
# - **Inner product**
#
# Použití těchto algoritmů je klíčové pro efektivní vyhledávání relevantního obsahu. Výběr závisí na rychlosti, přesnosti a velikosti dat.
#
# ---
#
# ### Reranking Techniques
#
# Po počátečním vyhledání dokumentů se často používají **reranking** techniky, které upřednostňují nejrelevantnější dokumenty. Například:
#
# - **Cross-encoder models** (např. `cross-encoder/ms-marco-MiniLM-L-6-v2`)
# - **Hybrid reranking** – kombinace BM25 a vektorového vyhledávání
#
# Reranking poskytuje lepší kvalitu odpovědi, protože model může přehodnotit výsledky z počátečního vyhledávání.
#
# ---
#
# ### Hybrid Search Implementation
#
# Hybrid search kombinuje různé metody vyhledávání:
#
# - **Vektorové vyhledávání** (např. podobnost vektorů)
# - **Textové vyhledávání** (např. BM25, full-text search)
#
# Implementace hybridního vyhledávání může být například:
#
# ```python
# # Pseudokód
# retrieved_docs = vector_search(query, top_k=10)
# reranked_docs = rerank(query, retrieved_docs, top_k=5)
# ```
#
# Tento přístup zvyšuje přesnost a zároveň umožňuje efektivní vyhledávání i na velkých datech.
#
# ---
#
# ## 3. Důležité detaily
#
# ### Časté chyby a jak se jim vyhnout
#
# - **Nedostatečné chunking strategie** – může vést ke ztrátě kontextu.
# - **Špatná volba embedding modelu** – pro konkrétní doménu může být model neefektivní.
# - **Chybějící reranking** – výsledky mohou být nepřesné, i když se nachází blízko.
#
# ### Best practices
#
# - Využívejte **semantic chunking** pro zachování kontextu.
# - Používejte **reranking modely** v případě vysoké přesnosti.
# - Implementujte **cache mechanismus** pro zrychlení opakovaných dotazů.
#
# ### Performance tipy
#
# - Předvytvořte embeddingy offline, aby se minimalizoval čas odpovědi.
# - Využívejte **indexování** a **vyhledávání na rozdílných úrovních** (např. dokument vs. odstavec).
# - Zvažte použití **in-memory cache** pro běžné dotazy.
#
# ---
#
# ## 4. Propojení s předchozími kapitolami
#
# Tato kapitola využívá znalosti z předchozích témat jako jsou:
#
# - **Jazykové modely a jejich fungování**
# - **Embeddingy a jejich role v NLP**
# - **Textové indexace a vyhledávání**
#
# RAG rozšiřuje tyto koncepty tím, že ukazuje, jak lze využít vektorové reprezentace a vyhledávací systémy ve spolupráci s LLM pro vytváření přesných a kontextuálně relevantních odpovědí.
#
# ---
#
# Tato kapitola je klíčová pro studenty, kteří chtějí porozumět pokročilým aplikacím jazykového modelu v praxi. RAG je nejen teoretický koncept, ale i praktický nástroj, který se používá ve velkých systémech AI – od interních asistentů až po výzkumné nástroje.

# %% [markdown]
# ## 💻 Praktické příklady
#
# <div style="background: #e8f5e9; padding: 20px; border-left: 5px solid #4caf50; margin: 20px 0; border-radius: 5px;">
#     <h3 style="color: #2c3e50; margin-top: 0;">👨‍💻 Hands-on příklady ke spuštění</h3>
#     <p>Následující příklady si můžete hned vyzkoušet. Každý příklad je samostatně spustitelný.</p>
# </div>

# %% [markdown]
# ### Příklad 1
#
# Příklad 1: Základní struktura RAG systému**

# %% [markdown]
# ### Příklad 2
#
# ### **1. Název příkladu**
# Základní RAG architektura s jednoduchým vektorovým vyhledáváním

# %% [markdown]
# ### Příklad 3
#
# ### **2. Co demonstruje**
# Tento příklad ukazuje základní komponenty RAG systému: vytváření embeddingů, ukládání dokumentů do vektorové databáze a jednoduché vyhledávání podle podobnosti.

# %% [markdown]
# ### Příklad 4
#
# ### **3. Kompletní spustitelný kód**

# %%
# Instalace potřebných knihoven:
# pip install sentence-transformers chromadb

from sentence_transformers import SentenceTransformer
import chromadb
import numpy as np

# Inicializace modelu pro vytváření embeddingů
model = SentenceTransformer('all-MiniLM-L6-v2')

# Vytvoření jednoduchého dokumentu
documents = [
    "Praha je hlavní město České republiky.",
    "Vítejte v Praze, která má bohatou historii.",
    "Česká republika se nachází v Evropě."
]

# Vytvoření embeddingů pro dokumenty
embeddings = model.encode(documents)

# Vytvoření klienta ChromaDB (lokální databáze)
client = chromadb.Client()
collection = client.create_collection("rag_docs")

# Uložení dokumentů do kolekce
for i, (doc, emb) in enumerate(zip(documents, embeddings)):
    collection.add(
        ids=[f"doc_{i}"],
        documents=[doc],
        embeddings=[emb.tolist()]
    )

# Vyhledání podobných dokumentů k dotazu
query = "Kde se nachází hlavní město ČR?"
query_embedding = model.encode([query])

# Hledání nejbližších dokumentů (similarity search)
results = collection.query(
    query_embeddings=query_embedding.tolist(),
    n_results=2
)

print("Dotaz:", query)
print("Nalezené dokumenty:")
for i, doc in enumerate(results['documents'][0]):
    print(f"{i+1}. {doc}")

# %% [markdown]
# ### Příklad 5
#
# ### **4. Očekávaný výstup**
# ```
# Dotaz: Kde se nachází hlavní město ČR?
# Nalezené dokumenty:
# 1. Praha je hlavní město České republiky.
# 2. Vítejte v Praze, která má bohatou historii.
# ```

# %% [markdown]
# ### Příklad 6
#
# ### **5. Vysvětlení**
# Tento kód demonstruje základní RAG workflow:
# 1. Použití `SentenceTransformer` pro vytvoření embeddingů z textu.
# 2. Vytvoření lokální ChromaDB kolekce a uložení dokumentů s jejich embeddingy.
# 3. Dotazování na podobné dokumenty pomocí `collection.query()`.
#
# ---
#
# ## **

# %% [markdown]
# ### Příklad 7
#
# Příklad 2: Použití různých vektorových databází (ChromaDB vs Weaviate)**

# %% [markdown]
# ### Příklad 8
#
# ### **1. Název příkladu**
# Porovnání vektorových databází – ChromaDB vs Weaviate

# %% [markdown]
# ### Příklad 9
#
# ### **2. Co demonstruje**
# Porovnání základních funkcí dvou populárních vektorových databází: ChromaDB (lokální) a Weaviate (síťová).

# %% [markdown]
# ### Příklad 10
#
# ### **3. Kompletní spustitelný kód**

# %%
# Instalace potřebných knihoven:
# pip install chromadb weaviate-client sentence-transformers

from sentence_transformers import SentenceTransformer
import chromadb
import weaviate

model = SentenceTransformer('all-MiniLM-L6-v2')
documents = [
    "Kočka je milá zvíře.",
    "Pes běží po ulici.",
    "Stromy rostou v lese."
]

# ChromaDB
chroma_client = chromadb.Client()
chroma_collection = chroma_client.create_collection("chroma_docs")
embeddings = model.encode(documents)
for i, (doc, emb) in enumerate(zip(documents, embeddings)):
    chroma_collection.add(
        ids=[f"doc_{i}"],
        documents=[doc],
        embeddings=[emb.tolist()]
    )

# Weaviate
weaviate_client = weaviate.Client("http://localhost:8080")
schema = {
    "class": "Document",
    "properties": [
        {"name": "text", "dataType": ["text"]}
    ]
}
weaviate_client.schema.delete_class("Document")
weaviate_client.schema.create_class(schema)

for i, doc in enumerate(documents):
    weaviate_client.data_object.create(
        class_name="Document",
        data_object={"text": doc},
        vector=model.encode([doc])[0].tolist()
    )

print("ChromaDB a Weaviate inicializovány.")

# %% [markdown]
# ### Příklad 11
#
# ### **4. Očekávaný výstup**
# Zobrazení zprávy: `ChromaDB a Weaviate inicializovány.`

# %% [markdown]
# ### Příklad 12
#
# ### **5. Vysvětlení**
# Tento příklad ukazuje základní inicializaci dvou různých vektorových databází:
# - **ChromaDB**: lokální, jednoduché použití (ideální pro testovací prostředí).
# - **Weaviate**: síťová databáze (vyžaduje spuštěný Weaviate server).
#
# ---
#
# ## **

# %% [markdown]
# ### Příklad 13
#
# Příklad 3: Chunking strategie – rozdělení dokumentu na části**

# %% [markdown]
# ### Příklad 14
#
# ### **1. Název příkladu**
# Rozdělení dokumentu na chunky pomocí různých strategií

# %% [markdown]
# ### Příklad 15
#
# ### **2. Co demonstruje**
# Tento příklad ukazuje, jak lze rozdělit text na části (chunking), což je klíčové pro efektivní práci s velkými dokumenty v RAG systémech.

# %% [markdown]
# ### Příklad 16
#
# ### **3. Kompletní spustitelný kód**

# %%
from sentence_transformers import SentenceTransformer
import re

# Vstupní dokument
document = """
Vítáme vás v historickém městě Praze, které je známé svou bohatou kulturou a architekturou.
Praha má několik nejvýznamnější památek jako jsou pražský hrad, karlův most a staroměstské náměstí.
Tato město je součástí Evropy a patří mezi nejnavštěvovanější destinace v České republice.
"""

# Strategie 1: Rozdělení podle odstavců
def chunk_by_paragraphs(text):
    return [p.strip() for p in text.split('\n\n') if p.strip()]

# Strategie 2: Rozdělení podle slov (např. každých 50 slov)
def chunk_by_words(text, max_words=50):
    words = text.split()
    chunks = []
    for i in range(0, len(words), max_words):
        chunks.append(' '.join(words[i:i+max_words]))
    return chunks

# Rozdělení dokumentu
paragraph_chunks = chunk_by_paragraphs(document)
word_chunks = chunk_by_words(document)

print("Rozdělení podle odstavců:")
for i, chunk in enumerate(paragraph_chunks):
    print(f"{i+1}. {chunk}")

print("\nRozdělení podle slov (50 slov):")
for i, chunk in enumerate(word_chunks):
    print(f"{i+1}. {chunk}")

# %% [markdown]
# ### Příklad 17
#
# ### **4. Očekávaný výstup**
# ```
# Rozdělení podle odstavců:
# 1. Vítáme vás v historickém městě Praze, které je známé svou bohatou kulturou a architekturou.
# 2. Praha má několik nejvýznamnější památek jako jsou pražský hrad, karlův most a staroměstské náměstí.
# 3. Tato město je součástí Evropy a patří mezi nejnavštěvovanější destinace v České republice.
#
# Rozdělení podle slov (50 slov):
# 1. Vítáme vás v historickém městě Praze, které je známé svou bohatou kulturou a architekturou. Praha má několik nejvýznamnější památek jako jsou pražský hrad, karlův most a staroměstské náměstí.
# 2. Tato město je součástí Evropy a patří mezi nejnavštěvovanější destinace v České republice.
# ```

# %% [markdown]
# ### Příklad 18
#
# ### **5. Vysvětlení**
# Rozdělení dokumentů (chunking) je důležité pro zlepšení přesnosti vyhledávání:
# - **Podle odstavců** zachovává kontext.
# - **Podle slov** umožňuje detailnější kontrolu, ale může ztratit souvislost.
#
# ---
#
# ## **

# %% [markdown]
# ### Příklad 19
#
# Příklad 4: Implementace similarity search algoritmů (cosine similarity)**

# %% [markdown]
# ### Příklad 20
#
# ### **1. Název příkladu**
# Výpočet podobnosti mezi dokumenty pomocí cosine similarity

# %% [markdown]
# ### Příklad 21
#
# ### **2. Co demonstruje**
# Demonstruje výpočet podobnosti mezi dokumenty pomocí kosinové vzdálenosti a vektorové databáze.

# %% [markdown]
# ### Příklad 22
#
# ### **3. Kompletní spustitelný kód**
# ```python
# from sentence_transformers import SentenceTransformer
# import numpy as np
# from sklearn.metrics.pairwise import cosine_similarity
#
# model = SentenceTransformer('all-MiniLM-L6-v2')
#
# # Dokumenty
# documents = [
#     "Kočka je milá zvíře.",
#     "Pes běží po ulici.",
#     "Stromy rostou v lese.",
#     "Vítejte v Praze."
# ]
#
# # Vytvoření embeddingů
# embeddings = model.encode(documents

# %% [markdown]
# ## 🎯 Cvičení a úkoly
#
# <div style="background: #fff3e0; padding: 20px; border-left: 5px solid #ff9800; margin: 20px 0; border-radius: 5px;">
#     <h3 style="color: #2c3e50; margin-top: 0;">✍️ Praktická cvičení k procvičení</h3>
#     <p>Vyřešte následující úkoly. Začněte od jednoduššších a postupujte k složitějším.</p>
# </div>
#
# # Cvičení k kapitě: RAG (Retrieval Augmented Generation)
#
# ---
#
# ## 1. **Název úkolu**
# RAG Pipeline – Implementace jednoduchého retrieval + generation systému
#
# ### 2. **Detailní zadání**
# Vytvořte jednoduchý RAG pipeline, který vezme uživatelský dotaz a pomocí vyhledávání v dokumentech (retrieval) připraví kontext pro generování odpovědi (generation). Použijte klasický přístup s embeddingy a FAISS indexem.
#
# ### 3. **Vstupní data/požadavky**
# - Databáze dokumentů (např. krátké texty o historii, vědě, atd.)
# - Dotaz od uživatele (např. "Kdo byl Albert Einstein?")
# - Embedding model (např. sentence-transformers/all-MiniLM-L6-v2)
#
# ### 4. **Očekávaný výstup**
# - Nalezené relevantní dokumenty z databáze
# - Generovaná odpověď na dotaz, která využívá kontext z nalezených dokumentů
#
# ### 5. **Hints/Nápověda**
# 1. Nejprve vytvořte vektorovou reprezentaci dokumentů pomocí embedding modelu.
# 2. Použijte FAISS k indexování a vyhledávání podobných dokumentů.
# 3. Předdejte nejrelevantnější dokumenty do generativního modelu (např. LLaMA, GPT-2).
# 4. Spojujte výstup z retrieval a generation do jedné odpovědi.
#
# ### 6. **Kostra řešení**
# ```python
# from sentence_transformers import SentenceTransformer
# from faiss import IndexFlatIP
# import numpy as np
#
# # Načti dokumenty
# documents = ["...", "..."]  # seznam dokumentů
#
# # Vytvoř embeddingy
# model = SentenceTransformer('all-MiniLM-L6-v2')
# embeddings = model.encode(documents)
#
# # Indexuj do FAISS
# index = IndexFlatIP(384)  # dimenze embeddingu
# index.add(np.array(embeddings))
#
# # Najdi nejblíže dokumenty
# query = "Kdo byl Albert Einstein?"
# query_embedding = model.encode([query])
# scores, indices = index.search(query_embedding, k=2)
#
# # Vytiskni relevantní dokumenty a vygeneruj odpověď
# ```
#
# ### 7. **Bonusové rozšíření**
# Implementujte možnost přidání „prompt engineeringu“ pro lepší generování odpovědi, např. předávejte do modelu prompt jako:
# `"Odpověz na otázku: {question} pouze z následujícího kontextu: {context}"`
#
# ---
#
# ## 2. **Název úkolu**
# RAG s vlastním datovým setem – Inference a vyhodnocení
#
# ### 2. **Detailní zadání**
# Zadání: Připravte testovací dataset (např. 10 otázek a odpovědí) a ověřte, jak dobře váš RAG systém odpovídá na tyto otázky. Implementujte metriku pro vyhodnocení odpovědí (např. ROUGE nebo BLEU).
#
# ### 3. **Vstupní data/požadavky**
# - Dataset s otázkami a odpověďmi (např. Q&A z Wikipedie)
# - Vlastní RAG pipeline
#
# ### 4. **Očekávaný výstup**
# - Vyhodnocení výsledků (např. průměrná ROUGE skóre)
# - Seznam otázek + odpovědi + přesnost
#
# ### 5. **Hints/Nápověda**
# 1. Vytvořte dataset jako seznam slovníků `{"question": "...", "answer": "..."}`
# 2. Použijte knihovnu `rouge-score` nebo `nltk.translate.bleu_score`
# 3. Pro každou otázku spusťte RAG pipeline a porovnejte výsledky
# 4. Vypište průměrné skóre z testovacího setu
#
# ### 6. **Kostra řešení**
# ```python
# from rouge_score import rouge_scorer
#
# test_dataset = [
#     {"question": "Kdo byl Newton?", "answer": "Isaac Newton"},
#     ...
# ]
#
# scorer = rouge_scorer.RougeScorer(['rouge1'], use_stemmer=True)
# scores = []
#
# for item in test_dataset:
#     response = rag_pipeline(item["question"])
#     score = scorer.score(item["answer"], response)
#     scores.append(score['rouge1'].fmeasure)
# ```
#
# ### 7. **Bonusové rozšíření**
# Přidejte možnost logování výsledků do souboru (např. JSON) a vizualizaci průměrných skóre pomocí matplotlib.
#
# ---
#
# ## 3. **Název úkolu**
# RAG s dynamickým vyhledáváním – RAG s filtrací podle kategorie
#
# ### 2. **Detailní zadání**
# Vytvořte RAG pipeline, která umožňuje filtrovat dokumenty podle kategorie (např. „historie“, „technologie“) před vyhledáváním a generováním.
#
# ### 3. **Vstupní data/požadavky**
# - Dokumenty s metadata (např. `{"text": "...", "category": "historie"}`)
# - Dotaz od uživatele
# - Možnost zadat filtr kategorie
#
# ### 4. **Očekávaný výstup**
# - Filtrování dokumentů podle kategorie
# - Nalezené odpovědi z vybraného podskupinu dokumentů
#
# ### 5. **Hints/Nápověda**
# 1. Přidejte metadata do indexu (např. pomocí FAISS s vlastními ID).
# 2. Před vyhledáváním filtrovat dokumenty podle kategorie.
# 3. Využijte např. `filter` parametr při vyhledávání.
# 4. Výstup závisí na tom, jaký filtr je zadán.
#
# ### 6. **Kostra řešení**
# ```python
# # Přidání metadata do dokumentů
# documents_with_metadata = [
#     {"text": "...", "category": "historie"},
#     ...
# ]
#
# # Filtrování podle kategorie
# filtered_docs = [doc for doc in documents_with_metadata if doc["category"] == "historie"]
# ```
#
# ### 7. **Bonusové rozšíření**
# Implementujte multi-kategorické vyhledávání (např. hledej dokumenty ve více kategoriích).
#
# ---
#
# ## 4. **Název úkolu**
# RAG s vlastním generativním modelem – Fine-tuning a použití LLM
#
# ### 2. **Detailní zadání**
# Použijte malý LLM (např. GPT-2 nebo Mistral) a přizpůsobte ho pro generování odpovědí na základě kontextu z RAG pipeline. Využijte např. `transformers` knihovnu.
#
# ### 3. **Vstupní data/požadavky**
# - RAG pipeline s výstupem dokumentů
# - Generativní model (např. `gpt2`, `mistralai/Mistral-7B-v0.1`)
# - Instrukce pro generování
#
# ### 4. **Očekávaný výstup**
# - Nalezené dokumenty + odpověď vygenerovaná LLM modelem
# - Zlepšená kvalita odpovědi
#
# ### 5. **Hints/Nápověda**
# 1. Vytvořte prompt: „Použij následující informace: [context] odpověz na otázku: [question].“
# 2. Použijte `transformers` k načtení modelu a generování.
# 3. Předej

# %% [markdown]
# ## 📚 Další zdroje a materiály
#
# <div style="background: #e3f2fd; padding: 20px; border-left: 5px solid #2196f3; margin: 20px 0; border-radius: 5px;">
#     <h3 style="color: #2c3e50; margin-top: 0;">🔗 Doporučené materiály k dalšímu studiu</h3>
# </div>
#
# # Doporučené zdroje pro kapitolu: RAG (Retrieval Augmented Generation)
#
# ---
#
# ## 📚 5 doporučených článků/tutoriálů
#
# 1. **"Retrieval-Augmented Generation for Knowledge-Intensive NLP Tasks"**
#    *Popis:* Původní vědecký článek od Google, který zavádí koncept RAG. Vysvětluje, jak kombinovat retrieval a generativní modely pro zlepšení přesnosti odpovědí.
#    *Odkaz:* [https://arxiv.org/abs/2005.11401](https://arxiv.org/abs/2005.11401)
#
# 2. **"A Gentle Introduction to Retrieval-Augmented Generation (RAG)"**
#    *Popis:* Jednoduchý a přehledný úvod do RAG, vhodný pro začátečníky. Vysvětluje principy a praktické aplikace.
#    *Odkaz:* [https://www.pinecone.io/learn/retrieval-augmented-generation/](https://www.pinecone.io/learn/retrieval-augmented-generation/)
#
# 3. **"Understanding Retrieval-Augmented Generation (RAG) with Hugging Face Transformers"**
#    *Popis:* Tutoriál zaměřený na implementaci RAG pomocí knihovny Hugging Face, včetně praktického kódu a příkladů.
#    *Odkaz:* [https://huggingface.co/blog/retrieval-augmented-generation](https://huggingface.co/blog/retrieval-augmented-generation)
#
# 4. **"Building RAG Systems with LangChain and Vector Stores"**
#    *Popis:* Detailní návod na tvorbu RAG systému pomocí LangChain a vektorových databází (např. Chroma, FAISS).
#    *Odkaz:* [https://docs.langchain.com/docs/](https://docs.langchain.com/docs/)
#
# 5. **"RAG Explained: How to Build a Question-Answering System with Transformers"**
#    *Popis:* Praktický průvodce s kódem v Pythonu – jak vytvořit jednoduchý RAG systém od nuly.
#    *Odkaz:* [https://towardsdatascience.com/rag-explained-7b82610e6c9c](https://towardsdatascience.com/rag-explained-7b82610e6c9c)
#
# ---
#
# ## 🎥 3 YouTube videa
#
# 1. **"What is Retrieval-Augmented Generation (RAG)? | Explained in 5 Minutes"**
#    *Délka:* 5 min
#    *Popis:* Stručný výklad konceptu RAG s ilustrací principu práce systému.
#
# 2. **"How to Build a RAG System with Hugging Face Transformers | Full Tutorial"**
#    *Délka:* 20 min
#    *Popis:* Kompletní průvodce tvorbou RAG systému pomocí Hugging Face modelů a Pythonu.
#
# 3. **"RAG vs. Traditional LLMs – Practical Use Cases & Limitations"**
#    *Délka:* 15 min
#    *Popis:* Srovnání RAG s běžnými generativními modely, diskuze o jejich použití v praxi.
#
# ---
#
# ## 📖 3 knihy nebo oficiální dokumentace
#
# 1. **"Transformers Book by Hugging Face"**
#    *Popis:* Komplexní příručka k modelům Transformers, včetně kapitoly o RAG systémech a jejich implementaci.
#
# 2. **"LangChain Documentation – RAG Guide"**
#    *Popis:* Oficiální dokumentace pro LangChain s podrobnými příklady pro tvorbu RAG systémů.
#
# 3. **"Deep Learning with Python by François Chollet" (kapitola o textových generátorech)**
#    *Popis:* Přehled pokročilých technik zpracování jazyka, včetně

# %% [markdown]
# ## 📝 Shrnutí kapitoly
#
# <div style="background: linear-gradient(135deg, #667eea 0%, #764ba2 100%); padding: 30px; border-radius: 10px; color: white; margin: 30px 0;">
#     <h3 style="color: white; margin-top: 0;">✅ Co jste se naučili</h3>
#     <ul style="list-style: none; padding-left: 0;">
#         <li>✓ RAG architecture</li>
# <li>✓ Vector databases: ChromaDB, Pinecone, Weaviate</li>
# <li>✓ Embeddings models</li>
# <li>✓ Document chunking strategies</li>
# <li>✓ Similarity search algorithms</li>
#     </ul>
#
#     <h3 style="color: white;">🎯 Klíčové dovednosti</h3>
#     <p>Po dokončení této kapitoly byste měli být schopni prakticky použít všechny probrané koncepty.</p>
#
#     <h3 style='color: white;'>➡️ Další kapitola</h3><p>Kapitola 36 - pokračujte ve studiu!</p>
# </div>
#
# ---
#
# *📅 Notebook vygenerován: 2025-09-29 13:26:59*
# *🤖 Generátor: Comprehensive Colab Generator v2.0*
# *📚 Učebnice programování - Od základů k AI*

# %% [markdown]
# ## 🧪 Sandbox - Prostor pro experimenty
#
# Použijte následující buňky pro vlastní experimenty a testování:

# %%
# 🧪 Zde můžete experimentovat s kódem z kapitoly
# Napište svůj kód zde:
